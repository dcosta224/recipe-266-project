# %%
from transformers import AutoTokenizer, AutoModelWithLMHead
tokenizer = AutoTokenizer.from_pretrained("mbien/recipenlg")
model = AutoModelWithLMHead.from_pretrained("mbien/recipenlg")
# Out:
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/666 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/298 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/328 [00:00<?, ?B/s]
# /Users/danielcosta/miniconda3/envs/ml-266/lib/python3.11/site-packages/transformers/models/auto/modeling_auto.py:1949: FutureWarning: The class `AutoModelWithLMHead` is deprecated and will be removed in a future version. Please use `AutoModelForCausalLM` for causal language models, `AutoModelForMaskedLM` for masked language models and `AutoModelForSeq2SeqLM` for encoder-decoder models.
#   warnings.warn(
# /Users/danielcosta/miniconda3/envs/ml-266/lib/python3.11/site-packages/torchvision/io/image.py:14: UserWarning: Failed to load image Python extension: 'dlopen(/Users/danielcosta/miniconda3/envs/ml-266/lib/python3.11/site-packages/torchvision/image.so, 0x0006): Library not loaded: @rpath/libjpeg.9.dylib
#   Referenced from: <EB3FF92A-5EB1-3EE8-AF8B-5923C1265422> /Users/danielcosta/miniconda3/envs/ml-266/lib/python3.11/site-packages/torchvision/image.so
#   Reason: tried: '/Users/danielcosta/miniconda3/envs/ml-266/lib/python3.11/site-packages/torchvision/../../../libjpeg.9.dylib' (no such file), '/Users/danielcosta/miniconda3/envs/ml-266/lib/python3.11/site-packages/torchvision/../../../libjpeg.9.dylib' (no such file), '/Users/danielcosta/miniconda3/envs/ml-266/lib/python3.11/lib-dynload/../../libjpeg.9.dylib' (no such file), '/Users/danielcosta/miniconda3/envs/ml-266/bin/../lib/libjpeg.9.dylib' (no such file)'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(
# model.safetensors:   0%|          | 0.00/665M [00:00<?, ?B/s]

# %%
import pandas as pd

recipe_nlg_dataset = pd.read_csv('./dataset/full_dataset.csv')

# %%
recipe_nlg_dataset.drop('Unnamed: 0', axis=1, inplace=True)

# %%
for val in recipe_nlg_dataset.iloc[10180]:
    print(val)
# Out:
# Pineapple Coconut Pie
# ["4 eggs", "2 c. sugar", "1 stick margarine (soft)", "2 Tbsp. self-rising flour", "1 small can crushed pineapple", "1 small can Angel Flake coconut"]
# ["Combine ingredients.", "Pour into 2 prepared pie crusts.", "Bake at 300\u00b0 for 30 to 40 minutes."]
# www.cookbooks.com/Recipe-Details.aspx?id=968391
# Gathered
# ["eggs", "sugar", "margarine", "flour", "pineapple", "Angel"]

# %%
def get_domain(recipe_url):
    recipe_parts = recipe_url.split('/')
    domain = recipe_parts[0]
    if domain.startswith("www."):
        domain = domain[4:]
    return domain

get_domain("www.cookbooks.com/Recipe-Details.aspx?id=60089")
# Out:
# 'cookbooks.com'

# %%
def has_www(recipe_url):
    return "/" in recipe_url

has_www("www.cookbooks.com/Recipe-Details.aspx?id=60089")
# Out:
# True

# %%
domains = recipe_nlg_dataset['link'].apply(get_domain)

# %%
domains.value_counts()
# Out:
# link
# cookbooks.com          896341
# food.com               499616
# epicurious.com         129444
# tastykitchen.com        78768
# myrecipes.com           64895
# allrecipes.com          64602
# cookpad.com             61020
# cookeatshare.com        59307
# yummly.com              51963
# tasteofhome.com         51594
# foodnetwork.com         49443
# food52.com              48501
# kraftrecipes.com        42010
# recipeland.com          24418
# recipes-plus.com        20524
# cooking.nytimes.com     16367
# foodandwine.com         15436
# seriouseats.com         12632
# foodgeeks.com            8963
# cookstr.com              8797
# online-cookbook.com      5691
# chowhound.com            5671
# vegetariantimes.com      4578
# delish.com               3880
# landolakes.com           2492
# foodrepublic.com         2259
# lovefood.com             1930
# Name: count, dtype: int64

# %%
df = recipe_nlg_dataset.copy()
print(df.shape)
# Out:
# (2231142, 6)

# %%
df_mini = df.sample(10000)
df_mini = df_mini.sort_values(by='directions', key=lambda x: -x.str.len())

# %%
for val in df_mini.iloc[0]:
    print(val)
# Out:
# Rainbow Unicorn Cake
# ["For the Cake Base", "1 recipe cake of your choice for the cake", "three 8 by 2-inch round cake pans for the cake", "For the Cake Decoration", "1 1/2 recipes of simple vanilla buttercream frosting (recipe follows)", "recipes of vanilla swiss meringue buttercream frosting (recipe follows)", "1/8 teaspoon gel green food coloring", "1/8 teaspoon gel pink food coloring", "1/8 teaspoon gel sky blue food coloring", "6 inches ball white fondant", "2 inches ball of pink fondant", "2 inches ball of black fondant", "For Simple Vanilla Buttercream Frosting", "2 cups unsalted butter, room temperature", "4 cups confectioners' sugar, sifted", "2 teaspoons pure vanilla extract", "1 -2 teaspoon whole milk, optional. If the buttercream is too stiff, a touch of milk will help loosen it a little", "For Vanilla Swiss Meringue Buttercream Frosting", "1 cup egg white (about 7 to 8 large eggs)", "2 1/4 cups granulated sugar", "2 teaspoons pure vanilla extract", "seeds of 1 vanilla bean (optional)", "1 pinch fine sea salt"]
# ["Tools:", "1 piping bag fitted with a multi-opening tip.", "1 piping bag fitted with a small leaf tip.", "2 piping bags each fitted with open star tips.", "Wooden skewer cut into 2 equal pieces plus additional wooden skewer (cut to fit, if need be).", "To make the simple vanilla buttercream:", "In the bowl of a stand mixer with a paddle attachment, beat the butter on high speed until it is light and fluffy, about 2 minutes. Scrape down the sides of the bowl with a spatula. Add the sifted confectioners' sugar, vanilla extract, and milk, if using. Mix on low speed to combine the ingredients. Once the sugar is incorporated, crank the mixer to high speed and beat the mixture for another 2 minutes, until it has more than doubled in volume, for a fluffy whipped frosting.", "Leftover buttercream can be stored in an airtight container in the fridge for up to 2 weeks or in the freezer for 1 month; bring it back to room temperature and rewhip in a stand mixer before using. This recipe can easily be halved or doubled.", "To make the vanilla swiss meringue buttercream:", "To ensure that the metal bowl of your stand mixer is completely clean, dry, and free of grease, give it a quick wipe out with a halved lemon, then rinse and dry it thoroughly.", "In the bowl of the stand mixer fitted with the whisk attachment, mix the egg whites and the sugar on low to combine into a sugary slurry. Fill a medium saucepan with a few inches of water and place it on the stovetop over medium-high heat. Set the mixer bowl on top of the saucepan to create a kind of double boiler, making sure the mixer bowl doesn't touch the water.", "Heat the egg and sugar mixture until it reaches 160\u00b0F on a thermometer or is hot to the touch, whisking occasionally. This usually takes me about 5 to 7 minutes.", "Carefully return the metal mixing bowl to the stand mixer, with the whisk attachment in place. Now, bring the mixer up to high speed and beat the mixture for 8 to 10 minutes, until you've created medium-stiff peaks and it's a billowy, sticky, cloudy meringue. Whipping the meringue will also help cool down the bowl.", "Swap out the whisk for the paddle attachment. Make sure your meringue has cooled sufficiently before adding the butter-the bowl shouldn't be hot, just slightly warm, if that. With the mixer on low speed, add the butter a few pieces at a time, until all the butter is incorporated-it will look like a thick soup at this point. Add the vanilla extract, if using, the vanilla bean seeds, along with the pinch of salt (and any small amount of gel color if so desired), then bring the speed up to medium-high and beat until a fluffy, silky, magical buttercream has formed, about 2 to 3 minutes.", "If your Swiss meringue buttercream turns into a soupy disaster, try placing the whole bowl in the fridge for about 5 to 10 minutes to cool it down a bit, then bring it out and try whipping it again, first on low speed, then bringing it up to high speed. Or try adding a few more chunks of butter to the mix.", "If your Swiss meringue buttercream becomes a gross-looking, curdled mess, try lightly heating the whole bowl over a low-boiling pot of water for 1 minute, just to get some heat back in there. Once it's warmed up a teensy bit, try mixing it again. You will be amazed at how a bowl of seemingly awful-looking buttercream can actually be saved and whipped back into a gorgeous, fluffy, satiny, creamy frosting.", "Vanilla Swiss Meringue Buttercream will keep in an airtight container for up to 1 week in the fridge or up to 1 month in the freezer. Bring it back to room temperature and gently rewhip before using.", "Prepare the cake. Bake the three layers of cake according to the recipe instructions. Level, fill, and frost your cake using the uncolored buttercream.", "Fill a piping bag fitted with a multi-opening tip with about half of the uncolored buttercream.", "Pipe the fur. Starting at the bottom edge of the cake, hold the piping bag at a 90-degree angle against the c ...
# www.food.com/recipe/rainbow-unicorn-cake-536631
# Gathered
# ["cake", "three", "Decoration", "vanilla buttercream frosting", "vanilla swiss meringue buttercream frosting", "gel green food coloring", "gel pink", "gel sky blue food coloring", "white fondant", "fondant", "black fondant", "Simple", "unsalted butter", "sugar", "vanilla", "milk", "egg white", "sugar", "vanilla", "vanilla bean", "salt"]

# %% [markdown]
# ### EDA

# %%
df.head()
# Out:
#                    title                                        ingredients  \
# 0    No-Bake Nut Cookies  ["1 c. firmly packed brown sugar", "1/2 c. eva...
# 1  Jewell Ball'S Chicken  ["1 small jar chipped beef, cut up", "4 boned ...
# 2            Creamy Corn  ["2 (16 oz.) pkg. frozen corn", "1 (8 oz.) pkg...
# 3          Chicken Funny  ["1 large whole chicken", "2 (10 1/2 oz.) cans...
# 4   Reeses Cups(Candy)    ["1 c. peanut butter", "3/4 c. graham cracker ...
#
#                                           directions  \
# 0  ["In a heavy 2-quart saucepan, mix brown sugar...
# 1  ["Place chipped beef on bottom of baking dish....
# 2  ["In a slow cooker, combine all ingredients. C...
# 3  ["Boil and debone chicken.", "Put bite size pi...
# 4  ["Combine first four ingredients and press in ...
#
#                                               link    source  \
# 0   www.cookbooks.com/Recipe-Details.aspx?id=44874  Gathered
# 1  www.cookbooks.com/Recipe-Details.aspx?id=699419  Gathered
# 2   www.cookbooks.com/Recipe-Details.aspx?id=10570  Gathered
# 3  www.cookbooks.com/Recipe-Details.aspx?id=897570  Gathered
# 4  www.cookbooks.com/Recipe-Details.aspx?id=659239  Gathered
#
#                                                  NER
# 0  ["brown sugar", "milk", "vanilla", "nuts", "bu...
# 1  ["beef", "chicken breasts", "cream of mushroom...
# 2  ["frozen corn", "cream cheese", "butter", "gar...
# 3  ["chicken", "chicken gravy", "cream of mushroo...
# 4  ["peanut butter", "graham cracker crumbs", "bu...

# %%
df.describe()
# Out:
#                     title                                    ingredients  \
# count             2231141                                        2231142
# unique            1312870                                        2226362
# top     Chicken Casserole  ["1 c. peanut butter", "1 c. sugar", "1 egg"]
# freq                 4099                                             28
#
#                                directions  \
# count                             2231142
# unique                            2211644
# top     ["Mix all ingredients together."]
# freq                                  274
#
#                                                   link    source      NER
# count                                          2231142   2231142  2231142
# unique                                         2231142         2  2133496
# top     www.cookbooks.com/Recipe-Details.aspx?id=44874  Gathered       []
# freq                                                 1   1643098      573

# %% [markdown]
# ### Cleaning

# %%
# Is '", "' the list separator?
one_ing = df[~df['ingredients'].str.contains('", "')]

print(f"Number of recipes with one ingredient: {len(one_ing)}")

for index, row in one_ing.iterrows():
    print(row['ingredients'])
    print("---"*10)
# Out:
# Number of recipes with one ingredient: 4102
# ["1 pkg. Stove Top stuffing, cooked"]
# ------------------------------
# ["roast (3 to 5 lb.)"]
# ------------------------------
# ["1 large box brownie mix"]
# ------------------------------
# ["1 pkg. Top Ramen - any flavor cuz I like them all!"]
# ------------------------------
# ["1 box Duncan Hines yellow cake mix"]
# ------------------------------
# ["1 (32 oz.) carton plain nonfat yogurt"]
# ------------------------------
# ["fresh cucumbers (firm and a good size for pickle)"]
# ------------------------------
# ["1 shot glass each: Jack Daniels, Irish cream, Kahlua, Rumplemintz Schnapps, vodka, Amaretto, Frangelico and cream"]
# ------------------------------
# ["1 pkg. soft corn tortillas (in refrigerator section)"]
# ------------------------------
# ["1 hen, washed and cut into pieces"]
# ------------------------------
# ["Desired amount of cucumbers"]
# ------------------------------
# ["poke greens"]
# ------------------------------
# ["1 box (any flavor) cake mix with pudding"]
# ------------------------------
# ["Duncan Hines butter cake mix"]
# ------------------------------
# ["1 box prepared brownie mix"]
# ------------------------------
# ["1 box Duncan Hines cake mix"]
# ------------------------------
# ["10 oz. tube refrigerated biscuits"]
# ------------------------------
# ["1 pkg. orange supreme cake mix"]
# ------------------------------
# ["1 whole brisket"]
# ------------------------------
# ["equal parts fresh berries and sugar"]
# ------------------------------
# ["4 (8 oz.) containers plain low-fat yogurt"]
# ------------------------------
# ["1 1/2 lb. round steak"]
# ------------------------------
# ["1 buffet turkey ham, sliced in 1/4-inch slices"]
# ------------------------------
# ["2 or 3 medium onions, sliced"]
# ------------------------------
# ["1 pkg. your favorite prepared cake mix"]
# ------------------------------
# ["1 T.V. dinner"]
# ------------------------------
# ["2 whole chicken breasts"]
# ------------------------------
# ["1 package or tube Pillsbury croissants"]
# ------------------------------
# ["1 Pillsbury cake mix with pudding (yellow or white), prepare according to directions on box using round cake pans"]
# ------------------------------
# ["4 ribs (baby back)"]
# ------------------------------
# ["1 box chocolate cake mix"]
# ------------------------------
# ["1 box cake mix (Duncan Hines Butter Recipe)"]
# ------------------------------
# ["1 to 2 c. water"]
# ------------------------------
# ["ripe bananas"]
# ------------------------------
# ["2 pkg. kielbasa (Hillshire Farms or from Polish market, etc.)"]
# ------------------------------
# ["6 white or whole wheat pocket breads (10 oz. pkg.)"]
# ------------------------------
# ["potatoes"]
# ------------------------------
# ["1 German chocolate cake mix"]
# ------------------------------
# ["hot cornmeal mush"]
# ------------------------------
# ["Yeast Rolls dough"]
# ------------------------------
# ["1 pkg. Ballard biscuits"]
# ------------------------------
# ["fresh corn-on-the-cob"]
# ------------------------------
# ["1 qt. favorite juice"]
# ------------------------------
# ["1/2 pkg. twirl pasta"]
# ------------------------------
# ["Peanut in shell"]
# ------------------------------
# ["13 lb. turkey"]
# ------------------------------
# ["1 whole chicken, cut up"]
# ------------------------------
# ["1 box chocolate cake mix, prepared as directed"]
# ------------------------------
# ["3 slabs"]
# ------------------------------
# ["6 to 12 potatoes"]
# ------------------------------
# ["1 devil's food cake mix"]
# ------------------------------
# ["2 cans crescent rolls"]
# ------------------------------
# ["Fresh chili peppers"]
# ------------------------------
# ["4 (4 oz.) fresh salmon fillets"]
# ------------------------------
# ["2 lb. turnip greens"]
# ------------------------------
# ["Little Debbie Swiss rolls"]
# ------------------------------
# ["2 pieces round steak (approximately 3 lb.)"]
# ------------------------------
# ["1 (10 lb.) bag Jolly Ranchers (supplied by Dad H.)"]
# ------------------------------
# ["medium baking potatoes"]
# ------------------------------
# ["1 pkg. chocolate cake mix (2-layer size)"]
# ------------------------------
# ["1 Duncan Hines chocolate cake mix"]
# ------------------------------
# ["1 chocolate cake mix"]
# ------------------------------
# ["4 or 5 pork chops"]
# ------------------------------
# ["frozen loaf bread (1 loaf per pizza)"]
# ------------------------------
# ["1 pkg. yellow cake mix"]
# ------------------------------
# ["3 to 4 (8-inch) zucchini and/or yellow squash"]
# ------------------------------
# ["6 oz. vanilla-flavored candy coating or almond bark, melted"]
# ------------------------------
# ["any amount sour milk or fresh clabber"]
# ------------------------------
# ["1 qt. soap chips"]
# ------------------------------
# ["sweetened condensed milk (Eagle Brand)"]
# ------------------------------
# ["1 pkg. Pillsbury chocolate chip cookie dough"]
# ------------------------------
# ["firm peppers with glossy, deep hued skins"]
# ------------------------------
# ["1 box Betty Crocker German chocolate SuperMoist cake mix"]
# ------------------------------
# ["1 box Duncan Hines sugar cookie mix"]
# ------------------------------
# ["1 box Duncan Hines yellow cake mix"]
# ------------------------------
# ["1/2 lb. salmon per person"]
# ------------------------------
# ["country ham slices, sliced 1/4-inch thick"]
# ------------------------------
# ["1 large bologna (according to how many you serve)"]
# ------------------------------
# ["steak"]
# ------------------------------
# ["1 (2 lb.) bag carrots"]
# ------------------------------
# ["5 lb. bottom round or sirloin"]
# ------------------------------
# ["10 to 12 pods okra, cut lengthwise or 3 squash, cut lengthwise"]
# ------------------------------
# ["1 (17 to 18 1/2 oz.) cake mix"]
# ------------------------------
# ["raisins or apples (quantity desired)"]
# ------------------------------
# ["1 c. Quaker oats (quick or old fashioned), uncooked"]
# ------------------------------
# ["6 Golden Delicious apples, peel, core and slice"]
# ------------------------------
# ["1 box Duncan Hines white cake mix"]
# ------------------------------
# ["1 can Spaghetti-Os (any brand)"]
# ------------------------------
# ["1 (10 oz.) pkg. refrigerated sugar cookies"]
# ------------------------------
# ["1 roll Pillsbury sugar cookies"]
# ------------------------------
# ["1 devil's food cake mix"]
# ------------------------------
# ["garlic (whole or cloves), as desired"]
# ------------------------------
# ["1 Cook's Brand ham"]
# ------------------------------
# ["thawed turkey"]
# ------------------------------
# ["sausage"]
# ------------------------------
# ["potatoes"]
# ------------------------------
# ["suckers (when in season)"]
# ------------------------------
# ["variety of breads"]
# ------------------------------
# ["1 loaf bread dough (frozen and unbaked)"]
# ------------------------------
# ["3/4 c. sugar"]
# ------------------------------
# ["6 to 12 potatoes"]
# ------------------------------
# ["2 pkg. crescent rolls"]
# ------------------------------
# ["5 potatoes, peeled"]
# ------------------------------
# ["1 box yellow cake mix"]
# ------------------------------
# ["1 box chocolate cake mix"]
# ------------------------------
# ["1 box white cake mix, prepared and cooked as directed on box"]
# ------------------------------
# ["1 chocolate cake mix"]
# ------------------------------
# ["4 to 5 medium beets"]
# ------------------------------
# ["1 baked pie shell"]
# ------------------------------
# ["1 lb. elbow macaroni"]
# ------------------------------
# ["1/2 recipe Can Do Quick Sweet Dough"]
# ------------------------------
# ["1 Tbsp. lye to 1 gal. shelled corn"]
# ------------------------------
# ["3 lb. beef chuck roast or country style spareribs"]
# ------------------------------
# ["medium or large potatoes"]
# ------------------------------
# ["1 standing rib roast"]
# ------------------------------
# ["1 cow"]
# ------------------------------
# ["fresh corn (amount needed)"]
# ------------------------------
# ["red snapper, mackerel, grouper, amberjack, bass or crappie (3 lb.), cleaned for baking (gut and take heads off)"]
# ------------------------------
# ["1 pkg. crescent rolls"]
# ------------------------------
# ["Duncan Hines yellow cake mix with pudding"]
# ------------------------------
# ["seedless grapes"]
# ------------------------------
# ["1 box Duncan Hines moist deluxe golden cake mix"]
# ------------------------------
# ["1 pkg. sugar cookie mix"]
# ------------------------------
# ["favorite brownie mix"]
# ------------------------------
# ["1 Swiss Chocolate Cake Mix"]
# ------------------------------
# ["potatoes (6 to 8 oz. each)"]
# ------------------------------
# ["1 box yellow cake mix"]
# ------------------------------
# ["6 pork chops or 1 chicken, cut up"]
# ------------------------------
# ["2 (10 count) pkg. fresh chicken wings"]
# ------------------------------
# ["18 to 20 lb. ham"]
# ------------------------------
# ["1 jar clear apple jelly"]
# ------------------------------
# ["1 box Duncan Hines all butter cake mix"]
# ------------------------------
# ["2 slices bread (whatever flavor you may desire, white, wheat, rye, etc.)"]
# ------------------------------
# ["about 1/2 pt. heavy cream (depending on the amount you want to make)"]
# ------------------------------
# ["2 slices light bread"]
# ------------------------------
# ["1 box honey graham crackers, divided"]
# ------------------------------
# ["franks, sliced diagonally"]
# ------------------------------
# ["1 bag Top Ramen noodles"]
# ------------------------------
# ["dried greenthread plant"]
# ------------------------------
# ["1 (9-inch) pie shell, baked and cooled"]
# ------------------------------
# ["1 box Duncan Hines fudge cake mix"]
# ------------------------------
# ["1 box butter cake mix"]
# ------------------------------
# ["1/2 can per each serving green beans"]
# ------------------------------
# ["1 box yellow cake mix"]
# ------------------------------
# ["2 chickens, quartered"]
# ------------------------------
# ["1 heavy beef chuck roast"]
# ------------------------------
# ["2 lb. chicken"]
# ------------------------------
# ["butter and nothing else"]
# ------------------------------
# ["Blend in food processor until smooth."]
# ------------------------------
# ["8 to 10 fresh ears of corn"]
# ------------------------------
# ["1 box Swiss chocolate cake mix"]
# ------------------------------
# ["1 newborn baby"]
# ------------------------------
# ["eggs"]
# ------------------------------
# ["1/2 to 1 slice ham for each person"]
# ------------------------------
# ["16 dried, red chile pods"]
# ------------------------------
# ["1 doz. eggs, boiled"]
# ------------------------------
# ["1/2 inch of vinegar"]
# ------------------------------
# ["can biscuits"]
# ------------------------------
# ["1 (4 to 5 lb.) duck"]
# ------------------------------
# ["potatoes"]
# ------------------------------
# ["1 loaf French bread"]
# ------------------------------
# ["1 box Capri Suns or any fruit drink"]
# ------------------------------
# ["1 box chocolate cake mix"]
# ------------------------------
# ["8 cooked carrots, halved lengthwise"]
# ------------------------------
# ["1 can Eagle Brand sweetened condensed milk"]
# ------------------------------
# ["1/2 or whole ham"]
# ------------------------------
# ["Chocuco (a chocolate and coconut liqueur, made in St. Croix)"]
# ------------------------------
# ["plump, full berries with light blue color"]
# ------------------------------
# ["1 box chocolate cake mix"]
# ------------------------------
# ["carrots (fresh)"]
# ------------------------------
# ["1 can freestone peaches, drained"]
# ------------------------------
# ["6 potatoes, cut crosswise"]
# ------------------------------
# ["2 to 3 Red Delicious apples"]
# ------------------------------
# ["yellow cake mix"]
# ------------------------------
# ["1 chocolate cake mix"]
# ------------------------------
# ["green peas"]
# ------------------------------
# ["1 pkg. chocolate cake mix"]
# ------------------------------
# ["yellow cake mix"]
# ------------------------------
# ["6 c. prepared fruit juice"]
# ------------------------------
# ["any brownie mix"]
# ------------------------------
# ["1 Duncan Hines pineapple supreme or lemon supreme cake mix"]
# ------------------------------
# ["little bits cereal left at the bottom of cereal boxes"]
# ------------------------------
# ["2 whole watermelons"]
# ------------------------------
# ["2 (10 oz.) chopped frozen broccoli, cooked 3 minutes"]
# ------------------------------
# ["2 c. sugar to 1 c. blackberries"]
# ------------------------------
# ["white cake mix (3 layer cake)"]
# ------------------------------
# ["1 pkg. devil's food cake mix"]
# ------------------------------
# ["1 bag raw Virginia type peanuts in shell or shelled"]
# ------------------------------
# ["1 lb. hamburger"]
# ------------------------------
# ["butternuts"]
# ------------------------------
# ["2 layer butter cake mix"]
# ------------------------------
# ["1 standing rib roast"]
# ------------------------------
# ["1 c. each: pecans, crushed pineapple, mandarin oranges, coconut, sour cream and mini marshmallows"]
# ------------------------------
# ["1 (18 oz.) roll Pillsbury Refrigerated Choc-Chip Cookies"]
# ------------------------------
# ["chickens, halved (1/2 per person), rubbed with salt, pepper and poultry seasoning"]
# ------------------------------
# ["2 c. (8 oz.) Parmesan cheese, shredded"]
# ------------------------------
# ["eggs"]
# ------------------------------
# ["4 large onions"]
# ------------------------------
# ["2 c. rice (brown or white)"]
# ------------------------------
# ["2 rolls chocolate chip cookie dough"]
# ------------------------------
# ["fresh or frozen venison"]
# ------------------------------
# ["14 to 20 egg roll wrappers (2 pkg.)"]
# ------------------------------
# ["equal amounts of fruit and sugar"]
# ------------------------------
# ["3 c. plain non-fat yogurt"]
# ------------------------------
# ["1 German chocolate cake, as directed below"]
# ------------------------------
# ["1 box sugar cookie mix"]
# ------------------------------
# ["1 pt. heavy whipping cream"]
# ------------------------------
# ["1 lb. fresh dover sole or 1 lb. orange roughy (or how much you need)"]
# ------------------------------
# ["1 frozen store bought pizza"]
# ------------------------------
# ["4 plain bagels"]
# ------------------------------
# ["jello"]
# ------------------------------
# ["1 can pork and beans"]
# ------------------------------
# ["2 c. wheat (preferably soft wheat), soaked in 4 1/2 c. water for 12 hours"]
# ------------------------------
# ["deboned chicken breasts"]
# ------------------------------
# ["1 box yellow cake mix"]
# ------------------------------
# ["1 head cabbage, shredded and soaked in ice water 1/2 hour)"]
# ------------------------------
# ["ears of corn, still in shucks"]
# ------------------------------
# ["1 box spice cake"]
# ------------------------------
# ["1 box Duncan Hines cake mix with stick of butter"]
# ------------------------------
# ["6 or 8 center cut pork chops"]
# ------------------------------
# ["bacon"]
# ------------------------------
# ["1 box devil's food cake"]
# ------------------------------
# ["favorite sugar cookie recipe or Pillsbury premade dough (in refrigerator section of grocer)"]
# ------------------------------
# ["1 (14 oz.) can Borden sweetened condensed milk (Eagle Brand)"]
# ------------------------------
# ["Wintergreen Life Savers"]
# ------------------------------
# ["1 box Duncan Hines chocolate cake mix"]
# ------------------------------
# ["1 pkg. microwave popcorn"]
# ------------------------------
# ["1 box Swiss chocolate cake mix"]
# ------------------------------
# ["1 box Duncan Hines Swiss chocolate cake mix"]
# ------------------------------
# ["3 or 4 lb. frozen chuck roast"]
# ------------------------------
# ["1 box Duncan Hines yellow cake mix"]
# ------------------------------
# ["any size rib roast or rump roast"]
# ------------------------------
# ["36 fresh mushrooms"]
# ------------------------------
# ["1 box yellow cake mix"]
# ------------------------------
# ["1 box yellow or white cake mix"]
# ------------------------------
# ["any canned vegetables (such as corn, green beans, peas, etc.)"]
# ------------------------------
# ["1 pkg. (2 layer size) yellow cake mix plus pudding"]
# ------------------------------
# ["4 or 5 potatoes"]
# ------------------------------
# ["1 (18.5 oz.) yellow cake mix"]
# ------------------------------
# ["roast"]
# ------------------------------
# ["1 uncooked country ham"]
# ------------------------------
# ["white cake mix, prepared as directed"]
# ------------------------------
# ["2 pkg. chicken wings (3 to 4 lb.)"]
# ------------------------------
# ["low calorie bread"]
# ------------------------------
# ["1 pkg. Pillsbury Refrigerated Sugar Cookie Dough"]
# ------------------------------
# ["1 box ice cream bars"]
# ------------------------------
# ["1 box devil's food cake mix"]
# ------------------------------
# ["1 box yellow cake mix"]
# ------------------------------
# ["2 pkg. Pillsbury crescent rolls"]
# ------------------------------
# ["1 box instant or cooked pudding"]
# ------------------------------
# ["juice (from lemon or citrus fruits such as grapefruit, orange, etc.)"]
# ------------------------------
# ["large dry onions, silver skinned or yellow"]
# ------------------------------
# ["1 box yellow cake mix"]
# ------------------------------
# ["1 devil's food cake"]
# ------------------------------
# ["1 (20 oz.) pkg. Pillsbury refrigerated cookie dough"]
# ------------------------------
# ["1 box butter fudge cake mix"]
# ------------------------------
# ["1 turkey"]
# ------------------------------
# ["corn"]
# ------------------------------
# ["1 box Duncan Hines sugar cookie mix"]
# ------------------------------
# ["2 c. fresh blueberries"]
# ------------------------------
# ["1 - 18.5 oz. box butter cake mix"]
# ------------------------------
# ["hot dogs"]
# ------------------------------
# ["large flat sweet Texas onions (Texas 1015's)"]
# ------------------------------
# ["4 lb. or more large chuck roast (any grade)"]
# ------------------------------
# ["6 or 8 pork chops (1 1/2-inch thick)"]
# ------------------------------
# ["double recipe of pie dough (enough for two 9-inch pies)"]
# ------------------------------
# ["several medium to large onions"]
# ------------------------------
# ["pork tenderloin, trimmed of sinew and excess fat"]
# ------------------------------
# ["3 to 4 lb. large crawfish tails, peeled and cleaned"]
# ------------------------------
# ["chocolate pudding"]
# ------------------------------
# ["1 Mrs. Smith's Dutch apple pie (frozen)"]
# ------------------------------
# ["1 lb. each: black beans, red beans, pinto beans, navy beans, Great Northern beans, dried lentils, split peas, black-eyed peas and barley pearls"]
# ------------------------------
# ["3/4 c. each: soy sauce, catsup and brown sugar"]
# ------------------------------
# ["4 medium sweet potatoes"]
# ------------------------------
# ["1 batch very ripe tomatoes, Batch size to suit amount of bread crumbs available (I am never sure what that amount is)"]
# ------------------------------
# ["1 can Eagle Brand milk"]
# ------------------------------
# ["1 large yam"]
# ------------------------------
# ["1 spaghetti squash"]
# ------------------------------
# ["1 standing rib roast (any size)"]
# ------------------------------
# ["5 or 6 large baking potatoes"]
# ------------------------------
# ["pan with crust"]
# ------------------------------
# ["2 slices bread (use whole wheat for added fiber)"]
# ------------------------------
# ["1 can peas"]
# ------------------------------
# ["10 to 14 lb. ham"]
# ------------------------------
# ["1 ring kielbasa, sliced and browned"]
# ------------------------------
# ["1 box Pillsbury deluxe fudge brownie mix"]
# ------------------------------
# ["potatoes"]
# ------------------------------
# ["medium to large baking potatoes"]
# ------------------------------
# ["3 strips fried bacon to 1 sandwich"]
# ------------------------------
# ["1/2 tsp. each: salt, pepper, oregano, sugar, thyme, garlic powder, paprika, brown sugar, rosemary and onion"]
# ------------------------------
# ["1 (16 oz.) box white angel food cake mix"]
# ------------------------------
# ["1 (20 oz.) roll Pillsbury sugar cookie dough (1 lb. 4 oz.)"]
# ------------------------------
# ["4 lb. potatoes"]
# ------------------------------
# ["1 can sweetened condensed milk"]
# ------------------------------
# ["1 (5 lb.) trimmed beef brisket flat"]
# ------------------------------
# ["4 to 5 lb. brisket"]
# ------------------------------
# ["7 whole wheat pita bread rounds"]
# ------------------------------
# ["1 chocolate cake mix"]
# ------------------------------
# ["applesauce equal to the amount of oil called for in the original recipe"]
# ------------------------------
# ["Duncan Hines Moist Deluxe Swiss chocolate cake mix"]
# ------------------------------
# ["1 c. green beans"]
# ------------------------------
# ["1 English muffin, split and toasted"]
# ------------------------------
# ["1 box yellow cake mix (I used IGA Brand), mixed as directed on box"]
# ------------------------------
# ["1 stewing hen"]
# ------------------------------
# ["1 fryer, cooked with salt and pepper"]
# ------------------------------
# ["no ingredients necessary"]
# ------------------------------
# ["4 to 6 whole potatoes"]
# ------------------------------
# ["1 (3 to 4 lb.) roast beef"]
# ------------------------------
# ["1 pkg. raspberry Jell-O"]
# ------------------------------
# ["8 to 10 ears corn"]
# ------------------------------
# ["1 box yellow cake mix"]
# ------------------------------
# ["Jiffy cake mix (chocolate)"]
# ------------------------------
# ["25 (plus or minus) Ritz crackers"]
# ------------------------------
# ["1 can sweetened condensed milk"]
# ------------------------------
# ["1 box butter Duncan Hines yellow cake mix"]
# ------------------------------
# ["6 to 8 quail"]
# ------------------------------
# ["1 pkg. yellow cake mix"]
# ------------------------------
# ["1 box yellow cake mix"]
# ------------------------------
# ["1 pkg. Duncan Hines pineapple supreme cake mix"]
# ------------------------------
# ["1 orange cake mix"]
# ------------------------------
# ["1 yellow cake mix (with pudding in the batter)"]
# ------------------------------
# ["2 Chronicles 7:14"]
# ------------------------------
# ["1 box chocolate cake mix"]
# ------------------------------
# ["1 Smithfield or any well-cured country ham"]
# ------------------------------
# ["1 box Duncan Hines yellow cake mix"]
# ------------------------------
# ["bite-size pieces of vegetables*"]
# ------------------------------
# ["1 c. butter"]
# ------------------------------
# ["1/2 c. sugar"]
# ------------------------------
# ["1 Butter Recipe cake mix (Duncan Hines)"]
# ------------------------------
# ["1 box Duncan Hines Swiss chocolate cake mix"]
# ------------------------------
# ["1 can condensed milk"]
# ------------------------------
# ["garlic"]
# ------------------------------
# ["1 Duncan Hines lemon cake"]
# ------------------------------
# ["1 whole chicken, cooked in 6 c. water"]
# ------------------------------
# ["7 1/2 lb. cukes (after peeling and seeding)"]
# ------------------------------
# ["1 (25 lb.) country ham"]
# ------------------------------
# ["1 box yellow cake mix"]
# ------------------------------
# ["5 lb. stewing hen or larger"]
# ------------------------------
# ["1/2 dish pan full corn"]
# ------------------------------
# ["1 to 8 ears corn"]
# ------------------------------
# ["1 box Duncan Hines sugar cookie mix"]
# ------------------------------
# ["honey equal to the amount of sugar called for in the original recipe"]
# ------------------------------
# ["1/2 lb. chocolate"]
# ------------------------------
# ["Hard cooked eggs, grated or chopped finely"]
# ------------------------------
# ["1 box golden yellow cake mix (pudding in the mix) or chocolate cake mix (pudding in the mix)"]
# ------------------------------
# ["12 ears corn, cut off cob"]
# ------------------------------
# ["2 gal. pickles"]
# ------------------------------
# ["3 to 5 c. apples"]
# ------------------------------
# ["1 box white cake mix"]
# ------------------------------
# ["1 large Boston Butt or Pic-Nic Roast"]
# ------------------------------
# ["1 husband"]
# ------------------------------
# ["1 Duncan Hines butter cake mix"]
# ------------------------------
# ["1 can refrigerated biscuits"]
# ------------------------------
# ["3 shrimp cocktails (use sauce from 2 bottles, use shrimp from third)"]
# ------------------------------
# ["roast beef (cut of your choice)"]
# ------------------------------
# ["any flavor Kool-Aid"]
# ------------------------------
# ["1 pkg. Jell-O cake mix or 1/2 box any yellow cake mix"]
# ------------------------------
# ["1 box yellow cake mix"]
# ------------------------------
# ["1 pkg. any cookie dough"]
# ------------------------------
# ["cucumbers"]
# ------------------------------
# ["chocolate cake"]
# ------------------------------
# ["1 lb. scrubbed dandelion roots"]
# ------------------------------
# ["1 (2 to 5 lb.) carp"]
# ------------------------------
# ["1 or 2 rolls frozen bread"]
# ------------------------------
# ["1 pkg. your favorite microwaveable brownie mix"]
# ------------------------------
# ["1 bag Ramen noodles"]
# ------------------------------
# ["1 small Granny Smith apple, peeled, cored and cut into 12 thin slices"]
# ------------------------------
# ["8 oz. circle brie cheese"]
# ------------------------------
# ["1 Duncan Hines butter fudge cake mix or Betty Crocker devil's food sour cream mix"]
# ------------------------------
# ["2 or 3 cucumbers, peeled and sliced thin"]
# ------------------------------
# ["1 pkg. white or yellow cake mix"]
# ------------------------------
# ["1 box Duncan Hines Swiss chocolate cake mix"]
# ------------------------------
# ["1 loaf frozen bread dough"]
# ------------------------------
# ["1 Duncan Hines Orange Cake Mix"]
# ------------------------------
# ["18 (6-inch) corn tortillas, torn into bite size pieces*"]
# ------------------------------
# ["block Cheddar cheese (we like extra sharp)"]
# ------------------------------
# ["water"]
# ------------------------------
# ["1 tube of prepared sugar cookie dough from the dairy department"]
# ------------------------------
# ["1 store bought sandwich type cookie"]
# ------------------------------
# ["any size uncooked beef roast"]
# ------------------------------
# ["1 (3 oz.) pkg. Jell-O in each of the following flavors: black cherry, red cherry or red raspberry, lime, lemon, orange, orange pineapple and strawberry"]
# ------------------------------
# ["4 large baking potatoes (about 4 1/2 inches long; Russets are best)"]
# ------------------------------
# ["1 ripe watermelon"]
# ------------------------------
# ["3 c. apples, sliced thin"]
# ------------------------------
# ["several whole garlic heads"]
# ------------------------------
# ["1 (1 lb.) can fruit (packed in juice or light syrup)"]
# ------------------------------
# ["green beans"]
# ------------------------------
# ["14 large cucumbers (can use 1 gal. small cucumbers instead of 14 large cukes)"]
# ------------------------------
# ["Act II microwave caramel popcorn"]
# ------------------------------
# ["2 cans jalapeno bean dip"]
# ------------------------------
# ["1 box white cake mix (enough for one 13 x 9-inch pan)"]
# ------------------------------
# ["2 to 6 c. tap water (depends on your individual needs)"]
# ------------------------------
# ["1 pkg. German chocolate cake mix"]
# ------------------------------
# ["1 ham"]
# ------------------------------
# ["2 lb. white potatoes"]
# ------------------------------
# ["1 box Duncan Hines butter cake mix"]
# ------------------------------
# ["pie crust (enough for top and bottom)"]
# ------------------------------
# ["1 box white cake mix"]
# ------------------------------
# ["juice (favorite)"]
# ------------------------------
# ["Pfeiffer Italian low-calorie dressing or Zesty Italian dressing by Kraft Reduced calorie and Dale's steak seasoning"]
# ------------------------------
# ["pickles (your choice)"]
# ------------------------------
# ["4 (3/4 to 1 lb.) Cornish hens"]
# ------------------------------
# ["equal amounts of cream cheese and marshmallow cream"]
# ------------------------------
# ["1 box chocolate cake mix"]
# ------------------------------
# ["Duncan Hines moist deluxe brownie mix"]
# ------------------------------
# ["overripe bananas"]
# ------------------------------
# ["Duncan Hines Butter Cake Mix"]
# ------------------------------
# ["your favorite meat loaf recipe"]
# ------------------------------
# ["1 box strawberry cake mix"]
# ------------------------------
# ["as many squash as needed for the meal"]
# ------------------------------
# ["4 to 5 c. peeled and sliced apples"]
# ------------------------------
# ["1 (12 oz.) pkg. small elbow macaroni"]
# ------------------------------
# ["2 (15 oz.) cans lima beans"]
# ------------------------------
# ["1 pkg. Sunbeam or Publix brand dinner rolls"]
# ------------------------------
# ["1 box Red Baron pepperoni pizza"]
# ------------------------------
# ["2 tubes crescent rolls"]
# ------------------------------
# ["1 red potato per person, washed and cut in half"]
# ------------------------------
# ["1 Betty Crocker butter pecan cake mix"]
# ------------------------------
# ["2 to 4 baking potatoes"]
# ------------------------------
# ["6 or 8 large bell peppers, red, green or yellow"]
# ------------------------------
# ["5 or 6 qt. popcorn"]
# ------------------------------
# ["1 can bean dip"]
# ------------------------------
# ["1 strawberry cake mix"]
# ------------------------------
# ["standing rib beef roast (any size)"]
# ------------------------------
# ["1 bottle inexpensive Italian dressing"]
# ------------------------------
# ["any type corn bread (scratch or boxed) We like Jiffy corn bread for this"]
# ------------------------------
# ["apple"]
# ------------------------------
# ["1 box yellow cake mix"]
# ------------------------------
# ["1 can pineapple chunks"]
# ------------------------------
# ["1 box Duncan Hines Swiss chocolate cake mix"]
# ------------------------------
# ["1 pkg. refrigerator cookie dough"]
# ------------------------------
# ["1 box German chocolate cake mix (or 1 box chocolate mix with pudding)"]
# ------------------------------
# ["4 to 8 potatoes"]
# ------------------------------
# ["1 lb. medium sweet potatoes or yams"]
# ------------------------------
# ["1 box devil's food cake mix"]
# ------------------------------
# ["beans"]
# ------------------------------
# ["fresh rutabagas"]
# ------------------------------
# ["1 can chicken noodle soup (recommend Campbell's)"]
# ------------------------------
# ["2 to 6 medium potatoes"]
# ------------------------------
# ["greens"]
# ------------------------------
# ["1 turkey (any size), thawed"]
# ------------------------------
# ["1 box devil's food cake mix"]
# ------------------------------
# ["1 Duncan Hines Butter Recipe fudge cake mix"]
# ------------------------------
# ["1/3 c. each: white glue, flour and cornstarch (or equal parts for any quantity)"]
# ------------------------------
# ["1 pkg. vanilla or German chocolate cake mix"]
# ------------------------------
# ["1 pkg. chocolate cake mix"]
# ------------------------------
# ["potatoes"]
# ------------------------------
# ["1 roll biscuits (any kind)"]
# ------------------------------
# ["1 1/2 to 2 lb. piece boneless ham"]
# ------------------------------
# ["chocolate cake mix (pudding recipe)"]
# ------------------------------
# ["1 (2 1/2-inch) piece celery"]
# ------------------------------
# ["2 to 3 Tbsp. bean sprout seeds"]
# ------------------------------
# ["1 can refried beans (bean dip optional)"]
# ------------------------------
# ["1 medium to large turkey"]
# ------------------------------
# ["fruits for freezing (can be apples, peaches or berries)"]
# ------------------------------
# ["leftover pizza from Pizza Hut or your favorite pizza place (pizza from Tuesday night is best because kids under 12 eat free)"]
# ------------------------------
# ["1 jar apple butter or any other preserves for any other flavor"]
# ------------------------------
# ["1 box Pillsbury pumpkin bread"]
# ------------------------------
# ["1 lb. ground venison sausage"]
# ------------------------------
# ["Take 1 child"]
# ------------------------------
# ["1 or 2 ears of fresh corn"]
# ------------------------------
# ["2 pkg. Crescent Rolls"]
# ------------------------------
# ["butter recipe cake mix"]
# ------------------------------
# ["bacon (2 slices for each serving)"]
# ------------------------------
# ["2 cans Pillsbury crescent rolls"]
# ------------------------------
# ["8 to 10 apples"]
# ------------------------------
# ["1 stick butter or margarine"]
# ------------------------------
# ["good oven roast (any size)"]
# ------------------------------
# ["flank steak"]
# ------------------------------
# ["1 whole cut up fryer or your favorite pieces"]
# ------------------------------
# ["6 ears corn with husks on"]
# ------------------------------
# ["2 pkg. crescent rolls"]
# ------------------------------
# ["radishes"]
# ------------------------------
# ["1 (16 oz.) can fruit (peaches or pears are good choices), well drained"]
# ------------------------------
# ["cake mix"]
# ------------------------------
# ["1 box Duncan Hines Swiss Chocolate Cake mix"]
# ------------------------------
# ["1 pkg. yellow cake mix"]
# ------------------------------
# ["1 (18 to 20 lb.) country cured ham or a small Clifty Farm ham"]
# ------------------------------
# ["2 lb. pork tenderloin"]
# ------------------------------
# ["fresh collards or turnip salad (amount as desired)"]
# ------------------------------
# ["any bread other than cracked wheat"]
# ------------------------------
# ["chicken"]
# ------------------------------
# ["your favorite plain white bread recipe, less the shortening"]
# ------------------------------
# ["1 box Duncan Hines chocolate cake mix"]
# ------------------------------
# ["1 (14 oz.) can sweetened condensed milk"]
# ------------------------------
# ["2 lb. round rye bread"]
# ------------------------------
# ["2 small boxes Duncan Hines brownie mix"]
# ------------------------------
# ["corn tortillas"]
# ------------------------------
# ["1 pkg. yeast roll mix or purchase 2 (8 1/2-inch round) fococcia or purchase Francisco French rolls"]
# ------------------------------
# ["6 eggs, beaten and poured into hot skillet (make as for scrambled eggs)"]
# ------------------------------
# ["8 oz. whole milk"]
# ------------------------------
# ["1 yellow cake mix"]
# ------------------------------
# ["8 (7 or 8) flour tortillas"]
# ------------------------------
# ["12 oz. pkg. large shells or manicotti"]
# ------------------------------
# ["1 bag popcorn"]
# ------------------------------
# ["1 box yellow cake mix"]
# ------------------------------
# ["several large heads cabbage"]
# ------------------------------
# ["2 boxes Pillsbury crust (red box, in refrigerated section)"]
# ------------------------------
# ["One Duncan Hines Strawberry cake mix--save small amount of cake mix to dust pans"]
# ------------------------------
# ["1 large can Franco American spaghetti and meatballs"]
# ------------------------------
# ["chicken, hen, turkey or beef"]
# ------------------------------
# ["cleaned ears of corn"]
# ------------------------------
# ["1 pkg. regular Oscar Meyer hot dogs"]
# ------------------------------
# ["smoked ham (butt), size that fits in roaster pan"]
# ------------------------------
# ["28 c. apples, peeled and sliced"]
# ------------------------------
# ["1 c. room temperature whipping cream"]
# ------------------------------
# ["1 chocolate cake mix"]
# ------------------------------
# ["1 1/2 lb. hot dogs"]
# ------------------------------
# ["1 c. flour, sifted"]
# ------------------------------
# ["1 orange"]
# ------------------------------
# ["4 lb. spare ribs, cut into serving pieces"]
# ------------------------------
# ["1 box Duncan Hines chocolate cake mix with pudding"]
# ------------------------------
# ["3/4 c. sugar"]
# ------------------------------
# ["2 pkg. crescent rolls"]
# ------------------------------
# ["1 or 2 cooked chickens from Rini Rego's"]
# ------------------------------
# ["1 German chocolate cake mix"]
# ------------------------------
# ["1 pkg. sugar cookie dough (Pillsbury)"]
# ------------------------------
# ["1 skinless breast (for each person)"]
# ------------------------------
# ["corn-on-the-cob"]
# ------------------------------
# ["1 box Pillsbury gingerbread mix"]
# ------------------------------
# ["Eggs"]
# ------------------------------
# ["2 to 3 medium size sweet potatoes peeled and sliced"]
# ------------------------------
# ["1 box Entenmann's lemon crumb cake (look under box to make sure it's a day old)"]
# ------------------------------
# ["1 box Jiffy pie crust"]
# ------------------------------
# ["equal parts McCormick garlic salt, black pepper and cumin"]
# ------------------------------
# ["pork roast, boned and tied (1/2 to 3/4 lb. per person)"]
# ------------------------------
# ["1 pkg. Jell-O cheesecake"]
# ------------------------------
# ["1 medium loaf Italian bread (preferably whole wheat)"]
# ------------------------------
# ["1 can bean dip"]
# ------------------------------
# ["3 loaves frozen bread"]
# ------------------------------
# ["1 beef brisket (3 to 5 lb.)"]
# ------------------------------
# ["1 orange cake mix"]
# ------------------------------
# ["favorite juice"]
# ------------------------------
# ["1 pkg. frozen fruit (any type)"]
# ------------------------------
# ["potatoes (quantity depends on number of people)"]
# ------------------------------
# ["1 (8 1/2 oz.) pkg. corn bread mix"]
# ------------------------------
# ["4 or 5 medium sweet potatoes, peeled and cut into 1-inch strips"]
# ------------------------------
# ["1 box Duncan Hines deep chocolate cake mix"]
# ------------------------------
# ["1 whole chicken or parts of chicken"]
# ------------------------------
# ["5 lb. pork (shoulder is good)"]
# ------------------------------
# ["Keebler Club crackers"]
# ------------------------------
# ["1 big cucumber, sliced very thin"]
# ------------------------------
# ["1 lb. dry pinto beans, lima beans or black-eyed peas"]
# ------------------------------
# ["1 1/2 lb. ground chuck"]
# ------------------------------
# ["1 eye of round, rolled in salt and pepper or your favorite seasoning"]
# ------------------------------
# ["1/4 c. poppy seed, caraway seed, herb de provence or other spice"]
# ------------------------------
# ["fresh young dandelion leaves"]
# ------------------------------
# ["4 c. cut up fruit (apples, bananas, grapes, oranges or pears)"]
# ------------------------------
# ["1 box Tyson chicken nuggets or whatever is on sale"]
# ------------------------------
# ["1/2 Duncan Hines yellow or golden vanilla cake mix"]
# ------------------------------
# ["broccoli, cauliflower, bell pepper and onions, cut up"]
# ------------------------------
# ["4 to 6 ears fresh corn"]
# ------------------------------
# ["1 can (16 oz.) El Paso refried beans"]
# ------------------------------
# ["2 to 6 apples (any kind)"]
# ------------------------------
# ["beef"]
# ------------------------------
# ["2 (8 oz.) or 1 (16 oz.) Second Nature Egg Beaters"]
# ------------------------------
# ["1 box paella"]
# ------------------------------
# ["orange juice (or any other juice)"]
# ------------------------------
# ["equal parts: apricot jelly and cream cheese"]
# ------------------------------
# ["bananas"]
# ------------------------------
# ["1 pkg. Duncan Hines Butter Recipe cake mix (yellow)"]
# ------------------------------
# ["2 to 4 lb. wings"]
# ------------------------------
# ["eggs"]
# ------------------------------
# ["1 Duncan Hines butter cake mix"]
# ------------------------------
# ["1 lb. spaghetti"]
# ------------------------------
# ["1 box Swiss chocolate cake mix"]
# ------------------------------
# ["1 box chocolate cake mix with pudding in mix"]
# ------------------------------
# ["okra or squash"]
# ------------------------------
# ["1 pumpkin, cut in uniform pieces (peeled with center removed)"]
# ------------------------------
# ["1 (16 oz.) can mixed fruit or sliced peaches or pears, packed in juice or extra-light syrup"]
# ------------------------------
# ["1 (8-inch) graham cracker crust pie"]
# ------------------------------
# ["12 chicken breasts, skinned and boned"]
# ------------------------------
# ["1 pkg. Duncan Hines chocolate cake mix"]
# ------------------------------
# ["8 potatoes, scrubbed, peeled and sliced lengthwise into 8 equal strips"]
# ------------------------------
# ["1 to 3 lb. peanuts in shell"]
# ------------------------------
# ["corn tortillas"]
# ------------------------------
# ["1 potato, thinly sliced (peel or don't peel)"]
# ------------------------------
# ["12 to 14 lb. ham"]
# ------------------------------
# ["1 Duncan Hines golden butter cake mix"]
# ------------------------------
# ["1 pkg. Duncan Hines yellow cake mix"]
# ------------------------------
# ["1 whole ham (Petit Jean fully cooked preferred)"]
# ------------------------------
# ["Rice-A-Roni (any flavor)"]
# ------------------------------
# ["8 chicken breasts (with bones), skinned"]
# ------------------------------
# ["1 box yellow cake mix with pudding"]
# ------------------------------
# ["1 regular cake mix (any flavor)"]
# ------------------------------
# ["16 pieces chocolate"]
# ------------------------------
# ["1 box Duncan Hines cake mix"]
# ------------------------------
# ["1 log Toll House chocolate chip cookie dough"]
# ------------------------------
# ["flounder or sole fillets"]
# ------------------------------
# ["1 box Duncan Hines Deluxe yellow cake mix"]
# ------------------------------
# ["1 devil's food or other chocolate cake mix"]
# ------------------------------
# ["1 Large Angel Food Cake"]
# ------------------------------
# ["14 whole graham crackers (28 sq.)"]
# ------------------------------
# ["chocolate cake mix"]
# ------------------------------
# ["1 (6 to 8 lb.) goose"]
# ------------------------------
# ["1 medium (4 inches in diameter) artichoke"]
# ------------------------------
# ["carrots"]
# ------------------------------
# ["1 head lettuce"]
# ------------------------------
# ["1 to 2 lb. chuck roast"]
# ------------------------------
# ["homemade or store purchased angel food cake"]
# ------------------------------
# ["1 pkg. lime Jell-O"]
# ------------------------------
# ["3 sq. semi-sweet chocolate"]
# ------------------------------
# ["macaroni and cheese in a box"]
# ------------------------------
# ["1 can chicken noodle soup"]
# ------------------------------
# ["1 box Swiss chocolate cake mix"]
# ------------------------------
# ["1 box 2 step angel food cake mix"]
# ------------------------------
# ["1 box Duncan Hines chocolate cake mix"]
# ------------------------------
# ["2 - 3 pieces of orange Roughy"]
# ------------------------------
# ["7 lb. cucumbers, sliced crosswise"]
# ------------------------------
# ["1 white cake mix"]
# ------------------------------
# ["1 large cheese pumpkin (this best for cooking)"]
# ------------------------------
# ["1 orange cake mix"]
# ------------------------------
# ["2 cans crescent rolls"]
# ------------------------------
# ["your favorite kinds"]
# ------------------------------
# ["enough pastry for a 2 crust pie"]
# ------------------------------
# ["1 (3 oz. pkg. each) Jell-O: black cherry, lime, lemon, orange, orange pineapple and wild strawberry"]
# ------------------------------
# ["2 dishes"]
# ------------------------------
# ["1 can jellied cranberry sauce"]
# ------------------------------
# ["carrots"]
# ------------------------------
# ["1 (4 oz.) pkg. instant pudding (any flavor)"]
# ------------------------------
# ["1 telephone"]
# ------------------------------
# ["1 lb. good ground beef"]
# ------------------------------
# ["Duncan Hines cookie mix"]
# ------------------------------
# ["1 (20 oz.) pkg. refrigerated sugar cookie dough"]
# ------------------------------
# ["1 dark chocolate cake mix with pudding"]
# ------------------------------
# ["3 lb. chicken legs or wings"]
# ------------------------------
# ["1 devil's food cake mix (without pudding)"]
# ------------------------------
# ["1 pkg. turkey hot dogs (may substitute chicken hot dogs, no other)"]
# ------------------------------
# ["6 oz. pkg. lime jello"]
# ------------------------------
# ["1 can Eagle Brand condensed milk"]
# ------------------------------
# ["Hi-Energy Orange Supplement"]
# ------------------------------
# ["1 box any brand mac and cheese"]
# ------------------------------
# ["moist white cake mix"]
# ------------------------------
# ["1 box white cake mix"]
# ------------------------------
# ["2 lb. asparagus"]
# ------------------------------
# ["5 lb. bucket chitterlings, thawed and cleaned"]
# ------------------------------
# ["4 medium baking potatoes, peeled and cut into strips (16 per potato)"]
# ------------------------------
# ["1 box swiss chocolate cake mix"]
# ------------------------------
# ["1 pkg. Duncan Hines yellow cake mix"]
# ------------------------------
# ["1 devil's food cake"]
# ------------------------------
# ["Griffin's Strawberry, Apricot, or Peach Preserves"]
# ------------------------------
# ["3 or 4 lb. boneless spareribs"]
# ------------------------------
# ["1 devil's food cake mix"]
# ------------------------------
# ["chicken pieces (use as many needed for number of servings needed)"]
# ------------------------------
# ["4 slices bacon"]
# ------------------------------
# ["1 carton no-fat yogurt"]
# ------------------------------
# ["5-6 pound Roast"]
# ------------------------------
# ["2 cans Ballard biscuit mix (20 biscuits)"]
# ------------------------------
# ["2 1/2 lb. (1 medium) squash"]
# ------------------------------
# ["6 sweet potatoes"]
# ------------------------------
# ["equal parts sour cream, yogurt, confectioners sugar and cocoa (other ingredients may have to substitute, in a pinch) *"]
# ------------------------------
# ["1 box Duncan Hines Butter Recipe cake mix"]
# ------------------------------
# ["5 to 6 lb. leg of lamb"]
# ------------------------------
# ["1 devil's food cake mix"]
# ------------------------------
# ["1 can Quality Food's Texas butter biscuits"]
# ------------------------------
# ["red beets"]
# ------------------------------
# ["1 box Duncan Hines vanilla cake mix"]
# ------------------------------
# ["1 large head cabbage"]
# ------------------------------
# ["6 lb. cabbage, cut in 1/4-inch pieces"]
# ------------------------------
# ["thawed frozen broccoli"]
# ------------------------------
# ["4 lb. chicken cutlets, cleaned, breaded and fried"]
# ------------------------------
# ["broccoli"]
# ------------------------------
# ["1 box white or yellow cake mix"]
# ------------------------------
# ["1 whole fryer or 2 if expecting company"]
# ------------------------------
# ["1/2 to 1 lb. cooked, seasoned bulk sausage, 1/2 to 1 lb. cooked, seasoned lean hamburger or 1/2 to 1 lb. cooked ham, chopped"]
# ------------------------------
# ["soda, juice or Kool-Aid"]
# ------------------------------
# ["crescent rolls"]
# ------------------------------
# ["4 lb. boneless beef (stew or pot roast)"]
# ------------------------------
# ["3 or 4 gal. milk (fresh cow milk)"]
# ------------------------------
# ["Keebler Club crackers"]
# ------------------------------
# ["1 yellow cake mix"]
# ------------------------------
# ["various (your choice)"]
# ------------------------------
# ["1 yellow cake mix"]
# ------------------------------
# ["any kind of juice"]
# ------------------------------
# ["1 lb. cherry tomatoes"]
# ------------------------------
# ["sliced country ham"]
# ------------------------------
# ["1 c. chocolate pieces"]
# ------------------------------
# ["1 medium roast"]
# ------------------------------
# ["1 box Duncan Hines yellow cake mix"]
# ------------------------------
# ["1 can lemonade"]
# ------------------------------
# ["bread"]
# ------------------------------
# ["Bisquick"]
# ------------------------------
# ["1 butter cake mix"]
# ------------------------------
# ["1 pkg. cake mix (any flavor)"]
# ------------------------------
# ["1 box German Chocolate Cake Mix"]
# ------------------------------
# ["comfortable chair"]
# ------------------------------
# ["baking potatoes"]
# ------------------------------
# ["equal amounts peppermint, spearmint and tansy"]
# ------------------------------
# ["family"]
# ------------------------------
# ["1 small turkey or Purdue hen (6 to 7 lb.)"]
# ------------------------------
# ["seedless grapes of any kind"]
# ------------------------------
# ["1 round steak, about 3 inches thick"]
# ------------------------------
# ["flour"]
# ------------------------------
# ["1 box Duncan Hines butter recipe cake mix (for layers)"]
# ------------------------------
# ["equal portions of beef and pork roasts (any cut) *"]
# ------------------------------
# ["1 box yellow cake mix (follow directions on box)"]
# ------------------------------
# ["collards"]
# ------------------------------
# ["1 pkg. milk chocolate morsels or almond bark"]
# ------------------------------
# ["1 pkg. Casino Monterey Jack cheese, cut into 1/4-inch slices, then cut each slice in half"]
# ------------------------------
# ["1 (15 oz.) pkg. fudge brownie mix"]
# ------------------------------
# ["hot drippings from chicken or pork chops"]
# ------------------------------
# ["large bunch red seedless grapes"]
# ------------------------------
# ["6 slices bread"]
# ------------------------------
# ...
# ["N/A"]
# ------------------------------
# ["180 grams Thick cut of filet mignon (beef fillet steak)"]
# ------------------------------
# ["1 Chicken tenders"]
# ------------------------------
# ["1 Kintoki (red) carrots"]
# ------------------------------
# ["10 gal WATER"]
# ------------------------------
# ["1 slab striploin"]
# ------------------------------
# ["1/2 pound broccoli"]
# ------------------------------
# ["1 whole boneless turkey breast with skin (about 4 lb.)"]
# ------------------------------
# ["12 egg roll skins"]
# ------------------------------
# ["Bluefish Mussels Oysters Canned Salmon Canned Sardines Mackerel Smoked Fish Clams Marlin Salmon Swordfish Tuna"]
# ------------------------------
# ["Boca burgers (vegetarian, fat free) Health Choice fat free finely grated pizza cheese mushrooms, sliced 1 & 1/2 for each burger green bell peppers, seeded and cored, sliced in strips Sourdough English Muffins I cannot believe it's not butter spray Non-stick spray or possibly broth for sauteing"]
# ------------------------------
# ["1 box chocolate cake mix"]
# ------------------------------
# ["1 fish Katsuo (this time, I used Frigate Mackerel)"]
# ------------------------------
# ["1/4 teaspoon dried thyme"]
# ------------------------------
# ["1 cup nuts pecans, walnuts, hazelnuts or almonds"]
# ------------------------------
# ["Vinegar Blackberry jam vinaigrette"]
# ------------------------------
# ["One rack of corned beef ribs 2.5 to 3 pounds"]
# ------------------------------
# ["180 ml Uncooked white rice"]
# ------------------------------
# ["Italian meatballs; Bull's Eye Barbecue Sauce"]
# ------------------------------
# ["8 well ripened bananas, mostly brown skins"]
# ------------------------------
# ["1 cup of all purpose flour,1ts spoon of baking powder, 1 / 2 ts of salt, 1 / 2 ts spoon of cinnamon, 1 / 2c of chopped nuts, 2/3 c of oil, 3/4 c of sugar, 2 eggs, 3 slices pineapple chopped, 4 large grind carrots, vanilla extract"]
# ------------------------------
# ["Porco de Vinha de Alhos - Portuguese Pork Chops"]
# ------------------------------
# ["1 (703 g) Delissio Thin Crispy Crust Pizza, Deluxe"]
# ------------------------------
# ["In response to cooking for a crowd."]
# ------------------------------
# ["1 a list of helpful hints to rescue your soup! Add ingredients carefully and taste as you adjust to get the right balance"]
# ------------------------------
# ["1 half colriflower brunch cut full mouth side, half zucchini slices, half of each red and yellow sweet peppers slices, 1 ts spoon chopped garlic, 1 tb spoon of oyster sauce, 1 teaspoon of light soy sauce, 1/2 ts of sugar, 1 / 4 ts of black pepper, 1ts spoon"]
# ------------------------------
# ["1/4 cup (60 ml) applesauce"]
# ------------------------------
# ["1 Corn on the cob"]
# ------------------------------
# ["1 tub (7 oz.) BAKER'S Dipping Chocolate, any variety, melted"]
# ------------------------------
# ["Ask your fishmonger to skin and roughly chop about 700g of salmon for you, so you end up with about 600g of skinned salmon chunks. You can also use trout or other fish in this."]
# ------------------------------
# ["The Asparagus Growers is the best source of The Farm Retail"]
# ------------------------------
# ["1 c. Moore"]
# ------------------------------
# ["3 ounces bittersweet or milk chocolate"]
# ------------------------------
# ["1 pkt Cake Mix,any kind"]
# ------------------------------
# ["hotdogs buns wax coated cardboard qt lowfat milk carton aluminum foil"]
# ------------------------------
# ["Hatch chiles"]
# ------------------------------
# ["See directions"]
# ------------------------------
# ["1 packages cheese or meat ravioli"]
# ------------------------------
# ["2 or 3 pounds fresh pork fatback, cut into pieces"]
# ------------------------------
# ["1 Fish (I have a mackerel in the picture)"]
# ------------------------------
# ["KRAFT FREE Honey Dijon Dressing"]
# ------------------------------
# ["8 Pancakes"]
# ------------------------------
# ["2 cups Non-dairy Milk (unsweetened If Possible, It Will Get Sweeter As It Reduces)"]
# ------------------------------
# ["Cake Ingredients"]
# ------------------------------
# ["1 packages rolled cinnamon buns"]
# ------------------------------
# ["1 eggs"]
# ------------------------------
# ["1 package gelatin (Your favorite flavor, red or green looks best)"]
# ------------------------------
# ["Variation continued..."]
# ------------------------------
# ["1 box Chef Boyardee cheese pizza mix"]
# ------------------------------
# ["3 loaves' worth Crusts from toast bread"]
# ------------------------------
# ["1 pkt Arab bread (pita bread) Seasonings*, to taste"]
# ------------------------------
# ["8 oz (224 grm). heavy cream or whipping cream"]
# ------------------------------
# ["1-3 pounds ricotta (whatever amount required in recipe)"]
# ------------------------------
# ["10 whole Vanilla Beans"]
# ------------------------------
# ["2 kiwis, peeled"]
# ------------------------------
# ["1-1/4 cups canned peach slices"]
# ------------------------------
# ["1 cup (8 ounces) unsalted butter"]
# ------------------------------
# ["1 Cute pieces of candy"]
# ------------------------------
# ["1 Box Pepperidge Farm pastry sheets"]
# ------------------------------
# ["aubergine lemon garlic 1-2 tsp oil optional salt"]
# ------------------------------
# ["1 lb tofu, hard, cubed assorted veggies, broccoli, carrot, mushroom, minced fine cauliflower flowerets, zucchini Sauce Mix Tamari Rice Vinegar ginger garlic pwdr 3/4 teas. garlic salt 1 teas."]
# ------------------------------
# ["Photograph by Antonis Achilleos"]
# ------------------------------
# ["1/2 kg Pork Chops"]
# ------------------------------
# ["http://brooklynkosherbaking.ebakenow.com/"]
# ------------------------------
# ["None"]
# ------------------------------
# ["13 pieces tofu that's already fried and cut in a square (make a hole on whatever side but make sure doesn't break the other sides)"]
# ------------------------------
# ["1 x See Below"]
# ------------------------------
# ["1 packages bacon"]
# ------------------------------
# ["6 oz. low-fat (1%) yogurt, favorite flavor"]
# ------------------------------
# ["16 ounce water"]
# ------------------------------
# ["1 recipe overnight refrigerator rolls (3 coffee rings)"]
# ------------------------------
# ["I normally use 1 whole celeriac to 1 head of celery."]
# ------------------------------
# ["1 each Boudain Sausage"]
# ------------------------------
# ["8 tablespoons freshly grated Parmesan cheese"]
# ------------------------------
# ["Short pastry for shells"]
# ------------------------------
# ["2 sticks unsalted butter, softened"]
# ------------------------------
# ["10 lb Turkey"]
# ------------------------------
# ["1 red, orange yellow Paprika peppers"]
# ------------------------------
# ["2 1/2 to 3 lbs. cut up frying chicken"]
# ------------------------------
# ["1 cup freshly grated Parmigiano-Reggiano cheese"]
# ------------------------------
# ["1 pkg. lime Jello, dissolved in 3/4 c. boiling water"]
# ------------------------------
# ["1 sm Trout, whole Flour Corn oil Salt & pepper, to taste Tabasco"]
# ------------------------------
# ["BAKER'S Bittersweet Chocolate"]
# ------------------------------
# ["1 pound fresh peas, shelled and rinsed"]
# ------------------------------
# ["1 chocolate layer cake (Pillsbury, Betty Crocker)"]
# ------------------------------
# ["3/4 pound haricots verts (French-style thin green beans, available at specialty produce markets) or green beans, trimmed"]
# ------------------------------
# ["5 pounds heads and bones from white-fleshed fish, like snapper, bass or cod"]
# ------------------------------
# ["8 large eggs"]
# ------------------------------
# ["1 MEAT OR FISH"]
# ------------------------------
# ["1 Ramps (or alpine leek)"]
# ------------------------------
# ["6 pigs feet, scrubbed & rinsed"]
# ------------------------------
# ["Breakfast Fun Ideas"]
# ------------------------------
# ["1 medium-sized plastic bag's worth Fresh parsley"]
# ------------------------------
# ["1 x corn tortillas refried beans nonfat cheddar cheese green tomato salsa see recipe"]
# ------------------------------
# ["2 1/2 pounds pork shoulder"]
# ------------------------------
# ["1 as much as you have Garlic"]
# ------------------------------
# ["Pumpkin slices, peeled, 1/2-inch thick Yellow onions, peeled, sliced Salt & pepper to taste Melted butter or possibly extra virgin olive oil Brown sugar"]
# ------------------------------
# ["1 1/4 lbs. live lobster"]
# ------------------------------
# ["OCHO RIOS, Jamaica -- With allspice, there has been nothing but confusion from the get-go."]
# ------------------------------
# ["5 to 7 boneless chicken breasts"]
# ------------------------------
# ["None"]
# ------------------------------
# ["2 cups raisins"]
# ------------------------------
# ["1 cup brown sugar 2 large eggs (room temp) 1 tablespoon vanilla 1 tablespoon milk 1 teaspoon baking soda 1 teaspoon baking powder 1 teaspoon salt 1 1/4 cup flour 1 cup quick oats not instant 1 cup or to taste mini semi-sweet chocolate chips or peanut butter chips"]
# ------------------------------
# ["12 large eggs"]
# ------------------------------
# ["1 as many (to taste) Apple"]
# ------------------------------
# ["Swordfish steaks Butter or possibly oil Salt and freshly grnd black pepper Lemon wedges, lemon butter, tarragon butter, or possibly parsley butter"]
# ------------------------------
# ["thin strips of venison oil salt and pepper, to your taste. brown sugar butter"]
# ------------------------------
# ["4 Tbsp. Atholl Brose per glass Whipped cream Oatmeal, fine, lightly toasted"]
# ------------------------------
# ["2 heads garlic"]
# ------------------------------
# ["Oil Broccoli Sliced scallions Chopped ginger Chopped garlic Soba (buckwheat noodles)"]
# ------------------------------
# ["1 lb oxtails"]
# ------------------------------
# ["1 corn on cob with husk"]
# ------------------------------
# ["T-bone or porterhouse steaks or sirloin or flank steak (8-10 ounces per person bone in and 6 to 8 ounces boneless)"]
# ------------------------------
# ["2 minutes to think about what your doing or that your fixing to do"]
# ------------------------------
# ["1 big onion"]
# ------------------------------
# ["1 burger and bun per person"]
# ------------------------------
# ["1 pound chestnuts, flat side cut (see Notes)"]
# ------------------------------
# ["1 quart Full Fat Yogurt (Balkan Style Is My Favourite)"]
# ------------------------------
# ["1 Banana"]
# ------------------------------
# ["8 pounds beef roast, rib-eye ribs, from standing rib roast"]
# ------------------------------
# ["Fish, about 1/2 lb. per serving Coating mix, see instructions"]
# ------------------------------
# ["1 1/2 pound beef chuck or possibly round steak, fat trimmed"]
# ------------------------------
# ["1 Quail eggs"]
# ------------------------------
# ["3 lbs. stew beef"]
# ------------------------------
# ["1 whatever amount you are going to use Tofu"]
# ------------------------------
# ["1 gallon unpasteurized apple cider, with no additives"]
# ------------------------------
# ["2 each Portobello mushrooms"]
# ------------------------------
# ["10 sausage links"]
# ------------------------------
# ["1 cauliflower, 2 eggs, one bag of cheese, pepperoni, onions, olives, and jalapenos."]
# ------------------------------
# ["2 large tomatoes"]
# ------------------------------
# ["12 slices good-quality white bread, such as brioche, pain de mie, or Pullman"]
# ------------------------------
# ["1 can Chipotles In Adobo Sauce 7 Ounces"]
# ------------------------------
# ["4 cups seeded watermelon, cut into chunks"]
# ------------------------------
# ["1 (9x13\") pan of brownies"]
# ------------------------------
# ["1 unbaked (10 inch) pie shell"]
# ------------------------------
# ["2 - 2 1/2 lbs. chicken legs or possibly thighs"]
# ------------------------------
# ["8 ounce. lasagna noodles (uncooked)"]
# ------------------------------
# ["1 leftovers Pizza cheese"]
# ------------------------------
# ["For the red curry"]
# ------------------------------
# ["2 cups sticky rice"]
# ------------------------------
# ["1 lb (1 box) elbow macaroni butter salt and pepper (to taste) 1/4 cup grated parmesan cheese 2 packages extra sharp Cracker Barrell white cheddar cheese 2 cups milk 1/2 cup bread crumbs"]
# ------------------------------
# ["See part 1"]
# ------------------------------
# ["6 ounce Orzo, or possibly mini farfalle pasta"]
# ------------------------------
# ["2 cups domestic Parmesan cheese, processed to a powder"]
# ------------------------------
# ["2 (27 ounce.) can sauerkraut"]
# ------------------------------
# ["Large, uncooked shrimp, shell on"]
# ------------------------------
# ["1 Yellow striped butterfish"]
# ------------------------------
# ["2 1/2 cup parmingiano-reggiano"]
# ------------------------------
# ["4 chicken breasts, split and boned"]
# ------------------------------
# ["Small branches from a sassafras tree"]
# ------------------------------
# ["1 baking dishes and pans"]
# ------------------------------
# ["Copyright 2001 Television Food Network, GP. All rights reserved"]
# ------------------------------
# ["2 bunches Fresh parsley"]
# ------------------------------
# ["1 cookie"]
# ------------------------------
# ["Q. What can I substitute for cane syrup"]
# ------------------------------
# ["1 (8 ounce.) box of macaroni, cooked and liquid removed"]
# ------------------------------
# ["Skin from uncooked pork shoulder roast or smoked ham"]
# ------------------------------
# ["1 Dough"]
# ------------------------------
# ["1/2 cup grated Parmesan"]
# ------------------------------
# ["1 1/4 cup raw almonds"]
# ------------------------------
# ["(A clone, from Top Secret Recipes)"]
# ------------------------------
# ["2 pounds green chili peppers dried"]
# ------------------------------
# ["1 beef"]
# ------------------------------
# ["5 pounds pork shoulder"]
# ------------------------------
# ["1 quart. strawberries"]
# ------------------------------
# ["Information Only"]
# ------------------------------
# ["Philo dough or possibly rolled crescent rolls Chicken breast (boneless and cooked) Feta cheese paprika garlic pwdr"]
# ------------------------------
# ["3/4 cup of tomato ketchup sweet kind, 1/4c of brown sugar, 1 / 4 c of water, 2tb spoon of dijon mustard, 2ts of pepper,1ts spoon of soy sauce, 1 tb spoon of steak seasoning, 1tb spoon of garlic powder and 1 tb spoon of onion powder"]
# ------------------------------
# ["About 1/2 loaf French or Italian bread, preferably a day or 2 old"]
# ------------------------------
# ["Copyright"]
# ------------------------------
# ["1 lb beets About 3/4 c. water Salt and freshly grnd black pepper to taste Preheat oven to 375 degrees."]
# ------------------------------
# ["12 lb Turkey - never frzn, not injected"]
# ------------------------------
# ["1 large coconut without any cracks and containing liquid"]
# ------------------------------
# ["2 cups pasteurized (not ultra-pasteurized) cream"]
# ------------------------------
# ["6 ounces pepperoni, thinly sliced"]
# ------------------------------
# ["1 Snicker's Bar"]
# ------------------------------
# ["4 x Idaho potatoes (10 ounce each)"]
# ------------------------------
# ["1 Pam spray, banana chips, peacans, milk, eggs, powder sugar, jiffy banana muffin mix"]
# ------------------------------
# ["unsalted butter"]
# ------------------------------
# ["a 4 to 7 pound turkey, split"]
# ------------------------------
# ["Maurin (Fast Eddy)."]
# ------------------------------
# ["1 Peaches"]
# ------------------------------
# ["Mixed fruit Peaches Plums Apricots Berries Cherries Grapes Brandy Dark rum"]
# ------------------------------
# ["2 pounds littleneck or cherrystone clams, cleaned"]
# ------------------------------
# ["Taro leaves Onion Garlic Ginger Besan Red pepper pwdr Coriander pwdr Garam masala Turmeric Salt"]
# ------------------------------
# ["bunch Onions"]
# ------------------------------
# ["1 pack of semi sweet chocolates"]
# ------------------------------
# ["1 pkg. angelhair or finely shredded cole slaw , 1 1/2 cups cooked pulled pork, 1/3 cup KC Masterpiece BBQ sauce, 1/4 cup chili sauce, 6 tblsp minced sweet onion, 1/4 cup diced tomato, 1 tblsp chopped jalapeno pepper or to taste, 1 tsp crushed red pepper flakes or to taste, 1/2 cup shredded 4 blend Mexican cheese, 6 corn taco shells ( tortillas can also be used)"]
# ------------------------------

# %% [markdown]
# Some of these recipes appear to be malformed, or would require tailored parsing. As they constitute a very low percentage of recipes, I'll exclude these.

# %%
list_sep = '", "'
df = df[df['ingredients'].str.contains(list_sep)]

# %% [markdown]
# What about the directions?

# %%
df_onedir = df[~df['directions'].str.contains(list_sep)]

print(f"Number of recipes with one direction: {len(df_onedir)}")
for index, row in df_onedir.sample(1000).iterrows():
    print(row['directions'])
    print("---"*10)
# Out:
# Number of recipes with one direction: 176520
# ["Melt butter over medium heat. Saute onion and pepper for 2-3 mins, until onion is tender. Add curry powder and crushed bouillon cube. Cook, stirring, for 1 min. Add tuna and milk. Simmer for 2-3 mins. Add cornstarch slurry and bring to a boil, stirring. Reduce heat and simmer for 3 mins. Add broccolini, spinach and lemon juice. Season. Simmer for 3 mins. Sprinkle spring onions over top. Serve."]
# ------------------------------
# ["In large mixing bowl, combine flour, sugar, baking powder, spices and salt. Thoroughly mix Hunt's sauce and soda in small bowl. Add to flour mixture. Stir in eggs, oil, nuts, raisins and fruit juice. Mix well. Pour into greased 10-inch Bundt or tube pan. Bake at 350\u00b0 for 45 to 55 minutes. Cool in pan 15 minutes before turning out on serving plate. Dust top with powdered sugar. Makes one 10-inch cake."]
# ------------------------------
# ["Place all ingredients in a pot and cook as you would plain rice."]
# ------------------------------
# ["Combine all ingredients; store in an airtight container."]
# ------------------------------
# ["Mix together all of the ingredients and pour in greased baking dish."]
# ------------------------------
# ["Melt Spread in a large nonstick skillet over medium heat and cook onion, stirring occasionally, until golden, about 10 minutes. Add vinegar and cook 1 minute. Stir in next 3 ingredients and bring to a boil. Reduce heat and simmer, stirring occasionally, until sauce is slightly thickened, about 5 minutes. Serve over sliced steak."]
# ------------------------------
# ["In a large skillet, cook bacon until crisp;drain on paper towels. Brown potatoes and onion in drippings. In a bowl, beat eggs; add milk, Worcestershire sauce, salt and pepper. Pour over potatoes; cook and stir until eggs are set. Crumble bacon and stir into eggs. Sprinkle with cheese. Meanwhile, warm tortillas according to package directions. Spoon egg mixture down center of tortillas; fold in sides of tortilla. Serve with salsa."]
# ------------------------------
# ["Preheat grill to 350\u00b0 to 400\u00b0 (medium-high) heat. Brush 1 side of each bread slice with olive oil; sprinkle with Italian seasoning, salt, and pepper. Grill bread slices, seasoned sides down, covered with grill lid, 4 to 5 minutes or until toasted."]
# ------------------------------
# ["Process in blender or food processor until smooth."]
# ------------------------------
# ["Preheat the oven to 350\u00b0. Spread the goat cheese on the focaccia. Drizzle with 4 tablespoons of the olive oil and season with salt and pepper. Put the focaccia on a baking sheet and bake until the cheese begins to melt and the bread is lightly toasted, about 10 minutes. Remove from the oven and set aside."]
# ------------------------------
# ["For hot sticks, mix butter with taco mix."]
# ------------------------------
# ["Whisk the honey and egg yolks in a small saucepan until combined and lightened in colour. Add the lemon juice and zest. Cook over low heat until it starts to thicken, stirring constantly with a wooden spoon. Add the butter and cook for another minute or so until it's thick and the butter has been incorporated. Pour it into a small jar or container with a lid and refrigerate. It'll keep for about a week in the fridge."]
# ------------------------------
# ["Mix, chill and serve."]
# ------------------------------
# ["Cream Crisco and sugar with a spoon; add eggs, then food coloring and water, then cocoa. Blend in buttermilk; add flour and salt gradually. Add vanilla and beat well with spoon. Mix vinegar and soda together and fold into mixture. Do not beat. Bake for 30 to 35 minutes in 350\u00b0 oven. Makes 2 (9-inch) layers or 9 x 13-inch sheet cake. Frost with Fluff Frosting."]
# ------------------------------
# ["Combine all ingredients and stir in mayonnaise to moisten. Chill."]
# ------------------------------
# ["Place oil, vinegar, orange rind, Dijon mustard, mustard seed, salt and pepper in food processor; process until well blended. Set aside."]
# ------------------------------
# ["Saute the mushrooms and white onions in oil for a few minutes. Add the kale and some stock, stir. When the kale and mushrooms are mostly done add the other ingredients with a little more stock. Stir, cook until done. Deglaze with a little more stock."]
# ------------------------------
# ["Mix ingredients and pour into unbaked pie shell. Cook at 350\u00b0."]
# ------------------------------
# ["Saute green pepper, onion, celery and garlic in oleo, then add 1 cup chicken broth and simmer 1 hour."]
# ------------------------------
# ["In the bowl of a food processor or blender combine, lemon juice, garlic, mustard, anchovy fillets, egg yolks, salt and pepper. Blend together and mix thoroughly. In a slow stream add avocado oil and olive oil through hole in the lid. Adding the oil slowly is key to making the dressing. This will help it emulsify and become creamy. Most food processors have an insert with a little whole. You can just add your oil there and keep the food processor on until all the oil has mixed in."]
# ------------------------------
# ["Mix coconut and pecans and press in a 9 x 13-inch pan. Prepare cake mix as directed and pour over nut mixture."]
# ------------------------------
# ["In a food processor or mixer blend all ingredients together to smooth."]
# ------------------------------
# ["*Can use 1 tablespoon pickling spice for spices listed."]
# ------------------------------
# ["Cook apples or peaches with sugar on low until there is no juice. Using biscuit dough for crust, roll out small amount, then fill with cooled fruit. Close with fork and deep fry."]
# ------------------------------
# ["Combine ketchup, horseradish, lemon juice, soy sauce, Worcestershire sauce, pepper, and hot sauce, if desired; stir well to combine."]
# ------------------------------
# ["Blend all four ingredients together with a mixer until creamy. Serve with apple wedges."]
# ------------------------------
# ["Mix all ingredients and refrigerate for at least 3 to 4 hours."]
# ------------------------------
# ["Take 1/3 cup flour from the 2 cups flour and add cold water. Make a paste. In a separate bowl, mix the remaining flour, shortening and salt together until mixture forms small peas. Add the paste and mix a little, then roll out dough. Put in pie plates."]
# ------------------------------
# ["In a medium saucepan, combine the cola, ketchup, onion, garlic powder and hot pepper sauce. Cook over medium heat until reduced by a third and thickened."]
# ------------------------------
# ["Bring cocoa, sugar and milk to a boil for 1 minute. Remove from heat and add margarine. Stir until melted. Add peanut butter. Stir until melted. Add oats and mix well. Drop by spoonfuls onto wax paper. Let cool."]
# ------------------------------
# ["Saute onions and garlic for 20 minutes on low, or until onions are translucent. Add peas, corn, green beans, tomatoes and onion/garlic mixture in a large pot, and bring to a simmer. Brown ground beef and cook white rice, when done, add to pot with the beef stock and tomato paste, sauce and simmer for 1 hour."]
# ------------------------------
# ["Heat a Dutch oven over medium-high heat. Coat pan with cooking spray. Add celery, onion, garlic, and turkey. Cook 5 minutes or until ground turkey is browned, stirring to crumble. Add 3 cups water and remaining ingredients except cheese; bring to a boil. Cover, reduce heat, and simmer 20 minutes or until vegetables are tender. Discard bay leaves. Ladle 1 1/2 cups soup into each of 6 bowls; top each serving with 1 tablespoon cheese."]
# ------------------------------
# ["Mix all ingredients together. Roll into small balls and bake at 350\u00b0 for 10 to 15 minutes."]
# ------------------------------
# ["Mix mayonnaise, sugar, salt and cocoa together and then flour, soda and baking powder alternately with water then add vanilla. Bake at 350\u00b0 for 35-40 minutes."]
# ------------------------------
# ["Cook pasta according to directions; drain and keep warm. Meanwhile, heat the oil in a nonstick saucepan over medium-low heat. Add onion and garlic; cook until onion is soft, about 5 minutes. Stir in roasted peppers and basil; cook about 1 minute longer. Add broth; simmer, uncovered, 10 minutes longer. Remove from heat and stir in half-and-half. Puree the sauce in a food processor or blender. Pour sauce over the pasta and toss to coat."]
# ------------------------------
# ["Mix all ingredients but salt, pepper and olive oil together. Marinate meat for several hours or overnight in marinade."]
# ------------------------------
# ["Combine and spread over top of meat loaf before baking."]
# ------------------------------
# ["Beat all ingredients at low speed for 7 to 10 minutes, or until icing forms peaks. Tip: Keep icing covered with a wet kitchen towel at all times. Icing can dry out quickly."]
# ------------------------------
# ["Brown ground beef. Combine all ingredients except pasta in a large deep sauce pan. Bring to a boil reduce heat to simmer and simmer for 60 minutes. Cook pasta according to pkg.. In a 13\" x 13\" x 4\" casserole dish line bottom with 1/2 sauce, then layer with 1/3 of cheese, then layer of pasta, then layer with 1/3 of cheese, Top with remaining sauce and cheese. Bake at 350 covered for 30 minutes."]
# ------------------------------
# ["Pour 1 shot of Creme De Menthe - Green into a tall glass and top with soda water."]
# ------------------------------
# ["In a 8-qt. punch bowl, combine the pineapple juice, fruit punch and cranberry juice. Slowly stir in ginger ale and ice cream. Serve immediately."]
# ------------------------------
# ["Blend sugar, flour and salt. Add to melted butter. Add lemon juice and lemon rind. Mix well. Add egg yolks and milk; stir well. Fold in egg whites. Pour into buttered custard cups. Place in pan of hot water. Bake at 350\u00b0 for 30 to 45 minutes until lightly brown on top. Remove from pan. Cool and refrigerate."]
# ------------------------------
# ["Flatten biscuits and put into a 9 x 12-inch casserole dish, covering the bottom of dish. Brown sausage until almost done. Spread on top of biscuit dough. Scramble egg until just a little bit runny; pour on top of sausage and top with cheese. Bake at 375\u00b0 for about 30 minutes, or until the crust is brown."]
# ------------------------------
# ["Steam the carrots in a saucepan for 5 to 6 minutes, until slightly tender. Saute them briefly in the butter in a medium skillet; add the sugar, nutmeg, orange juice and honey. Cook, stirring constantly, until the sugar melts and the carrots are well glazed."]
# ------------------------------
# ["Spray counter lightly with non-stick cooking spray. Roll combined rolls into a 10x14-inch rectangle. Place in a 9x13-inch sprayed pan. Cover with plastic wrap and let rise for 30 minutes. Remove wrap. Press dough down with fingers to form a dimpled surface. Brush with olive oil. Top with tomato halves and fresh rosemary. Sprinkle with sea salt. Bake at 350\u00b0F 20-30 minutes."]
# ------------------------------
# ["Cook ham hocks in Dutch oven over low to medium heat until hot. Reduce heat to low for 2 hours. Add onion, carrots and potatoes and enough water to fill pot about 3/4 full. Cook 1 hour. Add peas and cook 1/2 hour or until dry peas are done. Serve with cornbread."]
# ------------------------------
# ["Mix together and put in refrigerator for 1 hour."]
# ------------------------------
# ["Spray counter lightly with non-stick cooking spray. Flatten 1 Texas roll or 2 dinner rolls combined into a 5-inch circle. Repeat with remaining rolls. Place on large sprayed baking sheets. Cook ground beef with taco seasoning according to the directions on the packet. Mix ground beef mixture, beans and salsa together. Divide evenly between dough circles. Toss chips with enchilada sauce and spoon evenly over hamburger mixture. Top with cheese and bake at 350\u00b0F 20-25 minutes or until edges are lightly browned. Remove from oven and garnish as desired to resemble Jack-O-Lanterns."]
# ------------------------------
# ["Mix carrots, soup and cheese together. Add French fried onions on top. Bake at 350\u00b0 for 20 minutes."]
# ------------------------------
# ["Fill a standard shot glass 1/2 full of Creme de Noyaux and then layer Kahlua on top; black and red -- just like Hollyfields' ear."]
# ------------------------------
# ["Heat the oil in a wok over medium-high heat. Stir-fry the onion for 2-3 minutes until softened. Add the garlic, chilli, ginger and sugar, then cook for a further 1 minute until the mixture is fragrant and the sugar has dissolved. Add the chopped capsicum, beans and kaffir lime leaves, then stir-fry for 1-2 minutes until the vegetables are just tender. Add the cooked rice, chopped turkey, fish sauce and tamari, then stir-fry for 2-3 minutes until heated through. Stir in the basil, then serve the rice in bowls with lime wedges to squeeze."]
# ------------------------------
# ["Evenly spoon sugar into 4 small coffee cups. Evenly top with Breyers(R) Smooth & Dreamy 1/2 the Fat Creamy Vanilla Ice Cream, then pour in espresso."]
# ------------------------------
# ["Mix all the ingrediants into a blender and blend on high for two minutes."]
# ------------------------------
# ["Chop fresh garlic in a food processor. Peel fresh ginger root and mince. Mix all ingredients in a roasting pan and bake at 250* for 2 hours, stirring every 15 minutes."]
# ------------------------------
# ["Mix and cook until mixture thickens."]
# ------------------------------
# ["Preheat oven to 425\u00b0F. Prepare Brussels sprouts by cutting away tough root ends and removing any blemished outer leaves. Slice in half through the base and place in large bowl. Add shallots, garlic and mushroom caps. Prepare fennel by trimming off dried root end and slicing bulb thinly widthwise. Add to vegetables and toss with olive oil, vinegar, tarragon, and salt and pepper to taste. Place in 9 x12-inch glass or ceramic baking dish and roast uncovered 25 minutes. Stir vegetables and roast 25 minutes more. Remove from oven and serve."]
# ------------------------------
# ["Blend in mixer, blender or food processor. Add salt, pepper, hot sauce and garlic powder to taste. Fix a day ahead and keep in sealed container. Will keep for 2 to 3 weeks in refrigerator. Makes 1 1/2 pounds."]
# ------------------------------
# ["You also need 18 sticks."]
# ------------------------------
# ["Mix together butter, sugar, and egg. Thoroughly sift together flour, baking powder and salt. Add gradually to butter mixture. Blend well. Add lemon rind and juice. Blend thoroughly. Wrap in waxed paper and chill one hour or longer. Roll on lightly floured surface to 1/8 inch thickness. Cut with fancy cutters. (Work fast or dough will get sticky - if so, re-chill. Place on ungreased cookie sheets. Bake at 400 degrees about 8 minutes. Cool and decorate with milk and powdered sugar icing tinted with food coloring and with appropriate sprinkles."]
# ------------------------------
# ["Heat oil in a large Dutch oven over medium-high heat. Add onion and next 5 ingredients (onion through bay leaves); saute 2 minutes. Add water, tomatoes, and broth; bring to a boil. Add kale, rice, chickpeas, and raisins; reduce heat, and simmer 10 minutes or until thoroughly heated."]
# ------------------------------
# ["In the pitcher of your blender, combine the coconut milk, vanilla frozen yogurt, chocolate sandwich cookies and coconut flakes. Blend on high until combined, about 10 seconds or so. Pour into two glasses, top with coconut flakes and broken up chocolate sandwich cookies, and serve immediately. Enjoy!"]
# ------------------------------
# ["Mix together well and pour into unbaked pastry shell. Bake at 350 degrees for 40 minutes."]
# ------------------------------
# ["Mix all ingredients together and beat well. Bake at 350\u00b0 until done. This makes three 9-inch layers. Let completely cool before icing."]
# ------------------------------
# ["Add all ingredients according to your bread machine instructions."]
# ------------------------------
# ["Boil sugar and water for 5 minutes and add to juice and rind. Use for instant lemonade."]
# ------------------------------
# ["Take any refrigerator ready-to-bake biscuits and dip in milk. Roll in mixture of Parmesan cheese and a dash of garlic powder. Bake as directed."]
# ------------------------------
# ["Add ingredients in order suggested by your manufacturer. Select whole wheat setting."]
# ------------------------------
# ["In a large saucepan, combine the cabbage, beans, celery, carrots, zucchini, onion and tomato juice; bring to a boil. Reduce heat; cover and cook for 15 minutes or until vegetables are tender. Add the bouillon, seasoning blend, basil and rosemary; bring to a boil. Reduce heat; cover and simmer for 10 minutes."]
# ------------------------------
# ["Clean and wash the mirabelles, taking care you only use the best ones without blemishes, and put them in a glass container (so you can see how they 'ripen'). Add a stick of cinnamon, a handful of whole cloves, some green fennel seeds (if you have them), and stir two teaspoonfuls of vanilla bean paste into 1.5 pint of good quality Cuban rum with some honey according to taste. Pour the rum over the plums. close and shake well. Let this sit in a visible place in your kitchen. so you can enjoy the pre-pleasures of seeing them ripen ( 3 months, unless you're too hungry...)."]
# ------------------------------
# ["Bring all the ingredients close to the stove. Have them measured and ready to go. In a 12 inch saute pan over high heat bring the peanut oil to the smoking point. Add the zucchini and quickly brown it. Add the panch pharon to and toast it. Add the butter, almonds, and garlic. Toss and stir a couple of times. When you smell the garlic you are done. Season with salt and pepper to taste. Serve immediately."]
# ------------------------------
# ["Cut steak into 2-inch cubes. Combine oil, Worcestershire sauce, catsup, salt, marjoram, Burgundy, soy sauce, garlic, sugar, vinegar and black pepper. Marinate steak in pan at least 6 hours or overnight, turning each piece often."]
# ------------------------------
# ["Mix all ingredients, except bread crumbs, margarine and 4 cups broth. Put 2 cups bread crumbs in bottom of baking dish. Add chicken mixture. Add 2 more cups bread crumbs. Melt margarine and add 4 cups broth. Pour on top of mixture. Bake at 350\u00b0 for 30 minutes."]
# ------------------------------
# ["Simmer sauce ingredients in a small saucepan over medium heat, stirring often, until reduced to about 1 1/4 cups, 8 to 12 minutes. Let it sit overnight - as the consistency will thicken - and enjoy delicious BBQ sauce with everything and anything imaginable!"]
# ------------------------------
# ["In a Dutch oven, combine the half-and-half, eggs and sugar. Cook and stir over medium heat until mixture reaches 160\u00b0 or is thick enough to coat the back of a metal spoon. Remove from the heat; cool slightly. Stir in the remaining ingredients. Cover and refrigerate until chilled."]
# ------------------------------
# ["Mix together ingredients in the order given. Chill 1 hour before serving."]
# ------------------------------
# ["In a large saucepan, over medium heat, melt 1/2 cup of the butter. Add the oats and cook until golden, about 5 minutes. Spread on a baking sheet to cool. Using an electric mixer on high, beat the remaining butter and the sugar until light and fluffy. Reduce speed to medium and add the peanut butter and vanilla extract. Reduce to low and slowly add the flour. Stir in the oats. Cover and refrigerate for 30 minutes. Heat oven to 375\u00b0 F. Form 16 to 20 large cookies, using about 1/4 cup of dough for each. Place on parchment- or foil-lined baking sheets, 2 inches apart. Flatten slightly using the tines of a fork. Bake until golden but not quite set, about 20 minutes. Let cool on the sheets for 10 minutes. Transfer to a rack to finish cooling. Sandwich about 1/3 cup of the ice cream between 2 cookies. Serve immediately, or wrap in plastic and freeze."]
# ------------------------------
# ["Mix juice from pineapple, cherries and boil. Make it 1 cup by adding water, if needed. Add jello, cream cheese, pineapple, cherries and nuts. Mix well. Add 2 small Coca-Colas and congeal."]
# ------------------------------
# ["Mix all together and refrigerate 24 hours before serving."]
# ------------------------------
# ["Mix all ingredients together and refrigerate at least 2 hours before serving."]
# ------------------------------
# ["Mix in bowl together. Put in casserole dish. Crush up 2 C of corn flakes and sprinkle over top. Pour another 1/2 stick of melted butter over top. Bake at 350 degrees for 1 1/2 hours."]
# ------------------------------
# ["Blend first six ingredients together in food processer til consistency of thick paste. Remove to bowl; add crumbled Feta & chopped herbs, season with salt & pepper and allow several hours to overnight for flavors to fully meld."]
# ------------------------------
# ["Heat a Dutch oven or a high-sided pan. Add the oil, then the onions. Cook for 3 minutes, then add the garlic and cook another 3 minutes. Toss in the collard greens, toss and cover the pot. Let cook for another 2-3 minutes. Salt and pepper at this point, then enjoy."]
# ------------------------------
# ["Beat cream cheese until smooth, add Khaula, whip again. Add nuts & raisins, blend well. Form into ball,(or other shape- using plastic lined mold) wrap in plastic film & chill. Before serving roll in crushed nuts. (Or other garnish if using mold) Serve with plain crackers."]
# ------------------------------
# ["Mix well. Roll in 1/2-inch rolls (this makes about 5 rolls). Wrap tightly in plastic wrap. Store in refrigerator for 24 hours; place on broiler pan. Bake at 300\u00b0 for 1 1/2 hours. Cool. Keep refrigerated or frozen."]
# ------------------------------
# ["Mix dressing ingredients and add to cabbage, carrot and onion. Mix well. Cover and refrigerate at least 2 hours before serving."]
# ------------------------------
# ["Combine all ingredients, mix well. Add additional pepper if desired."]
# ------------------------------
# ["You will need a 12 x 15-inch piece of aluminum foil."]
# ------------------------------
# ["In a medium sized bowl mix all ingredients very well. Add it into your ice cream maker. Follow the manufacturer's directions for making ice cream with your ice cream maker. Mine only took 25 minutes for a soft serve consistency. Enjoy!"]
# ------------------------------
# ["Preheat oven to 350. Place chicken in bottom of pan. Pour rice over. Mix soup and milk, layer on top. Cover with tin foil, cook 1 hour."]
# ------------------------------
# ["Use a 9 x 13-inch pan."]
# ------------------------------
# ["Melt butter in a heavy saucepan over medium-low heat; add flour, whisking until smooth. Cook, whisking constantly, 1 minute. Increase heat to medium, and gradually add milk; cook, whisking constantly, until slightly thickened. Remove from heat; add cheese and remaining ingredients, stirring until cheese melts. Keep warm."]
# ------------------------------
# ["Mix all ingredients together and bake for 5 hours at 275 degrees."]
# ------------------------------
# ["You will need foil and an iron."]
# ------------------------------
# ["*Substitute 1 pound ground meat for refried beans, if desired."]
# ------------------------------
# ["Mix all ingredients well, except chipped beef. Chop it fine into small pieces. Fold in. Will shape into ball easier after being in refrigerator for awhile."]
# ------------------------------
# ["Mix all ingredients together and bake at 350 degrees for 30 minutes."]
# ------------------------------
# ["shake, strain into highball glass."]
# ------------------------------
# ["Place roast in Crock aPot. Mix water with seasoning and gravy mixes. Pour over roast. Cook on low for 5 hours or until done."]
# ------------------------------
# ["Mix all ingredients and chill."]
# ------------------------------
# ["In a small bowl, combine the sour cream, confectioners' sugar, mint and cardamom. Chill for at least 30 minutes. Just before serving, arrange star fruit, oranges and kiwi on salad plates or a serving platter; sprinkle with cranberries and dollop with cream topping."]
# ------------------------------
# ["To potatoes, add sugar, eggs, salt, margarine and vanilla flavoring.\tMix well and place in a baking dish."]
# ------------------------------
# ["Combine all ingredients in a large bowl until well mixed. Allow to sit in refrigerator for a couple of hours. The longer it sits the better."]
# ------------------------------
# ["Prepare 1 (22-ounce) bag frozen mashed potatoes according to package directions. Stir in 1 (4-ounce) container garlic-and-herbs spreadable cheese, 1/2 cup sour cream, 1/4 cup chopped fresh parsley, 1/2 teaspoon seasoned pepper, and 1/4 teaspoon salt."]
# ------------------------------
# ["Beat together cream cheese, sour cream, oregano and garlic powder. Spread evenly in a 9 or 10 inch pie plate. Spread pizza sauce over the top. Sprinkle with pepperoni, onion and green pepper. Bake at 350 degrees for 10 minutes. Top with cheese and bake for 5 minutes more until heated through. Serve with crackers, vegetables or chips."]
# ------------------------------
# ["Mix all ingredients and bake at 350\u00b0 until done."]
# ------------------------------
# ["In a bowl, combine the brown sugar, mustard, horseradish and 2 tablespoons cola; mix well. Rub over ham. Place in a 5-qt. Slow cooker; pour remaining cola over ham. Cover and cook on low for 8-10 hours or until a meat thermometer reads 140\u00b0. Yield: 15-20 servings."]
# ------------------------------
# ["In a large bowl, dissolve gelatin in boiling water. Stir in the milk, sour cream and orange zest. Fold in the whipped topping. Spoon into crust. Cover and refrigerate for at least 4 hours."]
# ------------------------------
# ["In a medium-sized mixing bowl, combine cream cheese and milk until creamy. Add more milk for a thinner dip. Using a fork, whip the anchovy paste, onion, and garlic powder into the mixture. Cover and refrigerate this dip at least one hour before serving."]
# ------------------------------
# ["Rub into ribs then cook according to your own recipe."]
# ------------------------------
# ["Core head of cabbage well. Parboil in large pot of water. Separate leaves. Remove hard vein without cutting through the leaf. Cabbage leaves should be flimsy (cooked enough) so that when filled, they do not crack."]
# ------------------------------
# ["For 3 to 12 cups cooked rice or seven 1/2 cup servings."]
# ------------------------------
# ["Arrange chicken breast halves in a 10 x 6 x 2-inch baking dish coated with cooking spray."]
# ------------------------------
# ["Brown beef on all sides in oil in skillet. Place in slow cooker. Layer onions, potatoes, carrots and lima beans over beef. Mix tomatoes and seasonings together in bowl. Pour over meat and vegetables. Cover. Cook on low 8 to 10 hours."]
# ------------------------------
# ["In a jar with tight-fitting lid, combine the first 10 ingredients; shake well. Refrigerate. Serve over salad."]
# ------------------------------
# ["Peel shrimp; devein, if desired. Stir-fry shrimp in hot peanut oil in a wok over high heat 1 minute. Add red bell pepper strips, and chopped garlic; stir-fry 2 minutes. Add snow peas; stir-fry 1 minute. Add stir-fry sauce; stir-fry 1 minute. Serve over hot cooked rice."]
# ------------------------------
# ["Also good with onions, mushrooms and white wine."]
# ------------------------------
# ["Put all ingredients in a bowl, except Reeses chips. Mix well. Spread in greased 12 X 15 pan and bake at 325\u00b0 for 20 minutes. Sprinkle Reeses chips on top."]
# ------------------------------
# ["Put cooked orzo in a bowl with the other ingredients while still warm."]
# ------------------------------
# ["Mix ingredients with tablespoon of mayonnaise (enough to coat)."]
# ------------------------------
# ["Combine butter, sugar and eggs. Then add in sour cream and vanilla. Then add in flour, powder, soda and salt. Mix in chocolate chips until well combined. Spread into greased 11 x 13 pan."]
# ------------------------------
# ["Chill liquids. Mix and serve."]
# ------------------------------
# ["Combine mayonnaise, lemon juice, garlic, and pepper and stir. Refrigerate for 30 minutes before serving to let the flavors blend."]
# ------------------------------
# ["Combine all ingredients in a large saucepan. Bring to a boil. Reduce heat; simmer 1 hour or until apples are tender, stirring occasionally."]
# ------------------------------
# ["Cream butter and sugar; add eggs, beans, milk and vanilla. Add nuts and coconut. Mix all together and pour into 3 unbaked pie shells. Bake at 300\u00b0 for 45 to 55 minutes. Can wrap and freeze."]
# ------------------------------
# ["Heat 1/4 c. oil in skillet& add onion, shallots & garlic.Cook Stirring, about 3 min.Do not brown.Add wine, tomatoes,tarragon,pepper flakes,S & P. Bring sauce to a boil.Add cream & stir.,Meanwhile boil water for pasta, add pasta & cook.Just before pasta is done add broccoli to the pasta water.When water returns to a boil drain and reserve 1/3 c. water. As the pasta & broccoli cook, prepare scallops(if large cut in half)Add remaining 1 tblspn. of oil to large skillet and add scallops.Cook briefly ,add sauce. Cook about 3 min. ,add shrimp.Cook about 1 min.Remove from heat.Drain pasta & broccoli,add to sauce,add reserved water. Sprinkle with parsley and serve."]
# ------------------------------
# ["Fill a tall glass with ice. Fill to 3/4 with lemon-lime soda. Pour in Wild Turkey whiskey and hazelnut liqueur."]
# ------------------------------
# ["In a blender, puree 2/3 cup roasted red peppers (in olive oil but drained) until smooth. With the motor running, add 1 1/2 tablespoons oil from the peppers and 1 tablespoon red wine vinegar. Season with salt and pepper. Serve with steak or chicken."]
# ------------------------------
# ["Bring water to a boil; cook shells 13 minutes. Do not overcook. Cook chicken thoroughly. Save 1 cup of chicken stock. Bring 1 cup stock to boil. Add seasoning package from stuffing mix. Simmer 5 minutes. Add bread crumbs. Cut chicken into small bite-sized pieces. Mix soup with 3 cans milk and slowly bring to a boil. Line baking pan with 1/2 cup of soup. Mix together chicken, stuffing and mayonnaise. Stuff shells with mixture. Lay out in pan and top with remaining soup. Soup will thicken and shells will finish cooking while in a 350\u00b0 oven for 35 minutes."]
# ------------------------------
# ["In a large bowl, combine dry ingredients. In another bowl, combine the eggs, milk, syrup, and oil. Stir into the dry ingredients just until moistened (batter will be thin). Pour into two greased 9-in. by 5-in. by 3-in. loaf pans. Bake at 325\u00b0 for 60-70 minutes or until a toothpick inserted near the center comes out clean. Cool for 10 minutes before removing from pans to wire racks."]
# ------------------------------
# ["Combine all ingredients and serve."]
# ------------------------------
# ["Mix all ingredients, tossing lightly, and serve on bed of lettuce."]
# ------------------------------
# ["Mix all ingredients together. Pour into crock-pot that has been sprayed with Pam. Reserve small amount of cheese for top. Cover and cook for 3 hours on low."]
# ------------------------------
# ["Toss the slaw mix with the onion slices. Combine remaining ingredients. Shake well to blend and pour over vegetables. This needs to cure at least 48 hours in the fridge before serving and it should be stirred up at least twice. Will keep 10 days in the fridge. Serves 12. Since it is mayonnaise-free, it is perfect for picnics and potlucks."]
# ------------------------------
# ["Cook, rinse, drain and cool pasta; place in bowl with other ingredients."]
# ------------------------------
# ["Mix well and bake at 350\u00b0 for 35 to 40 minutes."]
# ------------------------------
# ["In a skillet, saute celery and onion in butter until crisp-tender, about 5 minutes. Stir in apple. Cover and simmer for 3 minutes. Sprinkle with flour, curry powder, salt and pepper. Cook for 2 minutes, stirring occasionally. Serve immediately."]
# ------------------------------
# ["Divide watercress and endive among 10 salad plates. Arrange the oranges, cucumber and onion over salad greens. In a jar with a tight-fitting lid, combine dressing ingredients; shake well. Drizzle over salads."]
# ------------------------------
# ["In a small saucepan, combine shallot, vinegar, lemon juice and sugar. Stir over low heat for 2-3 mins, until sugar dissolves. Let cool then add chives. Drizzle over oysters."]
# ------------------------------
# ["Mix together and press into an aluminum foil-lined 9 x 13 x 2-inch pan."]
# ------------------------------
# ["Cook rice as directed. Add all ingredients except paprika & cheese. Mix thoroughly. Pour into well-greased shallow 3 quart baking dish. Sprinkle with paprika & cheese. Bake at 350 degrees for 30-40 minutes until bubbly."]
# ------------------------------
# ["Mix ingredients together. Bake for 25 minutes at 350\u00b0 in a greased pan."]
# ------------------------------
# ["Soap was made in the 18th century by using lye made by leaching water through ashes in an ash hopper and any fats or greases which were not used for other purposes, such as candles, cooking, etc."]
# ------------------------------
# ["Raisins and nuts can be added."]
# ------------------------------
# ["Preheat oven to 400\u00b0. Spray lite vegetable cooking oil spray over cookie sheet."]
# ------------------------------
# ["Mix together the vinegar, water, sugar and salt. Stir to dissolve sugar and salt. Add Black pepper and red pepper flakes. Stir in vegetables and beans if using. Refrigerate. Scatter parsley leaves on top. Refrigerate till serving; it will keep for several days in the refrigerator."]
# ------------------------------
# ["Place all ingredients in the work bowl of a food processor fitted with blade and process until smooth."]
# ------------------------------
# ["Mix all ingredients in blender or processor."]
# ------------------------------
# ["Preheat oven to 375\u00b0. For filling, combine 2 tablespoons of cake mix, with brown sugar, cinnamon and pecans. Set aside."]
# ------------------------------
# ["Mix with pastry blender everytime you add something else. Start with drained tomatoes, then the chopped onions, green chilies, jalapenos, Crisco, olive oil and salt."]
# ------------------------------
# ["Steam potatoes and unpeeled garlic until potatoes are fork tender, about 30 minutes. Remove potatoes to bowl and cut so that skin is in smaller pieces. Squeeze garlic out of their peels into bowl with potatoes. Add butter, half and half, yogurt and salt. Smash and mix with fork. Cover with foil until ready to eat."]
# ------------------------------
# ["Drain pineapple, then mix all ingredients together. Pour into casserole dish and freeze."]
# ------------------------------
# ["Mix all of the ingredients. Place in casserole dish and top with 1 stack of Ritz crackers (crushed). Ritz crackers mixed with one stick of melted butter. Bake at 350\u00b0 until done."]
# ------------------------------
# ["Dissolve Jell-O and marshmallows in boiling water. Let cool. Mash cottage cheese fine. Combine all ingredients. Place in a salad bowl and chill overnight."]
# ------------------------------
# ["Grease a 13 x 9 inch pan. Make a layer of blueberries. Make another layer of the crushed pineapple. Pour dry cake mix over top. Add pecans. pour melted margarine over the top. Bake at 350\u00b0 for 1 hour."]
# ------------------------------
# ["Heat oil in a medium skillet over medium heat. Cook shallots and garlic until soft, about 1 minute. Reduce heat. Cook until golden, 3 to 5 minutes. Add peppers and juice; bring to a boil. Lower heat; simmer until peppers are soft, about 5 minutes. Cool. Puree in a blender. Pour into a 9\" x 13\" baking dish. Coat eggplants with cooking spray and broil on a baking sheet until golden on both sides, about 15 minutes. Heat oven to 400\u00b0F. Mash cheese, olives, capers and 1 tablespoon of the parsley in a bowl. Place 1 tablespoon of filling at the end of each eggplant slice; roll up. Lay seam side down in dish. Bake 10 to 15 minutes. Top with remaining 1 tablespoon parsley."]
# ------------------------------
# ["Cook broccoli for 5 minutes and drain. Add remaining ingredients (except for crackers) and blend together well. Top with crushed cheese crackers. Dot with butter. Bake in baking dish 45 minutes at 350\u00b0."]
# ------------------------------
# ["Slice angel food cake and layer in a 9 x 9-inch cake pan that has been lined with wax paper."]
# ------------------------------
# ["Heat up wok or large skillet until an added drop of water sizzles. Add olive oil and shrimp; stir. Add Italian spices to taste. Cook for between five and ten minutes."]
# ------------------------------
# ["Mix ingredients and sprinkle with apple pie spice."]
# ------------------------------
# ["Mix and press in 9 x 13-inch baking dish."]
# ------------------------------
# ["Melt 2 teaspoons butter in medium skillet. Add shallot and mushrooms. Cook and stir 1 minute or until tender. Remove. Add remaining butter and oil to skillet. Add pork. Cook 8 to 10 minutes. Turn once. Sprinkle with salt and pepper. Remove and keep warm. Gradually add apple juice. Stir in mustard and cream. Bring to boil. Boil 1 to 2 minutes. Add mushroom mixture. Cook 1 minute, stirring constantly. Place pork on plate. Spoon sauce over. Garnish with thyme. Goes well with wild rice."]
# ------------------------------
# ["Cook spaghetti according to package directions; drain. Meanwhile, heat oil and butter in a large skillet. Saute onion until translucent; add ham and bacon, if using. Cook until meat is done; quickly stir in seasonings. Remove ham mixture from skillet and keep warm. Add spaghetti to skillet; tom with ham mixture. Let fry without stirring until spaghetti turns golden on bottom. Stir from bottom, mixing everything together; fry until heated through. Just before serving, reduce heat to low and pour in eggs. Stir and cook 3 to 5 minutes, until eggs are cooked. Serve with catsup, if desired."]
# ------------------------------
# ["Combine all ingredients together and add seasoning to taste."]
# ------------------------------
# ["Mix ingredients together and spread over bread. Toast at 400\u00b0."]
# ------------------------------
# ["Beat together all of the ingredients."]
# ------------------------------
# ["Process first 4 ingredients in a blender until smooth. Add ice cream, and process until blended. Garnish, if desired."]
# ------------------------------
# ["Place all ingredients in crock pot and add 1/2 cup of water, cover and cook on low heat for about 8 hours or until dinnertime."]
# ------------------------------
# ["Mix together; shape into large ball. Roll into walnuts and chill."]
# ------------------------------
# ["Mix well and put into graham cracker pie crust."]
# ------------------------------
# ["Mash butter in small bowl. Add remaining ingredients and stir until well combined."]
# ------------------------------
# ["Cook broccoli according to package and drain. Set aside. Melt margarine and stir in flour. Gradually add milk and soup, stirring over low heat. Add Cheez Whiz and stir until melted. Continue stirring over low heat until soup thickens and bubbles. Salt and pepper to taste."]
# ------------------------------
# ["You will need 1 package of skewers."]
# ------------------------------
# ["Combine all ingredients and chill before serving."]
# ------------------------------
# ["Mix all ingredients with 1 cup mayonnaise. Put in baking dish. Crumble 2 tubes Ritz crackers and mix with 2 sticks margarine that has been melted. Sprinkle top. Bake at 400\u00b0 for 20 minutes."]
# ------------------------------
# ["Melt morsels and peanut butter over low heat. Remove pan from burner. Add cereal and stir until well coated. Put 1 cup of confectioners sugar into very large Ziploc bag. Add cereal mixture. Add 1 cup of confectioners sugar. Seal bag and shake gently to coat cereal."]
# ------------------------------
# ["Pour the coffee into a mug. Stir in the coffee liqueur and tequila. Garnish with whipped topping, cinnamon, and cocoa powder."]
# ------------------------------
# ["Combine olives, capers, tomatoes, parsley and oregano. Whisk together mustard, oil, lemon juice and garlic then toss with olive mixture. Serve with bread."]
# ------------------------------
# ["throw it all in the blender. Add a little water if necessary or some juice"]
# ------------------------------
# ["Mix all ingredients and bake at 325\u00b0 for 20 to 25 minutes, using three 9-inch round pans."]
# ------------------------------
# ["Super easy. Mix all the ingredients together in a big bowl and eat right away or chill in the refrigerator for a few hours first. Keep leftovers refrigerated."]
# ------------------------------
# ["Prepare egg noodles per package directions. Combine cottage cheese, sour cream, onion, garlic, worcestershire sauce and salt. Combine cheese mixture with noodles. Pour into casserole dish. Top with shredded cheese. Cover and bake at 350 degrees for 20 minutes. Uncover and bake additional 15 minutes to brown top."]
# ------------------------------
# ["Cook chicken until almost done. Add water or orange juice. Bring to boil then simmer until almost done. Add butter. You may need a little more water. Add rice and bring to a boil. Cover and simmer until done."]
# ------------------------------
# ["Add enough boiling water to pineapple juice to make 2 cups and dissolve jello in it. Mix salt, pimento and cream cheese together and add to hot jello gradually. May soften cheese in microwave. Chill. When it begins to thicken, fold in drained pineapple, celery, 1 cup chopped nuts and whipped topping. Pour into mold or salad bowl and chill to set."]
# ------------------------------
# ["Beat first 3 ingredients at low speed with an electric mixer until well blended. Add milk and vanilla; beat at low speed until blended, and then at high speed 1 minute or until fluffy."]
# ------------------------------
# ["This is brine covering for canning beets."]
# ------------------------------
# ["Mix well and bake in 9 x 13 inch pan at 350\u00b0 for 25-30 minutes."]
# ------------------------------
# ["In bowl, combine the eggs and milk. Stir in bread crumbs, onion, parsley, salt, sage, and pepper. Add ground beef. Thoroughly mix meat and seasonings."]
# ------------------------------
# ["Cook broccoli in boiling salted water until tender; drain. Place spears crosswise in 13 x 9 x 2-inch baking dish. Melt butter in saucepan; blend in flour. Add broth all at once and cook, stirring constantly, until mixture thickens. Stir in cream, sherry, salt and dash of pepper. Pour half the sauce over broccoli. Top with chicken slices. To remaining sauce, add 1/4 cup Parmesan cheese. Pour over chicken and sprinkle with additional Parmesan cheese. Bake for about 20 minutes or until hot at 350\u00b0. Broil just until sauce is golden brown. Makes 6 to 8 servings."]
# ------------------------------
# ["You will need 48 miniature muffin cups."]
# ------------------------------
# ["Cream butter and cheese together add seasonings, add crab, spread over english muffins (can be frozen) Bake until brown or broil after thawed. 400 F."]
# ------------------------------
# ["This is a full course meal in one dish; great for a cold winter night or a full blown gospel tent meeting."]
# ------------------------------
# ["Heat butter with oil in a 12-inch heavy skillet over moderately high heat until foam subsides, then saute radishes with salt and pepper, stirring occasionally, 6 minutes. Add water and cook, covered, until crisp-tender, about 2 minutes, then cook, uncovered, stirring occasionally, until liquid is evaporated, 1 to 4 minutes. Add watercress and saute, stirring, until wilted, about 1 minute."]
# ------------------------------
# ["*Substitute Worcestershire sauce and serve with spaghetti."]
# ------------------------------
# ["Combine cream cheese, sugar and milk. Mix well. Fold in Cool Whip. Layer cake, cheese filling and pie filling in glass serving dish. Chill."]
# ------------------------------
# ["Combine first 9 ingredients in a bowl; beat at medium speed of a mixer until combined (mixture will not be smooth). Spread 2/3 cup tofu mixture evenly over 1 bread slice; top with 3 cucumber slices, 1 lettuce leaf, 2 tomato slices, and 1 bread slice. Repeat procedure with remaining ingredients."]
# ------------------------------
# ["Brown ground beef and chopped onion in a Dutch oven, stirring until beef crumbles. Drain, rinse with hot water and return to Dutch oven. Stir in corn and next 4 ingredients. Bring to a boil over medium heat, stirring occasionally. Reduce heat. Cover and simmer 20 minutes, stirring occasionally. Serve over rice. Sprinkle with hot sauce, if desired. Yield: 1 1/2 quarts."]
# ------------------------------
# ["Combine all ingredients. Bake at 350\u00b0 for about 1 hour or until done."]
# ------------------------------
# ["Mix all ingredients in a 3 1/2 quart slow cooker. Cover and cook on high heat setting 2 hours or until apples are tender. Stir."]
# ------------------------------
# ["Add all the ingredients to the blender and puree until smooth."]
# ------------------------------
# ["Butter 9 x 13-inch cake pan; spread pineapple, then cherry filling. Crumble dry cake mix over fruits. Slice oleo and lay over cake mix. Completely cover."]
# ------------------------------
# ["Brown sausage or ground chuck and drain. Cut cheese into chunks. Put all ingredients in crock-pot and let cook. Serve with tortilla chips."]
# ------------------------------
# ["For each qt jar:"]
# ------------------------------
# ["Boil potatoes until tender. Peel and dice. Mix potatoes with other ingredients. Put in a casserole dish. Top with shredded Cheddar cheese. Cook in a 350\u00b0 oven for 20 to 30 minutes."]
# ------------------------------
# ["Stir pineapple juice and pina colada mix together in a punch bowl. Stir orange juice concentrate, club soda, and lemon-lime carbonated beverage into the mixture respectfully, stirring each one in before adding the next. Float orange slices atop the punch and add enough ice to chill."]
# ------------------------------
# ["Combine all ingredients in a blender. Blend until smooth. Enjoy this smoothie as a mid-morning snack or before you work out for a boost of protein, dietary fat, and fiber."]
# ------------------------------
# ["Cook pasta, drain. Cut up crab meat, onion, celery and carrots. Add to pasta. Combine miracle whip and Italian dressing. Pour over pasta and mix."]
# ------------------------------
# ["All ingredients should be room temperature."]
# ------------------------------
# ["Combine all ingredients and set aside."]
# ------------------------------
# ["Saute the onions and 2 cloves of garlic in olive oil. In small dish combine melted butter, garlic clove and parsley Add celery to pot and saute. Then add wine and bay leaves. Cook 2 minutes. Add mussels; cook covered on high until mussels open, about 6-8 minutes. You can add a little cream at the very end and serve with the melted butter mixture."]
# ------------------------------
# ["Preheat oven to 375. Lightly grease 2 large cookie sheets. Blend butter, sugars, egg, and vanilla until fluffy (scrape bowl once if needed). Mix flour, baking soda, and salt. Add to butter mixture and mix until just combined (DO NOT OVER MIX). Turn in chocolate chips and nuts. Drop large spoonfuls (between 1/8 cup to 1/3 cup, depending on how large of cookies you want) about 2 inches apart on the prepared cookie sheets. Bake until light brown around edges, about 10-15 minutes."]
# ------------------------------
# ["Allow to simmer 45 minutes to 1 hour or until darkens in color and thicker. Add 1/2 teaspoon vanilla. Let the icing cool off the heat as the finished cake cools in the tube pan on a rack about 15 minutes. Turn the cake out onto a rack placed on a sheet of waxed paper. Slowly spoon the icing onto the warm cake. Allow the cake to cool completely before slicing."]
# ------------------------------
# ["Boil noodles saving about 1/4 pasta water -- mix undiluted chicken soup with noodles adding a little pasta water if you want a thinner consistancy."]
# ------------------------------
# ...
# ------------------------------
# ["Mix thoroughly in order given. Chill for 1 hour. Roll dough on lightly floured board and cut with your favorite cookie cutters. Bake at 375\u00b0 for 6 to 8 minutes."]
# ------------------------------
# ["Mix all the salad ingredients together."]
# ------------------------------
# ["Blend ingredients. Roll in balls. Bake at 375\u00b0 for 10 minutes or until brown."]
# ------------------------------
# ["Preheat oven to 250\u00b0. Bring all ingredients except popped corn and soda to a boil, stirring constantly. Boil without stirring for 5 minutes. Remove from heat and carefully add soda. Pour over the popped corn. Place in oven for 1 hour. Stir every 10 to 15 minutes. Yum!"]
# ------------------------------
# ["In plastic bag, combine flour, paprika and pepper. Add chicken to coat. In skillet, brown chicken in margarine. Remove from pan. In same skillet, add remaining ingredients; simmer 3 minutes. Add chicken. Simmer covered 25 minutes or until tender. Serve with rice and salad."]
# ------------------------------
# ["Mix cocoa, sugar, margarine, milk and salt in saucepan. Heat to boiling. Boil 1 1/2 minutes. Remove from heat and add all other ingredients. Mix well and drop by heaping teaspoonful onto waxed paper."]
# ------------------------------
# ["If making your own meatballs, cook in oven at 350\u00b0 until cooked through."]
# ------------------------------
# ["In a small bowl, combine the oil, vinegar, rosemary, and garlic. Place the steaks in a shallow dish. Pour the marinade over them. Refrigerate for 1 hour. Heat a skillet over medium-high heat until hot. Remove the steaks from the marinade and season with the salt and pepper. Sear for 4 minutes per side for medium rare. Let rest 3 to 4 minutes before slicing or serving. Serve with Horseradish and Chive Baked Potatoes."]
# ------------------------------
# ["Heat oil in medium skillet and add onion. Saute until golden. Stir in tomatoes and garlic. Set aside. Cook bowties in boiling water 3 minutes. Add peas and cook until pasta is tender, about 8 minutes; drain. Toss oil mixture with pasta mixture until blended. Sprinkle with pepper and grated cheese."]
# ------------------------------
# ["Mix together; roll into little balls and enjoy."]
# ------------------------------
# ["*Can also use pecans or almonds."]
# ------------------------------
# ["Yield: 6 servings"]
# ------------------------------
# ["Combine the vegetables in a large pot and add 1 1/2-quart water. Bring to a boil for 5 minutes. Pour immediately into hot jars, leaving 1-inch at the top. Add 1 teaspoon salt to each quart jar and 1/2 teaspoon salt to each pint jar. Process pints for 55 minutes and quarts for 1 hour and 25 minutes at 10 pounds pressure."]
# ------------------------------
# ["Mix together; if too thick, add a little pineapple juice. Pour into crust."]
# ------------------------------
# ["Brown meat and onions. Drain off excess grease. Add garlic powder, chilies, Lea & Perrins, tomato sauce and cheese. Cook and stir over medium heat until cheese melts. Serve hot in chafing dish. Dip with Fritos, Doritos or similar chips. Serves 12."]
# ------------------------------
# ["In a bowl, combine the yogurt, sugar, lemon juice and zest; mix well. Stir in food coloring if desired. Pour into cylinder of ice cream freezer; freeze according to manufacturer's directions. Transfer ice cream to freezer containers, allowing headspace for expansion. Freeze 2-4 hours or until firm."]
# ------------------------------
# ["Combine chocolate and water in the top of a double boiler. Cook over simmering water until smooth (about 10 minutes), stirring frequently with a whisk. Remove from heat; let stand 15 minutes. For a thicker glaze, add less water."]
# ------------------------------
# ["You will need a 13 x 9-inch pan."]
# ------------------------------
# ["Preheat oven to 357. Arrange potatoes in a glass baking dish so they lay in a single row a 15 x 10 x 2 works well. Combine all ingredients except potatoes and almonds in a small heavy saucepan over medium heat. Bring to boil stirring until sugar dissolves. Pour over the potatoes and toss to coat. Cover the dish tightly with foil. Bake potatoes for 50 minutes then uncover and check for tenderness - potatoes should be mashable. Mash the potatoes blending the sugar glaze and bake another 20 minutes uncovered. (If making ahead, stop here and cover with foil and refrigerate) Increase the oven temperature to 500 and add the almonds to the top. Bake until the almonds begin to brown, about 3 minutes."]
# ------------------------------
# ["Roast spices separately and grind in a blender, a coffee grinder or with a mortar and pestle; add grated nutmeg, if used."]
# ------------------------------
# ["Place lime sherbet in a punch bowl; slowly pour 1 bottle of lemon-lime soda over sherbet and stir gently. Fill bowl with remaining soda as drinks run out."]
# ------------------------------
# ["In small mixing bowl, whip butter. Alternately add lemon juice and sugar until smooth and creamy."]
# ------------------------------
# ["Mix first 9 ingredients gently and shape into 1-inch balls. Put raw vegetables on a greased cookie sheet and bake at 350\u00b0 until brown; turn once."]
# ------------------------------
# ["Mix the ingredients together in a small bowl and store in a tightly covered glass jar in a dark dry area of kitchen or pantry storage."]
# ------------------------------
# ["In a bowl combine all the ingredients together."]
# ------------------------------
# ["Stir 1 (8-ounce) can crushed pineapple, drained (or 1/2 cup chopped strawberries) into 2 cups slightly softened frozen yogurt. Serve with Cinnamon Waffle Crisps, if desired."]
# ------------------------------
# ["In a skillet over medium heat, cook sausage until no longer pink; drain. In a bowl, combine soup, cheese and water. Stir in Bisquick mix until blended. Add sausage. Fill greased muffin cups 3/4 full. Bake at 350\u00b0 for 20 to 25 minutes or until a toothpick comes out clean. Cool for 5 minutes before removing from pans to wire racks. Serve warm."]
# ------------------------------
# ["Mix all ingredients thoroughly and pour over greens."]
# ------------------------------
# ["Press rolls in jelly roll pan. Bake at 350\u00b0 for 10 minutes. Cool."]
# ------------------------------
# ["Shape into loaf pan and bake at 350\u00b0 for about 1 1/4 hours."]
# ------------------------------
# ["Saute onions with garlic salt in a large, heavy bottomed pan in the olive oil over medium-high heat for 10 minutes or until very soft. Add garlic and saute 2 minutes more, then add chicken and saute until chicken is no longer pink. Add broth, chiles, beans, hominy, cumin, oregano, chile powder if using and cayenne and stir to combine. Bring to a boil, then lower to simmer for 30 minutes. Turn heat down to low and add sour cream, blending well. Cook for 5 minutes more, then serve hot. Top with additional sour cream, shredded Monterey Jack cheese and crushed tortilla chips."]
# ------------------------------
# ["Spread each tortilla with 1/4 of each ingredient. Roll into a burrito and cut in half. Serve immediately or wrap in plastic wrap, place in refrigerator for later use."]
# ------------------------------
# ["*Or mix 1 teaspoon salt, a few grains of pepper and 2 teaspoons dried parsley flakes and sprinkle on all."]
# ------------------------------
# ["Cook spaghetti; put in large bowl and add all ingredients. Toss. Refrigerate overnight or all day."]
# ------------------------------
# ["Combine all in a tall glass."]
# ------------------------------
# ["Mix in saucepan the first 5 ingredients and bring to a boil. Set aside and let cool."]
# ------------------------------
# ["Brown the butter: Melt the butter in a skillet or small saucepan over medium heat. Swirl or stir the butter with a wooden spoon as it starts to foam and sputter. When the butter begins to turn golden brown and smells nutty, about 1 minute. To the brown butter, add the apples, sage leaves, salt, and pepper. Cook, stirring, until the apples are just tender, about 4 minutes. Serve with pork or chicken."]
# ------------------------------
# ["Layer cabbage and onion in large bowl. Pour sugar on top and do not stir. In a small sauce pan, combine vegetable oil, vinegar, celery seed, pepper and salt; bring to a boil. Pour hot mixture over cabbage and again, do not stir. Let stand 1 hour, then cover tightly and refrigerate overnight. Stir before serving. This keep up to 2 weeks in the refrigerator."]
# ------------------------------
# ["Pulse together the feta, basil, and peppercorns in a food processor until combined. Add the olive oil and lemon juice, alternating between each and pulsing after each addition, until the mixture is dense but spreads easily. Remove to a serving plate, garnish with lemon zest, and serve."]
# ------------------------------
# ["Combine ingredients."]
# ------------------------------
# ["Mix together. Freeze in molds."]
# ------------------------------
# ["In medium saucepan, melt peanut butter chips, butter and condensed milk. When melted, add chopped peanuts. Put mixture in a waxed paper lined 8-inch square pan. Smooth out. Let chill for 2 to 3 hours. Store refrigerated."]
# ------------------------------
# ["Preheat oven to 350. Butter a 10 x 15 pan and set aside. In medium bowl combine flour, baking powder & salt. Set aside. In large bowl beat butter, sugar & vanilla. Slowly beat in eggs. On low speed gradually add in flour mixture. Stir in toffee & pecans. Spread in pan. Bake 20-25 minutes. Let cool & cut. You can drizzle melted chocolate chips over if desired."]
# ------------------------------
# ["Mix well and serve with chips."]
# ------------------------------
# ["Blend dry cake mix, water, vanilla extract and egg. Work in nuts with your hands. Shape into 2 inch rolls. Wrap in wax paper and chill thoroughly in refrigerator or freezer."]
# ------------------------------
# ["Cream butter and sugar. Sift flour and cinnamon together and add to butter mixture. Add egg yolk. Mix well and spread mixture on a greased cookie sheet, 10 x 15-inch. Brush top with beaten egg white. Sprinkle nuts on top. Bake in 350\u00b0 oven until slightly brown, approximately 15 minutes. Remove from oven and cut into bars. Makes 4 dozen 1 x 3-inch logs."]
# ------------------------------
# ["Mix; cover 1 hour."]
# ------------------------------
# ["In a saucepan, add the chopped green chilies, onion, salt, and tomatoes. Add chopped cassava and light coconut milk. Cook until the milk has almost evaporated (cook over medium heat). Add the thick coconut milk and bring to a boil. Cook for exactly 5 minutes. Allow to cool and garnish with a few coriander leaves."]
# ------------------------------
# ["Blend all the ingredients in a food processor or high-powered blender until smooth."]
# ------------------------------
# ["Heat olive oil in a large skillet over low heat and cook garlic until softened, about 10 minutes. Add zucchini and zucchini blossoms; mix well with olive oil. Add chickpeas and stir to combine. Season with salt and stir in basil. Serve immediately."]
# ------------------------------
# ["Preheat oven to 350\u00b0. Place butter in large iron skillet. Place in oven and let melt. Then stir in brown sugar and let melt. Place 1st pie crust on top of mixture in skillet. Place sliced apples on top of crust and sprinkle with white granulated sugar and cinnamon mixture. Place second pie crust on top of apple mixture and make small slits in crust. Bake 45 minutes or until lightly browned."]
# ------------------------------
# ["Skae all ingredients in a cocktail shaker with ice, serve in a chilled glass."]
# ------------------------------
# ["Spread about 2 tablespoons spreadable cheese over each tortilla. Layer with roast beef and spinach. Remove seeds from peppers and slice into thin strips; arrange over spinach. Roll up each tortilla tightly; wrap in plastic. Refrigerate until ready to serve."]
# ------------------------------
# ["Lightly mix the shrimp, tomatoes, red onion, cucumber, and cilantro in a bowl, and pour in the Bloody Mary mix. Squeeze the limes over the mixture, add a dash of hot pepper sauce, and sprinkle with salt and pepper. Toss again, cover the bowl, and refrigerate for 3 to 4 hours, stirring occasionally."]
# ------------------------------
# ["Mix half of oil with other ingredients. Pour remaining oil in skillet. Pour cornbread mixture into hot skillet. Bake at 375\u00b0 until brown."]
# ------------------------------
# ["Combine the ricotta cheese, pudding, Cool Whip, Splenda, and vanilla extract. Stir until smooth. Sprinkle with cocoa powder. Dig in!"]
# ------------------------------
# ["Cook beef, onion, green pepper and garlic until meat is brown and onions are tender. Stir in remaining ingredients. Cover and simmer about two hours stirring often to prevent burning."]
# ------------------------------
# ["Place chicken in greased baking dish. In a small bowl, combine picante sauce, brown sugar and mustard. Pour over chicken. Bake in 400\u00b0 oven for 30 minutes. Serve over rice. 4 servings."]
# ------------------------------
# ["Combine all ingredients; stir well. Best to let it meld flavors for an hour or so before using."]
# ------------------------------
# ["Preheat oven to 450\u00b0F. Spray rimmed baking sheet with nonstick spray. Mix walnuts, panko, and all herbs in small bowl; sprinkle with salt and pepper. Brush each fish fillet with 1 tablespoon melted butter; sprinkle with salt and pepper. Place fish on prepared baking sheet. Sprinkle panko-herb mixture atop fish, dividing equally and pressing to adhere. Roast fish until just opaque in center, about 8 minutes. If crisper topping desired, preheat broiler and broil fish about 1 minute, watching carefully to prevent burning. Transfer fish to plates; garnish with lemon wedges."]
# ------------------------------
# ["Mix all ingredients and serve with sliced apples."]
# ------------------------------
# ["Combine soup, mayonnaise, egg, onion, salt and pepper and broccoli. Pour into greased casserole dish. Sprinkle cheese on top. Melt 3/4 stick of butter, mix well with stuffing mix and sprinkle on top of cheese. Bake at 350\u00b0 for 25 minutes."]
# ------------------------------
# ["Combine 4 cups shredded romaine lettuce, 12 cherry tomatoes, halved, and 1 purple onion, sliced. Drizzle with 1/2 cup fat-free French dressing; toss."]
# ------------------------------
# ["Fill a tumbler with ice. Add the Campari, orange juice and sugar and stir well to combine. Add the orange slices and serve with a straw."]
# ------------------------------
# ["Mix sour cream and salad dressing mix. Refrigerate."]
# ------------------------------
# ["Blend till smooth and serve in a Champagne glass."]
# ------------------------------
# ["Place strawberries and sugar in a bowl. toss to combine, cover and refrigerate for 1 hour. Stir vinegar through and serve in chilled glasses. Great served with fresh whipped cream."]
# ------------------------------
# ["Place on ungreased cookie sheet. Divide ingredients equally on each side. Bake in preheated 425\u00b0 oven 10 to 12 minutes or until hot and bubbly."]
# ------------------------------
# ["You will also need toothpicks for dipping."]
# ------------------------------
# ["Have crust ready to fill before starting."]
# ------------------------------
# ["Spread lobster rolls with butter on each side and toast in a pan over medium heat for 2-3 minutes per side. Line the inside of the bun with a piece of Bibb or leaf lettuce. Mix all the remaining ingredients together, salt and pepper to taste and spoon the mixture into the toasted roll."]
# ------------------------------
# ["Mix all ingredients together and serve on lettuce."]
# ------------------------------
# ["Scramble the eggs in 1 Tablespoon of oil and set aside. Heat remaining oil over medium-high heat and fry carrot, celery and onion until tender. Add the cooked rice, and fry until brown and starting to crisp in areas. Then add scrambled eggs, tamari and sesame oil and mix until well combined and heated through. Serve!"]
# ------------------------------

# %% [markdown]
# There doesn't seem to be a consistent way to decide which punctuation denotes a separate step. Given that this is only 8% of recipes, we will discard these.

# %%
df = df[df['directions'].str.contains(list_sep)]

# %%
df_onener = df[~df['NER'].str.contains(list_sep)]

print(f"Number of recipes with one NER: {len(df_onener)}")
# Out:
# Number of recipes with one NER: 2905

# %%
df = df[df['NER'].str.contains(list_sep)]

print(f"Size of cleaned dataset: {len(df)}")
# Out:
# Size of cleaned dataset: 2047615

# %% [markdown]
# ### Feature Engineering

# %%
# N Ingredients / N NER
# N Steps
# Break down by link/source
# Average length of step

# %%
# N Ingredients / N NER / N Steps

df['n_ingredients'] = df['ingredients'].apply(lambda x: len(x.split(list_sep)))
df['n_steps'] = df['directions'].apply(lambda x: len(x.split(list_sep)))
df['n_ner'] = df['NER'].apply(lambda x: len(x.split(list_sep)))

# %%
trim = 0.05

ingredients_high_cutoff = df['n_ingredients'].quantile(1 - trim)
steps_high_cutoff = df['n_steps'].quantile(1 - trim)
ner_high_cutoff = df['n_ner'].quantile(1 - trim)

ingredients_low_cutoff = df['n_ingredients'].quantile(trim)
steps_low_cutoff = df['n_steps'].quantile(trim)
ner_low_cutoff = df['n_ner'].quantile(trim)

print(f"5th percentile ingredients: {ingredients_low_cutoff}")
print(f"5th percentile steps: {steps_low_cutoff}")
print(f"5th percentile NER: {ner_low_cutoff}")

print(f"95th percentile ingredients: {ingredients_high_cutoff}")
print(f"95th percentile steps: {steps_high_cutoff}")
print(f"95th percentile NER: {ner_high_cutoff}")
# Out:
# 5th percentile ingredients: 4.0
# 5th percentile steps: 2.0
# 5th percentile NER: 3.0
# 95th percentile ingredients: 16.0
# 95th percentile steps: 17.0
# 95th percentile NER: 16.0

# %%
df = df[(df['n_ingredients'] < ingredients_high_cutoff) &
          (df['n_ingredients'] > ingredients_low_cutoff) &
          (df['n_steps'] < steps_high_cutoff) &
          (df['n_steps'] > steps_low_cutoff) &
          (df['n_ner'] < ner_high_cutoff) &
          (df['n_ner'] > ner_low_cutoff)]
print(f"Size of dataset after filtering: {len(df)}")
# Out:
# Size of dataset after filtering: 1487956

# %%
df.n_ingredients.hist()
# Out:
# <Axes: >

# %%
df['domain'] = df['link'].apply(get_domain)
df.drop('link', axis=1, inplace=True)

# %%
df.head()
# Out:
#                       title  \
# 0       No-Bake Nut Cookies
# 3             Chicken Funny
# 4      Reeses Cups(Candy)
# 5  Cheeseburger Potato Soup
# 6       Rhubarb Coffee Cake
#
#                                          ingredients  \
# 0  ["1 c. firmly packed brown sugar", "1/2 c. eva...
# 3  ["1 large whole chicken", "2 (10 1/2 oz.) cans...
# 4  ["1 c. peanut butter", "3/4 c. graham cracker ...
# 5  ["6 baking potatoes", "1 lb. of extra lean gro...
# 6  ["1 1/2 c. sugar", "1/2 c. butter", "1 egg", "...
#
#                                           directions    source  \
# 0  ["In a heavy 2-quart saucepan, mix brown sugar...  Gathered
# 3  ["Boil and debone chicken.", "Put bite size pi...  Gathered
# 4  ["Combine first four ingredients and press in ...  Gathered
# 5  ["Wash potatoes; prick several times with a fo...  Gathered
# 6  ["Cream sugar and butter.", "Add egg and beat ...  Gathered
#
#                                                  NER  n_ingredients  n_steps  \
# 0  ["brown sugar", "milk", "vanilla", "nuts", "bu...              6        6
# 3  ["chicken", "chicken gravy", "cream of mushroo...              5        6
# 4  ["peanut butter", "graham cracker crumbs", "bu...              5        3
# 5  ["baking potatoes", "extra lean ground beef", ...             10       16
# 6  ["sugar", "butter", "egg", "buttermilk", "flou...             10        6
#
#    n_ner         domain
# 0      6  cookbooks.com
# 3      4  cookbooks.com
# 4      5  cookbooks.com
# 5     10  cookbooks.com
# 6     10  cookbooks.com

# %%
df.groupby('domain')['n_steps'].mean().sort_values(ascending=False).plot(kind='bar', figsize=(12, 6), title='Average number of ingredients per source')
# Out:
# <Axes: title={'center': 'Average number of ingredients per source'}, xlabel='domain'>

# %%
cookbooks = df[df['domain'] == 'cookbooks.com']

for index, row in cookbooks.sample(10).iterrows():
    print(row['directions'])
    print("---"*10)
# Out:
# ["Mix flour, baking powder, butter and 1 tablespoon sugar.", "Add enough milk to make stiff like pie dough.", "Roll out, put peaches on dough and sprinkle with cinnamon and sugar.", "Roll, cut and put dumplings in pan and pour dressing over."]
# ------------------------------
# ["Slice and arrange layer of bananas evenly over the bottom of an ungreased 13 x 9 x 2-inch baking dish.", "Prepare lemon gelatin according to directions on package; pour over bananas.", "Chill in the refrigerator until solid (about 1 hour)."]
# ------------------------------
# ["Start heating oven to 350\u00b0.", "Sift flour, soda, baking powder and salt.", "Mix shortening and peanut butter.", "Beat in sugars and egg until very light and fluffy.", "Mix in flour mixture.", "Pinch off small pieces of dough, rolling each with palms of hands into roll 2-inches long.", "Place on ungreased cookie sheet.", "With tines of fork, press lengthwise.", "Bake 12 to 15 minutes."]
# ------------------------------
# ["Wash pickles and pack in jars.", "Mix other ingredients together.", "Pour over on pickles in jars and seal at once."]
# ------------------------------
# ["Cut the sausage into 1-inch slices; saute in a Dutch oven until fully cooked and browned; drain.", "Add sauerkraut, tomatoes with liquid, celery, onion, green pepper, brown sugar and seasonings; mix well.", "Cover and simmer for 20 to 25 minutes or until vegetables are tender.", "Remove bay leaf before serving."]
# ------------------------------
# ["Preheat oven to 375\u00b0.", "Coat a large shallow baking pan with cooking spray.", "Remove the mushroom stems and chop coarsely. Arrange the mushroom caps on pan, cavities facing up.", "Brush insides and edges with 2 tablespoons of the oil."]
# ------------------------------
# ["To melted butter, add molasses and milk; heat until warm (do not boil). Mix sugar and spices in bowl with 5 cups of the flour; use remaining flour to sprinkle on board and add to dough as needed.", "Make a hole in the center of dry mixture of ingredients; gradually add warm mixture to center.", "Add egg; mix until thick. Knead like bread dough to roll out on board.", "Use small amount of mixture rolled out desired thickness of 1/4-inch. Cut out desired size to fit pan to bake.", "Bake each layer at 325\u00b0 for 10 to 15 minutes.", "Check after 10 minutes for doneness.", "Makes 8 layers. Stack layers, spreading tops of each layer generously with apple butter. \"Ice\" sides of entire cake with apple butter. Let cake \"set\" for a few days after \"icing\" with the apple butter. It improves with age."]
# ------------------------------
# ["Dissolve jello; cool.", "Add soda.", "Chill until partially set. Drain pineapple (reserve juice).", "Fold in pineapple and sliced bananas.", "Pour into a 9 x 12-inch glass pan and set until firm."]
# ------------------------------
# ["Peel and cube eggplant.", "Cook in salted water until soft. Drain well; add bread cubes, butter, eggs, salt, pepper and all but 1/2 cup of cheese.", "Sprinkle half the fine bread crumbs over bottom of buttered baking dish.", "Add eggplant mixture.", "Cover with remaining bread crumbs and cheese.", "Cover with lid or foil and bake 30 minutes at 375\u00b0.", "Remove cover and brown for 5 minutes."]
# ------------------------------
# ["Place cucumbers in 2 gallons water and lime.", "Let set for 24 hours. Drain and rinse off cover.", "Cover with cold water and let stand 3 hours.", "Cover with vinegar and spices and let stand over night.", "Heat cucumbers, vinegar and spices to boiling.", "Simmer for 35 minutes.", "Place in clean jars and seal."]
# ------------------------------

# %%
df['avg_step_length'] = df['directions'].apply(lambda x: len(x.split()) / len(x.split(list_sep)))
df['total_step_length'] = df['directions'].apply(lambda x: len(x.split()))

# %%
df = df[
    (df['avg_step_length'] > df['avg_step_length'].quantile(trim)) & 
    (df['avg_step_length'] < df['avg_step_length'].quantile(1 - trim))
]

# %%
df = df[df['total_step_length'] < df['total_step_length'].quantile(1-trim)]

# %%
df_smol = df[~df['domain'].isin(['cookbooks.com', 'food.com'])]
df_smol.groupby('domain')['n_steps'].count().sort_values(ascending=False).plot(kind='bar', figsize=(12, 6), title='Average number of ingredients per source')
# Out:
# <Axes: title={'center': 'Average number of ingredients per source'}, xlabel='domain'>

# %%
df_smol.index.size
# Out:
# 389875

# %%
df.to_csv('./dataset/cleaned_dataset.csv', index=False)
df_smol.to_csv('./dataset/cleaned_dataset_no_top_2.csv', index=False)
