# %% [markdown]
# ## Setup

# %%
from google.colab import drive
root = '/content/drive'
drive.mount(root)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Configure Environment

# %%
# !pip install -U bitsandbytes

# !pip install -U transformers accelerate
# !pip install evaluate rouge_score
# Out:
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.46.1-py3-none-manylinux_2_24_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: torch<3,>=2.2 in /usr/local/lib/python3.11/dist-packages (from bitsandbytes) (2.6.0+cu124)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from bitsandbytes) (2.0.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (4.14.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (2025.3.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch<3,>=2.2->bitsandbytes)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch<3,>=2.2->bitsandbytes)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch<3,>=2.2->bitsandbytes)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch<3,>=2.2->bitsandbytes)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch<3,>=2.2->bitsandbytes)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch<3,>=2.2->bitsandbytes)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch<3,>=2.2->bitsandbytes)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch<3,>=2.2->bitsandbytes)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch<3,>=2.2->bitsandbytes)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch<3,>=2.2->bitsandbytes)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<3,>=2.2->bitsandbytes) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<3,>=2.2->bitsandbytes) (3.0.2)
# Downloading bitsandbytes-0.46.1-py3-none-manylinux_2_24_x86_64.whl (72.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 MB 31.0 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 103.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 85.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 61.1 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 11.2 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 38.4 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 18.5 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.8 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 72.9 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, bitsandbytes
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed bitsandbytes-0.46.1 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.54.0)
# Collecting transformers
#   Downloading transformers-4.54.1-py3-none-any.whl.metadata (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: accelerate in /usr/local/lib/python3.11/dist-packages (1.9.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.34.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from accelerate) (2.6.0+cu124)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.14.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.1.5)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.7.14)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.2)
# Downloading transformers-4.54.1-py3-none-any.whl (11.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 118.9 MB/s eta 0:00:00
# Installing collected packages: transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.54.0
#     Uninstalling transformers-4.54.0:
#       Successfully uninstalled transformers-4.54.0
# Successfully installed transformers-4.54.1
# Collecting evaluate
#   Downloading evaluate-0.4.5-py3-none-any.whl.metadata (9.5 kB)
# Collecting rouge_score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from evaluate) (4.0.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from evaluate) (2.0.2)
# Requirement already satisfied: dill in /usr/local/lib/python3.11/dist-packages (from evaluate) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from evaluate) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from evaluate) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.11/dist-packages (from evaluate) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from evaluate) (3.5.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.11/dist-packages (from evaluate) (0.70.16)
# Requirement already satisfied: fsspec>=2021.05.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from evaluate) (0.34.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from evaluate) (25.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from rouge_score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (from rouge_score) (3.9.1)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.11/dist-packages (from rouge_score) (1.17.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets>=2.0.0->evaluate) (3.18.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.0.0->evaluate) (18.1.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.0.0->evaluate) (6.0.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (3.12.14)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.14.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.7.0->evaluate) (1.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (2025.7.14)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk->rouge_score) (8.2.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk->rouge_score) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk->rouge_score) (2024.11.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->evaluate) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.20.1)
# Downloading evaluate-0.4.5-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 2.9 MB/s eta 0:00:00
# Building wheels for collected packages: rouge_score
#   Building wheel for rouge_score (setup.py) ... done
#   Created wheel for rouge_score: filename=rouge_score-0.1.2-py3-none-any.whl size=24934 sha256=4831334e482160d4cc55b8e5252b9b0591b18a10058511644b3c4b1743dc5299
#   Stored in directory: /root/.cache/pip/wheels/1e/19/43/8a442dc83660ca25e163e1bd1f89919284ab0d0c1475475148
# Successfully built rouge_score
# Installing collected packages: rouge_score, evaluate
# Successfully installed evaluate-0.4.5 rouge_score-0.1.2

# %% [markdown]
# ### Imports

# %%
# ✅ Confirm install
import torch
from transformers import (
    AutoTokenizer,
    AutoModelForCausalLM,
    BitsAndBytesConfig
)
from peft import PeftModel, PeftConfig

from datasets import load_from_disk
from huggingface_hub import login
import evaluate

import os

import pandas as pd
import re

# %% [markdown]
# ### Login to Hugging Face

# %%
os.environ['HF_TOKEN'] = '<REDACTED>'
os.environ["CUDA_LAUNCH_BLOCKING"] = "1"
os.environ['TORCH_USE_CUDA_DSA'] = "1"

login(token=os.environ["HF_TOKEN"])
# Out:
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# WARNING:huggingface_hub._login:Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.

# %% [markdown]
# ### Load Dataset

# %%
recipe_nlg_data_path = f'{root}/MyDrive/NLP-266/Project/RecipeNLG'

# %% [markdown]
# ### Globals

# %%
dataset = load_from_disk(f'file://{recipe_nlg_data_path}/numbered_recipe_nlg_dataset')

# %%
SYSTEM_PROMPT = """
You are an expert in generating recipe instructions from the recipe title and ingredient list.
""".strip()

PROMPT_HPS = {
  'do_sample': True,
  'temperature': 0.7,
  'top_p': 0.9,
  'max_new_tokens': 256,
  'stop_sequences':None,
  'repetition_penalty': 1.1,
  'use_cache': True
}

cot_prompt = """
Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?

Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
""".strip()

BATCH_SIZE = 32

# %% [markdown]
# ### Generation Helpers

# %%
number_instruction_text = "Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13])."
after_example_text = "After the following examples, provide your response."
main_instruction = "Write recipe instructions for the following recipe title and ingredient list."
use_reasoning_text = "Use the provided reasoning to inform your response."
nl = '\n'

def extract_text(text, tag):
    split_str = "Your response:"
    end = text.find(split_str)
    return text[end + len(split_str):].strip()

def form_example(row):
    direction_list = row['directions'].translate(str.maketrans('', '', '[]')).split('", "')
    directions = '\n'.join([f'[{i+1}] {direction}' for i, direction in enumerate(direction_list)])

    return f'''Recipe Title: {row['title']}
Ingredients: {row['ingredients']}
Recipe Instructions:
{directions}
'''


def form_examples(row, prompt_set, n_prompts, retrieved=False):
    # For each example_id, select from the prompt set
    if retrieved:
        example_ids = row['retrieval_neighbors'][:n_prompts] # changed
    else:
        example_ids = prompt_set.shuffle().select(range(n_prompts))['prompt_id']

    examples = prompt_set.select(example_ids)

    # For each selection
    return {"examples": ['\n'.join([form_example(row) for i, row in enumerate(examples)])]}


def form_prompt(title, ingredients, reasoning=None, examples=None, cot_prompt=None): #only
    if not cot_prompt or type(cot_prompt) != str:
      prompt = f"""{SYSTEM_PROMPT}
{main_instruction}{nl + use_reasoning_text if reasoning else ""}
{number_instruction_text}{nl + after_example_text + nl + examples if examples else ""}
Recipe Title: {title}
Ingredients: {ingredients}{nl + "Reasoning: " + reasoning if reasoning else ""}
Your response:""".strip()

    else: #only when generating reasoning
      prompt = f"""{SYSTEM_PROMPT}{nl + cot_prompt if cot_prompt else ""}
Recipe Title: {title}
Ingredients: {ingredients}
Your response:"""

    return prompt

def generate_instruction_batch(batch, model=None, tokenizer=None, cot_prompt=False, use_examples=False):
    if not cot_prompt:
      batch['reasoning'] = ["" for _ in batch['title']]
    if not use_examples:
      batch['examples'] = ["" for _ in batch['title']]

    prompts = [form_prompt(title, ingredients, reasoning, nl.join(examples), cot_prompt)
    for title, ingredients, reasoning, examples
    in zip(batch['title'], batch['ingredients'], batch['reasoning'], batch['examples'])
    ]

    print(prompts[0])

    inputs = tokenizer(
        prompts,
        return_tensors="pt",
        padding=True,
        truncation=True
    ).to(model.device)

    hps = PROMPT_HPS.copy()

    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            **hps,
            pad_token_id=tokenizer.pad_token_id
        )

    decoded = tokenizer.batch_decode(outputs, skip_special_tokens=True)

    return {'prompts': prompts, 'generated': decoded}



def generate_reason_batch(batch, model=None, tokenizer=None, cot_prompt=""): # TODO: fix the prompt comprehension
    prompts = [
        f"""{SYSTEM_PROMPT}{nl + cot_prompt if cot_prompt else ""}
Recipe Title: {title}
Ingredients: {ingredients}
Your response:"""
        for title, ingredients in zip(batch['title'], batch['ingredients'])
    ]

    print(prompts[0])

    inputs = tokenizer(
        prompts,
        return_tensors="pt",
        padding=True,
        truncation=True
    ).to(model.device)

    hps = PROMPT_HPS.copy()

    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            **hps,
            pad_token_id=tokenizer.pad_token_id
        )

    decoded = tokenizer.batch_decode(outputs, skip_special_tokens=True)
    return {'reasoning': [extract_text(decoded_example, "reasoning") for decoded_example in decoded]}

# %% [markdown]
# ### Model Config

# %%
quantization_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_use_double_quant=True,
    bnb_4bit_compute_dtype=torch.float16,
    llm_int8_enable_fp32_cpu_offload=True
)

# %%
model_id = "teknium/OpenHermes-2.5-Mistral-7B"
#model_id = "Qwen/Qwen2.5-14B-Instruct-1M" # original
#model_id = "Qwen/Qwen2.5-Coder-32B-Instruct" #even bigger (still smaller than 34B model that didn't work)

tokenizer = AutoTokenizer.from_pretrained(model_id, padding_side='left')
tokenizer.pad_token = tokenizer.eos_token
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/51.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/101 [00:00<?, ?B/s]

# %%
small_test = dataset['test']

# %%
train_ = load_from_disk(f'file://{recipe_nlg_data_path}/train_processed_1k')
print(train_)
# Out:
# Dataset({
#     features: ['title', 'ingredients', 'directions', 'source', 'NER', 'n_ingredients', 'n_steps', 'n_ner', 'domain', 'avg_step_length', 'total_step_length', 'directions_formatted', 'prompt', 'input_ids', 'labels'],
#     num_rows: 1000
# })

# %%
model = AutoModelForCausalLM.from_pretrained(
  model_id,
  return_dict=True,
  torch_dtype=torch.float16,
  device_map="auto",
  quantization_config=quantization_config
)
# Out:
# config.json:   0%|          | 0.00/624 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/4.54G [00:00<?, ?B/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.94G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/120 [00:00<?, ?B/s]

# %%
very_big_save_path = f'{recipe_nlg_data_path}/Generated_Data/32b_generated_train_reasoning'

model_very_big_ft_cot_instruction_generated = train_.map(
    generate_reason_batch,
    batched=True,
    batch_size=BATCH_SIZE,
    fn_kwargs={"cot_prompt": cot_prompt, "model": model, "tokenizer": tokenizer}
)

model_very_big_ft_cot_instruction_generated.save_to_disk(very_big_save_path)

# %%
#adapter_path_1 = f'{recipe_nlg_data_path}/qlora_1k_test_2e_1l'
adapter_path = f'{recipe_nlg_data_path}/qlora_10k_test'

#for n_layers, adapter_path in [('10', adapter_path_1), ('2', adapter_path_2)]:

config = PeftConfig.from_pretrained(adapter_path)

model_ft = PeftModel.from_pretrained(model, adapter_path)

ft_generation_save_path = f'file://{recipe_nlg_data_path}/Generated_Data/qlora_10k_test_2e_4l'

model_ft_generated = small_test.map(
  generate_instruction_batch,
  batched=True,
  batch_size=BATCH_SIZE,
  fn_kwargs={"cot_prompt": False, "model": model_ft, "tokenizer": tokenizer}
)

model_ft_generated.save_to_disk(ft_generation_save_path)

# %% [markdown]
# ### Setup Test Set for Examples

# %%
def get_retrieval_neighbors(example):
  for i, embed_example in enumerate(embed_dataset['test']):
    if example['title'] == embed_example['title'] and example['ingredients'] == embed_example['ingredients'] and example['directions'] == embed_example['directions']:
      return {"retrieval_neighbors": embed_example['retrieval_neighbors']}

embed_dataset = load_from_disk(f'file://{recipe_nlg_data_path}/test_retrieval_embeddings')
small_test = small_test.map(get_retrieval_neighbors)
# Out:
# Map:   0%|          | 0/500 [00:00<?, ? examples/s]
# Map:   0%|          | 0/500 [00:00<?, ? examples/s]

# %% [markdown]
# ### CoT Few-Shot

# %%
adapter_path = f'{recipe_nlg_data_path}/qlora_1k_test_2e_4l'
#adapter_path = f'{recipe_nlg_data_path}/qlora_1k_test_5e'

#for n_layers, adapter_path in [('10', adapter_path_1), ('2', adapter_path_2)]:

config = PeftConfig.from_pretrained(adapter_path)

model_ft = PeftModel.from_pretrained(model, adapter_path)

for shots in range(1, 4):
  for retrieval in [True, False]:

    cot_shot_generation_save_path = f'{recipe_nlg_data_path}/Generated_Data/cot_nft_shots_{shots}_retrieval_{retrieval}'

    if not os.path.exists(f'{cot_shot_generation_save_path}_reasoning'):

      shot_small_test = small_test.map(form_examples, fn_kwargs={
          "prompt_set": embed_dataset['retrieval'], "n_prompts": shots, "retrieved": retrieval})

      cot_shot_reason_generated = shot_small_test.map(
        generate_reason_batch,
        batched=True,
        batch_size=BATCH_SIZE,
        fn_kwargs={"cot_prompt": cot_prompt, "model": model, "tokenizer": tokenizer}
      )

      cot_shot_reason_generated.save_to_disk(f'file://{cot_shot_generation_save_path}_reasoning')

    else:

      cot_shot_reason_generated = load_from_disk(f'file://{cot_shot_generation_save_path}_reasoning')

    if not os.path.exists(f'{cot_shot_generation_save_path}'):

      cot_shot_instruction_generated = cot_shot_reason_generated.map(
        generate_instruction_batch,
        batched=True,
        batch_size=BATCH_SIZE,
        fn_kwargs={"cot_prompt": True, "model": model, "tokenizer": tokenizer, "use_examples": True}
      )

      cot_shot_instruction_generated.save_to_disk(f'file://{cot_shot_generation_save_path}')
# Out:
# /usr/local/lib/python3.11/dist-packages/peft/tuners/tuners_utils.py:190: UserWarning: Already found a `peft_config` attribute in the model. This will lead to having multiple adapters in the model. Make sure to know what you are doing!
#   warnings.warn(
# Map:   0%|          | 0/160 [00:00<?, ? examples/s]
# Map:   0%|          | 0/160 [00:00<?, ? examples/s]
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Spiced Chicken With Couscous Stuffing
# Ingredients: ["2/3 cup couscous", "1/4 cup chopped dried figs", "2 tbsp sliced almonds, toasted", "1 clove garlic, finely chopped", "1 tbsp chopped fresh cilantro", "1 tsp grated orange peel", "1/4 cup orange juice", "2 None Cornish game hens (1 1/2 lbs each)", "1 tsp cayenne pepper", "1 tsp ground cinnamon", "1 tsp ground cumin", "1 tsp sea salt", "4 large carrots, peeled and halved lengthwise", "4 None parsnips, peeled and halved lengthwise", "2 tbsp olive oil"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Banana Split Salad (Fat Free) Recipe
# Ingredients: ["1 c. ff plain or possibly vanilla yogurt (eliminate honey if using vanilla yogurt)", "1/2 c. crushed pineapple, liquid removed", "1 x TAB honey", "4 x bananas, peeled", "1/4 c. grape nuts", "1/2 c. crushed strawberries"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Crunchy Butter Toffee
# Ingredients: ["1 cup (225 ml) sugar", "1/2 tsp (2 ml) salt", "1/4 cup (60 ml) water", "1/2 cup (125 ml) butter", "1/4 chopped walnuts", "12 oz (336 grm) chocolate chips"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Stuffed Acorn Squash
# Ingredients: ["2 acorn squash", "1 cup walnuts, roughly chopped", "1 cup fresh cranberries", "1/3 cup brown sugar", "1/4 cup freshly squeezed orange juice", "4 tablespoons butter", "honey, optiona"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: The Parasol
# Ingredients: ["1/2 ounce fresh lemon juice", "1/2 ounce fresh lime juice", "3/4 ounce Simple Syrup", "1 ounce Pisco (South American grape-based spirit)", "2 ounces Aperol or Campari", "1 large egg white", "Ice", "4 drops of Angostura Bitters"]
# Your response:
# Saving the dataset (0/1 shards):   0%|          | 0/160 [00:00<?, ? examples/s]
# Map:   0%|          | 0/160 [00:00<?, ? examples/s]
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Use the provided reasoning to inform your response.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# After the following examples, provide your response.
# Recipe Title: Sauteed Soft-Shell Crab
# Ingredients: ["1 1/2 cups low-fat milk", "4 small soft-shell crabs, cleaned", "3/4 cup all-purpose flour", "Salt and freshly ground black pepper, to taste", "2 tablespoons olive oil", "2 tablespoons unsalted butter", "2 tablespoons chopped flat-leaf parsley", "Remoulade Sauce , for serving"]
# Recipe Instructions:
# [1] "1.
# [2] Place the milk in a shallow bowl large enough to hold the crabs in a single layer.
# [3] Add the crabs and let them soak for 1 hour.
# [4] Drain and discard the milk.
# [5] 2.
# [6] Season the flour with salt and pepper in a paper or plastic bag.
# [7] Lightly dredge each crab in the flour.
# [8] 3.
# [9] Heat the oil and butter together in a nonstick skillet over medium-high heat and saute the crabs in batches until golden, about 4 minutes per side.
# [10] Add more oil and butter to the pan if necessary.
# [11] 4.
# [12] To serve, place a crab in the center of 4 salad plates and garnish each with a sprinkle of chopped parsley and a small dollop of Remoulade Sauce."
#
# Recipe Title: Spiced Chicken With Couscous Stuffing
# Ingredients: ["2/3 cup couscous", "1/4 cup chopped dried figs", "2 tbsp sliced almonds, toasted", "1 clove garlic, finely chopped", "1 tbsp chopped fresh cilantro", "1 tsp grated orange peel", "1/4 cup orange juice", "2 None Cornish game hens (1 1/2 lbs each)", "1 tsp cayenne pepper", "1 tsp ground cinnamon", "1 tsp ground cumin", "1 tsp sea salt", "4 large carrots, peeled and halved lengthwise", "4 None parsnips, peeled and halved lengthwise", "2 tbsp olive oil"]
# Reasoning: First, gather all the necessary ingredients: 2/3 cup couscous, 1/4 cup chopped dried figs, 2 tbsp sliced almonds, toasted, 1 clove garlic, finely chopped, 1 tbsp chopped fresh cilantro, 1 tsp grated orange peel, 1/4 cup orange juice, 2 Cornish game hens, 1 tsp cayenne pepper, 1 tsp ground cinnamon, 1 tsp ground cumin, 1 tsp sea salt, 4 large carrots, peeled and halved lengthwise, 4 parsnips, peeled and halved lengthwise, and 2 tbsp olive oil.
# Preheat the oven to 400 degrees Fahrenheit.
# Cook the couscous according to package directions, and fluff with a fork when it's finished. Stir in the chopped dried figs, sliced almonds, finely chopped garlic, chopped fresh cilantro, grated orange peel, and orange juice. Set aside.
# Rub the Cornish game hens with olive oil and sprinkle them generously
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Use the provided reasoning to inform your response.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# After the following examples, provide your response.
# Recipe Title: Wild Rice Dressing
# Ingredients: ["1 32-ounce container low-sodium chicken broth", "1 cup wild rice", "1 1/4 brown rice", "1 stick unsalted butter, plus more for the dish", "1 small yellow onion, finely chopped", "3 stalks celery, finely chopped", "1 cup fresh flat-leaf parsley leaves, finely chopped", "1/4 cup fresh sage, finely chopped", "1 cup pecans, finely chopped", "1 cup dried apricots or cranberries, roughly chopped", "1 teaspoon kosher salt", "1/2 teaspoon black pepper"]
# Recipe Instructions:
# [1] "Heat oven to 350\u00b0 F.
# [2] In a pot, over medium-high heat, bring the broth and 2 cups water to a boil. Add the wild rice and brown rice, reduce heat to low, and cover. Simmer until tender, about 45 minutes.
# [3] Melt the butter in a large skillet over medium-low heat. Add the onion and celery and cook for 10 minutes. Add the cooked rice, parsley, sage, pecans, apricots or cranberries, salt, and pepper and toss. Transfer to a buttered casserole. Cover and bake for 25 minutes.
# [4] Assemble the dressing but do not bake it. Cover and refrigerate for up to 24 hours. Bake as directed, adding 10 minutes to the baking time."
#
# Recipe Title: Banana Split Salad (Fat Free) Recipe
# Ingredients: ["1 c. ff plain or possibly vanilla yogurt (eliminate honey if using vanilla yogurt)", "1/2 c. crushed pineapple, liquid removed", "1 x TAB honey", "4 x bananas, peeled", "1/4 c. grape nuts", "1/2 c. crushed strawberries"]
# Reasoning: First, we need to gather all of our ingredients. This includes the fat-free yogurt, crushed pineapple, honey, bananas, grape nuts, and crushed strawberries.
# Next, we will drain the liquid from the canned pineapple so that we don't have too much extra liquid in our salad.
# We will then mix together the yogurt, honey, and drained pineapple in a large bowl until well combined.
# While waiting for the mixture to set, we should slice the bananas into rounds.
# After that, we will add the sliced bananas to the yogurt mixture and gently fold them in.
# Then, we will sprinkle the grape nuts on top of the mixture and chill it in the refrigerator for at least an hour.
# Finally, just before serving, we will spoon the crushed strawberries over the top of the chilled salad.
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Use the provided reasoning to inform your response.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# After the following examples, provide your response.
# Recipe Title: Family-Style Parmesan Chili
# Ingredients: ["1-1/2 lb. (675 g) extra-lean ground beef", "1 green pepper, chopped", "1 onion, chopped King Sooper's 1 lb For $0.99 thru 02/09", "1 can (14 fl oz/398 mL) no-salt-added red kidney beans, rinsed", "1 can (14 fl oz/398 mL) no-salt-added diced tomatoes, undrained", "1 cup water", "1 tsp. chili powder", "1 tsp. ground cumin", "1/2 cup Kraft 100% Parmesan Light Grated Cheese, divided"]
# Recipe Instructions:
# [1] "Brown meat in large skillet; drain.
# [2] Add peppers and onions; cook 5 min., stirring frequently.
# [3] Add beans, tomatoes, water, seasonings and 1/4 cup cheese; stir.
# [4] Cover; simmer 45 min., stirring occasionally.
# [5] Serve topped with remaining cheese."
#
# Recipe Title: Crunchy Butter Toffee
# Ingredients: ["1 cup (225 ml) sugar", "1/2 tsp (2 ml) salt", "1/4 cup (60 ml) water", "1/2 cup (125 ml) butter", "1/4 chopped walnuts", "12 oz (336 grm) chocolate chips"]
# Reasoning: Firstly, we need to prepare the toffee sauce. To do so, mix 1 cup of sugar, 1/2 tsp of salt, and 1/4 cup of water in a pot over medium heat. Stir until the sugar has completely dissolved. Then let it boil for about 8-10 minutes without stirring until it reaches a golden caramel color. After that, remove from heat and add 1/2 cup of butter. Be cautious as the mixture may splatter.
# Next, we'll prepare the crust. Take a baking tray or dish and spread the toffee sauce evenly on the bottom. Sprinkle the chopped walnuts on top of the sauce. Melt the chocolate chips in a double boiler or microwave and pour it over the walnuts. Spread the melted chocolate evenly across the walnuts. Allow it to cool and harden at room temperature for about 1 hour. Once set, cut into squares or bars and serve.
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Use the provided reasoning to inform your response.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# After the following examples, provide your response.
# Recipe Title: Almond Cream
# Ingredients: ["7/8 cup almonds toasted and finely ground", "1 1/2 cups sugar", "7 3/4 tablespoons butter", "4 eggs", "9/16 cup cocoa bittersweet"]
# Recipe Instructions:
# [1] "Grind the almonds and the sugar in the food processor into a flour.
# [2] Melt the butter over very low heat with the chocolate and add to the almond and sugar mixture.
# [3] Add the eggs, one at a time.
# [4] Place the mixture on the stove and cook for approximately 10 to 15 minutes on very low heat, stirring often.
# [5] Refrigerate the cream (at first it will seem quite \"liquid\", but then it will thicken).
# [6] Serve."
#
# Recipe Title: Stuffed Acorn Squash
# Ingredients: ["2 acorn squash", "1 cup walnuts, roughly chopped", "1 cup fresh cranberries", "1/3 cup brown sugar", "1/4 cup freshly squeezed orange juice", "4 tablespoons butter", "honey, optiona"]
# Reasoning: To prepare the stuffed acorn squash, we'll start with preparing the filling. First, we need to chop the walnuts. Then, wash the cranberries and chop them into halves or quarters depending on their size. Next, we mix the chopped walnuts and cranberries together in a bowl. In a separate saucepan, melt 2 tablespoons of butter over medium heat. Add the brown sugar and stir until it is completely dissolved. Pour the mixture into the bowl with the nuts and berries, and mix well. Set aside.
#
# Next, we'll prepare the acorn squash. Cut the acorn squash in half lengthwise, and scoop out the seeds using a spoon. Season the inside of the squash halves with salt and pepper to taste. Place the squash halves cut side down in a baking dish, add water to the dish about 1/4 inch deep, and cover with foil. Bake at 375 degrees Fahrenheit for approximately 30 minutes, until the squash is tender when poked with a fork.
#
# While the squash is roasting, we can prepare the optional honey glaze. In a
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Use the provided reasoning to inform your response.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# After the following examples, provide your response.
# Recipe Title: Risoni With Roast Tomato And Olive Sauce
# Ingredients: ["9/16 pound risoni", "1 jar roasted tomatoes", "1 jar black olives", "olive oil", "tomato puree", "2 teaspoons penne all'arrabiata\" spice", "1 teaspoon oregano", "1 pinch salt", "1 cube sugar"]
# Recipe Instructions:
# [1] "Cook the risoni in salted boiling water.
# [2] Meanwhile, prepare the sauce.
# [3] In a pan, heat a tablespoon of oil and add the arrabiata spice mix.
# [4] Add half a glass of water, mix.
# [5] When the water comes to a boil, turn down the heat and add the tomato puree, sugar and oregano. Mix.
# [6] Drain the jars of the oven roasted tomatoes and black olives and pour into the sauce.
# [7] Serve on the risoni."
#
# Recipe Title: The Parasol
# Ingredients: ["1/2 ounce fresh lemon juice", "1/2 ounce fresh lime juice", "3/4 ounce Simple Syrup", "1 ounce Pisco (South American grape-based spirit)", "2 ounces Aperol or Campari", "1 large egg white", "Ice", "4 drops of Angostura Bitters"]
# Reasoning: To make "The Parasol" cocktail, follow these steps:
#
# 1. Begin by preparing the Simple Syrup if you haven't made it already. In a small saucepan, combine equal parts water and sugar over medium heat. Stir until the sugar dissolves completely, then remove from heat and let cool. This can be stored in the fridge for up to two weeks.
#
# 2. Next, prepare your ingredients. Squeeze half an orange for the fresh lemon juice and half a lime for the fresh lime juice.
#
# 3. Gather the remaining ingredients: 3/4 ounce of Simple Syrup, 1 ounce of Pisco, 2 ounces of Aperol or Campari, 1 large egg white, ice, and 4 drops of Angostura Bitters.
#
# 4. Fill a shaker with ice.
#
# 5. Crack open an egg and separate the yolk from the white. Pour the egg white into the shaker with ice.
#
# 6. Add the lemon juice, lime juice, Simple Syrup, Pisco, and Aperol or Campari to the shaker.
#
# 7. Secure the
# Your response:
# Saving the dataset (0/1 shards):   0%|          | 0/160 [00:00<?, ? examples/s]
# Map:   0%|          | 0/160 [00:00<?, ? examples/s]
# Map:   0%|          | 0/160 [00:00<?, ? examples/s]
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Spiced Chicken With Couscous Stuffing
# Ingredients: ["2/3 cup couscous", "1/4 cup chopped dried figs", "2 tbsp sliced almonds, toasted", "1 clove garlic, finely chopped", "1 tbsp chopped fresh cilantro", "1 tsp grated orange peel", "1/4 cup orange juice", "2 None Cornish game hens (1 1/2 lbs each)", "1 tsp cayenne pepper", "1 tsp ground cinnamon", "1 tsp ground cumin", "1 tsp sea salt", "4 large carrots, peeled and halved lengthwise", "4 None parsnips, peeled and halved lengthwise", "2 tbsp olive oil"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Banana Split Salad (Fat Free) Recipe
# Ingredients: ["1 c. ff plain or possibly vanilla yogurt (eliminate honey if using vanilla yogurt)", "1/2 c. crushed pineapple, liquid removed", "1 x TAB honey", "4 x bananas, peeled", "1/4 c. grape nuts", "1/2 c. crushed strawberries"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Crunchy Butter Toffee
# Ingredients: ["1 cup (225 ml) sugar", "1/2 tsp (2 ml) salt", "1/4 cup (60 ml) water", "1/2 cup (125 ml) butter", "1/4 chopped walnuts", "12 oz (336 grm) chocolate chips"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Stuffed Acorn Squash
# Ingredients: ["2 acorn squash", "1 cup walnuts, roughly chopped", "1 cup fresh cranberries", "1/3 cup brown sugar", "1/4 cup freshly squeezed orange juice", "4 tablespoons butter", "honey, optiona"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: The Parasol
# Ingredients: ["1/2 ounce fresh lemon juice", "1/2 ounce fresh lime juice", "3/4 ounce Simple Syrup", "1 ounce Pisco (South American grape-based spirit)", "2 ounces Aperol or Campari", "1 large egg white", "Ice", "4 drops of Angostura Bitters"]
# Your response:
# Saving the dataset (0/1 shards):   0%|          | 0/160 [00:00<?, ? examples/s]
# Map:   0%|          | 0/160 [00:00<?, ? examples/s]
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Use the provided reasoning to inform your response.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# After the following examples, provide your response.
# Recipe Title: Chicken And Vegetable Stir-Fry
# Ingredients: ["1 clove garlic, crushed", "1 tsp ground ginger", "1 tsp ground cumin", "2 None skinless chicken breasts, cubed", "2 tbsp olive oil", "1 None red onion, cut into wedges", "2 cups baby carrots, trimmed, sliced", "1 None zucchini, sliced", "1 cup apple juice or chicken stock", "1 None lemon, grated zest and juice", "1/4 cup cilantro leaves, plus extra, for garnish", "None None prepared couscous, to serve"]
# Recipe Instructions:
# [1] "In a small bowl, combine garlic, ginger and cumin and season with salt and pepper. Add chicken and toss well to coat.
# [2] Heat oil in a large deep pan on high. Saute onion for 1-2 mins, until tender. Stir in chicken and cook for 3-4 mins, until browned. Add carrots and zucchini. Reduce heat to medium and cook, stirring, for 3-4 mins, until vegetables begin to soften.
# [3] Pour in apple juice or stock and add lemon zest and juice. Simmer for 10-12 mins, until reduced by half.
# [4] Stir in the cilantro leaves. Serve with couscous and extra cilantro."
#
# Recipe Title: Couscous with Apricots
# Ingredients: ["1 1/2 cups couscous", "2 cups hot chicken stock", "10 dried apricots, chopped", "2 scallions, sliced thin, green parts only", "1 orange, juiced", "2 tablespoons extra-virgin olive oil", "Kosher salt and freshly ground black pepper", "2 tablespoons chopped fresh parsley leaves, for garnish"]
# Recipe Instructions:
# [1] "Put the couscous in a medium bowl; pour the hot stock over it and stir to combine.
# [2] Cover and let sit for 10 to 15 minutes.
# [3] Uncover and fluff with a fork.
# [4] Add the apricots, scallions, and orange juice; drizzle with olive oil and season with salt and pepper.
# [5] Toss gently to combine.
# [6] Garnish with chopped parsley."
#
# Recipe Title: Spiced Chicken With Couscous Stuffing
# Ingredients: ["2/3 cup couscous", "1/4 cup chopped dried figs", "2 tbsp sliced almonds, toasted", "1 clove garlic, finely chopped", "1 tbsp chopped fresh cilantro", "1 tsp grated orange peel", "1/4 cup orange juice", "2 None Cornish game hens (1 1/2 lbs each)", "1 tsp cayenne pepper", "1 tsp ground cinnamon", "1 tsp ground cumin", "1 tsp sea salt", "4 large carrots, peeled and halved lengthwise", "4 None parsnips, peeled and halved lengthwise", "2 tbsp olive oil"]
# Reasoning: First, preheat oven to 400°F.
# Next, prepare the stuffing by combining the couscous, chopped dried figs, sliced almonds, garlic, cilantro, orange peel, and orange juice in a bowl. Mix well and set aside.
# Then, mix together the cayenne pepper, ground cinnamon, ground cumin, and sea salt in a separate bowl.
# Now, season the chicken with the spice mixture, making sure to coat them evenly.
# After that, stuff the chicken with the couscous mixture, pushing it gently into the cavities.
# Place the chicken on a baking sheet lined with parchment paper.
# Slice the carrots and parsnips into bite-sized pieces and arrange them around the chicken on the baking sheet.
# Drizzle the vegetables and chicken with olive oil and season with salt and pepper.
# Bake for 45 minutes or until the chicken is cooked through and the vegetables are tender.
# Serve hot and enjoy your delicious Spiced Chicken With Couscous Stuffing!
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Use the provided reasoning to inform your response.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# After the following examples, provide your response.
# Recipe Title: apple fruit salad
# Ingredients: ["3 apples", "1/4 lb seedless grapes", "1 banana", "8 oz pineapple chunks canned in juice", "1/4 cup chopped walnuts", "1 tsp honey", "1 1/2 cup low-fat vanilla yogurt"]
# Recipe Instructions:
# [1] "in a small bowl, whisk together honey and yogurt.
# [2] Place rest of ingredients in large bowl, pour yogurt.
# [3] mixture over all, toss well to mix.
# [4] Serve immediately or cover and refrigerate for 20 minutes."
#
# Recipe Title: Fruit Salad
# Ingredients: ["1 container (12 oz.) Cool Whip", "1 container (12 oz.) sour cream", "2 cans fruit cocktail", "1 can (sm.) pineapple (crushed)", "1 pkg. walnuts (optional)", "3 to 4 bananas", "Strawberries", "Raspberries", "Blueberries", "1 can mandarin oranges"]
# Recipe Instructions:
# [1] "Drain all juice from canned fruits.
# [2] Pour into large bowl.
# [3] Add any fresh fruits of your choice.
# [4] Add walnuts.
# [5] Add sour cream and Cool Whip, stir well so that the sour cream and Cool Whip get well mixed."
#
# Recipe Title: Banana Split Salad (Fat Free) Recipe
# Ingredients: ["1 c. ff plain or possibly vanilla yogurt (eliminate honey if using vanilla yogurt)", "1/2 c. crushed pineapple, liquid removed", "1 x TAB honey", "4 x bananas, peeled", "1/4 c. grape nuts", "1/2 c. crushed strawberries"]
# Reasoning: First, we need to gather all the necessary ingredients. We will require:
# - 1 cup of fat free plain or vanilla yogurt (if using vanilla yogurt, omit honey)
# - 1/2 cup of crushed pineapple with the liquid removed
# - 1 tablespoon of honey
# - 4 bananas, peeled
# - 1/4 cup of grape nuts
# - 1/2 cup of crushed strawberries
#
# The order of operations should start with preparing the fruit:
# 1. Peel the bananas and slice them into rounds or small pieces. This step can take about 5 minutes.
# 2. Crush the strawberries until they reach a chunky consistency. This step may also take about 5 minutes.
# 3. Drain the liquid from the canned crushed pineapple, as it is not required in the recipe. This step will take less than 1 minute.
#
# Next, we move on to combining the ingredients:
# 4. In a large bowl, mix together the yogurt and honey until well combined. This step should take about 2 minutes.
# 5. Add the crushed pineapple, sliced bananas, gr
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Use the provided reasoning to inform your response.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# After the following examples, provide your response.
# Recipe Title: Toffee Crunch Cookies
# Ingredients: ["1 cup (2 sticks) butter", "1 cup light brown sugar", "1 cup white sugar", "1 teaspoon vanilla extract", "2 eggs", "2 cups all-purpose flour", "1/4 teaspoon salt", "1/4 teaspoon baking soda", "1 (10-ounce) bag toffee candy bits", "1 cup oatmeal", "1 cup sweetened flake coconut", "1 cup chopped whole, skinned almonds"]
# Recipe Instructions:
# [1] "Preheat oven to 350 degrees F.
# [2] Cream together the butter, sugar and vanilla.
# [3] Beat the eggs slightly; then add to the butter mixture and mix well.
# [4] Sift flour, salt and baking soda; then add slowly to the moist ingredients and mix thoroughly.
# [5] Mix in the toffee bits, oatmeal, coconut and nuts.
# [6] Drop dough by the teaspoonful onto an ungreased baking sheet and bake for 15 minutes."
#
# Recipe Title: Toffee Crunch Dessert
# Ingredients: ["1 1/2 cups (about 12) finely crushed Buttery Toffee Cookies", "1/4 cup Land O Lakes Butter, melted", "1 1/2 cups Land O Lakes Heavy Whipping Cream", "2/3 cup powdered sugar", "1/3 cup unsweetened cocoa", "3/4 teaspoon vanilla", "6 cups vanilla ice cream, softened", "Unsweetened cocoa, if desired"]
# Recipe Instructions:
# [1] "Prepare Buttery Toffee Cookies as directed.
# [2] Line inside of 9-inch square pan with plastic food wrap, extending wrap over edges of pan.
# [3] Combine all crust ingredients in bowl.
# [4] Press onto bottom of prepared pan.
# [5] Combine all mousse ingredients in bowl.
# [6] Beat at high speed, scraping bowl often, until stiff peaks form.
# [7] Cover; refrigerate.
# [8] Spread 3 cups ice cream over crust.
# [9] Spread half of mousse over ice cream.
# [10] Freeze 20-30 minutes or until set.
# [11] Spread remaining ice cream over mousse.
# [12] Top with remaining mousse.
# [13] Cover; freeze 4 hours or until set.
# [14] Remove dessert from pan.
# [15] Cut into individual servings; sprinkle each with unsweetened cocoa, if desired.
# [16] Store in freezer."
#
# Recipe Title: Crunchy Butter Toffee
# Ingredients: ["1 cup (225 ml) sugar", "1/2 tsp (2 ml) salt", "1/4 cup (60 ml) water", "1/2 cup (125 ml) butter", "1/4 chopped walnuts", "12 oz (336 grm) chocolate chips"]
# Reasoning: Firstly, we need to prepare the toffee mixture. In a saucepan, combine the sugar, salt, and water. Heat on medium-high heat until it reaches a boil. Once boiling, reduce the heat to low and let it simmer for about 10 minutes, stirring occasionally, until it turns golden brown. Remove from heat and add the butter, stirring until melted.
# Next, we can start working on the crust. Preheat the oven to 375 degrees Fahrenheit (190 degrees Celsius). Grease a baking dish with butter.
# Then, sprinkle the chopped walnuts evenly over the bottom of the dish.
# After that, pour the melted toffee mixture over the walnuts and spread it out evenly.
# Lastly, sprinkle the chocolate chips evenly over the toffee layer.
# Place the dish in the preheated oven and bake for 12-15 minutes or until the chocolate chips have melted and are bubbling.
# Once finished, remove from the oven and let cool completely before cutting into squares and serving.
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Use the provided reasoning to inform your response.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# After the following examples, provide your response.
# Recipe Title: Autumn Stuffed Acorn Squash
# Ingredients: ["2 acorn squash, halved and seeded", "1 1/2 teaspoons dark brown sugar", "1/4 teaspoon ground cinnamon", "salt and ground black pepper to taste", "1 tablespoon butter, cut in small pieces", "1 (16 ounce) package maple-flavored breakfast sausage", "1 cup cooked wild rice", "1/2 cup dried cranberries", "1/4 cup chicken stock"]
# Recipe Instructions:
# [1] "Preheat oven to 350 degrees F (175 degrees C).
# [2] Arrange squash halves, cut-side up, in a roasting pan.
# [3] Run a fork through the meat of each half, creating grooves.
# [4] Sprinkle with brown sugar, cinnamon, salt, and pepper; dot with butter pieces.
# [5] Bake in the preheated oven until meat is tender enough to puncture with a fork, 30 to 40 minutes.
# [6] Heat a large skillet over medium-high heat.
# [7] Cook and stir sausage in the hot skillet until browned and crumbly, 5 to 7 minutes; drain and discard grease.
# [8] Add wild rice, cranberries, and chicken stock; cook and stir until rice and cranberries have absorbed the chicken stock, about 5 minutes.
# [9] Spoon the sausage filling into each squash half.
# [10] Return stuffed squash to oven and bake until flavors have blended, 5 to 10 minutes."
#
# Recipe Title: Acorn Squash With Peaches
# Ingredients: ["2 small acorn squash", "1/4 teaspoon salt", "1/8 teaspoon pepper", "1-1/4 cups frozen unsweetened sliced peaches, thawed", "2 tablespoons brown sugar", "1 teaspoon lemon juice", "4 teaspoons butter", "1 tablespoon minced fresh parsley, optional"]
# Recipe Instructions:
# [1] "Cut squash in half; remove seeds. Place cut side up in a 13-in. x 9-in. baking dish coated with cooking spray. Sprinkle with salt and pepper.
# [2] Place the peaches, brown sugar and lemon juice in a food processor. Cover and process until blended. Spoon over squash; dot with butter.
# [3] Cover and bake at 350\u00b0 for 55-65 minutes or until tender. Sprinkle with parsley if desired."
#
# Recipe Title: Stuffed Acorn Squash
# Ingredients: ["2 acorn squash", "1 cup walnuts, roughly chopped", "1 cup fresh cranberries", "1/3 cup brown sugar", "1/4 cup freshly squeezed orange juice", "4 tablespoons butter", "honey, optiona"]
# Reasoning: First, we need to decide which ingredients will be used to stuff the acorn squash. In this case, we have walnuts, cranberries, brown sugar, orange juice, and optional honey. We also need to consider whether any of these ingredients require preparation before being added to the squash.
# For the walnuts, they can be left as is since they are already roughly chopped. For the cranberries, they should be washed and then chopped if desired. The brown sugar can be measured out and set aside. The orange juice needs to be freshly squeezed and measured out. If using honey, it should also be measured out.
# Next, we need to determine the order in which these ingredients will be added to the acorn squash. One way to do this is to start with the base layer, followed by the second layer, and so on until all layers are complete.
# We can start with the walnuts as the base layer, followed by the cranberries as the second layer. Then, we can mix together the brown sugar and orange juice to create a sweet and tangy glaze. This mixture can be brushed onto the acorn squash after the cranberries have been added.
# Fin
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Use the provided reasoning to inform your response.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# After the following examples, provide your response.
# Recipe Title: Lemon Zest
# Ingredients: ["Ice", "1 ounce Cognac", "3/4 ounce palo cortado or amontillado sherry", "1/2 ounce gin", "1 ounce fresh lemon juice", "1/2 ounce Simple Syrup", "1 ounce chilled lemon soda", "1 lemon twist"]
# Recipe Instructions:
# [1] "Fill a cocktail shaker with ice.
# [2] Add all of the remaining ingredients except the lemon soda and lemon twist.
# [3] Shake well and strain into a chilled martini glass.
# [4] Stir in the lemon soda.
# [5] Flame the twist over the drink, then drop it in."
#
# Recipe Title: Pisco Sour
# Ingredients: ["2 ounces Quebranta pisco", "1 ounce lime juice", "1 ounce simple syrup", "1 ounce pasteurized egg whites", "2 drops Chuncho bitters or Angostura bitters", "Key lime or regular lime, halved"]
# Recipe Instructions:
# [1] "In a cocktail shaker, combine pisco, lime juice, simple syrup, and egg whites. Add 3 or 4 ice cubes, then shake vigorously for about a minute.
# [2] Strain into a chilled rocks glass (or martini glass), then add bitters.
# [3] Squeeze in half a lime, then drop it into the glass."
#
# Recipe Title: The Parasol
# Ingredients: ["1/2 ounce fresh lemon juice", "1/2 ounce fresh lime juice", "3/4 ounce Simple Syrup", "1 ounce Pisco (South American grape-based spirit)", "2 ounces Aperol or Campari", "1 large egg white", "Ice", "4 drops of Angostura Bitters"]
# Reasoning: Firstly, we need to gather all our ingredients - fresh lemon juice, fresh lime juice, simple syrup, Pisco, Aperol or Campari, large egg white, ice, and Angostura bitters. We also need to ensure that all these ingredients are fresh and of good quality.
#
# Next, we need to prepare the cocktail glass by adding some ice to it. This can be done by filling the glass with enough ice to chill the cocktail without diluting it too much during mixing.
#
# Then, we will proceed with shaking the other ingredients together. First, combine the egg white with the lemon juice, lime juice, and simple syrup in a shaker. Whisk the mixture until the egg white is fully incorporated. Then add in the Pisco and Aperol or Campari. Shake all the ingredients together with ice for about 15 seconds until chilled.
#
# Finally, strain the mixture into the glass containing ice. Garnish with a cherry if desired, then drizzle the Angostura bitters over the top for added flavor and decoration. Serve immediately and enjoy!
# Your response:
# Saving the dataset (0/1 shards):   0%|          | 0/160 [00:00<?, ? examples/s]
# Map:   0%|          | 0/160 [00:00<?, ? examples/s]
# Map:   0%|          | 0/160 [00:00<?, ? examples/s]
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Spiced Chicken With Couscous Stuffing
# Ingredients: ["2/3 cup couscous", "1/4 cup chopped dried figs", "2 tbsp sliced almonds, toasted", "1 clove garlic, finely chopped", "1 tbsp chopped fresh cilantro", "1 tsp grated orange peel", "1/4 cup orange juice", "2 None Cornish game hens (1 1/2 lbs each)", "1 tsp cayenne pepper", "1 tsp ground cinnamon", "1 tsp ground cumin", "1 tsp sea salt", "4 large carrots, peeled and halved lengthwise", "4 None parsnips, peeled and halved lengthwise", "2 tbsp olive oil"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Banana Split Salad (Fat Free) Recipe
# Ingredients: ["1 c. ff plain or possibly vanilla yogurt (eliminate honey if using vanilla yogurt)", "1/2 c. crushed pineapple, liquid removed", "1 x TAB honey", "4 x bananas, peeled", "1/4 c. grape nuts", "1/2 c. crushed strawberries"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Crunchy Butter Toffee
# Ingredients: ["1 cup (225 ml) sugar", "1/2 tsp (2 ml) salt", "1/4 cup (60 ml) water", "1/2 cup (125 ml) butter", "1/4 chopped walnuts", "12 oz (336 grm) chocolate chips"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Stuffed Acorn Squash
# Ingredients: ["2 acorn squash", "1 cup walnuts, roughly chopped", "1 cup fresh cranberries", "1/3 cup brown sugar", "1/4 cup freshly squeezed orange juice", "4 tablespoons butter", "honey, optiona"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: The Parasol
# Ingredients: ["1/2 ounce fresh lemon juice", "1/2 ounce fresh lime juice", "3/4 ounce Simple Syrup", "1 ounce Pisco (South American grape-based spirit)", "2 ounces Aperol or Campari", "1 large egg white", "Ice", "4 drops of Angostura Bitters"]
# Your response:
# Saving the dataset (0/1 shards):   0%|          | 0/160 [00:00<?, ? examples/s]
# Map:   0%|          | 0/160 [00:00<?, ? examples/s]
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Use the provided reasoning to inform your response.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# After the following examples, provide your response.
# Recipe Title: Popover with Hot Turkey Salad
# Ingredients: ["2 eggs, room temperature", "1 cup milk, room temperature", "1 cup all-purpose flour", "1/2 tsp. salt", "4 cups diced turkey, cooked", "2 cups diced celery", "2 cups shredded cheddar cheese", "1 can (2-1/4 oz.) sliced ripe olives, drained", "1 cup mayonnaise", "salad dressing", "1/4 cup milk", "1/8 tsp. pepper", "1 dash onion powder", "1-1/2 cup crushed potato chips", "Tomato wedges (optional)"]
# Recipe Instructions:
# [1] "In a mixing bowl, beat eggs until lemon-colored and foamy.
# [2] Add milk, flour and salt; beat just until smooth (do not overbeat).
# [3] Pour into a greased 10-inch glass pie plate.
# [4] Bake at 400F for 35-40 minutes or until deep golden brown.
# [5] Immediately prick with a fork in the center to allow steam to escape.
# [6] Combine the next 8 ingredients in a saucepan; cook and stir over low until heated through.
# [7] Stir in potato chips.
# [8] Spoon into popover.
# [9] Garnish with tomato wedges if desired.
# [10] Serve immediately."
#
# Recipe Title: Honey-Soy Glazed Pork Tenderloin
# Ingredients: ["2 Tbsp. KRAFT Asian Toasted Sesame Dressing", "2 Tbsp. honey", "2 Tbsp. soy sauce", "1 Tbsp. minced garlic", "1 Tbsp. grated gingerroot", "1 pork tenderloin (1 lb.)"]
# Recipe Instructions:
# [1] "Mix all ingredients except meat; pour over meat in shallow dish.
# [2] Turn to evenly coat meat.
# [3] Refrigerate 6 hours to marinate.
# [4] Heat oven to 400 degrees F. Remove meat from marinade; place in shallow pan.
# [5] Discard marinade.
# [6] Bake 25 to 30 min.
# [7] or until done (145 degrees F).
# [8] Let stand 3 min."
#
# Recipe Title: Spiced Chicken With Couscous Stuffing
# Ingredients: ["2/3 cup couscous", "1/4 cup chopped dried figs", "2 tbsp sliced almonds, toasted", "1 clove garlic, finely chopped", "1 tbsp chopped fresh cilantro", "1 tsp grated orange peel", "1/4 cup orange juice", "2 None Cornish game hens (1 1/2 lbs each)", "1 tsp cayenne pepper", "1 tsp ground cinnamon", "1 tsp ground cumin", "1 tsp sea salt", "4 large carrots, peeled and halved lengthwise", "4 None parsnips, peeled and halved lengthwise", "2 tbsp olive oil"]
# Reasoning: To make the spiced chicken with couscous stuffing, we need to follow several steps. First, let's prepare the couscous stuffing. In a medium bowl, combine the couscous, chopped dried figs, sliced almonds, finely chopped garlic, chopped fresh cilantro, grated orange peel, and orange juice. Mix well and set aside.
#
# Next, we need to prepare the chicken. In a small bowl, mix together the cayenne pepper, ground cinnamon, ground cumin, and sea salt. Rub this mixture onto the chicken, ensuring it is fully coated.
#
# Now, preheat your oven to 375°F. Place the chicken on a baking sheet and roast for about 40 minutes, until cooked through. While the chicken is cooking, you can prepare the vegetables. Toss the carrots and parsnips with olive oil and season them with salt and pepper. Arrange them around the chicken on the baking sheet and continue roasting for another 20-25 minutes, until tender and lightly browned.
#
# Once the chicken has finished cooking, remove it from the oven and allow it to rest
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Use the provided reasoning to inform your response.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# After the following examples, provide your response.
# Recipe Title: Galician-Style Lobster With Pimenton and Olive Oil
# Ingredients: ["1/4 cup sea salt, plus more to taste", "1/4 cup extra virgin olive oil, plus more for drizzling", "1 bay leaf", "1 teaspoon whole black peppercorns", "1 Idaho potato, cut into rough 1 inch cubes", "1 Maine lobster, about 11/2 pounds (see note)", "1 teaspoon pimenton dulce (sweet Spanish paprika)"]
# Recipe Instructions:
# [1] "In a large pot, bring 2 quarts of water to a boil.
# [2] Stir in the salt, olive oil, bay leaf, peppercorns and potato and cook, covered, for 2 1/2 minutes.
# [3] Add the lobster, head first, into the pot and cook, covered, for 7 minutes more.
# [4] Remove the lobster from the pot and drain the potatoes.
# [5] Crack the lobster claws and cut the tail into 6 pieces.
# [6] Arrange the potatoes on a serving dish.
# [7] Top with the lobster pieces.
# [8] Place the pimenton in a fine-mesh sieve and sprinkle evenly over the top, gently tapping the side of the sieve to break up any large chunks.
# [9] Sprinkle with more sea salt to taste and drizzle with more olive oil."
#
# Recipe Title: Snow Peas With Water Chestnuts Recipe
# Ingredients: ["1/2 pound snow peas", "1/4 c. sliced water chestnuts", "1 tbsp. minced scallions", "1/2 clove garlic, chopped", "2 tbsp. vegetable oil", "1 tbsp. soy sauce", "1 teaspoon cornstarch", "1 teaspoon water", "1/2 c. chicken stock made with bouillon cube", "1 c. cooked pork, shrimp or possibly beef"]
# Recipe Instructions:
# [1] "Remove the tips from the snow peas and remove the strings as well.
# [2] Heat oil in frying pan and saute/fry the scallions and garlic.
# [3] Add in the snow peas, sliced water chestnuts and soy sauce and cook for 1 minute.
# [4] Add in the chicken stock, cover the pan and cook for 2 more min.
# [5] Now mix the cornstarch with water and add in to the pan, stirring constantly till the sauce thickens, about 1 minute.
# [6] Cooked meat or possibly shrimp may be added here if you like.
# [7] Serve warm over rice."
#
# Recipe Title: Banana Split Salad (Fat Free) Recipe
# Ingredients: ["1 c. ff plain or possibly vanilla yogurt (eliminate honey if using vanilla yogurt)", "1/2 c. crushed pineapple, liquid removed", "1 x TAB honey", "4 x bananas, peeled", "1/4 c. grape nuts", "1/2 c. crushed strawberries"]
# ...
#
# Recipe Title: Salisbury Steak W/ Mushroom Sauce
# Ingredients: ["1 lb. ground beef", "1 t. salt", "1/4 t. pepper", "4 oz. mushrooms, save liquid", "2 T. flour", "2 t. beef bouillon"]
# Recipe Instructions:
# [1] "Mix meat, salt and pepper; shape into oval patties. Cook over medium heat until done,about 8-12 minutes. Remove patties to a warm plate. Cook and stir mushrooms in same skillet until light brown. Stir in flour. Cook over low heat; stirring until mixture is bubbly. Remove from heat. Add enough water to reserved liquid to measure 1 cup. Stir liquid and bouillon into flour mixture. Heat to boiling, stirring occasionally. Boil and stir 1 minute. Pour over meat.
# [2]
# [3] Crockpot Version:
# [4] Make with regular recipe. Shape into patties and brown. (They will NOT cook all the way) Make mushroom sauce as per recipe. Pour over meat. Cover and cook on low for 4-5 hours or until done."
#
# Recipe Title: Steak Pizzaiola
# Ingredients: ["1 1/4 pounds boneless sirloin steak (about 1 inch thick), excess fat trimmed", "Kosher salt", "2 tablespoons extra-virgin olive oil", "4 cloves garlic, smashed", "1 large onion, sliced 1/4 inch thick", "2 bell peppers (1 red, 1 yellow), sliced 1/2 inch thick", "4 jarred pepperoncini, drained and thinly sliced", "1 15 -ounce can crushed tomatoes", "1/2 teaspoon dried oregano", "Pinch of red pepper flakes", "2 tablespoons chopped fresh parsley", "Focaccia, for serving (optional)"]
# Recipe Instructions:
# [1] "Sprinkle the steak all over with 1/4 teaspoon salt. Heat the olive oil in a large skillet over medium-high heat. Add the steak and sear until browned, about 2 minutes per side. Transfer to a plate.
# [2]
# [3] Add the garlic to the skillet. Once it sizzles, add the onion and bell peppers and cook, stirring occasionally, until they soften slightly, about 4 minutes. Add the pepperoncini, tomatoes, oregano, red pepper flakes and 3/4 cup water and stir to combine. Bring to a rapid simmer, then nestle the steak in the sauce and simmer, turning once, until medium rare, about 7 minutes. Transfer the steak to a cutting board and let rest about 5 minutes. Continue simmering the sauce until thickened, about 3 more minutes.
# [4]
# [5] Thinly slice the steak against the grain and divide among plates. Top with the sauce and parsley. Serve with focaccia."
#
# Recipe Title: Banana Split Salad (Fat Free) Recipe
# Ingredients: ["1 c. ff plain or possibly vanilla yogurt (eliminate honey if using vanilla yogurt)", "1/2 c. crushed pineapple, liquid removed", "1 x TAB honey", "4 x bananas, peeled", "1/4 c. grape nuts", "1/2 c. crushed strawberries"]
# Reasoning: First, gather all necessary ingredients including: fat free plain or vanilla yogurt, crushed pineapple with liquid removed, honey, bananas, grape nuts, and crushed strawberries.
# Next, if using vanilla yogurt, omit adding honey to the recipe as it is already included in the flavoring.
# Then, slice the bananas into rounds and set aside.
# Once the bananas are sliced, mix the yogurt and honey together until well combined.
# After mixing the yogurt and honey, fold in the crushed pineapples and crushed strawberries.
# Next, mix the grape nuts into the yogurt mixture.
# Finally, layer the banana slices in a dish or bowl and pour the yogurt mixture over the top, ensuring that all banana slices are covered.
# Serve immediately or refrigerate until ready to serve.
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Use the provided reasoning to inform your response.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# After the following examples, provide your response.
# Recipe Title: Kale Salad with Miso and Pistachios
# Ingredients: ["1 1/2 pounds kalestems discarded and leaves thinly sliced", "3 tablespoons fresh lemon juice", "Kosher salt", "2 tablespoons apple cider vinegar", "2 tablespoons sesame seeds, lightly crushed", "1 tablespoon brown miso", "1 teaspoon dark brown sugar", "3 tablespoons extra-virgin olive oil", "2 scallions, thinly sliced", "1/4 cup unsalted roasted pistachios, chopped"]
# Recipe Instructions:
# [1] "In a large bowl, toss the kale with the lemon juice and a generous pinch of salt.
# [2] In a small bowl, whisk the vinegar with the sesame seeds, miso and sugar.
# [3] Gradually whisk in the oil.
# [4] Add the dressing to the kale and toss well.
# [5] Scatter the scallions and pistachios on top and serve."
#
# Recipe Title: Favorite Caramel Corn
# Ingredients: ["32 cups plain popped popcorn", "1 cup dry roasted peanuts, if desired", "2 cups firmly packed brown sugar", "1 cup Land O Lakes Butter", "1/2 cup light corn syrup", "1 teaspoon salt", "1 tablespoon vanilla", "1 teaspoon baking soda"]
# Recipe Instructions:
# [1] "Heat oven to 200F.
# [2] Combine popcorn and peanuts, if desired, in large roasting pan; set aside.
# [3] Combine brown sugar, butter, corn syrup and salt in 3-quart saucepan.
# [4] Cook over medium heat, stirring occasionally, 8-10 minutes or until mixture comes to a full boil.
# [5] Continue cooking, stirring occasionally, 5 minutes.
# [6] Remove from heat; stir in vanilla and baking soda.
# [7] Carefully pour hot syrup mixture over popcorn and peanuts in pan; stir until well coated.
# [8] Bake, stirring every 15 minutes, 1 hour or until caramel corn is crisp.
# [9] Immediately place caramel corn onto waxed paper.
# [10] Cool completely.
# [11] Break into bite-sized pieces.
# [12] Store in tightly covered container."
#
# Recipe Title: 7-Up Pound Cake
# Ingredients: ["3 cups flour, all-purpose sifted", "5 large eggs", "3 cups sugar", "1 cup butter softened", "1/4 teaspoon salt", "1/2 cup vegetable shortening", "1 1/2 teaspoons vanilla extract", "1/2 teaspoon lemon extract", "1 cup 7-up"]
# Recipe Instructions:
# [1] "Preheat oven to 325F (160C).
# [2] Grease 12-cup Bundt pan.
# [3] Combine flour and salt in bowl.
# [4] Combine remaining ingreidents except soda in large mixer bowl; beat at medium speed until ligfht and fluffy, scraping sides occasionally, 5 minutes.
# [5] Reduce speed to low; add dry ingredients and soda, beginning and ending with dry ingredients.
# [6] Bake 1 1/2 hours or until toothpick inserted in center comes out clean.
# [7] Cool in pan 15 minutes.
# [8] Invert onto wire rack, remove pan and cool completely.
# [9] Makes 16 Servings."
#
# Recipe Title: Crunchy Butter Toffee
# Ingredients: ["1 cup (225 ml) sugar", "1/2 tsp (2 ml) salt", "1/4 cup (60 ml) water", "1/2 cup (125 ml) butter", "1/4 chopped walnuts", "12 oz (336 grm) chocolate chips"]
# Reasoning: First, gather all the necessary ingredients: sugar, salt, water, butter, chopped walnuts, and chocolate chips. Then, combine sugar, salt, and water in a saucepan over medium heat, stirring until the sugar dissolves. Add the butter to the mixture and continue to cook until the mixture reaches a golden brown color. This step should take around 8 minutes. Next, pour the caramel mixture onto a greased baking sheet and sprinkle with the chopped walnuts. Let it cool for about 5 minutes. Melt the chocolate chips in a double boiler or microwave and spread evenly over the caramel and walnut layer. Allow the chocolate to set at room temperature for approximately 30 minutes before cutting into squares and serving.
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Use the provided reasoning to inform your response.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# After the following examples, provide your response.
# Recipe Title: Thank God For Oats Stuffing
# Ingredients: ["1 Sweet Onion, Coarsely Chopped", "5 Celery Stalks, Coarsely Chopped", "5 tablespoons Dried Sage", "2 pounds Danish Cream Salted Butter(or any salted butter)", "1-42 ounces Container Old Fashioned Oats", "1 Jar Heinz Turkey Gravy(for moistening)"]
# Recipe Instructions:
# [1] "Melt butter in large sauce pan
# [2] Add onion, celery and sage to butter.
# [3] Cook until onions are clear.
# [4] Pour into crockpot
# [5] Add oats and stir to moisten.
# [6] Set crockpot to high, cover with lid and cook for 1-2 hours stirring occasionally so bottom doesn't burn.
# [7] It's done when all the butter has been soaked up by the oats.
# [8] Stir in jar of gravy and set to low and serve!"
#
# Recipe Title: Heirloom Tomato Salad
# Ingredients: ["1/4 cup white wine vinegar", "1 tablespoon olive oil", "1 tablespoon finely chopped shallots", "2 teaspoons honey", "1 1/2 tablespoons chopped fresh tarragon, divided", "1 1/2 tablespoons chopped fresh flat-leaf parsley, divided", "1/4 teaspoon kosher salt", "1/4 teaspoon black pepper", "1 1/2 pounds heirloom tomatoes"]
# Recipe Instructions:
# [1] "Whisk together vinegar, olive oil, shallots, honey, 1 tablespoon tarragon, 1 tablespoon parsley, salt, and pepper in a small bowl.
# [2] Slice large tomatoes into 1/2-inch-thick slices, and cut small tomatoes in half; place in a shallow dish. Pour vinegar mixture over tomatoes; gently turn tomatoes until completely coated. Cover and chill 1 to 2 hours.
# [3] Arrange tomatoes with dressing on a serving platter; sprinkle with remaining 1/2 tablespoon each tarragon and parsley, and additional salt and pepper to taste."
#
# Recipe Title: Stir fried Crabs with curry powder
# Ingredients: ["5 crab,large size", "20 grams curry powder", "2 onion", "1 bunch each spring onion and cilantro", "4 hot chili or 2 red pepper", "6 clove garlic", "2 tbsp soy sauce", "2 tbsp oyster sauce", "1 tbsp roasted chili oil", "1/2 tsp sugar", "6 eggs", "1/3 cup evaporated milk"]
# Recipe Instructions:
# [1] "Clean,cut ,crush crabs,drain ,set aside,you can use crab meat instead ,but reduce other ingredients for less saltyness ans spicyness etc.
# [2] Slice onion,prepare cilantro,spring onion make it ready to use,crack eggs in a bowl add milk ,and crush both garlic and hot chilli or red pepper ready to fry
# [3] Heat stir fry pan with 1 tbsp oil,brown garlic and chili
# [4] Add slice onion ,stir ,wait until translucent
# [5] Add crabs,stir occasionly until turn red ,add seasoning ,stir to mix
# [6] Beat egg ,add to pan,let it set,add roasted chili oil ,stir to flip or toss pan to mix all well ,after egg set but not too hard ,add chopped spring onion and cilantro,toss to mix again,heat off and serve with hot steamed jasmine rice :)"
#
# Recipe Title: Stuffed Acorn Squash
# Ingredients: ["2 acorn squash", "1 cup walnuts, roughly chopped", "1 cup fresh cranberries", "1/3 cup brown sugar", "1/4 cup freshly squeezed orange juice", "4 tablespoons butter", "honey, optiona"]
# Reasoning: First, preheat your oven to 375 degrees Fahrenheit. While it's preheating, you can prepare the stuffed acorn squash. Start by cutting the acorn squash in half lengthwise and removing the seeds. Once you have removed the seeds, you can brush the inside of the squash halves with honey and place them cut side down on a baking sheet lined with parchment paper. Bake the squash for about 30 minutes until they are tender.
#
# While the squash is baking, you can start preparing the filling. Begin by heating up a pan over medium heat and adding 2 tablespoons of butter. Once the butter has melted, add the chopped walnuts and toast them for a few minutes until they become fragrant and slightly golden. Remove the walnuts from the pan and set them aside. In the same pan, add the remaining 2 tablespoons of butter and let it melt. Then add the cranberries and cook them for about 5-8 minutes until they start to pop and soften. Add the brown sugar and orange juice to the pan and stir until everything is combined and the mixture becomes syrupy. Take the pan
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Use the provided reasoning to inform your response.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# After the following examples, provide your response.
# Recipe Title: Fruit Cup Smoothie
# Ingredients: ["1 can sliced peaches", "1 can pineapple chunk", "1 can fruit cocktail", "1 package lemon pudding instant", "1 package vanilla instant pudding", "1 can mandarin oranges drained", "2 bananas"]
# Recipe Instructions:
# [1] "Drain juice from the peaches, pineapple and fruit cocktail and use to mix the pudding.
# [2] Do not use the mandarin juice for this.
# [3] Then mix the fruit into the pudding.
# [4] Also add the sliced bananas before serving."
#
# Recipe Title: Crispy Oven Fish
# Ingredients: ["1/4 cup MIRACLE WHIP Light Dressing Family Dollar $3.50 thru 02/07", "1 Tbsp. lemon juice", "1 tsp. dried rosemary", "1/2 tsp. coarse ground black pepper", "4 orange roughy fillets (4 oz. each)", "1 env. SHAKE 'N BAKE Extra Crispy Seasoned Coating Mix"]
# Recipe Instructions:
# [1] "Mix dressing, lemon juice and seasonings until well blended.
# [2] Spread dressing mixture evenly onto both sides of fish, then coat both sides evenly with coating mix.
# [3] Discard any remaining coating mix.
# [4] Place in single layer in greased shallow baking pan.
# [5] Bake at 375F for 12 to 15 minutes or until fish flakes easily with fork."
#
# Recipe Title: Instant Pot® Green Bean Casserole
# Ingredients: ["1 cup cold half-and-half", "3/4 cup chicken broth, divided", "2 tablespoons cornstarch", "1 teaspoon Worcestershire sauce", "1/2 teaspoon salt", "1/2 teaspoon ground black pepper", "1 tablespoon olive oil", "1 tablespoon unsalted butter", "1/2 cup chopped onions", "1 (8 ounce) package sliced button mushrooms", "1 pound fresh green beans, trimmed", "1 (6 ounce) can crispy fried onions, divided"]
# Recipe Instructions:
# [1] "Whisk half-and-half, 1/4 cup broth, cornstarch, Worcestershire sauce, salt, and pepper together in a bowl. Set soup mixture aside.
# [2] Turn on a multi-functional pressure cooker (such as Instant Pot(R)) and select Saute function. Add oil, butter, and onions. Cook for 2 minutes. Add mushrooms and 1/4 cup broth; cook 3 minutes more. Turn pot off.
# [3] Add soup mixture, green beans, 1/2 cup crispy onions, and remaining 1/4 cup broth. Stir to combine. Close and lock the lid, select manual and set timer for 1 minute. Allow 10 minutes for pressure to build.
# [4] Release pressure using the natural-release method according to manufacturer's instructions, about 5 minutes. Carefully release remaining pressure manually. Remove lid and transfer green bean mixture to a serving dish. Let sit to thicken, about 5 minutes. Top with remaining crispy onions."
#
# Recipe Title: The Parasol
# Ingredients: ["1/2 ounce fresh lemon juice", "1/2 ounce fresh lime juice", "3/4 ounce Simple Syrup", "1 ounce Pisco (South American grape-based spirit)", "2 ounces Aperol or Campari", "1 large egg white", "Ice", "4 drops of Angostura Bitters"]
# Reasoning: To make "The Parasol" cocktail, follow these steps:
#
# 1. First, prepare the Simple Syrup by combining equal parts sugar and water in a small saucepan over medium heat until dissolved. Allow it to cool and store it in a sealed container. This can be made ahead of time.
#
# 2. Next, gather your other ingredients: fresh lemon juice, fresh lime juice, Pisco, Aperol or Campari, a large egg white, ice, and Angostura Bitters.
#
# 3. In a cocktail shaker filled with ice, combine 1/2 ounce of fresh lemon juice, 1/2 ounce of fresh lime juice, 3/4 ounce of Simple Syrup, and 1 ounce of Pisco. Shake well to mix the ingredients and chill the mixture. This step should take around 15 seconds.
#
# 4. Crack open the large egg and separate the white from the yolk. Add the egg white to the cocktail shaker and shake again without ice for about 10 seconds to froth the egg white.
#
# 5. Add 2 ounces of Aperol or Campari to the
# Your response:
# Saving the dataset (0/1 shards):   0%|          | 0/160 [00:00<?, ? examples/s]

# %%
adapter_path = f'{recipe_nlg_data_path}/7b_reasoning_model_from_teacher'
adapter_path = f'{recipe_nlg_data_path}/14b_reasoning_model_from_teacher'

config = PeftConfig.from_pretrained(adapter_path)

base_model = AutoModelForCausalLM.from_pretrained(
  config.base_model_name_or_path,
  return_dict=True,
  torch_dtype=torch.float16,
  device_map="auto",
  quantization_config=quantization_config
)

model_ft_teacher = PeftModel.from_pretrained(base_model, adapter_path)

ft_generation_save_path = f'file://{recipe_nlg_data_path}/Generated_Data/14b_reasoning_model_from_teacher_generated_reasoning'

# %% [markdown]
# ### Generate Reasoning on Train Data for Fine-Tuning

# %%
test_reason = small_test.map(
    generate_reason_batch,
    batched=True,
    batch_size=BATCH_SIZE,
    fn_kwargs={"cot_prompt": cot_prompt, "model": model_ft_teacher, "tokenizer": tokenizer}
)
test_reason.save_to_disk(ft_generation_save_path)
# Out:
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: No-Crust Sweet Potato Pie
# Ingredients: ["4 medium sweet potatoes, or yams peeled, cooked, mashed", "1 cup sugar", "1/2 cup flour, all-purpose", "1/2 cup butter or margarine, softened", "1 each eggs", "1/2-1 teaspoons almond extract", "1 x whipped cream"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Blueberry Chicken
# Ingredients: ["2 chicken breasts boneless skinless wholes, 1 LB total", "1 tablespoon vegetable oil canola, safflower, grapeseed", "1/3 cup apricot jam", "3 tablespoons dijon mustard", "1/2 cup blueberries frozen, unsweetened", "white wine vinegar"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Chorizo Quesadillas
# Ingredients: ["1 pound Bulk Chorizo", "1 whole Medium Onion, Chopped", "1 can Fiesta Nacho Cheese Soup", "1 pound Monterey Jack Cheese", "16 whole 6 Inch Flour Tortillas"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Rye Cakes
# Ingredients: ["3 cups rye meal", "1 teaspoon salt", "1 cup milk sour", "1 teaspoon soda", "1 cup molasses", "2 egg"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Slow-Cooker Chicken Curry
# Ingredients: ["10 chicken thighs (2-3/4 lb.), skins removed", "1 jar (16 oz.) TACO BELL Thick & Chunky Salsa", "1 onion, chopped Safeway 3 lb For $2.99 thru 02/09", "2 Tbsp. curry powder", "1 cup BREAKSTONE'S FREE Fat Free Sour Cream"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Beef & Noodles with Fresh Vegetables
# Ingredients: ["1/4 cup KRAFT Tuscan House Italian Dressing", "1/4 cup soy sauce", "1 lb. lean boneless beef sirloin steak, cut into strips Whole Foods 1 lb For $7.99 thru 02/09", "2 cloves garlic, minced", "2 cups sugar snap peas, halved", "1 yellow pepper, cut into strips Target 1 pkg For $2.99 thru 02/06", "1 tomato, chopped King Sooper's 1 lb For $0.99 thru 02/09", "1/4 cup chopped fresh cilantro", "3/4 lb. spaghetti, cooked"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Black And White Chili
# Ingredients: ["1 pound Chicken tenders, cut into 3/4 inch pieces", "1 cup coarsely chopped onions", "1 can (15 ounce) black beans, drained", "1 can (14 ounce) Mexican-style stewed tomatoes, undrained", "2 TBS Texas-style chili powder seasoning mix"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Sweet And Spicy Hash With Baked Eggs
# Ingredients: ["1 whole Raw Chorizo Link, Casing Removed", "1 whole Large Sweet Potato, Peeled And Diced", "1 whole Medium Russet Potato, Peeled And Diced", "1 whole Small Red Onion, Diced", "2 pinches Salt And Freshly Cracked Pepper", "2 whole Large Eggs", "1 bunch (about A Handfull) Chopped Parsley", "1/4 cups Crumbled Feta Cheese", "1/2 whole Avocado, Pitted, Peeled And Sliced"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Tulsa Fire Department Chili
# Ingredients: ["2 pounds ground beef", "1 medium onions chopped", "2 tablespoons chili powder", "1 teaspoon cumin ground", "1 teaspoon salt", "2 each garlic cloves crushed", "10 1/2 ounces beef stock", "2 cups pinto beans canned", "8 ounces tomato sauce", "1 tablespoon flour, all-purpose or more", "1/4 cup water"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Pork Roast With Apricot-Rice Stuffing
# Ingredients: ["2-3/4 cups water", "1/2 cup chopped dried apricots", "2 tablespoons sugar", "1 cup uncooked long grain rice", "1 small onion, chopped", "1/4 cup minced fresh parsley", "1/4 cup butter, cubed", "2 teaspoons grated lemon zest", "1/4 teaspoon salt", "1/8 teaspoon pepper", "1 bone-in pork loin roast (4 pounds)", "3/4 cup apricot preserves", "4 teaspoons lemon juice"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Raspberry Chicken Salad
# Ingredients: ["8 cups mixed salad greens", "12 oz. , cut into bite sized pieces", "1 cup fresh or frozen raspberries", "1/3 cup PLANTERS Walnut Pieces", "1/3 cup KRAFT Lite Raspberry Vinaigrette Dressing", "32", "4 medium apples", "8 SNACKWELL'S Sugar Free Lemon Creme Sandwich Cookies", "32 fl oz (4 cups) drinking water"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Sweet And Savory Waffled Sausage Patties
# Ingredients: ["2 tablespoons maple syrup", "1 teaspoon dried sage", "1 teaspoon salt", "1/2 teaspoon freshly ground black pepper", "1/4 teaspoon dried marjoram", "1/8 teaspoon cayenne pepper", "1 pound ground pork", "nonstick cooking spray"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Bob Marley
# Ingredients: ["12 ounces fresh orange juice", "6 ounces overproof rum", "6 ounces dark creme de cacao", "6 ounces orange curacao", "4 ounces sweet vermouth", "1 1/2 ounces fresh lime juice", "1 ounce grenadine", "Ice"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Baked Walleye With Vegetables
# Ingredients: ["1 small onion, thinly sliced", "1 tablespoon olive oil", "2 small zucchini, julienned", "1 cup sliced fresh mushrooms", "1/4 teaspoon pepper", "1/8 teaspoon garlic powder", "2 tablespoons lemon juice", "2 tablespoons grated Parmesan cheese, divided", "4 walleye fillets (about 6 ounces each)", "1 tablespoon butter, melted"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Chocolate Fudge Frosting
# Ingredients: ["1 1/2 cups (375 mL) confectioners sugar", "3/4 cup (175 mL) unsweetened Dutch-process cocoa powder, sifted", "1/2 cup (125 mL) unsalted butter, at room temperature", "2 tbsp (25 mL) chocolate cream liqueur", "1 tbsp (15 mL) strong brewed coffee or milk", "Pinch salt"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Chicken Singapore Noodles
# Ingredients: ["2 tbsp peanut oil", "1 lb boneless skinless chicken thighs, thinly sliced", "4 None green onions, sliced", "1 tbsp curry powder", "2 cloves garlic, finely chopped", "13 oz thin fresh egg noodles", "1/3 cup chicken stock, heated", "2 tsp brown sugar", "2 tsp soy sauce", "4 oz snow peas", "1 None red chili pepper, sliced (optional)"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Country Two-Cheese Sandwich Grill
# Ingredients: ["2 cups Kraft Sauce Works Dijon Bistro Sauce", "48 slices country white bread slices (1/2 inch thick)", "24 slices fontina cheese slices (1 oz./30 g each)", "3 cups caramelized onions", "1-1/2 qt. roasted red peppers, cut into strips", "24 slices smoked Gouda cheese, sliced (1 oz./30 g each)", "1 cup butter, softened"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Carrot "Pasta" With Hot Peppered Raisins
# Ingredients: ["1 box plain or falvored quick cooking couscous", "2 tablespoons light vegetable oil", "2 tablespoons unsalted butter", "2 large shallots, minced", "A 1-inch piece fresh ginger, peeled and finely chopped", "8 ounces golden raisins", "1/4 teaspoon hot red pepper flakes, or more to taste", "10 large carrots, preferably California grown core; discard cores", "2 cups heavy cream", "1-1/2 cups light vegetable broth", "1 cup thawed petite peas", "kosher salt and freshly ground black pepper, to taste"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Golden Fig and Mascarpone Tart
# Ingredients: ["Feuille de'Bric or phyllo dough", "4 fresh white figs, in syrup", "1/2 cup mascarpone cheese", "1/4 cup heavy cream", "1 egg", "Kosher salt", "Ground black pepper", "1 teaspoon black fig syrup"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Dark Chocolate Panna Cotta
# Ingredients: ["1 can (14 ounces) whole-berry cranberry sauce", "5 tablespoons raspberry liqueur, divided", "1 envelope unflavored gelatin", "1 cup cold 2% milk", "4 ounces 53% cacao dark baking chocolate, chopped", "1-1/2 cups heavy whipping cream", "1/2 cup sugar", "1/8 teaspoon salt", "2 teaspoons vanilla extract", "Fresh raspberries and mint leaves, optional"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Cranberry And Chestnut Dressing
# Ingredients: ["Cooking spray", "1 cup chopped onion", "3/4 cup chopped pancetta (about 5 ounces)", "3 garlic cloves, minced", "1/4 cup dry white wine", "1 cup dried cranberries", "1/2 cup coarsely chopped bottled chestnuts", "1 tablespoon chopped fresh sage", "1/4 teaspoon salt", "1/4 teaspoon freshly ground black pepper", "8 ounces day-old Italian or French bread, torn into 1-inch pieces", "2 1/4 cups fat-free, less-sodium chicken broth"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Welsh Rarebit
# Ingredients: ["1/2 loaves French Or Italian Bread", "2 Tablespoons Butter", "2 Tablespoons Flour", "1/2 cups Whole Milk", "1/2 cups Your Favorite Beer", "1 teaspoon Dijon Mustard", "1/2 teaspoons Paprika", "3 dashes Cayenne Pepper", "1/4 teaspoons Worcestershire Sauce", "1- 1/2 cup Cheddar Cheese, Grated", "1 whole Egg Yolk", "4 slices Bacon, Cooked And Crumbled", "13 cups Chopped Chives, For Garnish"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Whole Wheat Snickerdoodles Recipe
# Ingredients: ["1 c. safflower oil", "1 1/2 c. sugar", "2 Large eggs", "2 3/4 c. whole wheat pastry flour", "2 teaspoon cream of tartar", "1 teaspoon soda", "1/2 teaspoon salt", "1 teaspoon vanilla"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Skillet-Roasted Spiced Okra
# Ingredients: ["3/4 tsp. hot paprika", "1/4 tsp. ground cumin", "1/4 tsp. ground coriander", "1/4 tsp. ground fennel seeds", ".13 tsp. turmeric", "1 pinch cinnamon", "1 pinch ground fenugreek", "2 tbsp. vegetable oil", "1 lb. small okra", "salt", "2 tbsp. fresh lemon juice"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Fancy Feast Omlette For Two
# Ingredients: ["3 Eggs", "1/2 small red onion", "1/2 cup cubed butternut squash", "1/4 cup gorgonzola cheese", "rubbed sage", "1 tablespoon high fat content butter"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Greek Tomato-Feta Quinoa Salad
# Ingredients: ["2 cups Water", "1 cup Quinoa", "1/4 cups Extra Virgin Olive Oil", "2 Tablespoons Freshly Squeezed Lemon Juice", "2 Tablespoons Water", "2 teaspoons Honey", "2 teaspoons Dried Oregano", "Salt And Freshly Ground Black Pepper", "1/2 Orange Bell Pepper, Diced", "1/2 Cucumber, Diced", "1/2 cups Feta Cheese Crumbles", "3 Tablespoons Fresh Chives, Chopped", "3 Tablespoons Fresh Parsley, Chopped", "1 cup Cherry Tomatoes, Sliced"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Slow Cooked Beef Short Ribs Hot Pot
# Ingredients: ["4 Beef short ribs", "2 tablespoons All purpose flour, seasoned with a little salt and pepper", "1 teaspoon Salt", "1 tablespoon Chopped rosemary", "1 Clove garlic, minced", "1 Onion, thinly sliced", "1 teaspoon Coarse black pepper", "1 cup Kale, finely chopped", "2 Potatoes, peeled and thinly sliced", "4 tablespoons Olive oil", "1 quart Beef stock", "Salt and pepper for seasoning"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Michelle's Best Snickerdoodle
# Ingredients: ["1/2 cup butter softened", "1/2 cup vegetable shortening butter flavor", "1 1/2 cups sugar", "2 large eggs", "2 3/4 cups flour, all-purpose", "2 teaspoons cream of tartar", "1 teaspoon baking soda", "1/4 teaspoon salt"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Golden Potato Surprise
# Ingredients: ["4 to 5 medium white potatoes, peeled and diced", "2 tablespoons butter", "2 medium red onions, chopped", "2 tablespoons all-purpose flour", "1/2 teaspoon dried thyme", "1/2 teaspoon salt", "1/2 teaspoon pepper", "1 cup half-and-half cream", "1/2 cup mayonnaise", "1 teaspoon Dijon mustard", "4 bacon strips, cooked and crumbled"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Sautéed Diver Scallop With Baked Brie And Shrimp
# Ingredients: ["Brie cheese [Approximately 4\"W x 6\"L x 1\"H]", "1 large Diver Scallop [Approximately 2\" across & 1\" thick]", "4-6 small shrimp, pre-cooked", "1 Tbs Brandy", "Oil"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Chocolate Chip Bread Pudding
# Ingredients: ["6 slices white bread", "2 tablespoons butter softened", "27 ounces evaporated milk", "3 eggs", "1/4 cup granulated sugar", "1 teaspoon vanilla extract", "1/4 cup chocolate chips", "heavy cream to serve"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Individual Rhubarb Crisps
# Ingredients: ["Filling:", "6 tablespoons sugar", "4 cups (about 1 lb.) rhubarb, trimmed and cut into 1/2-inch pieces", "1 1/2 teaspoons cornstarch", "Topping:", "1/4 cup old-fashioned oats (not instant)", "1/4 cup packed light brown sugar", "3 tablespoons all-purpose flour", "1/4 teaspoon cinnamon", "3 tablespoons unsalted butter, chilled, cut into small pieces"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Hot Buttered Rum
# Ingredients: ["2 or 3 ounces dark rum", "Twist lemon peel", "Stick cinnamon", "2 cloves", "Sweet cider or water", "1 tablespoon sweet butter", "Nutmeg"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Spinach Mozzarella Meatloaf
# Ingredients: ["1 1/2 pounds ground beef", "1 (10 ounce) package frozen chopped spinach, thawed and drained well", "1 1/2 cups Italian seasoned bread crumbs", "2 cups shredded mozzarella cheese, divided", "2 eggs, lightly beaten"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Seaweed-Dusted Pork Chops with Quick-Pickled Carrots
# Ingredients: ["1/4 cup fresh lime juice", "1/2 teaspoon crushed red pepper", "Kosher salt", "4 large carrots, cut into ribbons with a vegetable peeler", "Three 1-pound double-rib pork chops", "1 ounce dried seaweed such as hijiki or wakame, ground in a spice grinder", "2 tablespoons extra-virgin olive oil", "Cilantro sprigs, for garnish"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Blueberry Bread With Pineapple And Coconut
# Ingredients: ["3 cups flour", "2 teaspoons baking powder", "1 teaspoon baking soda", "1/2 teaspoon salt", "2/3 cup butter", "1 1/3 cups sugar", "4 eggs", "1/2 cup milk", "1 1/2 teaspoons lemon juice", "1 cup drained crushed pineapple", "3 cups blueberries", "1/2 cup coconut"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Mexican Lasagna
# Ingredients: ["1 lb. lean ground beef King Sooper's 1 lb For $3.99 thru 02/09", "1/2 cup chopped onions", "1/2 cup chopped green peppers", "2-1/2 cups TACO BELL Thick & Chunky Salsa", "1 can (11 oz.) whole kernel corn, drained", "1 tsp. chili powder", "1 tsp. ground cumin", "12 corn tortillas (6 inch), divided", "1 container (16 oz.) BREAKSTONE'S or KNUDSEN Cottage Cheese", "1 cup KRAFT Shredded Sharp Cheddar Cheese", "1 can (2-1/4 oz.) sliced black olives, drained"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Cook The Book: Smoked Trout Chowder
# Ingredients: ["1 tablespoon butter", "2 medium leeks, white and light green parts only, cut lengthwise and thinly sliced (about 1 1/2 cups)", "2 stalks celery, cut into 1/2-inch dice (about 1 1/2 cups)", "1 medium carrot, cut into 1/2-inch dice (about 1 1/2 cups)", "2 cloves garlic, minced (about 1 tablespoon)", "2 medium Yukon gold potatoes, cut into 1-inch chunks", "2 cups water", "1/2 pound hot- or cold-smoked trout, broken into chunks", "3 cups whole milk", "Kosher salt and freshly ground black pepper", "2 tablespoons chopped fresh chives", "Chowder crackers"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Tempting Shrimp Phyllo Tarts
# Ingredients: ["4 ounces reduced-fat cream cheese", "1/4 cup shredded reduced-fat cheddar cheese", "3 tablespoons white wine or fat-free milk", "1/2 cup chopped cooked peeled shrimp", "1/2 teaspoon onion powder", "1/2 teaspoon salt", "1/4 to 1/2 teaspoon dried thyme", "2 packages (1.9 ounces each) frozen miniature phyllo tart shells"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Roasted Herb Potatoes
# Ingredients: ["1 x nonstick cooking spray vegetable", "3 medium potatoes", "2 tablespoons vegetable oil", "1/2 teaspoon rosemary leaves", "1/2 teaspoon salt"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Lisa'S Macaroni And Cheese
# Ingredients: ["2 pounds elbow macaroni", "10 ounces shredded Swiss cheese", "10 ounces shredded mozzarella cheese", "10 ounces shredded Cheddar cheese", "1/2 cup milk", "salt to taste", "1/8 teaspoon onion powder", "1 pinch garlic powder", "1/4 teaspoon dried parsley", "3 tablespoons margarine"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Friendship Brownies
# Ingredients: ["1 cup plus 2 tablespoons all-purpose flour", "2/3 cup packed brown sugar", "3/4 teaspoon salt", "2/3 cup sugar", "1 teaspoon baking powder", "1/3 cup baking cocoa", "1/2 cup semisweet chocolate chips", "1/2 cup chopped walnuts", "3 eggs", "2/3 cup canola oil", "1 teaspoon vanilla extract"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Very Very Snappy Shrimp Pasta
# Ingredients: ["1 Can Campbell's Cream of Shrimp Soup", "1 pound Pasta of your choice", "1 pinch Dried red pepper flakes", "2 tablespoons Fresh parsley", "1 pound Bag frozen cooked &amp; cleaned medium size shrimp", "4 tablespoons Parmesan cheese."]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Chilled Mixed Fruit
# Ingredients: ["1/2 cup sugar", "1/2 cup water", "2 medium grapefruit", "2 medium navel oranges", "1/4 cup lemon juice", "2 cups halved fresh strawberries", "1 medium apple, cut into 1/2-inch cubes", "1 medium pear, cut into 1/2-inch cubes", "1 medium banana, sliced", "1 cup halved green grapes"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Black Bean, Jicama, and Grilled Corn Salad
# Ingredients: ["2 large ears of corn, husked", "5 tablespoons extra-virgin olive oil, divided", "2 15-ounce cans black beans, rinsed, drained", "1 cup 1/3-inch dice peeled jicama", "1/2 cup 1/3-inch dice peeled carrots", "1/3 cup thinly sliced green onions", "1/3 cup chopped fresh cilantro", "1/4 cup (packed) chopped fresh basil", "3 tablespoons fresh lime juice", "2 tablespoons orange juice", "2 1/2 teaspoons grated lime peel", "1/4 teaspoon ground cumin"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Chocolate Gateau
# Ingredients: ["1 cup butter or margarine,softened", "1 cup sugar", "3 eggs", "3 ounces unsweetened chocolate melted", "1 teaspoon instant coffee crystals", "2 cups all-purpose flour Sifted", "1 teaspoon baking soda", "1 teaspoon salt", "1 cup whipping cream", "buttercream Chocolate, Filling*, recipe follows", "chocolate glaze recipe follows", "slivered almonds"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Sarah'S Slow Cooker Chicken Cacciatore
# Ingredients: ["1 1/2 pounds bone-in chicken thighs", "1 (14 ounce) can diced tomatoes", "1 (14 ounce) can chicken broth", "1 (4.5 ounce) can sliced mushrooms, drained", "1/4 teaspoon dried thyme", "12 ounces uncooked whole wheat penne pasta", "1 cup shredded Parmesan cheese", "1 cup shredded Romano cheese", "1 tablespoon cornstarch"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Oven Roasted Sea Bass & Vegetables
# Ingredients: ["4 pieces Sea Bass Fillets", "Old Bay Seasoning", "3/4 pounds, 38 ounces, weight Asparagus", "1 pound, 1-23 ounces, weight Baby Potatoes", "1 Tablespoon Olive Oil", "3 Tablespoons Balsamic Vinegar", "1/2 pounds, 2-58 ounces, weight Grape Tomatoes", "Salt And Pepper", "Fresh Basil"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Caprese Salad With Blueberry Croutons
# Ingredients: ["1 1/2 cups blueberries", "1 cup all-purpose flour", "2 large eggs, lightly beaten", "1 1/2 cups crushed cornflakes (done gently in a coffee grinder or food processor)", "2 1/2 tablespoons canola oil", "6 tablespoons extra-virgin olive oil", "2 tablespoons balsamic vinegar", "2 large ripe heirloom tomatoes, sliced", "12 ounces fresh mozzarella, sliced", "6 basil leaves, cut into thin strips"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Roasted Lemon-Basil Chicken
# Ingredients: ["1/3 cup Miracle Whip Original Spread Family Dollar $3.50 thru 02/07", "2 Tbsp. fresh lemon juice Safeway 4 ct For $5.00 thru 02/09", "2 tsp. honey", "1 tsp. dried basil leaves", "1 whole chicken (3 lb./1.4 kg), cut up Whole Foods 1 lb For $3.99 thru 02/09"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Caribbean Coffee
# Ingredients: ["1/2 cup Nabob Summit 100% Colombian Coffee", "1 tsp. pumpkin pie spice", "4 cups water", "4 cups skim milk", "1-1/4 tsp. coconut extract", "1 tsp. ground cinnamon"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Cold Angel Hair Pasta with Fresh Corn and Tomatoes
# Ingredients: ["8 to 10 ounces angel hair pasta (capellini)", "2 cups cooked fresh corn kernels (from 3 medium ears)", "2 pounds flavorful tomatoes, diced", "1/2 cup natural low-fat vinaigrette (try balsamic vinaigrette)", "6 to 8 fresh basil leaves, thinly sliced", "Salt and freshly ground pepper to taste"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Baked Tacos
# Ingredients: ["Ground Beef", "beans", "taco seasoning", "tomato sauce", "(any other favorite taco ingredients)", "cheese"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Oatmeal Raisin Cookies
# Ingredients: ["1/2 cup unsalted butter, softened", "1/2 cup butter flavored shortening", "1 cup packed light brown sugar", "1/2 cup white sugar", "2 eggs", "1 tsp vanilla extract", "1 1/2 cup flour", "1 tsp baking soda", "1 tsp ground cinnamon", "1/2 tsp ground cloves", "1/2 tsp salt", "3 cup rolled oats", "1 cup raisins"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Spaghetti and Chickpea 'Meatballs'
# Ingredients: ["1 can (14 fl oz/398 mL) chickpeas (garbanzo beans), rinsed", "1 onion, quartered", "3 cloves garlic", "1/2 cup fresh parsley", "1/4 cup Kraft Extra Virgin Olive Oil Italian Sun-Dried Tomato Dressing", "1 egg", "1/2 cup Kraft 100% Parmesan Shredded Cheese, divided", "1/2 cup dry bread crumbs", "220 g spaghetti, uncooked", "2 cups Classico di Napoli Tomato & Basil Pasta Sauce"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Creamed Spinach Deluxe Recipe
# Ingredients: ["2 Packages frzn minced spinach", "1 very lg. garlic pod", "1/8 pound butter", "1 can cream of mushroom soup", "Salt and pepper to taste"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Chicken Mexicana
# Ingredients: ["2 pkg. (6 oz. each) OSCAR MAYER CARVING BOARD Southwestern Seasoned Chicken Breast Strips", "1 cup TACO BELL Thick & Chunky Salsa", "1/2 cup KRAFT Mexican Style Shredded Cheese", "1/4 cup sliced black olives", "2 cups hot cooked instant brown rice", "1 Tbsp. chopped cilantro"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Shrimp with Spicy Peanut Sauce
# Ingredients: ["2 tablespoons ginger fresh, finely chopped", "2 each garlic cloves chopped", "13 cup red wine vinegar", "peanut butter creamy", "2 teaspoon red pepper flakes", "3 cup water creamy peanut butter", "1 1/2 lbs shrimp teaspoons hot red pepper flakes", "1/2 cup soy sauce, tamari", "3 cups water", "1 lemon sliced"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Strawberry Shortcake Kabobs
# Ingredients: ["1 box cake mix", "2 teaspoons butter", "1 1/3 cups water", "3/4 cup greek yogurt Vanilla", "2 pints strawberries", "2 cups chocolate chips 1 White, 1 Milk Chocolate", "1 cup heavy cream"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Aloha Ham-Wiches
# Ingredients: ["1/4 cup canned crushed pineapple in juice, well drained", "1/4 cup KRAFT Sweet'N Sour Sauce", "2 tsp. finely chopped red pepper", "12 slices OSCAR MAYER Deli Fresh Bold Brown Sugar Ham", "2 pieces leaf lettuce", "2 sandwich rolls, partially split"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Seared Cauliflower With Honey And Harissa
# Ingredients: ["1 head cauliflower, stem removed, cut into large florets", "2 tablespoons pistachio, toasted and rough chopped", "3 tablespoons olive oil", "1 cup parsley", "1 tablespoon Harissa", "4 tablespoons tahini", "2 tablespoons honey", "1 Orange, supremed"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Baked Salmon With Mandarin Orange And Pineapple Salsa
# Ingredients: ["16 ounces salmon filets wild Alaskan", "4 teaspoons lemon pepper seasoning", "1 cup red onion chopped", "2 cups mandarin oranges", "2 cups pineapple bits and pieces", "2 tablespoons honey", "1/4 cup pineapple juice", "1/4 cup cilantro", "1 pinch red pepper"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: The Elvis Tribute Krispy Kreme Bread Pudding
# Ingredients: ["1 cup Peanut Butter", "12 whole Krispy Kreme Glazed Donuts", "1/3 cups Milk", "2 whole Eggs", "1 can (14 Oz. Can) Sweetened Condensed Milk", "2 whole Bananas, Sliced"]
# Your response:
# Saving the dataset (0/1 shards):   0%|          | 0/1000 [00:00<?, ? examples/s]

# %%
adapter_path = f'{recipe_nlg_data_path}/7b_instruction_model_from_teacher'
adapter_path = f'{recipe_nlg_data_path}/14b_instruction_model_from_teacher'

config = PeftConfig.from_pretrained(adapter_path)

model_ft_teacher = PeftModel.from_pretrained(base_model, adapter_path)

ft_generation_save_path = f'file://{recipe_nlg_data_path}/Generated_Data/14b_instruction_model_from_teacher_generated_instructions'
# Out:
# /usr/local/lib/python3.11/dist-packages/peft/tuners/tuners_utils.py:190: UserWarning: Already found a `peft_config` attribute in the model. This will lead to having multiple adapters in the model. Make sure to know what you are doing!
#   warnings.warn(

# %%
test_generated = test_reason.map(
    generate_instruction_batch,
    batched=True,
    batch_size=BATCH_SIZE,
    fn_kwargs={"cot_prompt": True, "model": model_ft_teacher, "tokenizer": tokenizer}
)
test_generated.save_to_disk(ft_generation_save_path)
# Out:
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Use the provided reasoning to inform your response.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# Recipe Title: No-Crust Sweet Potato Pie
# Ingredients: ["4 medium sweet potatoes, or yams peeled, cooked, mashed", "1 cup sugar", "1/2 cup flour, all-purpose", "1/2 cup butter or margarine, softened", "1 each eggs", "1/2-1 teaspoons almond extract", "1 x whipped cream"]
# Reasoning: 1. Peeel and cook the sweet potatoes until they are tender. This process should take approximately 30 minutes to an hour, including preparation time.
# 2. Allow the cooked sweet potatoes to cool slightly before mashing them. Mash until smooth and creamy, which should take about 5-10 minutes.
# 3. In a separate bowl, mix together the sugar, flour, and almond extract. This step should only take about 5 minutes.
# 4. Add the dry mixture to the mashed sweet potatoes and stir until well combined. This step should take about 3-5 minutes.
# 5. In a separate bowl, cream the softened butter with a hand mixer or whisk until light and fluffy. This should take about 5-7 minutes.
# 6. Gradually add the egg to the butter mixture, one at a time, beating after each addition. This should take about 3-5 minutes per egg.
# 7. Fold the buttered mixture into the sweet potato mixture until fully incorporated. This should take about 2-3 minutes.
# 8. Pour the mixture into a pie crust or a greased pie dish.
# 9. Chill the filling in the refrigerator for at least 1 hour to allow the flavors to meld. This can take anywhere from 1-2 hours depending on your refrigerator's temperature.
# 10. Top the chilled filling with whipped cream and serve. This should take less than 5 minutes.
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Use the provided reasoning to inform your response.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# Recipe Title: Blueberry Chicken
# Ingredients: ["2 chicken breasts boneless skinless wholes, 1 LB total", "1 tablespoon vegetable oil canola, safflower, grapeseed", "1/3 cup apricot jam", "3 tablespoons dijon mustard", "1/2 cup blueberries frozen, unsweetened", "white wine vinegar"]
# Reasoning: - Cut the chicken into bite-sized pieces (5 minutes)
# - Heat the oil in a pan over medium heat (2 minutes)
# - Add the chicken to the pan and cook until browned on both sides (4-6 minutes per side)
# - Remove the chicken from the pan and set aside
# - In a separate bowl, mix together the apricot jam, dijon mustard, white wine vinegar, and blueberries
# - Return the chicken to the pan and pour the blueberry mixture over it
# - Cook for another 5-7 minutes, stirring occasionally, until the chicken is fully coated with the sauce
# - Serve hot and enjoy!
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Use the provided reasoning to inform your response.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# Recipe Title: Chorizo Quesadillas
# Ingredients: ["1 pound Bulk Chorizo", "1 whole Medium Onion, Chopped", "1 can Fiesta Nacho Cheese Soup", "1 pound Monterey Jack Cheese", "16 whole 6 Inch Flour Tortillas"]
# Reasoning: 1. Chop the onion
# 2. Heat a pan over medium heat
# 3. Cook the chorizo until browned and crispy
# 4. Prepare the tortillas by warming them in the microwave
# 5. Assemble the quesadillas by spreading cheese on one side of each tortilla and adding chorizo on top
# 6. Add another tortilla on top to create a sandwich
# 7. Cook the quesadillas in the heated pan until the cheese is melted and the tortillas are golden brown
# 8. Serve hot with salsa and sour cream if desired.
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Use the provided reasoning to inform your response.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# Recipe Title: Rye Cakes
# Ingredients: ["3 cups rye meal", "1 teaspoon salt", "1 cup milk sour", "1 teaspoon soda", "1 cup molasses", "2 egg"]
# Reasoning: 1. Mix the rye meal and salt together in a large bowl. This should take about 5 minutes.
# 2. In a separate bowl, mix the milk sour, soda, and molasses until well combined. This should take about 5 minutes as well.
# 3. Slowly pour the wet mixture into the dry mixture while stirring constantly to prevent lumps from forming. This should take about 5 minutes.
# 4. Let the mixture rest for about 10 minutes to allow the soda to activate and help the dough come together. This is a passive step and does not require constant attention.
# 5. After 10 minutes, beat the eggs in a separate bowl. This should take about 2 minutes.
# 6. Add the beaten eggs to the mixture and stir until fully incorporated. This should take about 2 minutes.
# 7. Preheat your oven to 350°F (180°C). This is a one-time task and does not need to be repeated for the rest of the recipe.
# 8. Using a spoon or scoop, portion out small amounts of the dough onto a floured surface. This should take about 5 minutes.
# 9. Roll each portion of dough into a ball and then flatten it slightly with your hands to form a round cake. This should take about 5 minutes per cake.
# 10. Place the formed cakes onto a baking sheet lined with parchment paper. This should take about 5 minutes.
# 11. Bake the cakes in the preheated oven for 20-25 minutes, or until they are golden brown on top and set. This should take about 25 minutes total.
# 12. Remove the cakes from the oven and let them cool on the baking sheet for 5 minutes before transferring them to a wire rack to cool completely. This should take about 5 minutes.
# 13. Serve the rye cakes warm or at room temperature. This is a passive step and does not require any additional action.
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Use the provided reasoning to inform your response.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# Recipe Title: Slow-Cooker Chicken Curry
# Ingredients: ["10 chicken thighs (2-3/4 lb.), skins removed", "1 jar (16 oz.) TACO BELL Thick & Chunky Salsa", "1 onion, chopped Safeway 3 lb For $2.99 thru 02/09", "2 Tbsp. curry powder", "1 cup BREAKSTONE'S FREE Fat Free Sour Cream"]
# Reasoning: 1. Remove the chicken thighs from the package and set aside.
# 2. Chop the onion into small pieces and set aside.
# 3. Check if you have curry powder, if not add it to your shopping list.
# 4. Check if you have BREAKSTONE'S FREE Fat Free Sour Cream, if not add it to your shopping list.
# 5. Open the jar of TACO BELL Thick & Chunky Salsa and check if it is not expired. If it has passed its expiration date, discard it and add salsa to your shopping list.
# 6. Add all ingredients to the slow cooker except for the sour cream. Stir until well combined.
# 7. Cover the slow cooker and cook on high for 4 hours.
# 8. After 4 hours, remove the lid and stir in the BREAKSTONE'S FAT FREE SOUR CREAM.
# 9. Serve hot with rice or other side dishes.
#
# The above reasoning process should help guide you through the preparation of the slow-cooker chicken curry. It covers all the necessary steps from removing the chicken thighs to adding the sour cream at the end. Make sure to check the expiration date on the jar of TACO BELL Thick & Chunky Salsa and add any missing ingredients to your shopping list. Enjoy your delicious homemade slow-cooker chicken curry!
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Use the provided reasoning to inform your response.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# Recipe Title: Beef & Noodles with Fresh Vegetables
# Ingredients: ["1/4 cup KRAFT Tuscan House Italian Dressing", "1/4 cup soy sauce", "1 lb. lean boneless beef sirloin steak, cut into strips Whole Foods 1 lb For $7.99 thru 02/09", "2 cloves garlic, minced", "2 cups sugar snap peas, halved", "1 yellow pepper, cut into strips Target 1 pkg For $2.99 thru 02/06", "1 tomato, chopped King Sooper's 1 lb For $0.99 thru 02/09", "1/4 cup chopped fresh cilantro", "3/4 lb. spaghetti, cooked"]
# Reasoning: The recipe requires some preparation and cooking time. Here is a detailed breakdown of the steps involved:
#
# Step 1: Prepare the marinade
# - Combine 1/4 cup of KRAFT Tuscan House Italian dressing and 1/4 cup of soy sauce in a bowl.
# - Add 2 cloves of minced garlic to the mixture.
# - Set aside the marinade to let it infuse the flavors.
#
# Step 2: Cook the beef
# - Cut the lean boneless beef sirloin steak into strips.
# - Heat a pan over medium heat on the stove.
# - Add the beef strips to the pan and cook until browned on all sides, about 5 minutes per side.
# - Remove the cooked beef from the pan and set it aside.
#
# Step 3: Cook the vegetables
# - In the same pan used for the beef, add the sugar snap peas and yellow pepper strips.
# - Cook for 3-4 minutes, or until the vegetables are tender but still crisp.
# - Add the chopped tomato to the pan and continue cooking for another minute.
#
# Step 4: Finish the dish
# - Return the cooked beef to the pan with the vegetables.
# - Stir in the chopped fresh cilantro.
# - Serve the beef and vegetable mixture over the cooked spaghetti.
#
# This recipe should take approximately 25 minutes to complete, including marinating the beef and cooking time. Enjoy your delicious Beef & Noodles with Fresh Vegetables!
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Use the provided reasoning to inform your response.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# Recipe Title: Black And White Chili
# Ingredients: ["1 pound Chicken tenders, cut into 3/4 inch pieces", "1 cup coarsely chopped onions", "1 can (15 ounce) black beans, drained", "1 can (14 ounce) Mexican-style stewed tomatoes, undrained", "2 TBS Texas-style chili powder seasoning mix"]
# Reasoning: Step 1: Prepare the chicken. This requires cutting it into small pieces, which should take approximately 10 minutes.
# Step 2: Start preparing the vegetables. First, chop the onion, which should take about 5 minutes.
# Step 3: Open the cans of black beans and drain them. This task is likely to take around 10 minutes due to the need to wait for the water to drain.
# Step 4: Drain the can of stewed tomatoes without opening it. This task is also expected to take around 10 minutes due to the need to wait for the liquid to drain.
# Step 5: Combine the prepared chicken with the chopped onion. This step should take about 5 minutes.
# Step 6: Add the drained black beans and the undrained stewed tomatoes to the mixture. These additions are likely to take another 5 minutes.
# Step 7: Finally, sprinkle the Texas-style chili powder seasoning mix over the entire mixture. This task is quick and should only take around 1 minute.
#
# Therefore, the total estimated time to prepare the black and white chili is around 40 minutes. Please note that these times are approximate and may vary depending on individual skill levels and kitchen setup.
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Use the provided reasoning to inform your response.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# Recipe Title: Sweet And Spicy Hash With Baked Eggs
# Ingredients: ["1 whole Raw Chorizo Link, Casing Removed", "1 whole Large Sweet Potato, Peeled And Diced", "1 whole Medium Russet Potato, Peeled And Diced", "1 whole Small Red Onion, Diced", "2 pinches Salt And Freshly Cracked Pepper", "2 whole Large Eggs", "1 bunch (about A Handfull) Chopped Parsley", "1/4 cups Crumbled Feta Cheese", "1/2 whole Avocado, Pitted, Peeled And Sliced"]
# Reasoning: 1. Cut off the casing of the raw chorizo link.
# 2. Chop the parsley into small pieces.
# 3. Dice the sweet potato and the russet potato into small cubes.
# 4. Finely dice the red onion.
# 5. Season the diced sweet potatoes and red onions with salt and freshly cracked pepper.
# 6. Heat up a large pan over medium heat.
# 7. Add the chopped parsley to the pan and sauté until it is fragrant.
# 8. Remove the parsley from the pan and set aside.
# 9. Add the raw chorizo to the pan and cook until browned and crispy.
# 10. Remove the cooked chorizo from the pan and set aside.
# 11. Add the diced sweet potatoes and red onions to the pan and cook until they are tender.
# 12. While the vegetables are cooking, beat the eggs in a separate bowl.
# 13. Once the vegetables are cooked, add the cooked chorizo back to the pan with the vegetables.
# 14. Stir everything together and cook for an additional 2-3 minutes.
# 15. Divide the mixture between two plates.
# 16. Top each plate with crumbled feta cheese and sliced avocado.
# 17. Serve immediately.
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Use the provided reasoning to inform your response.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# Recipe Title: Tulsa Fire Department Chili
# Ingredients: ["2 pounds ground beef", "1 medium onions chopped", "2 tablespoons chili powder", "1 teaspoon cumin ground", "1 teaspoon salt", "2 each garlic cloves crushed", "10 1/2 ounces beef stock", "2 cups pinto beans canned", "8 ounces tomato sauce", "1 tablespoon flour, all-purpose or more", "1/4 cup water"]
# Reasoning: Step 1: Preparation
# - Ground beef is the main ingredient, so it should be the first thing to prepare.
# - Start by browning the ground beef in a large pot over medium heat until it's fully cooked. This process helps create flavor and texture for the dish.
#
# Step 2: Sautéing the Onions
# - Once the ground beef is browned, add chopped onion to the pot.
# - Let them sauté until they become soft and translucent.
# - This step not only adds flavor but also makes the chili hearty.
#
# Step 3: Adding Spices
# - After sautéing the onions, sprinkle the chili powder, cumin, and salt evenly over the mixture.
# - Stir well to ensure that the spices are mixed evenly throughout the pot.
#
# Step 4: Cooking with Garlic
# - Add the crushed garlic to the pot and stir well.
# - Let it simmer for a few minutes to allow the garlic flavor to infuse into the chili.
#
# Step 5: Adding Liquid
# - Now, add the beef stock to the pot.
# - Stir well to combine everything together.
#
# Step 6: Canned Beans and Tomato Sauce
# - Next, add the canned pinto beans and tomato sauce to the pot.
# - Stir well to make sure the beans are coated with the other ingredients.
#
# Step 7: Flour and Water Mix
# - In a small bowl, mix 1 tablespoon of flour with 1/4 cup of water.
# - This mixture will help thicken the chili.
#
# Step 8: Adding Thickening Agent
# - Slowly pour the flour and water mixture into the pot, stirring constantly to avoid lumps.
# - Continue stirring until the chili thickens to your desired consistency.
#
# Step 9: Simmering
# - Allow the chili to simmer for about 30 minutes, giving all the flavors time to meld together.
# - This step is important to ensure that the flavors blend perfectly and the chili reaches the right consistency.
#
# Step 10: Serving
# - Finally,
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Use the provided reasoning to inform your response.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# Recipe Title: Pork Roast With Apricot-Rice Stuffing
# Ingredients: ["2-3/4 cups water", "1/2 cup chopped dried apricots", "2 tablespoons sugar", "1 cup uncooked long grain rice", "1 small onion, chopped", "1/4 cup minced fresh parsley", "1/4 cup butter, cubed", "2 teaspoons grated lemon zest", "1/4 teaspoon salt", "1/8 teaspoon pepper", "1 bone-in pork loin roast (4 pounds)", "3/4 cup apricot preserves", "4 teaspoons lemon juice"]
# Reasoning: Step 1: Preparation
# 1. Rinse the dried apricots under running water to remove any dust or debris.
# 2. In a medium saucepan, bring the water to a boil over high heat. Add the apricots and reduce the heat to medium-low. Simmer until the apricots have softened and broken down into a pulp. This should take about 15 minutes.
# 3. In a separate bowl, mix together the sugar, salt, and pepper.
# 4. While the apricots are cooking, start preparing the rice. Rinse it under cold water until the water runs clear. Then add it to a pot with the cubed butter and stir to coat the rice in the melted butter.
# 5. Once the apricots have finished cooking, let them cool slightly. Then mash them with a fork or potato masher until they become a smooth paste.
# 6. Add the apricot paste, minced parsley, lemon zest, and lemon juice to the rice mixture, and stir well to combine.
# 7. Set aside the rice and apricot mixture while you prepare the pork loin.
#
# Step 2: Cooking the Pork Loin
# 8. Preheat your oven to 325°F (160°C).
# 9. Season the pork loin with the salt, pepper, and apricot mixture. Rub it evenly all over the meat.
# 10. Place the pork loin in a roasting pan and roast it in the preheated oven for about 2-3 hours, or until the internal temperature reaches 145°F (63°C) using a meat thermometer. Let the pork rest for 10-15 minutes before slicing it thinly against the grain and serving it with the apricot-rice stuffing.
#
# Step 3: Assembly
# 11. Scoop out a cavity in the center of the cooked pork loin, making sure not to cut all the way through.
# 12. Fill the cavity with the apricot-rice mixture, pressing it in firmly but gently to fit it inside without breaking apart.
# 13. Close the
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Use the provided reasoning to inform your response.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# Recipe Title: Raspberry Chicken Salad
# Ingredients: ["8 cups mixed salad greens", "12 oz. , cut into bite sized pieces", "1 cup fresh or frozen raspberries", "1/3 cup PLANTERS Walnut Pieces", "1/3 cup KRAFT Lite Raspberry Vinaigrette Dressing", "32", "4 medium apples", "8 SNACKWELL'S Sugar Free Lemon Creme Sandwich Cookies", "32 fl oz (4 cups) drinking water"]
# Reasoning: 1. Start by washing the salad greens thoroughly and letting them dry. This can take around 5 minutes.
# 2. Prepare the chicken by cutting it into bite-sized pieces. This should take about 10 minutes.
# 3. In a separate bowl, mix together the PLANTERS Walnut Pieces and KRAFT Lite Raspberry Vinaigrette Dressing until well combined. This should take less than 5 minutes.
# 4. Toss the prepared chicken with the salad greens and the nut-dressing mixture until evenly coated. This should take around 5 minutes.
# 5. Next, slice the apples and add them to the salad. This should take about 5 minutes.
# 6. Crush the SNACKWELL'S Sugar Free Lemon Creme Sandwich Cookies to crumble them into small pieces. This should take around 5 minutes.
# 7. Add the cookie crumbles to the salad and toss everything together until evenly distributed. This should take around 5 minutes.
# 8. Finally, pour the drinking water over the salad and gently toss again to combine. This should take less than 5 minutes.
# 9. Serve immediately. Enjoy your delicious Raspberry Chicken Salad!
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Use the provided reasoning to inform your response.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# Recipe Title: Sweet And Savory Waffled Sausage Patties
# Ingredients: ["2 tablespoons maple syrup", "1 teaspoon dried sage", "1 teaspoon salt", "1/2 teaspoon freshly ground black pepper", "1/4 teaspoon dried marjoram", "1/8 teaspoon cayenne pepper", "1 pound ground pork", "nonstick cooking spray"]
# Reasoning: 1. Preheat your waffle iron.
# 2. In a large bowl, mix together the ground pork, salt, sage, marjoram, black pepper, cayenne pepper, and maple syrup until well combined.
# 3. Divide the mixture into 6 equal parts.
# 4. Form each part into a round patty.
# 5. Spray your non-stick waffle iron with cooking spray.
# 6. Once heated, place a patty on the waffle iron and cook until golden brown, about 4-5 minutes per side.
# 7. Repeat for the remaining patties.
# 8. Serve hot with your favorite toppings.
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Use the provided reasoning to inform your response.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# Recipe Title: Bob Marley
# Ingredients: ["12 ounces fresh orange juice", "6 ounces overproof rum", "6 ounces dark creme de cacao", "6 ounces orange curacao", "4 ounces sweet vermouth", "1 1/2 ounces fresh lime juice", "1 ounce grenadine", "Ice"]
# Reasoning: The Bob Marley is a refreshing cocktail with a tropical twist. Here's the step-by-step process to make it:
#
# 1. Start by preparing all the ingredients. Chill your glasses and prepare ice.
# 2. Fill a shaker with ice, then add the 12 ounces of fresh orange juice, 6 ounces of dark crème de cacao, 6 ounces of orange curaçao, 4 ounces of sweet vermouth, 1 ½ ounces of fresh lime juice, and 1 ounce of grenadine.
# 3. Shake well until everything is mixed and cold. This should take about 30 seconds to a minute.
# 4. Strain the mixture into the prepared chilled glasses.
# 5. Top off each glass with ice.
# 6. Enjoy your delicious Bob Marley cocktails!
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Use the provided reasoning to inform your response.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# Recipe Title: Baked Walleye With Vegetables
# Ingredients: ["1 small onion, thinly sliced", "1 tablespoon olive oil", "2 small zucchini, julienned", "1 cup sliced fresh mushrooms", "1/4 teaspoon pepper", "1/8 teaspoon garlic powder", "2 tablespoons lemon juice", "2 tablespoons grated Parmesan cheese, divided", "4 walleye fillets (about 6 ounces each)", "1 tablespoon butter, melted"]
# Reasoning: 1. Heat oven to 375 degrees F.
# 2. In a large baking dish, combine sliced onions with olive oil, salt, pepper, garlic powder, lemon juice, and half of the Parmesan cheese. Mix well.
# 3. Arrange the vegetable mixture evenly across the bottom of the baking dish.
# 4. Season the fish fillets with remaining Parmesan cheese.
# 5. Place the fish fillets on top of the vegetables.
# 6. Dot the top of the fish with melted butter.
# 7. Cover the dish with aluminum foil and bake for 20 minutes.
# 8. Remove the foil and continue baking until the fish is opaque and flakes easily with a fork, about 10-15 minutes more.
# 9. Serve hot with additional lemon wedges, if desired.
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Use the provided reasoning to inform your response.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# Recipe Title: Chocolate Fudge Frosting
# Ingredients: ["1 1/2 cups (375 mL) confectioners sugar", "3/4 cup (175 mL) unsweetened Dutch-process cocoa powder, sifted", "1/2 cup (125 mL) unsalted butter, at room temperature", "2 tbsp (25 mL) chocolate cream liqueur", "1 tbsp (15 mL) strong brewed coffee or milk", "Pinch salt"]
# Reasoning: To make the chocolate fudge frosting, start by gathering all necessary ingredients including confectioners sugar, unsweetened Dutch-process cocoa powder, unsalted butter, chocolate cream liqueur, strong brewed coffee or milk, and a pinch of salt. Sift the cocoa powder to ensure it is free of lumps. Once you have all the ingredients ready, proceed with the following steps:
#
# 1. In a medium mixing bowl, combine the confectioners sugar and sifted cocoa powder.
# 2. Add the unsalted butter to the dry mixture and beat it until it's well combined. It should result in a smooth, consistent texture.
# 3. Next, add the chocolate cream liqueur and strong brewed coffee or milk to the mixture. Be careful not to add too much liquid as it can make the frosting too runny. Start with a small amount and adjust as needed to achieve the desired consistency.
# 4. Finally, add a pinch of salt to enhance the flavor of the frosting. Mix everything together until the frosting is smooth and evenly colored.
# 5. Taste the frosting and adjust the sweetness level if necessary by adding more sugar or reducing the amount of liqueur.
# 6. Store the chocolate fudge frosting in an airtight container in the refrigerator for up to two weeks. Allow it to sit at room temperature for about 30 minutes before using it to spread it evenly on your desired baked goods. Enjoy!
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Use the provided reasoning to inform your response.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# Recipe Title: Chicken Singapore Noodles
# Ingredients: ["2 tbsp peanut oil", "1 lb boneless skinless chicken thighs, thinly sliced", "4 None green onions, sliced", "1 tbsp curry powder", "2 cloves garlic, finely chopped", "13 oz thin fresh egg noodles", "1/3 cup chicken stock, heated", "2 tsp brown sugar", "2 tsp soy sauce", "4 oz snow peas", "1 None red chili pepper, sliced (optional)"]
# Reasoning: 1. Heat the peanut oil in a large wok over medium-high heat. Add the chicken to the wok and cook until it is browned and cooked through. This should take about 5 minutes.
# 2. Remove the chicken from the wok and set aside.
# 3. In the same wok, add the green onions and garlic and sauté for about 1 minute.
# 4. Add the curry powder and stir to coat the onions and garlic evenly. Cook for another minute.
# 5. Pour in the chicken stock, bring to a boil, then reduce the heat and simmer for about 2 minutes.
# 6. Stir in the brown sugar and soy sauce until they are fully dissolved.
# 7. Add the noodles to the wok and cook according to package instructions.
# 8. While the noodles are cooking, prepare the vegetables. Blanch the snow peas in boiling water for 2-3 minutes, then drain and set aside. If using red chili pepper, slice it into thin strips.
# 9. Once the noodles are cooked, remove them from the wok and set aside with the chicken.
# 10. Return the wok to the stove and add the chicken back into the wok with the sauce. Stir to combine and let it heat through.
# 11. Serve the chicken and noodles together on a plate, garnished with the green onions and sliced red chili pepper if using. Enjoy!
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Use the provided reasoning to inform your response.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# Recipe Title: Country Two-Cheese Sandwich Grill
# Ingredients: ["2 cups Kraft Sauce Works Dijon Bistro Sauce", "48 slices country white bread slices (1/2 inch thick)", "24 slices fontina cheese slices (1 oz./30 g each)", "3 cups caramelized onions", "1-1/2 qt. roasted red peppers, cut into strips", "24 slices smoked Gouda cheese, sliced (1 oz./30 g each)", "1 cup butter, softened"]
# Reasoning: 1. Preheat a grill or grill pan over medium heat.
# 2. While waiting for the grill to heat up, begin preparing the ingredients. First, spread 2 cups of Kraft Sauce Works Dijon Bistro Sauce onto one side of each slice of country white bread. Next, set aside the sauced bread.
# 3. In a separate bowl, mix together the caramelized onions, roasted red peppers, and smoked Gouda cheese until well combined. Set this mixture aside as well.
# 4. Once the grill is heated, place a slice of bread with the sauced side facing down onto the grill. Then, add a layer of the cheese and vegetable mixture on top of the bread. Repeat this process with the remaining bread slices, ensuring that each slice has a different combination of toppings.
# 5. Once all sandwiches have been assembled, close the lid of the grill and cook for approximately 2-3 minutes per side, or until the bread is golden brown and the cheese is melted.
# 6. Remove the sandwiches from the grill and let them cool for a few moments before serving. Enjoy your delicious Country Two-Cheese Sandwich Grill!
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Use the provided reasoning to inform your response.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# Recipe Title: Carrot "Pasta" With Hot Peppered Raisins
# Ingredients: ["1 box plain or falvored quick cooking couscous", "2 tablespoons light vegetable oil", "2 tablespoons unsalted butter", "2 large shallots, minced", "A 1-inch piece fresh ginger, peeled and finely chopped", "8 ounces golden raisins", "1/4 teaspoon hot red pepper flakes, or more to taste", "10 large carrots, preferably California grown core; discard cores", "2 cups heavy cream", "1-1/2 cups light vegetable broth", "1 cup thawed petite peas", "kosher salt and freshly ground black pepper, to taste"]
# Reasoning: 1. Start with preparing the ingredients. Begin with the most time-consuming task which is cooking the couscous according to package directions until al dente. Set aside.
# 2. While waiting for the couscous to cook, start on the next most time-consuming task which is sautéing the vegetables. Heat the olive oil in a large pan over medium heat. Add the butter and let it melt. Then add the shallots and ginger and cook until they become translucent, about 5 minutes.
# 3. Add the golden raisins and stir to combine. Cook for another 2-3 minutes while adding the hot red pepper flakes.
# 4. Next, prepare the carrots. Wash and peel them, then cut off the ends and slice them into thin strips.
# 5. In another pot, bring the heavy cream and light vegetable broth to a boil. Reduce the heat and simmer until the sauce thickens slightly, about 5-7 minutes. Season with kosher salt and freshly ground black pepper to taste.
# 6. Once the sauce is ready, add the carrot strips and cook until tender, about 5 minutes.
# 7. Remove the pan with the sautéed vegetables and golden raisins from heat and stir in the petite peas.
# 8. Finally, combine the cooked couscous with the sauce and vegetable mixture. Mix well to ensure everything is evenly coated.
# 9. Serve hot and enjoy your delicious homemade "pasta"!
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Use the provided reasoning to inform your response.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# Recipe Title: Golden Fig and Mascarpone Tart
# Ingredients: ["Feuille de'Bric or phyllo dough", "4 fresh white figs, in syrup", "1/2 cup mascarpone cheese", "1/4 cup heavy cream", "1 egg", "Kosher salt", "Ground black pepper", "1 teaspoon black fig syrup"]
# Reasoning: The process of making a Golden Fig and Mascarpone Tart can be broken down into several steps. First, the phyllo dough needs to be thawed. This should take approximately 30 minutes. Once thawed, it can be rolled out on a floured surface, which should take around 10 minutes. Next, the dough is cut into a circle with a diameter of about 9 inches. This task might take 5-7 minutes, depending on the skill level of the person doing it.
#
# Once the crust is ready, the next step is to prepare the filling. For this, the mascarpone cheese, heavy cream, egg, kosher salt, ground black pepper, and black fig syrup are mixed together until smooth. This should take around 10-15 minutes. The amount of time may vary depending on how thoroughly you want to mix these ingredients.
#
# After the mixture is well combined, the fresh figs are sliced and then spread over the bottom of the tart crust. This should take about 5-7 minutes. Then, the mascarpone mixture is carefully spread over the top of the figs, taking care not to disturb them too much. This should also take around 5-7 minutes.
#
# Finally, the tart is chilled in the fridge for at least one hour. This allows the flavors to meld together and the tart to set properly. Overall, the entire process of making a Golden Fig and Mascarpone Tart from start to finish could take up to 3 hours and 15 minutes, including thawing the phyllo dough and waiting for the tart to chill.
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Use the provided reasoning to inform your response.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# Recipe Title: Dark Chocolate Panna Cotta
# Ingredients: ["1 can (14 ounces) whole-berry cranberry sauce", "5 tablespoons raspberry liqueur, divided", "1 envelope unflavored gelatin", "1 cup cold 2% milk", "4 ounces 53% cacao dark baking chocolate, chopped", "1-1/2 cups heavy whipping cream", "1/2 cup sugar", "1/8 teaspoon salt", "2 teaspoons vanilla extract", "Fresh raspberries and mint leaves, optional"]
# Reasoning: The recipe is a dessert dish called Dark Chocolate Panna Cotta. It involves preparing a mixture of cranberry sauce, raspberry liqueur, gelatin, milk, chocolate, cream, sugar, salt, and vanilla extract to create a creamy and sweet panna cotta. Optional fresh raspberries and mint leaves can be added on top as garnish.
#
# Here's a detailed step-by-step process for making Dark Chocolate Panna Cotta:
#
# 1. Begin by preparing the cranberry sauce. Open the can and scoop out 14 ounces of whole-berry cranberry sauce. Set it aside.
#
# 2. In a small bowl, sprinkle the gelatin over 1/2 cup of cold 2% milk, allowing it to soften and absorb the liquid. This will take about 5 minutes.
#
# 3. Melt the 4 ounces of 53% cacao dark baking chocolate in a double boiler or in the microwave. Once melted, set it aside to cool slightly.
#
# 4. In a medium-sized mixing bowl, combine the remaining 1 cup of cold 2% milk with the sugar and salt. Whisk until the sugar is fully dissolved. Add the vanilla extract and mix well.
#
# 5. Slowly pour the sweetened milk mixture into the softened gelatin, whisking continuously to prevent lumps from forming.
#
# 6. Stir in the melted cooled chocolate until well combined.
#
# 7. Pour the mixture into individual serving cups or a large baking dish. Cover with plastic wrap and refrigerate for at least 4 hours or until set.
#
# 8. Just before serving, top the panna cotta with fresh raspberries and mint leaves if desired.
#
# This recipe should yield a rich and creamy Dark Chocolate Panna Cotta, perfect for any dessert occasion. Enjoy!
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Use the provided reasoning to inform your response.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# Recipe Title: Cranberry And Chestnut Dressing
# Ingredients: ["Cooking spray", "1 cup chopped onion", "3/4 cup chopped pancetta (about 5 ounces)", "3 garlic cloves, minced", "1/4 cup dry white wine", "1 cup dried cranberries", "1/2 cup coarsely chopped bottled chestnuts", "1 tablespoon chopped fresh sage", "1/4 teaspoon salt", "1/4 teaspoon freshly ground black pepper", "8 ounces day-old Italian or French bread, torn into 1-inch pieces", "2 1/4 cups fat-free, less-sodium chicken broth"]
# Reasoning: Step 1: Preheat your oven to 350°F (175°C).
# Step 2: Grease a large mixing bowl with cooking spray.
# Step 3: In a pan over medium heat, sauté the chopped onion until it becomes translucent, about 5 minutes. Set aside.
# Step 4: Sauté the chopped pancetta in the same pan until crispy, about 6-7 minutes. Remove from heat and set aside.
# Step 5: In a separate pan, add the minced garlic and sauté for 1 minute until fragrant.
# Step 6: Add the dry white wine to the pan and bring to a boil. Reduce the heat and let it simmer for 5 minutes.
# Step 7: Add the dried cranberries, chestnuts, chopped sage, salt, and black pepper to the pan. Stir well to combine.
# Step 8: Add the cooked onion and pancetta to the pan, stirring well to combine.
# Step 9: Toss the bread into the pan and mix everything together until the bread is evenly coated.
# Step 10: Pour in the chicken broth and mix until the bread has absorbed most of the liquid. If the dressing is too wet, bake in the preheated oven for 15-20 minutes or until it reaches your desired consistency.
# Step 11: Serve warm or at room temperature. Enjoy!
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Use the provided reasoning to inform your response.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# Recipe Title: Welsh Rarebit
# Ingredients: ["1/2 loaves French Or Italian Bread", "2 Tablespoons Butter", "2 Tablespoons Flour", "1/2 cups Whole Milk", "1/2 cups Your Favorite Beer", "1 teaspoon Dijon Mustard", "1/2 teaspoons Paprika", "3 dashes Cayenne Pepper", "1/4 teaspoons Worcestershire Sauce", "1- 1/2 cup Cheddar Cheese, Grated", "1 whole Egg Yolk", "4 slices Bacon, Cooked And Crumbled", "13 cups Chopped Chives, For Garnish"]
# Reasoning: This recipe is a savory dish called Welsh Rarebit, which consists of grilled cheese with beer, typically made with cheddar cheese on toasted bread. The main ingredients include bread, butter, flour, milk, beer, mustard, paprika, cayenne pepper, worcestershire sauce, grated cheese, egg yolk, bacon, and chopped chives.
#
# The first step would be to prepare the ingredients. This includes softening the butter and melting it, stirring flour into the melted butter to make a paste, adding milk to the mixture while whisking constantly to prevent lumps, heating the beer in a separate pan until it's warm, and finally whisking it into the milk mixture.
#
# Next, you would need to season the mixture. This involves adding the mustard, paprika, cayenne pepper, and worcestershire sauce to the mixture and whisking well to combine.
#
# Then, you would prepare the cheese by grating it.
#
# After that, you would heat a large skillet over medium heat and add the butter and flour mixture (roux) to the skillet, stirring constantly until it forms a golden brown color and smells nutty.
#
# Once the roux is ready, you would slowly pour the seasoned milk mixture into the skillet, whisking constantly to prevent lumps from forming.
#
# Next, you would add the grated cheese to the skillet, stirring constantly until it is fully melted and the cheese is evenly distributed throughout the sauce.
#
# Finally, you would remove the skillet from the heat and stir in the egg yolk and crumbled bacon.
#
# The dish can then be served immediately, garnished with chopped chives for a beautiful presentation.
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Use the provided reasoning to inform your response.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# Recipe Title: Whole Wheat Snickerdoodles Recipe
# Ingredients: ["1 c. safflower oil", "1 1/2 c. sugar", "2 Large eggs", "2 3/4 c. whole wheat pastry flour", "2 teaspoon cream of tartar", "1 teaspoon soda", "1/2 teaspoon salt", "1 teaspoon vanilla"]
# Reasoning: Step 1: Preheat oven to 350°F (180°C).
# Step 2: In a large mixing bowl, whisk together 1 cup of safflower oil, 1 1/2 cups of sugar, 2 large eggs, 2 3/4 cups of whole wheat pastry flour, 2 teaspoons of cream of tartar, 1 teaspoon of baking soda, 1/2 teaspoon of salt, and 1 teaspoon of vanilla extract until well combined. Mix until smooth.
# Step 3: In a separate bowl, mix 1 cup of sugar with 1/2 teaspoon of cream of tartar and 1/2 teaspoon of baking soda. Stir until well combined.
# Step 4: Add the dry mixture to the wet mixture slowly while stirring continuously until just combined.
# Step 5: Scoop spoonfuls of dough onto a greased cookie sheet. Roll each spoonful into a ball between your hands and then into a ball shape.
# Step 6: Place the balls on the cookie sheet about 2 inches apart.
# Step 7: Bake for 12-14 minutes, or until golden brown around the edges.
# Step 8: Remove from oven and let cool for a few minutes before transferring to a wire rack to cool completely.
# Step 9: Serve warm or at room temperature. Enjoy!
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Use the provided reasoning to inform your response.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# Recipe Title: Skillet-Roasted Spiced Okra
# Ingredients: ["3/4 tsp. hot paprika", "1/4 tsp. ground cumin", "1/4 tsp. ground coriander", "1/4 tsp. ground fennel seeds", ".13 tsp. turmeric", "1 pinch cinnamon", "1 pinch ground fenugreek", "2 tbsp. vegetable oil", "1 lb. small okra", "salt", "2 tbsp. fresh lemon juice"]
# Reasoning: The first task is to prepare the spice mixture which includes hot paprika, ground cumin, ground coriander, ground fennel seeds, turmeric, cinnamon, ground fenugreek, salt, and vegetable oil. These ingredients should be mixed together in a bowl until well combined. This step should take approximately 5 minutes.
#
# Next, the okra needs to be sliced into thin rounds. It's important to remove the stem and tip of each okra pod to ensure it cooks evenly. This step should also take about 5 minutes.
#
# After preparing the spice mixture and slicing the okra, the next step is to heat the vegetable oil in a large skillet over medium-high heat. Once the oil is hot, add the spice mixture to the skillet and stir to coat the oil evenly. This step should take about 3 minutes.
#
# Once the spice mixture has been added to the skillet, the okra can be added. Spread the okra out in a single layer on the skillet. Cook the okra for about 8 minutes on each side, stirring occasionally, until it becomes golden brown and crispy. This step should take about 16 minutes total.
#
# Finally, the skillet-roasted spiced okra is ready to be served. Sprinkle with a pinch of salt and a squeeze of fresh lemon juice before serving. This step should take less than a minute.
#
# Total estimated time for the entire recipe: 30 minutes.
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Use the provided reasoning to inform your response.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# Recipe Title: Fancy Feast Omlette For Two
# Ingredients: ["3 Eggs", "1/2 small red onion", "1/2 cup cubed butternut squash", "1/4 cup gorgonzola cheese", "rubbed sage", "1 tablespoon high fat content butter"]
# Reasoning: 1. Crack 3 eggs into a mixing bowl.
# 2. Finely chop 1/2 small red onion and set aside.
# 3. Cube 1/2 cup of butternut squash and set aside.
# 4. Grate 1/4 cup of gorgonzola cheese and set aside.
# 5. Finely chop fresh sage leaves (optional) and set aside.
# 6. Heat a non-stick pan over medium heat.
# 7. Melt 1 tablespoon of high fat content butter in the pan.
# 8. Once the butter has melted, pour the eggs into the pan.
# 9. Let the eggs cook without stirring until the edges start to set.
# 10. Add the chopped onion to one side of the omelet.
# 11. Sprinkle the grated cheese over the other half of the omelet.
# 12. Add the cubed butternut squash to the same side as the cheese.
# 13. If using fresh sage, sprinkle it over the top of the omelet.
# 14. Use a spatula to carefully fold the omelet in half.
# 15. Cook for an additional 1-2 minutes, until the cheese is melted and the omelet is cooked through.
# 16. Slide the omelet onto a plate and serve immediately.
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Use the provided reasoning to inform your response.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# Recipe Title: Greek Tomato-Feta Quinoa Salad
# Ingredients: ["2 cups Water", "1 cup Quinoa", "1/4 cups Extra Virgin Olive Oil", "2 Tablespoons Freshly Squeezed Lemon Juice", "2 Tablespoons Water", "2 teaspoons Honey", "2 teaspoons Dried Oregano", "Salt And Freshly Ground Black Pepper", "1/2 Orange Bell Pepper, Diced", "1/2 Cucumber, Diced", "1/2 cups Feta Cheese Crumbles", "3 Tablespoons Fresh Chives, Chopped", "3 Tablespoons Fresh Parsley, Chopped", "1 cup Cherry Tomatoes, Sliced"]
# Reasoning: Step 1: Rinse quinoa in a fine mesh strainer under cold water until the water runs clear. Set aside.
# Step 2: In a medium saucepan, bring the water and quinoa to a boil over high heat. Once boiling, reduce the heat to low, cover, and simmer for about 15 minutes or until the quinoa is tender and the water has been absorbed. Let it cool down.
# Step 3: While the quinoa is cooking, prepare all the vegetables (bell pepper, cucumber) by dicing them into small pieces.
# Step 4: Prepare the dressing by combining extra virgin olive oil, lemon juice, water, honey, dried oregano, salt, and black pepper in a small bowl. Mix well until all ingredients are combined.
# ...
# 13. Heat the tomato sauce in a pan over medium heat until it's warm and bubbly.
# 14. Once the spaghetti is done, drain it and add it to the tomato sauce.
# 15. Serve the spaghetti and chickpea 'meatballs' together. Enjoy!
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Use the provided reasoning to inform your response.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# Recipe Title: Creamed Spinach Deluxe Recipe
# Ingredients: ["2 Packages frzn minced spinach", "1 very lg. garlic pod", "1/8 pound butter", "1 can cream of mushroom soup", "Salt and pepper to taste"]
# Reasoning: Step 1: Firstly, it's important to thaw out the frozen spinach according to package instructions. This might take around 5 minutes.
# Step 2: Once the spinach is thawed, squeeze out as much water as possible to remove excess moisture. This could take up to 10 minutes depending on the amount of spinach.
# Step 3: While waiting for the spinach to thaw and dry, you can start with chopping the large garlic pod into smaller pieces. It usually takes about 2-3 minutes.
# Step 4: After chopping the garlic, set it aside for later use. Now, take the 1/8 pound of butter and put it in a saucepan over medium heat.
# Step 5: Melt the butter until it turns golden brown. This should take approximately 3-4 minutes.
# Step 6: Add the cream of mushroom soup to the saucepan while continuously stirring to prevent burning. This process might take around 2-3 minutes.
# Step 7: Add salt and pepper to taste, and stir well.
# Step 8: Finally, add the thawed and drained spinach to the saucepan, and mix everything together. Cook for another 5 minutes, stirring occasionally, until the spinach is heated through.
# Step 9: Serve hot and enjoy your delicious creamed spinach!
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Use the provided reasoning to inform your response.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# Recipe Title: Chicken Mexicana
# Ingredients: ["2 pkg. (6 oz. each) OSCAR MAYER CARVING BOARD Southwestern Seasoned Chicken Breast Strips", "1 cup TACO BELL Thick & Chunky Salsa", "1/2 cup KRAFT Mexican Style Shredded Cheese", "1/4 cup sliced black olives", "2 cups hot cooked instant brown rice", "1 Tbsp. chopped cilantro"]
# Reasoning: 1. Prepare the chicken: Follow the package instructions to prepare the chicken strips according to the provided directions. This process usually involves placing the chicken on a cutting board and cutting it into strips. It's important to make sure the chicken is fully cooked before moving on to the next step.
# 2. Heat up the skillet: In a large skillet, heat up over medium-high heat. Once the skillet is hot, add a small amount of oil to prevent sticking.
# 3. Cook the chicken: Add the prepared chicken strips to the skillet and cook until browned on both sides. This should take about 5-7 minutes per side. Be sure to flip the chicken carefully to avoid any splattering.
# 4. Add the salsa: Once the chicken is fully cooked, remove it from the skillet and set it aside. Pour the Taco Bell Thick & Chunky Salsa into the skillet and stir to ensure it is evenly distributed.
# 5. Cook the salsa: Let the salsa simmer in the skillet for about 5 minutes, stirring occasionally, until it has thickened slightly.
# 6. Assemble the dish: To assemble the dish, place a layer of cooked chicken on a plate, then top it with a spoonful of the salsa. Sprinkle some shredded cheese and sliced black olives on top. Repeat these layers until you have used all the ingredients, finishing with a layer of cheese on top.
# 7. Serve with rice: Serve the chicken with the hot cooked instant brown rice on the side. Garnish with chopped cilantro for extra flavor.
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Use the provided reasoning to inform your response.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# Recipe Title: Shrimp with Spicy Peanut Sauce
# Ingredients: ["2 tablespoons ginger fresh, finely chopped", "2 each garlic cloves chopped", "13 cup red wine vinegar", "peanut butter creamy", "2 teaspoon red pepper flakes", "3 cup water creamy peanut butter", "1 1/2 lbs shrimp teaspoons hot red pepper flakes", "1/2 cup soy sauce, tamari", "3 cups water", "1 lemon sliced"]
# Reasoning: 1. Finely chop the fresh ginger. This is necessary to create the flavor profile of the dish, which includes the sweetness of the peanut sauce and the spiciness of the red pepper flakes.
# 2. Chop the garlic cloves into small pieces. Garlic is used to enhance the taste of the dish.
# 3. Combine 13 cup red wine vinegar and 2 teaspoon red pepper flakes in a bowl. The acidity of the vinegar helps to balance the spiciness of the red pepper flakes.
# 4. In another bowl, combine 3 cup creamy peanut butter with 2 teaspoon red pepper flakes. The peanut butter provides the creaminess and richness of the sauce while the red pepper flakes add heat.
# 5. Add 1 1/2 lbs shrimp to the bowl containing the red pepper flakes and mix well. The shrimp is the main protein of the dish and needs to be seasoned properly.
# 6. Heat 1/2 cup soy sauce and tamari in a pan over medium heat. These sauces provide salty, umami flavors that complement the other ingredients.
# 7. Add 3 cups water to the heated sauces and stir until combined. This dilutes the sauces and makes them easier to apply to the shrimp.
# 8. While waiting for the sauces to heat up, prepare the lemon slices. The lemon is used as a garnish for the final dish.
# 9. Once the sauces have heated up, add them to the shrimp mixture and stir until everything is well combined.
# 10. Serve the shrimp with spicy peanut sauce over rice or noodles, and garnish with sliced lemon.
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Use the provided reasoning to inform your response.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# Recipe Title: Strawberry Shortcake Kabobs
# Ingredients: ["1 box cake mix", "2 teaspoons butter", "1 1/3 cups water", "3/4 cup greek yogurt Vanilla", "2 pints strawberries", "2 cups chocolate chips 1 White, 1 Milk Chocolate", "1 cup heavy cream"]
# Reasoning: Step 1: First, preheat the oven to 350 degrees F (175 degrees C). In a large mixing bowl, combine the cake mix, two teaspoons of butter, and one and a third cups of water. Mix until the batter is well combined. Pour the mixture into a greased 9x13-inch baking dish and bake for about 20 minutes or until a toothpick inserted into the center comes out clean. Allow the cake to cool completely before cutting it into bite-sized pieces. Set aside.
# Step 2: While the cake is cooling, prepare the strawberry topping. In a separate bowl, mash the strawberries with a fork until they are coarsely crushed. In another bowl, mix together the Greek yogurt and vanilla extract until smooth. Add the mashed strawberries to the yogurt mixture and stir until well combined. Cover and refrigerate until ready to use.
# Step 3: Next, prepare the chocolate drizzle. Melt the white and milk chocolate chips separately in microwave-safe bowls. Once melted, allow them to cool slightly. Dip the end of a spoon into each type of melted chocolate and drizzle over the cake pieces and strawberries.
# Step 4: To assemble the kabobs, thread a piece of cake onto a skewer followed by a strawberry and then a piece of chocolate. Repeat this process until all cake and strawberry pieces have been used up. Serve immediately or refrigerate until ready to serve. Enjoy your delicious Strawberry Shortcake Kabobs!
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Use the provided reasoning to inform your response.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# Recipe Title: Aloha Ham-Wiches
# Ingredients: ["1/4 cup canned crushed pineapple in juice, well drained", "1/4 cup KRAFT Sweet'N Sour Sauce", "2 tsp. finely chopped red pepper", "12 slices OSCAR MAYER Deli Fresh Bold Brown Sugar Ham", "2 pieces leaf lettuce", "2 sandwich rolls, partially split"]
# Reasoning: This recipe requires several steps to complete. Here is the step-by-step process:
#
# 1. First, drain the crushed pineapple, removing as much of the juice as possible. This should take around 5 minutes.
#
# 2. Next, mix together the Sweet'N Sour Sauce with the minced red pepper. This will add flavor to the sandwich and take about 3 minutes.
#
# 3. While the pineapple is draining and the sauce is being prepared, you can begin preparing the ham slices. Unwrap the ham slices and set them aside. This step will take approximately 5 minutes.
#
# 4. Once the ham is ready, it's time to assemble the sandwiches. Spread the Sweet'N Sour sauce mixture evenly onto two pieces of lettuce. Place two ham slices on top of each piece of lettuce. Then, place two sandwich rolls, partially split, on top of the ham.
#
# 5. Finally, serve the Aloha Ham-Wiches immediately. Enjoy your delicious sandwiches!
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Use the provided reasoning to inform your response.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# Recipe Title: Seared Cauliflower With Honey And Harissa
# Ingredients: ["1 head cauliflower, stem removed, cut into large florets", "2 tablespoons pistachio, toasted and rough chopped", "3 tablespoons olive oil", "1 cup parsley", "1 tablespoon Harissa", "4 tablespoons tahini", "2 tablespoons honey", "1 Orange, supremed"]
# Reasoning: The recipe involves searing cauliflower with a combination of sweetness and spiciness from honey and harissa. The preparation requires some preparation time and cooking time. Here's a breakdown of the recipe process:
#
# 1. Prepare the cauliflower: Start by removing the cauliflower's stem, then cut it into large florets. This should take about 5 minutes.
# 2. Toast and chop the pistachios: Toast the pistachios until they turn golden brown. Allow them to cool down, then roughly chop them. This will take approximately 10 minutes total.
# 3. Prepare the sauce: In a small bowl, mix together the tahini, honey, and harissa. This can be done simultaneously while you prepare other ingredients.
# 4. Heat the olive oil: In a large skillet, heat up about 2 tablespoons of olive oil over medium-high heat.
# 5. Sear the cauliflower: Once the oil is hot, add the caulifloret to the skillet and sear them on both sides until they are golden brown. This should take about 8 minutes per side.
# 6. Add the pistachios: After searing the cauliflower, remove it from the skillet and set it aside. Add the remaining tablespoon of olive oil to the skillet and toast the pistachios until they are golden brown. This will take about 5 minutes.
# 7. Add the orange supreme: While the pistachios are toasting, take the supremed orange segments and add them to the skillet with the pistachios. They will infuse the dish with their citrus flavor.
# 8. Plate and serve: Once everything is ready, plate the seared cauliflower and top it off with the toasted pistachios, orange supremes, and drizzle the tahini, honey, and harissa mixture on top. Enjoy!
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Use the provided reasoning to inform your response.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# Recipe Title: Baked Salmon With Mandarin Orange And Pineapple Salsa
# Ingredients: ["16 ounces salmon filets wild Alaskan", "4 teaspoons lemon pepper seasoning", "1 cup red onion chopped", "2 cups mandarin oranges", "2 cups pineapple bits and pieces", "2 tablespoons honey", "1/4 cup pineapple juice", "1/4 cup cilantro", "1 pinch red pepper"]
# Reasoning: 1. Start with preparing the salmon fillets, which requires seasoning them with lemon pepper seasoning and letting them sit to marinate for some time. This process should take about 30 minutes to an hour depending on your preference.
#
# 2. After the salmon has marinated, preheat your oven to 400 degrees Fahrenheit (or 200 degrees Celsius).
#
# 3. While waiting for the oven to heat up, start working on the salsa. Chop the red onion into small pieces and mix it with the mandarin oranges, pineapple bits and pieces, honey, pineapple juice, and cilantro. This step should take around 15-20 minutes.
#
# 4. Once the oven is heated, place the marinated salmon fillets on a baking sheet lined with parchment paper.
#
# 5. Place the baking sheet in the oven and bake the salmon for about 15-20 minutes or until it's cooked through and flaky.
#
# 6. Remove the baking sheet from the oven and let the salmon rest for a few minutes before serving.
#
# 7. Serve the baked salmon with the mandarin orange and pineapple salsa on top or on the side. Enjoy your meal!
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Use the provided reasoning to inform your response.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# Recipe Title: The Elvis Tribute Krispy Kreme Bread Pudding
# Ingredients: ["1 cup Peanut Butter", "12 whole Krispy Kreme Glazed Donuts", "1/3 cups Milk", "2 whole Eggs", "1 can (14 Oz. Can) Sweetened Condensed Milk", "2 whole Bananas, Sliced"]
# Reasoning: Step 1: Preparation
# - Gather all necessary ingredients including peanut butter, Krispy Kreme glazed donuts, milk, eggs, sweetened condensed milk, and sliced bananas.
# - Set aside the sliced bananas for later use.
#
# Step 2: Mixing the Ingredients
# - In a large mixing bowl, combine the peanut butter and milk until well mixed. This should take approximately 5 minutes.
# - Add the eggs to the mixture and continue stirring until everything is well combined. This will take another 3 minutes.
#
# Step 3: Adding the Krispy Kreme Donuts
# - Add the sliced bananas to the mixture and stir until they're evenly distributed throughout. This will take about 2 minutes.
# - Next, add the sweetened condensed milk and mix thoroughly. This will take around 2 minutes as well.
#
# Step 4: Assembling the Bread Pudding
# - Pour the mixture into a greased 9x13 inch baking dish. Make sure it's evenly spread out.
# - Cover the dish with plastic wrap and refrigerate for at least 8 hours or overnight.
#
# Step 5: Cooking the Bread Pudding
# - Preheat your oven to 350°F (175°C).
# - Remove the bread pudding from the fridge and let it sit at room temperature for about 30 minutes.
# - Bake the bread pudding in the preheated oven for 35-40 minutes, or until a toothpick inserted into the center comes out clean.
#
# Step 6: Serving
# - Allow the bread pudding to cool slightly before serving.
# - Cut it into squares and serve warm. Enjoy!
# Your response:
# Saving the dataset (0/1 shards):   0%|          | 0/1000 [00:00<?, ? examples/s]

# %% [markdown]
# ### Fine-Tuned CoT

# %%
model_ft_cot_reason_generated = small_test.map(
    generate_reason_batch,
    batched=True,
    batch_size=BATCH_SIZE,
    fn_kwargs={"cot_prompt": cot_prompt, "model": model_ft, "tokenizer": tokenizer}
)
# Out:
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Orange Cookies Iii
# Ingredients: ["1 cup shortening", "2 cups white sugar", "2 eggs", "1 cup buttermilk", "1/2 cup orange juice", "2 tablespoons orange zest", "4 1/2 cups all-purpose flour", "2 teaspoons baking powder", "1 teaspoon salt", "1/2 teaspoon baking soda", "1/4 cup butter", "4 cups confectioners' sugar", "3 tablespoons thawed orange juice concentrate"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Creamy Roasted Garlic And Almond Soup
# Ingredients: ["3 garlic bulbs", "1 onion chopped", "4 tablespoons olive oil", "creme fraiche 30 cl.", "4 1/4 cups chicken stock", "10 cups sourdough bread", "2 tablespoons white vinegar", "1 3/8 cups almonds peeled", "salt", "pepper", "water 25 cl.", "3 oranges peeled and sectioned", "cilantro", "mint"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Skillet Pasta Florentine
# Ingredients: ["3 cups uncooked spiral pasta", "1 large egg, lightly beaten", "2 cups 2% cottage cheese", "1-1/2 cups reduced-fat ricotta cheese", "1 package (10 ounces) frozen chopped spinach, thawed and squeezed dry", "1 cup shredded part-skim mozzarella cheese, divided", "1 teaspoon each dried parsley flakes, oregano and basil", "1 jar (14 ounces) meatless spaghetti sauce", "2 tablespoons grated Parmesan cheese"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Roasted Pacific Cod With Spring Vegetables And Mint
# Ingredients: ["4 (6-ounces) pieces skinless Pacific cod or hake fillet (1 inch thick)", "4 tablespoons extra-virgin olive oil, divided, plus additional for drizzling", "1 bunch scallions, cut into 1-inch pieces", "1/2 pound zucchini (about 2 medium), cut into 1/2-inch-thick half-moons", "1 (9-ounces) package frozen artichoke hearts, thawed", "1 cup frozen peas, thawed", "1 head romaine, thinly sliced crosswise", "1/4 cup water", "1/4 cup mint leaves, coarsely chopped"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Chickpea Feta Salad over Greens
# Ingredients: ["3 tablespoons olive oil", "1/2 teaspoon grated lemon zest, plus 3 tablespoons lemon juice", "Kosher salt and freshly ground black pepper", "5 cups mixed greens (about 10 ounces)", "1 cup grape tomatoes, halved lengthwise", "One 15-ounce can chickpeas, drained", "2 kirby cucumbers, sliced into half-moons", "1 large shallot, chopped", "1/2 cup crumbled plain or herbed feta, crumbled"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Coffee-Almond Rice Pudding
# Ingredients: ["1 cup uncooked rice", "1-1/2 cups water", "1 qt. (4 cups) milk", "1/2 cup sugar", "2 Tbsp. MAXWELL HOUSE Instant Coffee", "2 Tbsp. grated orange zest Safeway 1 lb For $0.79 thru 02/09", "1/2 cup PLANTERS Slivered Almonds, toasted", "1 cup thawed COOL WHIP Whipped Topping"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Tomato, Mozzarella and Basil Salad
# Ingredients: ["2 tablespoons extra-virgin olive oil", "6 tablespoons balsamic vinegar", "2 teaspoons minced garlic", "1/2 teaspoon English dry mustard", "1/4 teaspoon sugar", "Salt, to taste", "Pepper, to taste", "2 large vine-ripened tomatoes, cut into 1/4-inch-thick slices", "1/2 pound mozzarella cheese (preferrably fresh), cut into 1/4-inch-thick slices", "10 large fresh basil leaves, sliced thin"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Jumbo Chocolate Chip Cookies
# Ingredients: ["2/3 cup shortening", "2/3 cup butter, softened", "1 cup sugar", "1 cup packed brown sugar", "2 large eggs, room temperature", "2 teaspoons vanilla extract", "3-1/2 cups all-purpose flour", "1 teaspoon baking soda", "1 teaspoon salt", "2 cups (12 ounces) semisweet chocolate chips", "1 cup chopped pecans"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Norwegian Potato Klub
# Ingredients: ["6 slices bacon", "2 cups all-purpose flour", "1/2 teaspoon baking powder", "10 medium potatoes, peeled and shredded", "2 teaspoons salt"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Dry-Aged Strip Steaks Without Drying Or Aging
# Ingredients: ["1 1/2 ounces dried porcini mushrooms", "1/2 teaspoon granulated white sugar", "1/2 teaspoon ground white pepper", "2 10-ounce boneless New York strip steaks, about 1 inch thick", "2 tablespoons soy sauce (gluten-free if that is a concern)", "3 tablespoons unsalted butter", "2 tablespoons balsamic vinegar"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Brazilian Summer Plantain Stew (Moqueca)
# Ingredients: ["4 large plantains, peeled and cut into thick slices on the diagonal", "2 limes, juice", "3 garlic cloves, finely chopped", "1 red onion, sliced", "1 long red chilli, finely chopped, seeds removed", "1 green pepper, sliced", "1 red pepper, sliced", "6 tomatoes, diced", "1.5 teaspoons sweet paprika", "150 milliliters coconut milk", "250 milliliters vegetable stock", "1 cup cilantro, roughly chopped (reserve a little for garnish)", "Large spoonful of cooked rice, for serving (optional)"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Easy Sobameshi - Yakisoba Noodles and Rice
# Ingredients: ["1 pack Steamed Chinese style or yakisoba noodles", "100 grams or (to taste) Pork", "1/2 Onion", "1/4 Carrot", "2 Green peppers", "1 bowlful Plain cooked rice", "1 dash Chopped green onion (for garnish)", "1 dash Sake", "2 handfuls Bonito flakes (fine)", "2 tbsp Japanese Worcestershire-style sauce", "2 tbsp Tonkatsu sauce (Japanese style Worcestershire sauce or steak sauce)", "1 tbsp Ketchup", "1 tbsp Vegetable oil"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Italian Turkey With Polenta
# Ingredients: ["Cooking spray", "1/2 pound ground turkey breast", "1 garlic clove, minced", "1 (15-ounce) can stewed tomatoes, undrained and chopped", "1 teaspoon dried Italian seasoning", "1/4 teaspoon ground red pepper", "1 (16-ounce) tube polenta", "1/4 cup shredded fresh Parmesan cheese"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: New Year'S Brunch: Black Truffle Fettuccine Recipe
# Ingredients: ["10 ounces of dried egg fettuccine", "3/4 cup heavy cream", "3 ounces black truffle butter (D'Artagnan)", "Pinch of freshly ground nutmeg", "Salt and pepper"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Oatmeal Cookie Drops with Milk Chocolate and Almonds
# Ingredients: ["2 each chocolate bars with almonds, 7 ounces each", "3/4 cup butter or margarine, softened", "1/2 cup brown sugar, light packed", "1/2 cup sugar granulated", "3 tablespoons corn syrup, light", "2 large eggs", "1 teaspoon vanilla extract", "1/2 teaspoon almond extract", "2 1/4 cups flour, all-purpose", "1 teaspoon baking soda", "1/2 teaspoon salt", "1 1/2 cups rolled oats old-fashioned", "1/2 cup almonds toasted, chopped"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Potato Bacon Frittata Recipe
# Ingredients: ["8 ounce. bacon, diced", "2 lg. potatoes, peeled & cubed", "1/4 c. minced onion", "1/4 c. diced green pepper", "1/4 teaspoon pepper", "1 teaspoon salt, divided", "6 Large eggs", "1 c. shredded Swiss (or possibly American) cheese", "1 c. lowfat milk", "1/3 c. Bisquick", "2 tbsp. melted butter"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Whole Wheat Banana Date And Peanut Loaf
# Ingredients: ["1 1/2 cups whole wheat self-rising flour", "1 cup wheatgerm", "1/2 cup raw sugar", "1 1/2 cups pitted dates, chopped", "8 tbsp (1 stick) butter, melted", "1/4 cup milk", "2 None eggs, lightly beaten", "3 None bananas, mashed", "1/4 cup unsalted roasted peanuts"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Turkey Meat Balls
# Ingredients: ["1 pound Ground Turkey", "1 whole Egg", "1 Tablespoon Lipton Onion Soup Mix", "1/4 teaspoons Garlic Powder", "1/4 teaspoons Ground Black Pepper", "1/4 teaspoons Salt", "3 Tablespoons Parmesan Cheese", "12 pieces Ritz Crackers", "3 Tablespoons Tomato Sauce", "3 Tablespoons Bread Crumbs", "2 Tablespoons Olive Oil"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Maple Leaf Sazerac From Minetta Tavern
# Ingredients: ["1 3/4 oz. Rittenhouse rye whiskey", "1/2 oz. Demerara", "1/4 oz. Sortilege maple liqueur", "3 dashes Peychaud's Bitters", "2 dashes Angostura bitters", "1 oz. Absinthe, used as rinse"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Strawberries with Cassis
# Ingredients: ["6 1-pint baskets strawberries, hulled and halved or quartered (depending on size of berries)", "1 1/4 cups creme de cassis liqueur", "1/3 cup sugar", "2 tablespoons fresh lemon juice", "3 cups chilled whipping cream", "3 tablespoons powdered sugar"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: PHILADELPHIA Chocolate Cheesecakes for Two
# Ingredients: ["60 g Philadelphia Brick Cream Cheese, softened", "1 oz. Baker's Semi-Sweet Chocolate, melted", "1 Tbsp. sugar", "1/2 cup thawed Cool Whip Whipped Topping", "2 Oreo Cookies"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Hot & Sour Soup
# Ingredients: ["3 inches Ginger (thinly shredded)", "2 Carrot (shredded)", "1 Chicken Breast", "1 bunch Coriander", "1 bunch Shitake Mushroom (thinly shredded)", "2 egg (beaten)", "1 tsp chili powder", "1 liter boiling water", "1 tsp sesame oil", "1 vinegar", "1 soya sauce", "1 red chili (optional)"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Delicious Kabocha Squash and Spinach Soup
# Ingredients: ["1/4 Kabocha squash", "1/2 bunch Spinach", "200 ml Milk", "2 tbsp Hot water", "1 Consomme soup stock cube", "1 heaped teaspoon) (if using consomme granules"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Balsamic Roasted Fall Vegetables
# Ingredients: ["1/4 cups Extra Virgin Olive Oil", "2 Tablespoons Balsamic Vinegar", "2 teaspoons Honey", "1 teaspoon Dijon Mustard", "2-1/2 pounds Assorted Vegetables, Cut Into 1/2 Inch Cubes Or Rounds (I Used Butternut Squash, Carrots, And Sunchokes But Sweet Potatoes, Zucchini, Squash, Eggplant Or Mushrooms Would Be Great)", "1 whole Red Onion, Chopped", "Salt And Pepper"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Piri-Piri Chicken
# Ingredients: ["8 cloves garlic minced", "3 lemons juiced, plus wedges to serve", "1/3 cup whiskey", "1 fresh bay leaf", "2 teaspoons sweet paprika", "1/4 cup olive oil", "4 chicken breasts skin-on", "1 red onion thinly sliced into rings", "1 pound cherry tomatoes", "4 red chilies long", "8 slices ciabatta bread", "2 tablespoons olive oil", "1/2 lemon juiced", "1 red chili long, finely chopped", "1 clove garlic minced"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Rich Chocolate Rum Cookies
# Ingredients: ["1 1/4 cups all-purpose flour", "1 1/2 teaspoons baking powder", "1/2 teaspoon salt", "1/2 cup ground hazelnuts (about 1/2 cup shelled nuts)", "12 ounces fine-quality bittersweet chocolate (not unsweetened)", "1/2 stick (1/4 cup) unsalted butter", "1/4 cup dark rum", "2 large eggs", "about 1/4 cup confectioners' sugar for sprinkling cookies"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Mashed Potato Leek Soup Recipe
# Ingredients: ["2 cups mashed potatoes (herbs, butter, anything you put in them)", "3 cups clean, chopped leeks", "1 medium stalk celery, chopped", "1 large carrot, chopped", "4 cups water", "1 1/2 teaspoon salt", "1 cup milk (as needed)", "fresh ground pepper"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Chocolate Puddles
# Ingredients: ["1 cup butter, softened", "1 cup sugar", "1 cup packed brown sugar", "2 large eggs", "2 teaspoons vanilla extract", "3 cups all-purpose flour", "3/4 cup baking cocoa", "1 teaspoon baking soda", "1 cup white baking chips", "1/2 cup plus 2 tablespoons sweetened condensed milk", "3/4 cup finely chopped mixed nuts"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: American 25
# Ingredients: ["1 ounce bonded apple brandy, preferably Lairds", "1/4 ounce smoky Scotch (Peat Monster and Laphroaig 10-year-old are good options)", "1/2 ounce fresh lemon juice", "1/2 ounce simple syrup (see note)", "3 to 4 ounces Champagne", "Lemon twist"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Broccoli Casserole
# Ingredients: ["2 boxes Chopped Broccoli", "1 can Cream Of Mushroom Soup", "1 cup Mayonnaise", "2 whole Eggs, Beaten", "1 whole Medium Onion, Chopped Finely", "1 cup Sharp Cheddar Cheese, Grated", "1/4 sticks Butter, Melted", "1/8 packages Pepperidge Farm Dressing"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Southern Style Oven "Fried" Chicken
# Ingredients: ["Ingredients", "3 spray(s) Cooking spray", "1 pound(s) Chicken, breast, raw, without skin, without bone, four 4-oz pieces", "1/2 tsp Salt, table, divided, or to taste", "1/4 tsp Cayenne pepper, divided, or to taste", "1/3 cup(s) Flour, white", "3 oz Milk, buttermilk, low-fat (1%)", "1/2 cup(s) Corn flakes crumbs"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response. The recipe instructions will be generated in a later response.
# Recipe Title: Octopus Stew With Onions
# Ingredients: ["1/3 tea cup of extra virgin olive oil", "1 X 1500g octopus, cut in bite-sized pieces", "6 medium onions, scored with a cross", "1 dried onion, finely chopped", "1 clove of garlic", "2 tomatoes, scored with a cross", "2 bay leaves", "a piece of orange zest", "5-6 allspice berries", "1/4 tea cup of vinegar", "1/2 tea cup of dry white wine", "freshly ground pepper"]
# Your response:

# %%
def remove_your_response_text(example):
  return {"reasoning": example['reasoning'][len('Your response: '):]}

model_ft_cot_reason_generated = model_ft_cot_reason_generated.map(remove_your_response_text)

# %%
adapter_path = f'{recipe_nlg_data_path}/qlora_1k_test_2e_4l'

model_ft = PeftModel.from_pretrained(base_model, adapter_path)

ft_generation_save_path = f'file://{recipe_nlg_data_path}/Generated_Data/ft_cot_reason_tuned'
# Out:
# /usr/local/lib/python3.11/dist-packages/peft/tuners/tuners_utils.py:190: UserWarning: Already found a `peft_config` attribute in the model. This will lead to having multiple adapters in the model. Make sure to know what you are doing!
#   warnings.warn(

# %%
model_ft_cot_instruction_generated = model_ft_cot_reason_generated_filtered.map(
    generate_instruction_batch,
    batched=True,
    batch_size=BATCH_SIZE,
    fn_kwargs={"cot_prompt": True, "model": model_ft, "tokenizer": tokenizer}
)

model_ft_cot_instruction_generated.save_to_disk(ft_generation_save_path)
# Out:
# Map:   0%|          | 0/379 [00:00<?, ? examples/s]
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Use the provided reasoning to inform your response.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# Recipe Title: Mango-Chile Ice Pops(Paletas De Mango Con Chile
# Ingredients: ["1 cup store-bought mango juice", "or nectar", "1/4 cup sugar", "2 tsp. fresh lemon juice", "1 tsp. ancho chile powder", "1 large mango, peeled, seeded,", "and cut into small cubes"]
# Reasoning: First, gather all necessary ingredients - 1 cup of store-bought mango juice, 1/4 cup of sugar, 2 teaspoons of fresh lemon juice, 1 teaspoon of ancho chile powder, 1 large ripe mango, peeled, seeded, and cut into small cubes.
# Next, if using fresh mango, make sure it is ripe and ready to use. If not, allow time for the mango to ripen.
# Then, in a medium bowl, mix together the mango juice, sugar, lemon juice, and chile powder until well combined.
# After mixing, fold in the diced mango pieces into the liquid mixture.
# Prepare the ice pop molds by filling them with the mango mixture, leaving about half an inch at the top for expansion. Insert the ice pop sticks and freeze overnight or for at least 6 hours until solid.
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Use the provided reasoning to inform your response.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# Recipe Title: Bacon, Cheddar, Chipotle Dip
# Ingredients: ["7 slices Oscar Meyer Pre-cooked Bacon, Crumbled", "1 cup Shredded Cheddar Cheese, Or More To Taste", "1 teaspoon Chipotle Seasoning, More Or Less To Taste", "1 cup (Real) Mayonnaise", "8 ounces, weight Sour Cream", "1 teaspoon Dried Onion Flakes"]
# Reasoning: First, I need to gather all the ingredients listed in the recipe, which includes 7 slices of pre-cooked bacon, crumbled, 1 cup of shredded cheddar cheese, 1 teaspoon of chipotle seasoning, 1 cup of mayonnaise, 8 ounces of sour cream, and 1 teaspoon of dried onion flakes.
# Next, I'll start by preparing the bacon. If using uncooked bacon, it needs to be cooked first. Otherwise, if using pre-cooked bacon, it can be used as is. Once the bacon is ready, I'll crumble it up into small pieces.
# After the bacon is prepared, I'll move on to the cheese. Since the recipe calls for shredded cheddar cheese, I'll need to grate the cheese if it's not already shredded.
# While the cheese is being grated, I can work on the chipotle seasoning. The amount needed depends on personal taste, so I'll add 1 teaspoon initially and adjust as necessary.
# Once all the ingredients are prepared, I'll combine them together in a
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Use the provided reasoning to inform your response.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# Recipe Title: Grapefruit And Avocado Salad
# Ingredients: ["2 ruby grapefruit (about 2 lb. total)", "1 firm, ripe avocado (about 3/4 lb.)", "2 heads Belgian endive (6 to 8 oz. total), rinsed and drained", "6 tablespoons lime juice", "1 tablespoon honey", "4 teaspoons chopped salted roasted pistachios", "Salt"]
# Reasoning: To prepare the Grapefruit and Avocado Salad, we need to follow these steps:
#
# 1. Cut off the top and bottom of the grapefruits.
# 2. Slice
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Use the provided reasoning to inform your response.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# Recipe Title: Fresh Raspberry Lattice Pie
# Ingredients: ["4 1/2 cups raspberries", "1 1/4 cups sugar", "5 tablespoon cornstarch", "1 dash salt", "1 tablespoon butter", "1 x pastry"]
# Reasoning: To make the Fresh Raspberry Lattice Pie, we first need to gather all of our ingredients. We'll need 4 1/2 cups of raspberries, 1 1/4 cups of sugar, 5 tablespoons of cornstarch,
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Use the provided reasoning to inform your response.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# Recipe Title: Warm Bulgur & Lentil Salad
# Ingredients: ["1 cup cooked bulgur", "1 cup cooked lentils", "1 carrot, diced, sauteed in olive oil", "3 tablespoons chopped cilantro", "1 dash smoked sea salt", "olive oil"]
# Reasoning: First, you need to cook the bulgur according to package instructions and set aside. Next, cook the lentils according to package instructions and set aside. While the lentils are cooking, dice the carrot into small pieces and sautee them in olive oil until they are slightly browned and softened. After both the bulgur and lentils have been cooked and set aside, mix together the cooked bulgur, cooked lentils, sauteed carrot, chopped cilantro, and smoked sea salt. Drizzle olive oil over the top of the salad before serving.
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Use the provided reasoning to inform your response.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# Recipe Title: Buffalo Chicken Nachos
# Ingredients: ["1 whole Rotisserie Chicken, Shredded And Nuked If Needed", "3/4 cups Buffalo Wing Sauce", "1 can (14.5 Oz. Size) Black Beans, Drained And Rinsed.", "4 cups Blue Corn Tortilla Chips", "2 cups Shredded Cheddar Cheese", "1/2 cups Crumbled Blue Cheese", "1/4 cups Finely Sliced Scallions", "1 whole Avocado, diced"]
# Reasoning: First, we need to prepare our ingredients. Shred the rotisserie chicken if it is not already shredded and nuke it in the microwave for 2-3 minutes to warm it up.
#
# Next, preheat the oven to 350 degrees Fahrenheit. This step should take around 10 minutes.
#
# While the oven is preheating, drain and rinse the black beans in a colander.
#
# Once the chicken is heated, mix it with 3/4 cup of buffalo wing sauce in a bowl.
#
# Now, let's start assembling the nachos. In an oven-safe dish, spread out one layer of blue corn tortilla chips. Then sprinkle half of the cheddar cheese over the top. Add half of the buffalo chicken mixture on top of the cheese.
#
# Then, add another layer of tortilla chips and repeat the layering process - cheese, then buffalo chicken mixture.
#
# After completing the layers, sprinkle crumbled blue cheese over the top of the dish.
#
# Bake the nachos in the preheated oven for 10-15 minutes until the cheese is melt
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Use the provided reasoning to inform your response.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# Recipe Title: Caramel Banana Toast in 5 Minutes
# Ingredients: ["1 slice Sliced bread", "1 Banana", "1 handful Nuts (almonds, walnuts, etc.)", "1 tbsp Butter (or vegetable oil)", "1 tbsp Raw cane sugar (or maple syrup)"]
# Reasoning: First, preheat your oven to 400°F or use a toaster if you have one.
# Second, toast the slice of sliced bread until it reaches your desired level of toasting. This step typically takes 2-3 minutes in an oven or 1-2 minutes in a toaster.
# Third, while the bread is toasting, peel and slice the banana into 1/2 inch thick rounds.
# Fourth, melt the butter in a frying pan over medium heat. If using vegetable oil, add enough to coat the bottom of the pan.
# Fifth, once the butter is melted, add the banana slices to the pan and cook them for about 2 minutes per side, or until they are golden brown and slightly caramelized.
# Sixth, remove the banana slices from the pan and place them on top of the toasted bread.
# Seventh, sprinkle the raw cane sugar evenly over the banana slices. If using maple syrup, drizzle it over the bananas instead.
# Eighth, put the pan back on the stove and cook the nuts in the remaining butter
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Use the provided reasoning to inform your response.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# Recipe Title: The Cartoon Kitchen: Trivial Spinach Lasagna Recipe
# Ingredients: ["A few cloves of garlic", "Tomato sauce", "Raw lasagna noodles", "Ricotta cheese", "Fresh spinach, washed and drained", "Mozzarella cheese"]
# Reasoning: 1. Preheat oven to 375 degrees Fahrenheit (or 190 degrees Celsius).
# 2. Cook the raw lasagna noodles according to the package instructions. Drain and set aside.
# 3. While the noodles are cooking, heat up some olive oil in a pan over medium heat. Add minced garlic to the pan and cook until fragrant, about 2 minutes.
# 4. Add the tomato sauce to the pan with the garlic and stir well. Simmer for 5-7 minutes until it thickens slightly.
# 5. In another bowl, mix together ricotta cheese and fresh spinach leaves. This mixture should be creamy and green.
# 6. Layer the cooked noodles at the bottom of a greased baking dish. Then spread a thin layer of the tomato sauce on top of the noodles. Next, add a layer of the spinach and ricotta mixture.
# 7. Repeat this layering process, starting with the noodles, then tomato sauce, and finally the spinach and ricotta mixture. The last layer should end with a covering of mozzarella cheese.
# 8. Bake
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Use the provided reasoning to inform your response.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# Recipe Title: Easy Homemade Vegetable Beef Soup Recipe
# Ingredients: ["1 pound stew meat", "2 (16 ounce.) cans Veg-All", "2 (8 ounce.) cans tomato sauce", "2 sm. potatoes", "Rice", "Spaghetti noodles"]
# Reasoning: To make the Easy Homemade Vegetable Beef Soup Recipe, we need to have the following ingredients ready:
#
# 1. Cut the stew meat into small pieces, as it needs to be cooked first to ensure even cooking and proper texture. This may take around 10 minutes depending on the size of the cuts.
#
# 2. Peel and dice the two small potatoes, as they need to be cooked alongside the meat. The dicing process should take around 5 minutes.
#
# 3. Open the two cans of Veg-All and pour them into a large pot, then add the two cans of tomato sauce. Stir the mixture well so that the ingredients are evenly distributed.
#
# 4. Add the pre-cooked stew meat and diced potatoes into the pot with the Veg-All and tomato sauce mixture. Mix everything together.
#
# 5. Bring the soup to a boil, then reduce heat and let it simmer for at least 30 minutes. This allows the flavors to blend and the vegetables to become tender.
#
# 6. Prepare the rice according to package directions while the soup is simmering. Rice typically takes about 15
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Use the provided reasoning to inform your response.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# Recipe Title: Expandable Potato Salad
# Ingredients: ["5 medium-large red-skinned or Yukon Gold potatoes", "1/2 cup soy mayonnaise", "2 teaspoons prepared yellow mustard", "1 large celery stalk, finely diced", "1 cup frozen green peas, thawed", "Salt and freshly ground pepper to taste", "1/2 medium red bell pepper, finely diced", "Crumbled feta or goat cheese", "1 to 2 scallions, thinly sliced", "Toasted sunflower seeds, to taste", "Minced fresh dill, to taste", "Chopped fresh parsley, to taste"]
# Reasoning: Step 1: First, you'll need to gather your ingredients: 5 medium-large red-skinned or Yukon Gold potatoes,
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Use the provided reasoning to inform your response.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# Recipe Title: Chinese Turnovers Recipe
# Ingredients: ["1 env. beef mushroom soup mix", "1 pound grnd beef", "1 c. liquid removed bean sprouts", "2 tbsp. minced onion", "2 pkg. refrigerator crescent rolls"]
# Reasoning: First, we need to prepare the filling
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Use the provided reasoning to inform your response.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# Recipe Title: Runzas
# Ingredients: ["3/4 pound Ground Beef", "1/2 head Cabbage (shredded)", "1 package Hot Roll Mix (i.e. Pillsbury)", "1/4 teaspoon Garlic Salt", "2 tablespoons Butter", "1/4 teaspoon Salt", "1/2 cup Onion"]
# Reasoning: First, I would need to prepare
# Your response:
# Saving the dataset (0/1 shards):   0%|          | 0/379 [00:00<?, ? examples/s]

# %%
## Only do this after running below code

model_ft_generated = small_test.map(
    generate_instruction_batch,
    batched=True,
    batch_size=BATCH_SIZE,
    fn_kwargs={"cot": False, "model": model_ft, "tokenizer": tokenizer}
)

model_ft_generated.save_to_disk(ft_generation_save_path)
# Out:
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
#
# Recipe Title: Orange Cookies Iii
# Ingredients: ["1 cup shortening", "2 cups white sugar", "2 eggs", "1 cup buttermilk", "1/2 cup orange juice", "2 tablespoons orange zest", "4 1/2 cups all-purpose flour", "2 teaspoons baking powder", "1 teaspoon salt", "1/2 teaspoon baking soda", "1/4 cup butter", "4 cups confectioners' sugar", "3 tablespoons thawed orange juice concentrate"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
#
# Recipe Title: Creamy Roasted Garlic And Almond Soup
# Ingredients: ["3 garlic bulbs", "1 onion chopped", "4 tablespoons olive oil", "creme fraiche 30 cl.", "4 1/4 cups chicken stock", "10 cups sourdough bread", "2 tablespoons white vinegar", "1 3/8 cups almonds peeled", "salt", "pepper", "water 25 cl.", "3 oranges peeled and sectioned", "cilantro", "mint"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
#
# Recipe Title: Skillet Pasta Florentine
# Ingredients: ["3 cups uncooked spiral pasta", "1 large egg, lightly beaten", "2 cups 2% cottage cheese", "1-1/2 cups reduced-fat ricotta cheese", "1 package (10 ounces) frozen chopped spinach, thawed and squeezed dry", "1 cup shredded part-skim mozzarella cheese, divided", "1 teaspoon each dried parsley flakes, oregano and basil", "1 jar (14 ounces) meatless spaghetti sauce", "2 tablespoons grated Parmesan cheese"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
#
# Recipe Title: Roasted Pacific Cod With Spring Vegetables And Mint
# Ingredients: ["4 (6-ounces) pieces skinless Pacific cod or hake fillet (1 inch thick)", "4 tablespoons extra-virgin olive oil, divided, plus additional for drizzling", "1 bunch scallions, cut into 1-inch pieces", "1/2 pound zucchini (about 2 medium), cut into 1/2-inch-thick half-moons", "1 (9-ounces) package frozen artichoke hearts, thawed", "1 cup frozen peas, thawed", "1 head romaine, thinly sliced crosswise", "1/4 cup water", "1/4 cup mint leaves, coarsely chopped"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
#
# Recipe Title: Chickpea Feta Salad over Greens
# Ingredients: ["3 tablespoons olive oil", "1/2 teaspoon grated lemon zest, plus 3 tablespoons lemon juice", "Kosher salt and freshly ground black pepper", "5 cups mixed greens (about 10 ounces)", "1 cup grape tomatoes, halved lengthwise", "One 15-ounce can chickpeas, drained", "2 kirby cucumbers, sliced into half-moons", "1 large shallot, chopped", "1/2 cup crumbled plain or herbed feta, crumbled"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
#
# Recipe Title: Coffee-Almond Rice Pudding
# Ingredients: ["1 cup uncooked rice", "1-1/2 cups water", "1 qt. (4 cups) milk", "1/2 cup sugar", "2 Tbsp. MAXWELL HOUSE Instant Coffee", "2 Tbsp. grated orange zest Safeway 1 lb For $0.79 thru 02/09", "1/2 cup PLANTERS Slivered Almonds, toasted", "1 cup thawed COOL WHIP Whipped Topping"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
#
# Recipe Title: Tomato, Mozzarella and Basil Salad
# Ingredients: ["2 tablespoons extra-virgin olive oil", "6 tablespoons balsamic vinegar", "2 teaspoons minced garlic", "1/2 teaspoon English dry mustard", "1/4 teaspoon sugar", "Salt, to taste", "Pepper, to taste", "2 large vine-ripened tomatoes, cut into 1/4-inch-thick slices", "1/2 pound mozzarella cheese (preferrably fresh), cut into 1/4-inch-thick slices", "10 large fresh basil leaves, sliced thin"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
#
# Recipe Title: Jumbo Chocolate Chip Cookies
# Ingredients: ["2/3 cup shortening", "2/3 cup butter, softened", "1 cup sugar", "1 cup packed brown sugar", "2 large eggs, room temperature", "2 teaspoons vanilla extract", "3-1/2 cups all-purpose flour", "1 teaspoon baking soda", "1 teaspoon salt", "2 cups (12 ounces) semisweet chocolate chips", "1 cup chopped pecans"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
#
# Recipe Title: Norwegian Potato Klub
# Ingredients: ["6 slices bacon", "2 cups all-purpose flour", "1/2 teaspoon baking powder", "10 medium potatoes, peeled and shredded", "2 teaspoons salt"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
#
# Recipe Title: Dry-Aged Strip Steaks Without Drying Or Aging
# Ingredients: ["1 1/2 ounces dried porcini mushrooms", "1/2 teaspoon granulated white sugar", "1/2 teaspoon ground white pepper", "2 10-ounce boneless New York strip steaks, about 1 inch thick", "2 tablespoons soy sauce (gluten-free if that is a concern)", "3 tablespoons unsalted butter", "2 tablespoons balsamic vinegar"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
#
# Recipe Title: Brazilian Summer Plantain Stew (Moqueca)
# Ingredients: ["4 large plantains, peeled and cut into thick slices on the diagonal", "2 limes, juice", "3 garlic cloves, finely chopped", "1 red onion, sliced", "1 long red chilli, finely chopped, seeds removed", "1 green pepper, sliced", "1 red pepper, sliced", "6 tomatoes, diced", "1.5 teaspoons sweet paprika", "150 milliliters coconut milk", "250 milliliters vegetable stock", "1 cup cilantro, roughly chopped (reserve a little for garnish)", "Large spoonful of cooked rice, for serving (optional)"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
#
# Recipe Title: Easy Sobameshi - Yakisoba Noodles and Rice
# Ingredients: ["1 pack Steamed Chinese style or yakisoba noodles", "100 grams or (to taste) Pork", "1/2 Onion", "1/4 Carrot", "2 Green peppers", "1 bowlful Plain cooked rice", "1 dash Chopped green onion (for garnish)", "1 dash Sake", "2 handfuls Bonito flakes (fine)", "2 tbsp Japanese Worcestershire-style sauce", "2 tbsp Tonkatsu sauce (Japanese style Worcestershire sauce or steak sauce)", "1 tbsp Ketchup", "1 tbsp Vegetable oil"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
#
# Recipe Title: Italian Turkey With Polenta
# Ingredients: ["Cooking spray", "1/2 pound ground turkey breast", "1 garlic clove, minced", "1 (15-ounce) can stewed tomatoes, undrained and chopped", "1 teaspoon dried Italian seasoning", "1/4 teaspoon ground red pepper", "1 (16-ounce) tube polenta", "1/4 cup shredded fresh Parmesan cheese"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
#
# Recipe Title: New Year'S Brunch: Black Truffle Fettuccine Recipe
# Ingredients: ["10 ounces of dried egg fettuccine", "3/4 cup heavy cream", "3 ounces black truffle butter (D'Artagnan)", "Pinch of freshly ground nutmeg", "Salt and pepper"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
#
# Recipe Title: Oatmeal Cookie Drops with Milk Chocolate and Almonds
# Ingredients: ["2 each chocolate bars with almonds, 7 ounces each", "3/4 cup butter or margarine, softened", "1/2 cup brown sugar, light packed", "1/2 cup sugar granulated", "3 tablespoons corn syrup, light", "2 large eggs", "1 teaspoon vanilla extract", "1/2 teaspoon almond extract", "2 1/4 cups flour, all-purpose", "1 teaspoon baking soda", "1/2 teaspoon salt", "1 1/2 cups rolled oats old-fashioned", "1/2 cup almonds toasted, chopped"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
#
# Recipe Title: Potato Bacon Frittata Recipe
# Ingredients: ["8 ounce. bacon, diced", "2 lg. potatoes, peeled & cubed", "1/4 c. minced onion", "1/4 c. diced green pepper", "1/4 teaspoon pepper", "1 teaspoon salt, divided", "6 Large eggs", "1 c. shredded Swiss (or possibly American) cheese", "1 c. lowfat milk", "1/3 c. Bisquick", "2 tbsp. melted butter"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
#
# Recipe Title: Whole Wheat Banana Date And Peanut Loaf
# Ingredients: ["1 1/2 cups whole wheat self-rising flour", "1 cup wheatgerm", "1/2 cup raw sugar", "1 1/2 cups pitted dates, chopped", "8 tbsp (1 stick) butter, melted", "1/4 cup milk", "2 None eggs, lightly beaten", "3 None bananas, mashed", "1/4 cup unsalted roasted peanuts"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
#
# Recipe Title: Turkey Meat Balls
# Ingredients: ["1 pound Ground Turkey", "1 whole Egg", "1 Tablespoon Lipton Onion Soup Mix", "1/4 teaspoons Garlic Powder", "1/4 teaspoons Ground Black Pepper", "1/4 teaspoons Salt", "3 Tablespoons Parmesan Cheese", "12 pieces Ritz Crackers", "3 Tablespoons Tomato Sauce", "3 Tablespoons Bread Crumbs", "2 Tablespoons Olive Oil"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
#
# Recipe Title: Maple Leaf Sazerac From Minetta Tavern
# Ingredients: ["1 3/4 oz. Rittenhouse rye whiskey", "1/2 oz. Demerara", "1/4 oz. Sortilege maple liqueur", "3 dashes Peychaud's Bitters", "2 dashes Angostura bitters", "1 oz. Absinthe, used as rinse"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
#
# Recipe Title: Strawberries with Cassis
# Ingredients: ["6 1-pint baskets strawberries, hulled and halved or quartered (depending on size of berries)", "1 1/4 cups creme de cassis liqueur", "1/3 cup sugar", "2 tablespoons fresh lemon juice", "3 cups chilled whipping cream", "3 tablespoons powdered sugar"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
#
# Recipe Title: PHILADELPHIA Chocolate Cheesecakes for Two
# Ingredients: ["60 g Philadelphia Brick Cream Cheese, softened", "1 oz. Baker's Semi-Sweet Chocolate, melted", "1 Tbsp. sugar", "1/2 cup thawed Cool Whip Whipped Topping", "2 Oreo Cookies"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
#
# Recipe Title: Hot & Sour Soup
# Ingredients: ["3 inches Ginger (thinly shredded)", "2 Carrot (shredded)", "1 Chicken Breast", "1 bunch Coriander", "1 bunch Shitake Mushroom (thinly shredded)", "2 egg (beaten)", "1 tsp chili powder", "1 liter boiling water", "1 tsp sesame oil", "1 vinegar", "1 soya sauce", "1 red chili (optional)"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
#
# Recipe Title: Delicious Kabocha Squash and Spinach Soup
# Ingredients: ["1/4 Kabocha squash", "1/2 bunch Spinach", "200 ml Milk", "2 tbsp Hot water", "1 Consomme soup stock cube", "1 heaped teaspoon) (if using consomme granules"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
#
# Recipe Title: Balsamic Roasted Fall Vegetables
# Ingredients: ["1/4 cups Extra Virgin Olive Oil", "2 Tablespoons Balsamic Vinegar", "2 teaspoons Honey", "1 teaspoon Dijon Mustard", "2-1/2 pounds Assorted Vegetables, Cut Into 1/2 Inch Cubes Or Rounds (I Used Butternut Squash, Carrots, And Sunchokes But Sweet Potatoes, Zucchini, Squash, Eggplant Or Mushrooms Would Be Great)", "1 whole Red Onion, Chopped", "Salt And Pepper"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
#
# Recipe Title: Piri-Piri Chicken
# Ingredients: ["8 cloves garlic minced", "3 lemons juiced, plus wedges to serve", "1/3 cup whiskey", "1 fresh bay leaf", "2 teaspoons sweet paprika", "1/4 cup olive oil", "4 chicken breasts skin-on", "1 red onion thinly sliced into rings", "1 pound cherry tomatoes", "4 red chilies long", "8 slices ciabatta bread", "2 tablespoons olive oil", "1/2 lemon juiced", "1 red chili long, finely chopped", "1 clove garlic minced"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
#
# Recipe Title: Rich Chocolate Rum Cookies
# Ingredients: ["1 1/4 cups all-purpose flour", "1 1/2 teaspoons baking powder", "1/2 teaspoon salt", "1/2 cup ground hazelnuts (about 1/2 cup shelled nuts)", "12 ounces fine-quality bittersweet chocolate (not unsweetened)", "1/2 stick (1/4 cup) unsalted butter", "1/4 cup dark rum", "2 large eggs", "about 1/4 cup confectioners' sugar for sprinkling cookies"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
#
# Recipe Title: Mashed Potato Leek Soup Recipe
# Ingredients: ["2 cups mashed potatoes (herbs, butter, anything you put in them)", "3 cups clean, chopped leeks", "1 medium stalk celery, chopped", "1 large carrot, chopped", "4 cups water", "1 1/2 teaspoon salt", "1 cup milk (as needed)", "fresh ground pepper"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
#
# Recipe Title: Chocolate Puddles
# Ingredients: ["1 cup butter, softened", "1 cup sugar", "1 cup packed brown sugar", "2 large eggs", "2 teaspoons vanilla extract", "3 cups all-purpose flour", "3/4 cup baking cocoa", "1 teaspoon baking soda", "1 cup white baking chips", "1/2 cup plus 2 tablespoons sweetened condensed milk", "3/4 cup finely chopped mixed nuts"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
#
# Recipe Title: American 25
# Ingredients: ["1 ounce bonded apple brandy, preferably Lairds", "1/4 ounce smoky Scotch (Peat Monster and Laphroaig 10-year-old are good options)", "1/2 ounce fresh lemon juice", "1/2 ounce simple syrup (see note)", "3 to 4 ounces Champagne", "Lemon twist"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
#
# Recipe Title: Broccoli Casserole
# Ingredients: ["2 boxes Chopped Broccoli", "1 can Cream Of Mushroom Soup", "1 cup Mayonnaise", "2 whole Eggs, Beaten", "1 whole Medium Onion, Chopped Finely", "1 cup Sharp Cheddar Cheese, Grated", "1/4 sticks Butter, Melted", "1/8 packages Pepperidge Farm Dressing"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
#
# Recipe Title: Southern Style Oven "Fried" Chicken
# Ingredients: ["Ingredients", "3 spray(s) Cooking spray", "1 pound(s) Chicken, breast, raw, without skin, without bone, four 4-oz pieces", "1/2 tsp Salt, table, divided, or to taste", "1/4 tsp Cayenne pepper, divided, or to taste", "1/3 cup(s) Flour, white", "3 oz Milk, buttermilk, low-fat (1%)", "1/2 cup(s) Corn flakes crumbs"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
#
# Recipe Title: Octopus Stew With Onions
# Ingredients: ["1/3 tea cup of extra virgin olive oil", "1 X 1500g octopus, cut in bite-sized pieces", "6 medium onions, scored with a cross", "1 dried onion, finely chopped", "1 clove of garlic", "2 tomatoes, scored with a cross", "2 bay leaves", "a piece of orange zest", "5-6 allspice berries", "1/4 tea cup of vinegar", "1/2 tea cup of dry white wine", "freshly ground pepper"]
# Recipe Instructions:
# Saving the dataset (0/1 shards):   0%|          | 0/1000 [00:00<?, ? examples/s]

# %% [markdown]
# ### More Experiments

# %% [markdown]
# ### OOB Generation

# %%
BATCH_SIZE = 32

# %%
BATCH_SIZE = 32
generated_dataset_oob_TEST = small_test.select([1,2]).map(
    generate_instruction_batch,
    batched=True,
    batch_size=BATCH_SIZE,
    fn_kwargs={"cot": False, "model": model, "tokenizer": tokenizer}
)


#generated_dataset_oob.save_to_disk(f'{recipe_nlg_data_path}/oob_generated')
# Out:
# Map:   0%|          | 0/2 [00:00<?, ? examples/s]
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Enclose your recipe instructions in <instructions> tags and number each step.
# Examples: None
# Title: Tarragon Chicken Salad
# Ingredients: ["1/4 cup MIRACLE WHIP FREE Dressing", "1/4 tsp. dried tarragon leaves", "3 oz. , cubed", "1 cup red or green grapes, seedless Target 1 lb For $2.99 thru 02/06", "1/2 whole wheat pita bread round", "2 SNACKWELL'S Sugar Free Shortbread Cookies", "4 fl oz (1/2 cup) orange juice"]
# Your response:
# 'You are an expert in generating recipe instructions from the recipe title and ingredient list.\nEnclose your recipe instructions in <instructions> tags and number each step.\nExamples: None\nTitle: Tarragon Chicken Salad\nIngredients: ["1/4 cup MIRACLE WHIP FREE Dressing", "1/4 tsp. dried tarragon leaves", "3 oz. , cubed", "1 cup red or green grapes, seedless Target 1 lb For $2.99 thru 02/06", "1/2 whole wheat pita bread round", "2 SNACKWELL\'S Sugar Free Shortbread Cookies", "4 fl oz (1/2 cup) orange juice"]\nYour response:\n<instructions>\n1. In a small bowl, mix together the Miracle Whip dressing and dried tarragon leaves. Set aside.\n2. In a separate bowl, combine the cubed chicken, grapes, and half of the dressing mixture from step 1. Mix well to coat all ingredients evenly.\n3. Cut the whole wheat pita bread into triangles or squares. Serve with the chicken salad as desired.\n4. Garnish the plate with two Snackwell\'s sugar-free shortbread cookies.\n5. Pour the remaining orange juice over the chicken salad just before serving for added moisture and flavor.\n</instructions>'

# %% [markdown]
# ### CoT Generation

# %%
cot_prompt = """
Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?

Only generate the reasoning in this response, the recipe instructions will be generated in a later response.
""".strip()

generated_dataset_cot_reasoning = small_test.map(
    generate_reason_batch,
    batched=True,
    batch_size=BATCH_SIZE,
    fn_kwargs={"cot": cot_prompt, "model": model, "tokenizer": tokenizer}
)
# Out:
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
# You are an expert in generating recipe instructions.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response, the recipe instructions will be generated in a later response.
# Enclose your reasoning in <reasoning> tags.
# Title: Orange Cookies Iii
# Ingredients: ["1 cup shortening", "2 cups white sugar", "2 eggs", "1 cup buttermilk", "1/2 cup orange juice", "2 tablespoons orange zest", "4 1/2 cups all-purpose flour", "2 teaspoons baking powder", "1 teaspoon salt", "1/2 teaspoon baking soda", "1/4 cup butter", "4 cups confectioners' sugar", "3 tablespoons thawed orange juice concentrate"]
# Your response:
# You are an expert in generating recipe instructions.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response, the recipe instructions will be generated in a later response.
# Enclose your reasoning in <reasoning> tags.
# Title: Creamy Roasted Garlic And Almond Soup
# Ingredients: ["3 garlic bulbs", "1 onion chopped", "4 tablespoons olive oil", "creme fraiche 30 cl.", "4 1/4 cups chicken stock", "10 cups sourdough bread", "2 tablespoons white vinegar", "1 3/8 cups almonds peeled", "salt", "pepper", "water 25 cl.", "3 oranges peeled and sectioned", "cilantro", "mint"]
# Your response:
# You are an expert in generating recipe instructions.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response, the recipe instructions will be generated in a later response.
# Enclose your reasoning in <reasoning> tags.
# Title: Skillet Pasta Florentine
# Ingredients: ["3 cups uncooked spiral pasta", "1 large egg, lightly beaten", "2 cups 2% cottage cheese", "1-1/2 cups reduced-fat ricotta cheese", "1 package (10 ounces) frozen chopped spinach, thawed and squeezed dry", "1 cup shredded part-skim mozzarella cheese, divided", "1 teaspoon each dried parsley flakes, oregano and basil", "1 jar (14 ounces) meatless spaghetti sauce", "2 tablespoons grated Parmesan cheese"]
# Your response:
# You are an expert in generating recipe instructions.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response, the recipe instructions will be generated in a later response.
# Enclose your reasoning in <reasoning> tags.
# Title: Roasted Pacific Cod With Spring Vegetables And Mint
# Ingredients: ["4 (6-ounces) pieces skinless Pacific cod or hake fillet (1 inch thick)", "4 tablespoons extra-virgin olive oil, divided, plus additional for drizzling", "1 bunch scallions, cut into 1-inch pieces", "1/2 pound zucchini (about 2 medium), cut into 1/2-inch-thick half-moons", "1 (9-ounces) package frozen artichoke hearts, thawed", "1 cup frozen peas, thawed", "1 head romaine, thinly sliced crosswise", "1/4 cup water", "1/4 cup mint leaves, coarsely chopped"]
# Your response:
# You are an expert in generating recipe instructions.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response, the recipe instructions will be generated in a later response.
# Enclose your reasoning in <reasoning> tags.
# Title: Chickpea Feta Salad over Greens
# Ingredients: ["3 tablespoons olive oil", "1/2 teaspoon grated lemon zest, plus 3 tablespoons lemon juice", "Kosher salt and freshly ground black pepper", "5 cups mixed greens (about 10 ounces)", "1 cup grape tomatoes, halved lengthwise", "One 15-ounce can chickpeas, drained", "2 kirby cucumbers, sliced into half-moons", "1 large shallot, chopped", "1/2 cup crumbled plain or herbed feta, crumbled"]
# Your response:
# You are an expert in generating recipe instructions.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response, the recipe instructions will be generated in a later response.
# Enclose your reasoning in <reasoning> tags.
# Title: Coffee-Almond Rice Pudding
# Ingredients: ["1 cup uncooked rice", "1-1/2 cups water", "1 qt. (4 cups) milk", "1/2 cup sugar", "2 Tbsp. MAXWELL HOUSE Instant Coffee", "2 Tbsp. grated orange zest Safeway 1 lb For $0.79 thru 02/09", "1/2 cup PLANTERS Slivered Almonds, toasted", "1 cup thawed COOL WHIP Whipped Topping"]
# Your response:
# You are an expert in generating recipe instructions.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response, the recipe instructions will be generated in a later response.
# Enclose your reasoning in <reasoning> tags.
# Title: Tomato, Mozzarella and Basil Salad
# Ingredients: ["2 tablespoons extra-virgin olive oil", "6 tablespoons balsamic vinegar", "2 teaspoons minced garlic", "1/2 teaspoon English dry mustard", "1/4 teaspoon sugar", "Salt, to taste", "Pepper, to taste", "2 large vine-ripened tomatoes, cut into 1/4-inch-thick slices", "1/2 pound mozzarella cheese (preferrably fresh), cut into 1/4-inch-thick slices", "10 large fresh basil leaves, sliced thin"]
# Your response:
# You are an expert in generating recipe instructions.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response, the recipe instructions will be generated in a later response.
# Enclose your reasoning in <reasoning> tags.
# Title: Jumbo Chocolate Chip Cookies
# Ingredients: ["2/3 cup shortening", "2/3 cup butter, softened", "1 cup sugar", "1 cup packed brown sugar", "2 large eggs, room temperature", "2 teaspoons vanilla extract", "3-1/2 cups all-purpose flour", "1 teaspoon baking soda", "1 teaspoon salt", "2 cups (12 ounces) semisweet chocolate chips", "1 cup chopped pecans"]
# Your response:
# You are an expert in generating recipe instructions.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response, the recipe instructions will be generated in a later response.
# Enclose your reasoning in <reasoning> tags.
# Title: Norwegian Potato Klub
# Ingredients: ["6 slices bacon", "2 cups all-purpose flour", "1/2 teaspoon baking powder", "10 medium potatoes, peeled and shredded", "2 teaspoons salt"]
# Your response:
# You are an expert in generating recipe instructions.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response, the recipe instructions will be generated in a later response.
# Enclose your reasoning in <reasoning> tags.
# Title: Dry-Aged Strip Steaks Without Drying Or Aging
# Ingredients: ["1 1/2 ounces dried porcini mushrooms", "1/2 teaspoon granulated white sugar", "1/2 teaspoon ground white pepper", "2 10-ounce boneless New York strip steaks, about 1 inch thick", "2 tablespoons soy sauce (gluten-free if that is a concern)", "3 tablespoons unsalted butter", "2 tablespoons balsamic vinegar"]
# Your response:
# You are an expert in generating recipe instructions.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response, the recipe instructions will be generated in a later response.
# Enclose your reasoning in <reasoning> tags.
# Title: Brazilian Summer Plantain Stew (Moqueca)
# Ingredients: ["4 large plantains, peeled and cut into thick slices on the diagonal", "2 limes, juice", "3 garlic cloves, finely chopped", "1 red onion, sliced", "1 long red chilli, finely chopped, seeds removed", "1 green pepper, sliced", "1 red pepper, sliced", "6 tomatoes, diced", "1.5 teaspoons sweet paprika", "150 milliliters coconut milk", "250 milliliters vegetable stock", "1 cup cilantro, roughly chopped (reserve a little for garnish)", "Large spoonful of cooked rice, for serving (optional)"]
# Your response:
# You are an expert in generating recipe instructions.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response, the recipe instructions will be generated in a later response.
# Enclose your reasoning in <reasoning> tags.
# Title: Easy Sobameshi - Yakisoba Noodles and Rice
# Ingredients: ["1 pack Steamed Chinese style or yakisoba noodles", "100 grams or (to taste) Pork", "1/2 Onion", "1/4 Carrot", "2 Green peppers", "1 bowlful Plain cooked rice", "1 dash Chopped green onion (for garnish)", "1 dash Sake", "2 handfuls Bonito flakes (fine)", "2 tbsp Japanese Worcestershire-style sauce", "2 tbsp Tonkatsu sauce (Japanese style Worcestershire sauce or steak sauce)", "1 tbsp Ketchup", "1 tbsp Vegetable oil"]
# Your response:
# You are an expert in generating recipe instructions.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response, the recipe instructions will be generated in a later response.
# Enclose your reasoning in <reasoning> tags.
# Title: Italian Turkey With Polenta
# Ingredients: ["Cooking spray", "1/2 pound ground turkey breast", "1 garlic clove, minced", "1 (15-ounce) can stewed tomatoes, undrained and chopped", "1 teaspoon dried Italian seasoning", "1/4 teaspoon ground red pepper", "1 (16-ounce) tube polenta", "1/4 cup shredded fresh Parmesan cheese"]
# Your response:
# You are an expert in generating recipe instructions.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response, the recipe instructions will be generated in a later response.
# Enclose your reasoning in <reasoning> tags.
# Title: New Year'S Brunch: Black Truffle Fettuccine Recipe
# Ingredients: ["10 ounces of dried egg fettuccine", "3/4 cup heavy cream", "3 ounces black truffle butter (D'Artagnan)", "Pinch of freshly ground nutmeg", "Salt and pepper"]
# Your response:
# You are an expert in generating recipe instructions.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response, the recipe instructions will be generated in a later response.
# Enclose your reasoning in <reasoning> tags.
# Title: Oatmeal Cookie Drops with Milk Chocolate and Almonds
# Ingredients: ["2 each chocolate bars with almonds, 7 ounces each", "3/4 cup butter or margarine, softened", "1/2 cup brown sugar, light packed", "1/2 cup sugar granulated", "3 tablespoons corn syrup, light", "2 large eggs", "1 teaspoon vanilla extract", "1/2 teaspoon almond extract", "2 1/4 cups flour, all-purpose", "1 teaspoon baking soda", "1/2 teaspoon salt", "1 1/2 cups rolled oats old-fashioned", "1/2 cup almonds toasted, chopped"]
# Your response:
# You are an expert in generating recipe instructions.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response, the recipe instructions will be generated in a later response.
# Enclose your reasoning in <reasoning> tags.
# Title: Potato Bacon Frittata Recipe
# Ingredients: ["8 ounce. bacon, diced", "2 lg. potatoes, peeled & cubed", "1/4 c. minced onion", "1/4 c. diced green pepper", "1/4 teaspoon pepper", "1 teaspoon salt, divided", "6 Large eggs", "1 c. shredded Swiss (or possibly American) cheese", "1 c. lowfat milk", "1/3 c. Bisquick", "2 tbsp. melted butter"]
# Your response:
# You are an expert in generating recipe instructions.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response, the recipe instructions will be generated in a later response.
# Enclose your reasoning in <reasoning> tags.
# Title: Whole Wheat Banana Date And Peanut Loaf
# Ingredients: ["1 1/2 cups whole wheat self-rising flour", "1 cup wheatgerm", "1/2 cup raw sugar", "1 1/2 cups pitted dates, chopped", "8 tbsp (1 stick) butter, melted", "1/4 cup milk", "2 None eggs, lightly beaten", "3 None bananas, mashed", "1/4 cup unsalted roasted peanuts"]
# Your response:

# %%
generated_dataset_cot_instructions = generated_dataset_cot_reasoning.map(
    generate_instruction_batch,
    batched=True,
    batch_size=BATCH_SIZE,
    fn_kwargs={"cot": True, "model": model, "tokenizer": tokenizer}
)
generated_dataset_cot_instructions.save_to_disk(f'{recipe_nlg_data_path}/oob_cot_generated')
# Out:
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
# Write recipe instructions for the following recipe title and ingredient list.
#     Use the provided reasoning to inform your response.
#     Enclose your recipe instructions in <instructions> tags and number each step.
#     Recipe Title: Orange Cookies Iii
#     Ingredients: ["1 cup shortening", "2 cups white sugar", "2 eggs", "1 cup buttermilk", "1/2 cup orange juice", "2 tablespoons orange zest", "4 1/2 cups all-purpose flour", "2 teaspoons baking powder", "1 teaspoon salt", "1/2 teaspoon baking soda", "1/4 cup butter", "4 cups confectioners' sugar", "3 tablespoons thawed orange juice concentrate"]
#     Reasoning: Your response:
# <reasoning>
# First, we gather all the necessary ingredients to make the cookies. We have 1 cup of shortening, 2 cups of white sugar, 2 eggs, 1 cup of buttermilk, 1/2 cup of orange juice, 2 tablespoons of orange zest, 4 1/2 cups of all-purpose flour, 2 teaspoons of baking powder, 1 teaspoon of salt, 1/2 teaspoon of baking soda, 1/4 cup of butter, 4 cups of confectioners' sugar, and 3 tablespoons of thawed orange juice concentrate.
#
# Next, we preheat our oven to 350 degrees F (175 degrees C) and line baking sheets with parchment paper. This step ensures that our cookies will bake evenly and not stick to the sheets.
#
# Then, we cream together the shortening and sugar in a large mixing bowl until light and fluffy. This step is important as it incorporates air into the mixture which helps create a tender cookie texture.
#
# Afterwards, we beat in the eggs, one at a time, making sure to fully incorporate each egg before adding the next.
#
# We then mix in the buttermilk, orange juice, orange zest, flour, baking powder, salt, and baking soda alternately into the butter mixture. Starting and ending with the flour mixture, we add the dry ingredients in three parts and the wet ingredients in two parts, ensuring that everything is mixed well after each addition.
#
# Once the dough is ready, we drop by rounded tablespoons onto the prepared baking sheets. This step is crucial as it determines the size and shape of our cookies.
#
# After placing the dough on the baking sheet, we bake the cookies at 350 degrees F (175 degrees C) for 12 to 15 minutes or until lightly browned. Baking time can vary depending on your oven and the size of the cookies, so it is important to keep an eye on them while they bake.
#
# Once the cookies are done, we remove them from the oven and allow them to cool completely on wire racks before frosting. Frosting warm cookies may result in the frosting melting and becoming less stable.
#
# Finally, in a medium saucepan over low heat, melt the butter and
#     Your response:
# Write recipe instructions for the following recipe title and ingredient list.
#     Use the provided reasoning to inform your response.
#     Enclose your recipe instructions in <instructions> tags and number each step.
#     Recipe Title: Creamy Roasted Garlic And Almond Soup
#     Ingredients: ["3 garlic bulbs", "1 onion chopped", "4 tablespoons olive oil", "creme fraiche 30 cl.", "4 1/4 cups chicken stock", "10 cups sourdough bread", "2 tablespoons white vinegar", "1 3/8 cups almonds peeled", "salt", "pepper", "water 25 cl.", "3 oranges peeled and sectioned", "cilantro", "mint"]
#     Reasoning: Firstly, preheat the oven to 400 degrees Fahrenheit.
# Then, slice off the top of each garlic bulb to expose the cloves, drizzle with olive oil and wrap tightly in aluminum foil. Set aside.
# Next, in a large pot, heat the remaining olive oil over medium-high heat. Add the chopped onion and cook until softened, about 5 minutes.
# Once the garlic is roasted, remove from the oven and let cool slightly. Then, squeeze out the garlic cloves and add them to the pot with the onion.
# Add the chicken stock to the pot and bring to a boil.
# While the soup is heating, cube the bread and set aside.
# Once the soup has reached a boil, add the cubed bread, crème fraîche, vinegar, salt, and pepper. Reduce heat to low and simmer for 30 minutes.
# While the soup is simmering, toast the almonds in a dry skillet over medium heat until golden brown, about 5 minutes. Let cool, then chop finely.
# Remove the soup from the heat and use an immersion blender to puree until smooth. If the soup is too thick, add water until desired consistency is achieved.
# To serve, ladle the soup into bowls and top with the chopped almonds, orange sections, and a sprinkle of chopped mint and cilantro. Season with additional salt and pepper if desired.
#     Your response:
# Write recipe instructions for the following recipe title and ingredient list.
#     Use the provided reasoning to inform your response.
#     Enclose your recipe instructions in <instructions> tags and number each step.
#     Recipe Title: Skillet Pasta Florentine
#     Ingredients: ["3 cups uncooked spiral pasta", "1 large egg, lightly beaten", "2 cups 2% cottage cheese", "1-1/2 cups reduced-fat ricotta cheese", "1 package (10 ounces) frozen chopped spinach, thawed and squeezed dry", "1 cup shredded part-skim mozzarella cheese, divided", "1 teaspoon each dried parsley flakes, oregano and basil", "1 jar (14 ounces) meatless spaghetti sauce", "2 tablespoons grated Parmesan cheese"]
#     Reasoning: Firstly, we need to cook the pasta according to package directions until al dente. This should take about 8 minutes.
# Once the pasta is cooked, drain it and set aside.
# Next, heat a nonstick skillet over medium heat. Add the meatless spaghetti sauce and bring it to a simmer. Let it simmer for about 5 minutes, stirring occasionally.
# While the sauce is simmering, prepare the spinach mixture. In a bowl, combine the cottage cheese, ricotta cheese, egg, spinach, 3/4 cup of the mozzarella cheese, and the dried herbs. Mix well.
# Add the cooked pasta to the skillet with the sauce and toss to coat the pasta evenly. Then, add the spinach mixture to the skillet and continue tossing until everything is combined.
# Sprinkle the remaining 1/4 cup of mozzarella cheese and the Parmesan cheese over the top of the pasta mixture.
# Now, reduce heat to low and cover the skillet. Allow it to cook for another 5 minutes, or until the cheeses have melted and the pasta is heated through.
#     Your response:
# Write recipe instructions for the following recipe title and ingredient list.
#     Use the provided reasoning to inform your response.
#     Enclose your recipe instructions in <instructions> tags and number each step.
#     Recipe Title: Roasted Pacific Cod With Spring Vegetables And Mint
#     Ingredients: ["4 (6-ounces) pieces skinless Pacific cod or hake fillet (1 inch thick)", "4 tablespoons extra-virgin olive oil, divided, plus additional for drizzling", "1 bunch scallions, cut into 1-inch pieces", "1/2 pound zucchini (about 2 medium), cut into 1/2-inch-thick half-moons", "1 (9-ounces) package frozen artichoke hearts, thawed", "1 cup frozen peas, thawed", "1 head romaine, thinly sliced crosswise", "1/4 cup water", "1/4 cup mint leaves, coarsely chopped"]
#     Reasoning: First, gather all the ingredients required for the recipe:
# - 4 (6-ounces) pieces of skinless Pacific cod or hake fillet (1 inch thick)
# - 4 tablespoons extra-virgin olive oil, divided
# - 1 bunch scallions, cut into 1-inch pieces
# - 1/2 pound zucchini (about 2 medium), cut into 1/2-inch-thick half-moons
# - 1 (9-ounces) package frozen artichoke hearts, thawed
# - 1 cup frozen peas, thawed
# - 1 head romaine, thinly sliced crosswise
# - 1/4 cup water
# - 1/4 cup mint leaves, coarsely chopped
# Next, preheat the oven to 400°F. Place the fish on a baking sheet and brush with 2 tablespoons of olive oil. Season with salt and pepper and roast for about 8 minutes until cooked through.
# While the fish is cooking, heat the remaining 2 tablespoons of olive oil over medium heat in a large frying pan. Add the scallions and cook until softened, about 3 minutes. Then add the zucchini and cook for another 5 minutes until it's tender but still holds its shape. Add the artichoke hearts, peas, and 1/4 cup of water to the pan, and cook for another minute. Remove from heat and set aside.
# Finally, arrange the sliced romaine on plates and spoon the vegetable mixture over top. Top each plate with a piece of roasted fish and sprinkle with chopped mint leaves. Drizzle with additional olive oil if desired.
#     Your response:
# Write recipe instructions for the following recipe title and ingredient list.
#     Use the provided reasoning to inform your response.
#     Enclose your recipe instructions in <instructions> tags and number each step.
#     Recipe Title: Chickpea Feta Salad over Greens
#     Ingredients: ["3 tablespoons olive oil", "1/2 teaspoon grated lemon zest, plus 3 tablespoons lemon juice", "Kosher salt and freshly ground black pepper", "5 cups mixed greens (about 10 ounces)", "1 cup grape tomatoes, halved lengthwise", "One 15-ounce can chickpeas, drained", "2 kirby cucumbers, sliced into half-moons", "1 large shallot, chopped", "1/2 cup crumbled plain or herbed feta, crumbled"]
#     Reasoning: First, you need to gather all the necessary ingredients: 3 tablespoons of olive oil, ½ teaspoon of grated lemon zest, 3 tablespoons of lemon juice, 5 cups of mixed greens (about 10 ounces), 1 cup of grape tomatoes, halved lengthwise, one 15-ounce can of chickpeas, drained, 2 kirby cucumbers, sliced into half-moons, and ½ cup of crumbled plain or herbed feta.
#
# Next, you'll want to prepare the dressing. In a small bowl, mix together the olive oil, grated lemon zest, lemon juice, and a pinch of kosher salt and freshly ground black pepper to taste. This can be done ahead of time if desired, but should be made fresh for best flavor.
#
# Then, on a serving platter or individual plates, arrange the mixed greens as the base. Scatter the grape tomatoes over the top of the greens.
#
# Afterward, prepare the chickpea mixture. In a medium bowl, combine the drained chickpeas, sliced kirby cucumbers, and chopped shallot. Add about two tablespoons of the prepared dressing to the chickpea mixture and toss until well coated. The chickpea mixture can also be prepared ahead of time.
#
# Finally, spoon the chickpea mixture over the greens and tomatoes on the plate or platter, sprinkle crumbled feta cheese over the top, and serve immediately.
#     Your response:
# Write recipe instructions for the following recipe title and ingredient list.
#     Use the provided reasoning to inform your response.
#     Enclose your recipe instructions in <instructions> tags and number each step.
#     Recipe Title: Coffee-Almond Rice Pudding
#     Ingredients: ["1 cup uncooked rice", "1-1/2 cups water", "1 qt. (4 cups) milk", "1/2 cup sugar", "2 Tbsp. MAXWELL HOUSE Instant Coffee", "2 Tbsp. grated orange zest Safeway 1 lb For $0.79 thru 02/09", "1/2 cup PLANTERS Slivered Almonds, toasted", "1 cup thawed COOL WHIP Whipped Topping"]
#     Reasoning: First, we need to cook the rice with water. While the rice is cooking, we can prepare the milk mixture by heating it up on the stove top. Once the rice is cooked, we can mix in the sugar and then add the instant coffee granules. The mixture should be stirred until the coffee has dissolved. Next, we can add in the grated orange zest and stir again. The toasted almonds can then be mixed into the rice mixture. Finally, the cool whip whipped topping can be folded into the rice mixture until well combined.
#     Your response:
# Write recipe instructions for the following recipe title and ingredient list.
#     Use the provided reasoning to inform your response.
#     Enclose your recipe instructions in <instructions> tags and number each step.
#     Recipe Title: Tomato, Mozzarella and Basil Salad
#     Ingredients: ["2 tablespoons extra-virgin olive oil", "6 tablespoons balsamic vinegar", "2 teaspoons minced garlic", "1/2 teaspoon English dry mustard", "1/4 teaspoon sugar", "Salt, to taste", "Pepper, to taste", "2 large vine-ripened tomatoes, cut into 1/4-inch-thick slices", "1/2 pound mozzarella cheese (preferrably fresh), cut into 1/4-inch-thick slices", "10 large fresh basil leaves, sliced thin"]
#     Reasoning: Step 1: Combine the dressing ingredients: In a small bowl, whisk together 2 tablespoons of extra-virgin olive oil, 6 tablespoons of balsamic vinegar, 2 teaspoons of minced garlic, 1/2 teaspoon of English dry mustard, 1/4 teaspoon of sugar, salt to taste, and pepper to taste. This can be done ahead of time and stored at room temperature until ready to use. The time it takes for this step is approximately 5 minutes.
# Step 2: Prepare the vegetables: Cut 2 large vine-ripened tomatoes into 1/4-inch-thick slices and set aside. Cut 1/2 pound of mozzarella cheese (preferably fresh) into 1/4-inch-thick slices and set aside. Slice 10 large fresh basil leaves thinly and set aside. This step should take around 5 minutes.
# Step 3: Assemble the salad: On a platter or individual plates, arrange the tomato and mozzarella slices alternately. Drizzle the dressing over the salad. Sprinkle the sliced basil leaves over the top. This step should take about 3 minutes.
#     Your response:
# Write recipe instructions for the following recipe title and ingredient list.
#     Use the provided reasoning to inform your response.
#     Enclose your recipe instructions in <instructions> tags and number each step.
#     Recipe Title: Jumbo Chocolate Chip Cookies
#     Ingredients: ["2/3 cup shortening", "2/3 cup butter, softened", "1 cup sugar", "1 cup packed brown sugar", "2 large eggs, room temperature", "2 teaspoons vanilla extract", "3-1/2 cups all-purpose flour", "1 teaspoon baking soda", "1 teaspoon salt", "2 cups (12 ounces) semisweet chocolate chips", "1 cup chopped pecans"]
#     Reasoning: The first step is to preheat the oven to 375°. This needs to be done before anything else can be done as it sets the temperature for baking the cookies.
# Next, cream together the shortening and butter with the sugars until light and fluffy. This needs to be done before adding the other wet ingredients so they get evenly distributed.
# Then add the eggs one at a time, beating well after each addition. This ensures that the eggs are fully incorporated into the batter.
# After that, stir in the vanilla extract. This step doesn't take much time but it adds flavor to the dough.
# Now combine the dry ingredients - flour, baking soda, and salt. Mix them together before adding them to the wet ingredients. Make sure to mix them well to ensure even distribution of the leavening agents.
# Once the dry ingredients are mixed, gradually add the dry mixture to the creamed mixture and mix until just combined. Do not overmix or the cookies will become tough.
# Then fold in the chocolate chips and pecans. This step ensures that the chocolate chips and pecans are evenly distributed throughout the cookie dough.
# Using an ice cream scoop, drop rounded tablespoons of dough onto ungreased baking sheets. Space them about 2 inches apart as they will spread while baking.
# Bake at 375° for 8-10 minutes or until golden brown. Remember to keep an eye on them so they don't burn.
# Let cool on wire racks. This allows the cookies to cool down and firm up before handling.
#     Your response:
# Write recipe instructions for the following recipe title and ingredient list.
#     Use the provided reasoning to inform your response.
#     Enclose your recipe instructions in <instructions> tags and number each step.
#     Recipe Title: Norwegian Potato Klub
#     Ingredients: ["6 slices bacon", "2 cups all-purpose flour", "1/2 teaspoon baking powder", "10 medium potatoes, peeled and shredded", "2 teaspoons salt"]
#     Reasoning: First, you will need to cook the bacon until crispy. This can take around 15 minutes. Once the bacon is cooked, set it aside on a paper towel-lined plate to drain excess oil.
# While the bacon is cooking, you can prepare the dough. In a bowl, mix together the flour, baking powder, and 1 teaspoon of salt. Then, gradually add water to the mixture while stirring until a soft dough forms. This typically takes around 3-4 minutes.
# Next, you can start boiling the potatoes. This can take around 15-20 minutes depending on the size of the potatoes. Once they are tender enough, drain them thoroughly using a colander.
# Now, you can crumble the cooked bacon and add it to the potato mixture. Mix well so that the bacon is evenly distributed throughout the potatoes. Taste and adjust seasoning if necessary with the remaining 1 teaspoon of salt.
# Finally, roll out the dough into 6 equal portions and shape them into round disks. Place about 2 tablespoons of the potato and bacon mixture onto the center of each disk. Fold the dough over the filling and press the edges to seal the edges tightly. Make sure there are no gaps where the filling could leak out during cooking.
# The filled dumplings are now ready for frying or boiling. To fry, heat oil in a pan over medium-high heat and fry the dumplings until golden brown on both sides. To boil, bring a large pot of salted water to a boil and gently drop the dumplings into the water. Cook until they float to the surface, then cook for 2 more minutes. Serve warm with sour cream or applesauce on the side.
#     Your response:
# Write recipe instructions for the following recipe title and ingredient list.
#     Use the provided reasoning to inform your response.
#     Enclose your recipe instructions in <instructions> tags and number each step.
#     Recipe Title: Dry-Aged Strip Steaks Without Drying Or Aging
#     Ingredients: ["1 1/2 ounces dried porcini mushrooms", "1/2 teaspoon granulated white sugar", "1/2 teaspoon ground white pepper", "2 10-ounce boneless New York strip steaks, about 1 inch thick", "2 tablespoons soy sauce (gluten-free if that is a concern)", "3 tablespoons unsalted butter", "2 tablespoons balsamic vinegar"]
#     Reasoning: The first step would be to rehydrate the dried porcini mushrooms. This can be done by placing them in a bowl and pouring boiling water over them until they are covered. Letting them sit for at least 20 minutes will allow the mushrooms to soften and absorb the liquid.
# After the mushrooms have been rehydrated, they should be strained and reserving the soaking liquid for use later in the recipe. The mushrooms can then be chopped finely.
# Next, create a marinade by combining the chopped mushrooms, soy sauce, balsamic vinegar, sugar, and white pepper in a small mixing bowl. Mix well to combine all ingredients.
# Now, season both sides of the steaks with salt and place them in a shallow dish or resealable plastic bag. Pour the marinade over the steaks, making sure they are fully coated. If using a plastic bag, seal it tightly and refrigerate for at least 4 hours, or up to 12 hours. If using a shallow dish, cover the dish with plastic wrap and refrigerate for at least 4 hours, or up to 12 hours.
# Once the steaks have finished marinating, preheat the oven to 450°F. Heat a cast iron skillet or griddle on high heat. When the skillet is hot, add the butter and let it melt. Cook the steaks in the skillet for about 2-3 minutes per side, until browned on the outside but still slightly pink in the center. Then transfer the skillet to the preheated oven and cook the steaks for another 3-4 minutes for medium-rare, or longer if desired.
# Remove the skillet from the oven and let the steaks rest for about 5 minutes before slicing and serving. Use the reserved soaking liquid as a sauce, if desired.
#     Your response:
# Write recipe instructions for the following recipe title and ingredient list.
#     Use the provided reasoning to inform your response.
#     Enclose your recipe instructions in <instructions> tags and number each step.
#     Recipe Title: Brazilian Summer Plantain Stew (Moqueca)
#     Ingredients: ["4 large plantains, peeled and cut into thick slices on the diagonal", "2 limes, juice", "3 garlic cloves, finely chopped", "1 red onion, sliced", "1 long red chilli, finely chopped, seeds removed", "1 green pepper, sliced", "1 red pepper, sliced", "6 tomatoes, diced", "1.5 teaspoons sweet paprika", "150 milliliters coconut milk", "250 milliliters vegetable stock", "1 cup cilantro, roughly chopped (reserve a little for garnish)", "Large spoonful of cooked rice, for serving (optional)"]
#     Reasoning: Firstly, you'll need to gather all your ingredients, including 4 large plantains, 2 limes, 3 garlic cloves, 1 red onion, 1 long red chilli, 1 green pepper, 1 red pepper, 6 tomatoes, 1.5 teaspoons sweet paprika, 150 milliliters coconut milk, 250 milliliters vegetable stock, and 1 cup cilantro. Once everything is prepared, start by peeling and cutting the plantains into thick slices on the diagonal. Next, juice the limes and set aside. Then, move on to the garlic, red onion, red chilli, green pepper, and red pepper. Finely chop the garlic, slice the red onion, and remove the seeds from the red chilli while finely chopping it. Slice the green pepper and red pepper. Now it's time to dice the tomatoes. Afterward, cook the rice according to package directions. In a separate pot, heat the vegetable stock and coconut milk together. When all these preparations are complete, it's time to combine the ingredients in a pan and simmer until the stew reaches your desired thickness. Finally, add the reserved cilantro for garnish and serve with the cooked rice.
#     Your response:
# Write recipe instructions for the following recipe title and ingredient list.
#     Use the provided reasoning to inform your response.
#     Enclose your recipe instructions in <instructions> tags and number each step.
#     Recipe Title: Easy Sobameshi - Yakisoba Noodles and Rice
#     Ingredients: ["1 pack Steamed Chinese style or yakisoba noodles", "100 grams or (to taste) Pork", "1/2 Onion", "1/4 Carrot", "2 Green peppers", "1 bowlful Plain cooked rice", "1 dash Chopped green onion (for garnish)", "1 dash Sake", "2 handfuls Bonito flakes (fine)", "2 tbsp Japanese Worcestershire-style sauce", "2 tbsp Tonkatsu sauce (Japanese style Worcestershire sauce or steak sauce)", "1 tbsp Ketchup", "1 tbsp Vegetable oil"]
#     Reasoning: Your response: <reasoning>
# First, gather all the ingredients: one pack of steamed Chinese style or yakisoba noodles, 100 grams or to taste pork, half an onion, 1/4 carrot, 2 green peppers, plain cooked rice, chopped green onion for garnish, sake, bonito flakes, Japanese Worcestershire-style sauce, tonkatsu sauce, ketchup, and vegetable oil.
#
# Next, prepare the ingredients by slicing the pork, dicing the onion, shredding the carrot, and slicing the green peppers. These steps can take approximately 5-10 minutes depending on your knife skills.
#
# Afterwards, heat up the pan with the vegetable oil and cook the pork until it is slightly browned. This process should take about 3-5 minutes.
#
# Once the pork is slightly browned, add the onions into the pan and cook them until they become translucent. This step usually takes around 3-5 minutes as well.
#
# Then, add in the shredded carrots and continue cooking for another 2 minutes.
#
# Subsequently, incorporate the green peppers and cook for another 2 minutes.
#
# Now, add the cooked rice into the pan and mix everything together, making sure that the vegetables and meat are evenly distributed throughout the mixture. Cook for about 2-3 minutes.
#
# Following that, pour in the sauces - Japanese Worcestershire-style sauce, tonkatsu sauce, and ketchup - as well as the sake. Mix the contents of the pan well so that the flavors are incorporated.
#
# Finally, introduce the steamed Chinese style or yakisoba noodles into the pan, breaking them apart with your spatula to ensure that they're evenly coated in the sauce and mixed with the other ingredients. Continue cooking for another 1-2 minutes.
#
# Serve hot and top with bonito flakes and chopped green onion for garnish.
#
# The entire process should take approximately 20-30 minutes, depending on the time taken for cooking each ingredient. The noodles need to be heated through, but they do not require extensive cooking as they have been pre-cooked and only need
#     Your response:
# Write recipe instructions for the following recipe title and ingredient list.
#     Use the provided reasoning to inform your response.
#     Enclose your recipe instructions in <instructions> tags and number each step.
#     Recipe Title: Italian Turkey With Polenta
#     Ingredients: ["Cooking spray", "1/2 pound ground turkey breast", "1 garlic clove, minced", "1 (15-ounce) can stewed tomatoes, undrained and chopped", "1 teaspoon dried Italian seasoning", "1/4 teaspoon ground red pepper", "1 (16-ounce) tube polenta", "1/4 cup shredded fresh Parmesan cheese"]
#     Reasoning: First, preheat the oven to 375°F. Next, prepare the turkey mixture by spraying a skillet with cooking spray and heating it over medium heat. Add the ground turkey breast and cook until browned, breaking it apart as it cooks. When the turkey is cooked, add the minced garlic, stewed tomatoes, Italian seasoning, and ground red pepper to the skillet and stir to combine. Let it simmer for about 10 minutes, until the sauce thickens. While the sauce is simmering, slice the polenta into 1/2 inch rounds. Microwave the polenta slices on high for about 2 minutes until heated through. Spray a baking sheet with cooking spray and place the polenta slices on it. Bake in the preheated oven for about 15 minutes until crispy. Finally, top the polenta slices with the turkey mixture and sprinkle with shredded Parmesan cheese. Serve hot.
#     Your response:
# Write recipe instructions for the following recipe title and ingredient list.
#     Use the provided reasoning to inform your response.
#     Enclose your recipe instructions in <instructions> tags and number each step.
#     Recipe Title: New Year'S Brunch: Black Truffle Fettuccine Recipe
#     Ingredients: ["10 ounces of dried egg fettuccine", "3/4 cup heavy cream", "3 ounces black truffle butter (D'Artagnan)", "Pinch of freshly ground nutmeg", "Salt and pepper"]
#     Reasoning: - First, bring a large pot of salted water to a boil.
# - Add the dried egg fettuccine to the boiling water and cook according to package directions until al dente.
# - While the pasta is cooking, heat the heavy cream in a small saucepan over medium heat until it begins to simmer.
# - Remove the saucepan from heat and whisk in the black truffle butter until melted and combined.
# - Add a pinch of freshly ground nutmeg and season with salt and pepper to taste.
# - Drain the cooked pasta and add it to the creamy truffle sauce. Toss to coat the pasta evenly.
# - Serve immediately, garnished with additional shaved black truffles if desired.
#     Your response:
# Write recipe instructions for the following recipe title and ingredient list.
#     Use the provided reasoning to inform your response.
#     Enclose your recipe instructions in <instructions> tags and number each step.
#     Recipe Title: Oatmeal Cookie Drops with Milk Chocolate and Almonds
#     Ingredients: ["2 each chocolate bars with almonds, 7 ounces each", "3/4 cup butter or margarine, softened", "1/2 cup brown sugar, light packed", "1/2 cup sugar granulated", "3 tablespoons corn syrup, light", "2 large eggs", "1 teaspoon vanilla extract", "1/2 teaspoon almond extract", "2 1/4 cups flour, all-purpose", "1 teaspoon baking soda", "1/2 teaspoon salt", "1 1/2 cups rolled oats old-fashioned", "1/2 cup almonds toasted, chopped"]
#     Reasoning: To start with, we need to gather all the necessary ingredients. We'll need two chocolate bars with almonds, weighing 7 ounces each, butter or margarine, softened, brown sugar (light packed), granulated sugar, corn syrup (light), two large eggs, vanilla extract, almond extract, all-purpose flour, baking soda, salt, old-fashioned rolled oats, and toasted almonds (chopped).
#
# Next, we'll want to preheat the oven to 350 degrees Fahrenheit, so that it's ready when we get to the baking stage.
#
# Once all the ingredients are together, we can begin mixing the wet ingredients together. This includes creaming the butter or margarine, adding the brown sugar, granulated sugar, and corn syrup, then beating in the eggs one at a time until they are well mixed. Following that, we can add the vanilla extract and almond extract.
#
# While the wet ingredients are being mixed, we can also prepare the dry ingredients. In a separate bowl, mix together the all-purpose flour, baking soda, and salt.
#
# Now comes the part where we combine the wet and dry ingredients. We'll gradually add the dry ingredients to the wet ingredients and mix them together until they form a dough. Then, we can fold in the rolled oats.
#
# After the dough is prepared, we can chop up the chocolate bars with almonds into small pieces and fold them into the dough as well.
#
# Finally, we can shape the dough into cookie drop shapes using our hands or a cookie scoop, place them onto a greased baking sheet, and bake for approximately 10-12 minutes or until lightly golden brown. Once baked, we can let them cool on the baking sheet for a few minutes before transferring them to a wire rack to cool completely.
#
# We'll want to make sure we have toasted and chopped the almonds beforehand, as they're added last to the dough. Also, the cookie dough needs to be chilled for at least 30 minutes before baking, so we should plan accordingly.
#     Your response:
# Write recipe instructions for the following recipe title and ingredient list.
#     Use the provided reasoning to inform your response.
#     Enclose your recipe instructions in <instructions> tags and number each step.
#     Recipe Title: Potato Bacon Frittata Recipe
#     Ingredients: ["8 ounce. bacon, diced", "2 lg. potatoes, peeled & cubed", "1/4 c. minced onion", "1/4 c. diced green pepper", "1/4 teaspoon pepper", "1 teaspoon salt, divided", "6 Large eggs", "1 c. shredded Swiss (or possibly American) cheese", "1 c. lowfat milk", "1/3 c. Bisquick", "2 tbsp. melted butter"]
#     Reasoning: First, preheat the oven to 350 degrees F. Next, cook the diced bacon in a large non-stick skillet over medium heat until browned and crispy. Use a slotted spoon to remove the cooked bacon and set it aside on a paper towel-lined plate to drain.
# Then, in the same skillet, combine the cubed potatoes with 1/2 teaspoon of salt and cook them over medium-high heat for about 10 minutes or until they are tender enough to pierce easily with a fork. After the potatoes have finished cooking, add the minced onion and diced green pepper to the skillet and continue cooking for another 3-4 minutes until the vegetables are softened. Add the cooked bacon back to the skillet and mix everything together. Turn off the heat and let the mixture cool for a few minutes.
# While the potato mixture is cooling, in a separate bowl whisk together the eggs, 1/2 teaspoon of salt, milk, and Bisquick until well combined. Then, stir in the shredded cheese.
# Pour the egg mixture over the potato mixture in the skillet, gently mixing everything together. Then pour the mixture into a lightly greased 9-inch round baking dish. Drizzle the melted butter over the top of the mixture.
# Bake the frittata in the preheated oven for 30-35 minutes or until the center is set and the top is golden brown. Let the frittata cool for a few minutes before serving.
#     Your response:
# Write recipe instructions for the following recipe title and ingredient list.
#     Use the provided reasoning to inform your response.
#     Enclose your recipe instructions in <instructions> tags and number each step.
#     Recipe Title: Whole Wheat Banana Date And Peanut Loaf
#     Ingredients: ["1 1/2 cups whole wheat self-rising flour", "1 cup wheatgerm", "1/2 cup raw sugar", "1 1/2 cups pitted dates, chopped", "8 tbsp (1 stick) butter, melted", "1/4 cup milk", "2 None eggs, lightly beaten", "3 None bananas, mashed", "1/4 cup unsalted roasted peanuts"]
#     Reasoning: First, preheat oven to 350°F and prepare a loaf pan with non-stick spray. In a large mixing bowl, combine the self-rising whole wheat flour and wheatgerm. In a separate bowl, mix together the melted butter and raw sugar until well combined. Then add the lightly beaten eggs to the butter and sugar mixture and mix again. Next, take the mashed bananas and mix them into the wet ingredients until fully incorporated. Add the chopped dates and roasted peanuts into the dry ingredient mixture and stir. Finally, pour the wet ingredients into the dry and mix thoroughly, adding milk as needed to make a smooth consistency. Once mixed, pour the batter into the prepared loaf pan, filling it about three-quarters full. Bake in the preheated oven for approximately one hour, or until a toothpick inserted into the center of the bread comes out clean. Allow the loaf to cool completely before slicing and serving.
#     Your response:
# Write recipe instructions for the following recipe title and ingredient list.
#     Use the provided reasoning to inform your response.
#     Enclose your recipe instructions in <instructions> tags and number each step.
#     Recipe Title: Turkey Meat Balls
#     Ingredients: ["1 pound Ground Turkey", "1 whole Egg", "1 Tablespoon Lipton Onion Soup Mix", "1/4 teaspoons Garlic Powder", "1/4 teaspoons Ground Black Pepper", "1/4 teaspoons Salt", "3 Tablespoons Parmesan Cheese", "12 pieces Ritz Crackers", "3 Tablespoons Tomato Sauce", "3 Tablespoons Bread Crumbs", "2 Tablespoons Olive Oil"]
#     Reasoning: To begin making turkey meatballs, start by preheating the oven to 350 degrees Fahrenheit. This will ensure that the meatballs cook evenly and thoroughly. While the oven is preheating, combine the ground turkey with the egg in a large mixing bowl. The egg acts as a binder for the meat, which is crucial for the meatballs' shape and structure.
# Once the turkey and egg mixture is well combined, add the Lipton onion soup mix, garlic powder, black pepper, and salt. These seasonings will add flavor to the meatballs. After mixing the seasonings into the turkey mixture, add the parmesan cheese and crumble the Ritz crackers into the mixture. The crackers add texture and help the meatballs hold their shape during cooking.
# Next, roll the turkey mixture into small, round balls and place them on a baking sheet lined with parchment paper. Make sure to space them apart so they don't touch while baking. In a small bowl, combine the tomato sauce and breadcrumbs to create a sauce for the meatballs. Brush the mixture over the meatballs with a pastry brush or spoon.
# Finally, drizzle the olive oil over the top of the meatballs. This will help them brown and crisp up during baking. Place the baking sheet in the preheated oven and bake for about 20-25 minutes until the meatballs are cooked through and golden brown. Serve hot and enjoy!
#     Your response:
# Write recipe instructions for the following recipe title and ingredient list.
#     Use the provided reasoning to inform your response.
#     Enclose your recipe instructions in <instructions> tags and number each step.
#     Recipe Title: Maple Leaf Sazerac From Minetta Tavern
#     Ingredients: ["1 3/4 oz. Rittenhouse rye whiskey", "1/2 oz. Demerara", "1/4 oz. Sortilege maple liqueur", "3 dashes Peychaud's Bitters", "2 dashes Angostura bitters", "1 oz. Absinthe, used as rinse"]
#     Reasoning: Firstly, gather all of the required ingredients - Rittenhouse rye whiskey, Demerara, Sortilege maple liqueur, Peychaud's Bitters, Angostura Bitters, and Absinthe. Start by rinsing a chilled glass with the Absinthe, swirling it around to coat the inside of the glass and then discarding the excess liquid. In a separate mixing glass or shaker filled with ice, combine the Rittenhouse rye whiskey, Demerara, Sortilege maple liqueur, Peychaud's Bitters, and Angostura Bitters. Stir well to ensure even distribution of the flavors. Once well-mixed, strain the liquid from the mixing glass or shaker into the Absinthe-rinsed glass over ice. Garnish with a lemon twist, if desired, and enjoy!
#     Your response:
# Write recipe instructions for the following recipe title and ingredient list.
#     Use the provided reasoning to inform your response.
#     Enclose your recipe instructions in <instructions> tags and number each step.
#     Recipe Title: Strawberries with Cassis
#     Ingredients: ["6 1-pint baskets strawberries, hulled and halved or quartered (depending on size of berries)", "1 1/4 cups creme de cassis liqueur", "1/3 cup sugar", "2 tablespoons fresh lemon juice", "3 cups chilled whipping cream", "3 tablespoons powdered sugar"]
#     Reasoning: Firstly, we need to gather all the required ingredients which include 6 pints of strawberries, creme de cassis liqueur, sugar, fresh lemon juice, whipping cream, and powdered sugar. We begin by hulling and halving or quartering the strawberries depending on their size. This step is important as it ensures even coating and distribution of the other ingredients. Secondly, we prepare the syrup by mixing together sugar and water in a saucepan over medium heat until the sugar dissolves. Afterwards, we remove the pan from heat and stir in the creme de cassis and fresh lemon juice. The mixture is then left to cool. In parallel, we whip the cream and powdered sugar together until stiff peaks form. This step should be done just before serving so that the whipped cream remains fresh. Finally, we mix the strawberries with the cooled syrup and serve them in individual dishes, topped with a dollop of the whipped cream.
#     Your response:
# Write recipe instructions for the following recipe title and ingredient list.
#     Use the provided reasoning to inform your response.
#     Enclose your recipe instructions in <instructions> tags and number each step.
#     Recipe Title: PHILADELPHIA Chocolate Cheesecakes for Two
#     Ingredients: ["60 g Philadelphia Brick Cream Cheese, softened", "1 oz. Baker's Semi-Sweet Chocolate, melted", "1 Tbsp. sugar", "1/2 cup thawed Cool Whip Whipped Topping", "2 Oreo Cookies"]
#     Reasoning: We will need to make sure that all of our ingredients are ready before we start making the cheesecake. We'll start by preparing the cream cheese by softening it. This can take around 30 minutes if left at room temperature. While waiting for the cream cheese to soften, we should prepare the chocolate by melting it over low heat on the stove top or using a microwave until smooth. It may take around 5 minutes to melt the chocolate. After the chocolate is melted, we can then prepare the sugar by measuring out 1 tablespoon of sugar and setting it aside. Next, we can get our Cool Whip Whipped Topping and allow it to thaw in the refrigerator for about 2-3 hours or until soft. Finally, we can crush two Oreo cookies into small crumbs which can be done quickly in a food processor or by placing them in a plastic bag and using a rolling pin to crush them.
#     Your response:
# Write recipe instructions for the following recipe title and ingredient list.
#     Use the provided reasoning to inform your response.
#     Enclose your recipe instructions in <instructions> tags and number each step.
#     Recipe Title: Hot & Sour Soup
#     Ingredients: ["3 inches Ginger (thinly shredded)", "2 Carrot (shredded)", "1 Chicken Breast", "1 bunch Coriander", "1 bunch Shitake Mushroom (thinly shredded)", "2 egg (beaten)", "1 tsp chili powder", "1 liter boiling water", "1 tsp sesame oil", "1 vinegar", "1 soya sauce", "1 red chili (optional)"]
#     Reasoning: Firstly, we need to prepare all the ingredients. This means we need to thinly shred the ginger, carrots and shitake mushrooms. We also need to chop up the chicken breast into small pieces, beat two eggs, and finely chop the coriander leaves. If desired, we can also chop up one red chili.
# Next, we need to have a pot ready with 1 liter of boiling water. Once the water is boiling, we add in the shredded ginger, carrots, shitake mushrooms, and the chicken breast pieces. Let it cook for about 5-10 minutes until the chicken is cooked through.
# Then, we add in the beaten eggs and let them cook for another minute or until they’re set. After that, we turn off the heat and add in the soy sauce, vinegar, chili powder and sesame oil. We stir everything together to ensure that the flavors mix well.
# Finally, we garnish the soup with the chopped coriander leaves. The soup is now ready to serve!
#     Your response:
# Write recipe instructions for the following recipe title and ingredient list.
#     Use the provided reasoning to inform your response.
#     Enclose your recipe instructions in <instructions> tags and number each step.
#     Recipe Title: Delicious Kabocha Squash and Spinach Soup
#     Ingredients: ["1/4 Kabocha squash", "1/2 bunch Spinach", "200 ml Milk", "2 tbsp Hot water", "1 Consomme soup stock cube", "1 heaped teaspoon) (if using consomme granules"]
#     Reasoning: Your response:
# <reasoning>
# Step 1: Start by preparing the Kabocha squash. Cut it into small pieces, about 1 inch in size. This should take around 5 minutes. Keep aside.
#
# Reasoning: Chopping the squash into small pieces allows it to cook more evenly and quickly. It's also easier to blend later on.
#
# Step 2: Next, chop the spinach. The leaves should be finely chopped while the stems can be left longer or chopped into smaller pieces as per preference. This should take around 3-4 minutes. Keep aside.
#
# Reasoning: Finely chopping the spinach helps distribute its flavor and nutrition throughout the soup. If stems are left longer, they can be removed before serving if desired.
#
# Step 3: In a pot, heat up some oil over medium heat. When hot, add the chopped Kabocha squash and sauté until slightly browned. This should take around 8-10 minutes.
#
# Reasoning: Sautéing the squash adds depth of flavor and browning brings out its natural sweetness.
#
# Step 4: Add the chopped spinach to the pot with the sautéed squash. Stir well and cook for another 2 minutes until spinach is wilted. Turn off the heat.
#
# Reasoning: Cooking the spinach along with the squash helps retain its bright green color and ensures even cooking. The residual heat from the pot will continue to cook the vegetables without burning them.
#
# Step 5: In a separate bowl or cup, dissolve the consomme soup stock cube or granules in 2 tablespoons of hot water. Set aside.
#
# Reasoning: Dissolving the stock cube or granules in hot water enhances their flavor and ensures even distribution in the soup.
#
# Step 6: Transfer the cooked vegetables to a blender or food processor and blend until smooth. This should take around 2-3 minutes.
#
# Reasoning: Blending the vegetables creates a creamy texture and makes the soup easier to swallow.
#
# Step 7: Pour the blended vegetable mixture back into the pot. Add the milk and the dissolved consomme mixture. Heat over low heat, stirring occasionally, until heated through. This should take around 5 minutes.
#
# Reasoning: Heating the soup
#     Your response:
# Write recipe instructions for the following recipe title and ingredient list.
#     Use the provided reasoning to inform your response.
#     Enclose your recipe instructions in <instructions> tags and number each step.
#     Recipe Title: Balsamic Roasted Fall Vegetables
#     Ingredients: ["1/4 cups Extra Virgin Olive Oil", "2 Tablespoons Balsamic Vinegar", "2 teaspoons Honey", "1 teaspoon Dijon Mustard", "2-1/2 pounds Assorted Vegetables, Cut Into 1/2 Inch Cubes Or Rounds (I Used Butternut Squash, Carrots, And Sunchokes But Sweet Potatoes, Zucchini, Squash, Eggplant Or Mushrooms Would Be Great)", "1 whole Red Onion, Chopped", "Salt And Pepper"]
#     Reasoning: 1. Preheat oven to 425 degrees F.
# 2. In a large bowl, whisk together extra virgin olive oil, balsamic vinegar, honey, and dijon mustard to make a dressing.
# 3. Add the chopped vegetables and red onion to the bowl with the dressing and toss until well coated.
# 4. Spread the vegetable mixture evenly on a baking sheet.
# 5. Season the vegetables with salt and pepper to taste.
# 6. Roast in preheated oven for about 30-35 minutes, stirring halfway through, until the vegetables are tender and caramelized.
# 7. Remove from oven and serve immediately.
#     Your response:
# Write recipe instructions for the following recipe title and ingredient list.
#     Use the provided reasoning to inform your response.
#     Enclose your recipe instructions in <instructions> tags and number each step.
#     Recipe Title: Piri-Piri Chicken
#     Ingredients: ["8 cloves garlic minced", "3 lemons juiced, plus wedges to serve", "1/3 cup whiskey", "1 fresh bay leaf", "2 teaspoons sweet paprika", "1/4 cup olive oil", "4 chicken breasts skin-on", "1 red onion thinly sliced into rings", "1 pound cherry tomatoes", "4 red chilies long", "8 slices ciabatta bread", "2 tablespoons olive oil", "1/2 lemon juiced", "1 red chili long, finely chopped", "1 clove garlic minced"]
#     Reasoning: Step 1: Prepare the marinade
#     - In a medium bowl, mix together the garlic, juice from three lemons, whiskey, bay leaf, sweet paprika, and 1/4 cup of olive oil. This will take approximately 2 minutes.
# Step 2: Marinate the chicken
#     - Place the chicken breasts in a large resealable plastic bag or container. Pour the prepared marinade over the chicken, making sure it is well coated. Seal the bag or container and refrigerate for at least 4 hours or overnight. This will take at least 4 hours up to overnight.
# Step 3: Preheat the grill
#     - Preheat your grill to medium-high heat. This will take about 10 minutes.
# Step 4: Cook the chicken
#     - Remove the chicken from the marinade and discard the marinade. Grill the chicken breasts, skin side down, for about 6-8 minutes per side, or until fully cooked. This will take about 15-20 minutes total.
# Step 5: Prepare the vegetables
#     - While the chicken is cooking, prepare the vegetables. Toss the sliced red onion, cherry tomatoes, and long red chilies in a bowl. Set aside. This will take about 2 minutes.
# Step 6: Toast the bread
#     - Brush the ciabatta slices with 2 tablespoons of olive oil and grill them for about 2 minutes per side, or until golden brown and crispy. Squeeze 1/2 lemon over the toasted bread and sprinkle with finely chopped red chili and minced garlic. This will take about 4-6 minutes.
# Step 7: Assemble the sandwiches
#     - Once the chicken is cooked, slice it into pieces and add it to the bowl with the grilled vegetables. Mix well and then divide the mixture between the toasted ciabatta slices. Serve immediately with lemon wedges on the side. This will take about 2 minutes.
#     Your response:
# Write recipe instructions for the following recipe title and ingredient list.
#     Use the provided reasoning to inform your response.
#     Enclose your recipe instructions in <instructions> tags and number each step.
#     Recipe Title: Rich Chocolate Rum Cookies
#     Ingredients: ["1 1/4 cups all-purpose flour", "1 1/2 teaspoons baking powder", "1/2 teaspoon salt", "1/2 cup ground hazelnuts (about 1/2 cup shelled nuts)", "12 ounces fine-quality bittersweet chocolate (not unsweetened)", "1/2 stick (1/4 cup) unsalted butter", "1/4 cup dark rum", "2 large eggs", "about 1/4 cup confectioners' sugar for sprinkling cookies"]
#     Reasoning: Firstly, gather all the necessary ingredients which include 1 1/4 cups of all-purpose flour, 1 1/2 teaspoons of baking powder, 1/2 teaspoon of salt, 1/2 cup of ground hazelnuts, 12 ounces of fine-quality bittersweet chocolate (not unsweetened), 1/2 stick (1/4 cup) of unsalted butter, 1/4 cup of dark rum, 2 large eggs, and about 1/4 cup of confectioners' sugar for sprinkling the cookies.
# Next, preheat your oven to 350 degrees Fahrenheit.
# Then, in a medium bowl, whisk together the flour, baking powder, and salt. This is important as it ensures that the cookies will have the right texture and rise properly during baking.
# After that, in another bowl, melt the chocolate and butter in a double boiler or microwave until smooth. This step ensures that the chocolate and butter are well combined and creates a smooth base for the cookie dough.
# Next, stir in the rum and then add the eggs one at a time, beating well after each addition. Mixing the wet ingredients ensures a moist and tender cookie.
# Now, add the chocolate mixture to the flour mixture, stirring just until blended. The dry mixture should be fully incorporated into the wet mixture, but do not overmix.
# Following that, fold in the ground hazelnuts. This step adds texture and depth of flavor to the cookies.
# Finally, drop rounded tablespoons of the cookie dough onto ungreased baking sheets, spacing them about 2 inches apart. Bake in the middle of the oven until the cookies are firm around the edges but still slightly soft in the center, about 12 minutes. Cool on the baking sheets for 5 minutes, then transfer to racks to cool completely. Once the cookies are cool, you can sprinkle them with confectioners' sugar for decoration.
#     Your response:
# Write recipe instructions for the following recipe title and ingredient list.
#     Use the provided reasoning to inform your response.
#     Enclose your recipe instructions in <instructions> tags and number each step.
#     Recipe Title: Mashed Potato Leek Soup Recipe
#     Ingredients: ["2 cups mashed potatoes (herbs, butter, anything you put in them)", "3 cups clean, chopped leeks", "1 medium stalk celery, chopped", "1 large carrot, chopped", "4 cups water", "1 1/2 teaspoon salt", "1 cup milk (as needed)", "fresh ground pepper"]
#     Reasoning: First, gather all the ingredients which include 2 cups of mashed potatoes (preferably with herbs and butter), 3 cups of cleaned and chopped leeks, 1 medium-sized stalk of celery chopped, 1 large carrot also chopped, 4 cups of water, 1 and a half teaspoons of salt, 1 cup of milk as needed, and freshly ground pepper.
# Next, heat up a large pot on medium heat and add the chopped leeks. Saute the leeks for about 5 minutes until they become tender. Then, add the chopped celery and carrots to the pot and continue sautéing for another 5 minutes.
# After that, pour in the 4 cups of water and bring it to a boil. Once boiling, reduce the heat to low and let it simmer for 10-15 minutes or until the vegetables are cooked through.
# Once the vegetables are cooked, use a blender to puree the mixture until smooth. If necessary, you can add some of the mashed potatoes at this stage to thicken the soup. Return the pureed mixture back to the pot.
# Then, add the mashed potatoes, salt, and milk to the pot and stir everything together. Let it cook for 2-3 minutes more just so that everything is heated through.
# Finally, sprinkle freshly ground pepper over the soup and serve hot.
#     Your response:
# Write recipe instructions for the following recipe title and ingredient list.
#     Use the provided reasoning to inform your response.
#     Enclose your recipe instructions in <instructions> tags and number each step.
#     Recipe Title: Chocolate Puddles
#     Ingredients: ["1 cup butter, softened", "1 cup sugar", "1 cup packed brown sugar", "2 large eggs", "2 teaspoons vanilla extract", "3 cups all-purpose flour", "3/4 cup baking cocoa", "1 teaspoon baking soda", "1 cup white baking chips", "1/2 cup plus 2 tablespoons sweetened condensed milk", "3/4 cup finely chopped mixed nuts"]
#     Reasoning: First, we need to gather all necessary ingredients: 1 cup of softened butter, 1 cup of sugar, 1 cup of packed brown sugar, 2 large eggs, 2 teaspoons of vanilla extract, 3 cups of all-purpose flour, 3/4 cup of baking cocoa, 1 teaspoon of baking soda, 1 cup of white baking chips, 1/2 cup plus 2 tablespoons of sweetened condensed milk, and 3/4 cup of finely chopped mixed nuts.
# Next, we need to preheat our oven at 350 degrees Fahrenheit (175 degrees Celsius) and prepare a cookie sheet with parchment paper or a silicone baking mat.
# Then we can start on the recipe itself. We begin by creaming together the butter and both sugars until light and fluffy in a large mixing bowl. This should take about 5 minutes using an electric mixer.
# After that, we add the eggs one at a time, beating well after each addition. Next, we stir in the vanilla extract.
# In a separate bowl, whisk together the flour, baking cocoa, and baking soda. Gradually add this dry mixture to the wet mixture, mixing until just combined.
# Once the dough is prepared, we can use a spoon or cookie scoop to drop rounded tablespoons onto the prepared cookie sheet. We then bake these for 8 to 10 minutes, or until they're set around the edges but still slightly soft in the centers.
# While the cookies are baking, we can prepare the chocolate filling. In a small saucepan, combine the white baking chips and sweetened condensed milk over low heat. Stir constantly until smooth and fully melted, which should take about 5 minutes. Remove from heat and let cool slightly.
# When the cookies have cooled for a few minutes, we can make an indentation in the center of each cookie with a spoon or thumb. While the indentation is still warm, we can fill it with the chocolate filling and sprinkle with finely chopped mixed nuts if desired.
#     Your response:
# Write recipe instructions for the following recipe title and ingredient list.
#     Use the provided reasoning to inform your response.
#     Enclose your recipe instructions in <instructions> tags and number each step.
#     Recipe Title: American 25
#     Ingredients: ["1 ounce bonded apple brandy, preferably Lairds", "1/4 ounce smoky Scotch (Peat Monster and Laphroaig 10-year-old are good options)", "1/2 ounce fresh lemon juice", "1/2 ounce simple syrup (see note)", "3 to 4 ounces Champagne", "Lemon twist"]
#     Reasoning: <instruction>First, gather all of the ingredients listed above.</instruction>
# <instruction>Next, measure out the required amounts of apple brandy, scotch, lemon juice, and simple syrup into separate containers or small glasses.</instruction>
# <instruction>After measuring out the liquid ingredients, prepare the simple syrup if you haven't already made it. To make simple syrup, combine equal parts sugar and water in a saucepan over medium heat until the sugar is dissolved. Once cooled, pour into a container for use in the cocktail.</instruction>
# <instruction>While waiting for the simple syrup to cool, begin preparing the lemon twist garnish. Using a sharp knife, cut a thin strip of lemon peel, ensuring that there is no pith (the white, bitter part) included. Squeeze the lemon twist over a lit flame or a bar spoon to char the edges slightly, which will enhance the aroma and flavor.</instruction>
# <instruction>Once everything is prepared, fill a shaker with ice and add the measured amounts of apple brandy, scotch, lemon juice, and simple syrup. Shake vigorously for about 15 seconds to chill and dilute the mixture.</instruction>
# <instruction>Strain the chilled mixture into a flute or champagne glass filled with fresh ice, then top off with chilled Champagne. Garnish with the lemon twist by expressing the oils from the twist over the drink and placing it on the rim of the glass.</instruction>
# <dependency>Note: If you don't have a simple syrup available, you can make it by combining equal parts granulated sugar and water in a saucepan over medium heat. Stir until the sugar has completely dissolved, then let it cool before using.</dependency>
#     Your response:
# Write recipe instructions for the following recipe title and ingredient list.
#     Use the provided reasoning to inform your response.
#     Enclose your recipe instructions in <instructions> tags and number each step.
#     Recipe Title: Broccoli Casserole
#     Ingredients: ["2 boxes Chopped Broccoli", "1 can Cream Of Mushroom Soup", "1 cup Mayonnaise", "2 whole Eggs, Beaten", "1 whole Medium Onion, Chopped Finely", "1 cup Sharp Cheddar Cheese, Grated", "1/4 sticks Butter, Melted", "1/8 packages Pepperidge Farm Dressing"]
#     Reasoning: Your response:
# <reasoning>
# We start by preheating our oven to 350°F (175°C). While the oven is heating up, we can begin preparing the broccoli. We take two boxes of chopped broccoli and place them into a large mixing bowl. Next, we open a can of cream of mushroom soup and pour it over the chopped broccoli. The mayonnaise goes into the same mixing bowl along with the beaten eggs. Now, we add in the chopped onion and half of the grated cheddar cheese. Mix everything together until well combined.
# Next, we move onto preparing the dressing. We'll take one-eighth of the Pepperidge Farm dressing and mix it in with our broccoli mixture. Once that's done, we'll transfer the mixture into a greased baking dish. We'll spread the remaining grated cheddar cheese over the top, and then drizzle the melted butter evenly over the cheese. Finally, we'll place the casserole into the preheated oven and bake for about 35-40 minutes, or until the top is golden brown and the broccoli is cooked through. Once finished, we can remove the casserole from the oven, let it cool slightly, and then serve hot.<reasoning>
#     Your response:
# Write recipe instructions for the following recipe title and ingredient list.
#     Use the provided reasoning to inform your response.
#     Enclose your recipe instructions in <instructions> tags and number each step.
#     Recipe Title: Southern Style Oven "Fried" Chicken
#     Ingredients: ["Ingredients", "3 spray(s) Cooking spray", "1 pound(s) Chicken, breast, raw, without skin, without bone, four 4-oz pieces", "1/2 tsp Salt, table, divided, or to taste", "1/4 tsp Cayenne pepper, divided, or to taste", "1/3 cup(s) Flour, white", "3 oz Milk, buttermilk, low-fat (1%)", "1/2 cup(s) Corn flakes crumbs"]
#     Reasoning: First, preheat the oven to 400°F. The chicken needs to be cooked at this temperature to ensure it is fully cooked and safe to eat.
# Next, season the chicken with half of the salt and cayenne pepper. This allows the chicken to absorb the flavors while it rests.
# While the chicken is resting, crush the corn flakes until they resemble breadcrumbs. This can take a few minutes depending on the consistency desired.
# In a shallow dish, mix together the flour and remaining salt and cayenne pepper. This creates the coating for the chicken.
# Dip each piece of chicken into the buttermilk, then coat evenly with the flour mixture. This step ensures that the chicken is thoroughly coated and crispy when baked.
# Spray a baking sheet with cooking spray. This prevents the chicken from sticking to the pan during baking.
# Place the coated chicken pieces on the prepared baking sheet. Make sure they are not touching so they cook evenly.
# Bake the chicken for about 20-25 minutes, or until the internal temperature reaches 165°F as measured with a thermometer. This ensures that the chicken is fully cooked and safe to eat.
#     Your response:

# %% [markdown]
# ### Few-Shot Evaluation

# %%
three_shot = small_test.map(form_examples, fn_kwargs={"prompt_set": embed_dataset['retrieval'], "n_prompts": 3})
two_shot = small_test.map(form_examples, fn_kwargs={"prompt_set": embed_dataset['retrieval'], "n_prompts": 2})
one_shot = small_test.map(form_examples, fn_kwargs={"prompt_set": embed_dataset['retrieval'], "n_prompts": 1})
three_shot_ret = small_test.map(form_examples, fn_kwargs={"prompt_set": embed_dataset['retrieval'], "n_prompts": 3, "retrieved": True})
two_shot_ret = small_test.map(form_examples, fn_kwargs={"prompt_set": embed_dataset['retrieval'], "n_prompts": 2, "retrieved": True})
one_shot_ret = small_test.map(form_examples, fn_kwargs={"prompt_set": embed_dataset['retrieval'], "n_prompts": 1, "retrieved": True})
# Out:
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]

# %%
shots = {
    "one_shot": one_shot,
    "two_shot": two_shot,
    "three_shot": three_shot,
    "one_shot_ret": one_shot_ret,
    "two_shot_ret": two_shot_ret,
    "three_shot_ret": three_shot_ret
}

for name, shot in shots.items():
  generated_dataset_shot_instructions = shot.map(
    generate_instruction_batch,
    batched=True,
    batch_size=BATCH_SIZE,
    fn_kwargs={"cot_prompt": False, "model": model_ft, "tokenizer": tokenizer, "use_examples": True}
)
  generated_dataset_shot_instructions.save_to_disk(f'{recipe_nlg_data_path}/Generated_Data/ft_{name}')
# Out:
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# After the following examples, provide your response.
# Recipe Title: Strawberry Blueberry Crisp
# Ingredients: ["2 pounds Fresh Strawberries, Hulled And Sliced", "1 pint Fresh Blueberries", "3 Tablespoons Cornstarch", "White Sugar To Taste If The Berries Are Tart", "1 cup Brown Sugar", "3/4 cups Flour", "3/4 cups Rolled Oats, Quick Cooking", "1 teaspoon Cinnamon", "1/2 cups Butter"]
# Recipe Instructions:
# [1] "Preheat oven to 350 F. Put the berries into a large bowl. Toss berries with cornstarch and white sugar (if using) until well coated. Butter a 10\" glass pie plate and place the berries into the pie plate. Set aside.
# [2] In a medium sized bowl, mix together the brown sugar, flour, rolled oats and cinnamon. Cut in butter until crumbly. Press the mixture lightly over top of the berries.
# [3] Bake for 45-55 minutes with a rimmed baking sheet on the rack below your pie plate in case it bubbles over.
# [4] Serve warm with a dollop of whipped cream. Great any time of year but fabulous with fresh local sweet berries."
#
# Recipe Title: Delectable Dirt Dessert Recipe
# Ingredients: ["1 lg. pkg. Oreos", "1/2 cube butter", "8 ounce. pkg. cream cheese", "1 c. powdered sugar", "3 c. lowfat milk", "2 Packages vanilla pudding mix (instant)", "12 ounce. Cold Whip", "Bananas, approx. 6", "1 (8 inch) plastic flower pot", "Garden trowel (for serving)", "1 plastic flower (for planting in pot)", "1 pkg. gummy worms"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# After the following examples, provide your response.
# Recipe Title: Scampi Au Champagne
# Ingredients: ["2 tablespoons clarified butter", "16 large shrimp peeled deveined", "2 tablespoons finely chopped shallots", "1 1/2 cup dry champagne", "3/4 cup heavy cream", "1/2 teaspoon salt", "freshly ground pepper", "fresh chervil spigs"]
# Recipe Instructions:
# [1] "Heat butter in a large heavy skillet over high heat until sizzling. Add shrimp and shallot saute until shrimp turn pink 2 to 3 minutes. Add champagne heat to boiling with skillet still on heat, remove shrimp with slotted spoon to ovenproof plate , keep warm in oven at lowest setting.
# [2] Boil champagne uncovered until reduced by two thirds 6 to 7 minutess add cream boil uncovered until iquid is reduced by one third about 5 minutes. Remove from heat add salt and pepper to taste.
# [3] Arrange shrimp on warmed platter pour sauce over. Serve immediately garnished with sprigs of fresh chervil."
#
# Recipe Title: Portobello Fajitas
# Ingredients: ["2 tablespoons oil divided", "12 ounces portobello mushrooms cut into 1/2-inch strips", "1 onion medium, cut into thin strips", "1 bell pepper medium, cut into thin strips", "1/4 cup water", "1 package fajita seasoning mix McCormick(R) Organics", "8 tortillas 6-inch, warmed"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# After the following examples, provide your response.
# Recipe Title: White-Bean-And-Shrimp Salad With Tarragon Vinaigrette
# Ingredients: ["1 cup navy beans, soaked in water overnight and drained", "4 cups water", "2 sprigs fresh thyme", "1 bay leaf", "1 clove garlic, peeled and crushed", "1 pound shrimp, cooked and shelled", "1 cup slivered fennel", "1 teaspoon salt", "Freshly ground pepper to taste", "2 tablespoons chopped fresh chives, for garnish", "4 teaspoons Sherry vinegar", "4 teaspoons olive oil", "2 tablespoons chopped fresh tarragon", "1/4 teaspoon salt", "Freshly ground pepper to taste"]
# Recipe Instructions:
# [1] "To make the salad, place the beans, water, thyme, bay leaf and garlic in a medium saucepan and bring to a boil.
# [2] Reduce to a simmer, cover and cook until the beans are tender but not mushy, about 45 minutes.
# [3] Drain and remove thyme, bay leaf and garlic.
# [4] Place in a large bowl and set aside until cool.
# [5] Toss in the shrimp, fennel, salt and pepper.
# [6] To make the vinaigrette, whisk together all ingredients.
# [7] Toss with the salad.
# [8] Divide among 4 plates, garnish with the chives and serve."
#
# Recipe Title: Penn Dutch Chicken Pot Pie Recipe
# Ingredients: ["1 chicken or possibly assorted pcs", "3 carrots, sliced", "1 onion, minced", "1 c. peas", "Salt and pepper"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# After the following examples, provide your response.
# Recipe Title: Garlic Roasted Broccoli With Parmesan Cheese
# Ingredients: ["1 head broccoli, washed and cut into bite-sized pieces", "2 cloves garlic, minced", "4 tablespoons extra virgin olive oil, divided", "1/2 teaspoon kosher salt", "1/2 teaspoon coarse ground black pepper", "1 tablespoon lemon juice", "1/4 cup Dietz & Watson Shaved Parmesan Cheese"]
# Recipe Instructions:
# [1] "Preheat your oven to 425 degrees F.
# [2] Wash the broccoli and cut it into bite-sized pieces. Place the broccoli on a large rimmed baking sheet.
# [3] Mince the garlic and toss it in with the broccoli.
# [4] Drizzle 3 tablespoons extra virgin olive oil over the broccoli, then season with coarse black pepper and kosher salt.
# [5] Bake in the oven for 20-25 minutes until the broccoli is tender.
# [6] Toss in lemon juice, parmesan cheese, and 1 tablespoon olive oil; serve immediately."
#
# Recipe Title: New England Clam Chowder III
# Ingredients: ["1/2 cup butter", "1 cup all-purpose flour", "8 onions, chopped", "2 bunches celery, chopped", "1 gallon milk", "18 (16 ounce) cans minced clams, drained with juice reserved", "4 quarts chicken broth", "2 quarts heavy cream", "2 tablespoons chopped fresh thyme", "salt and pepper to taste"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# After the following examples, provide your response.
# Recipe Title: French Riviera
# Ingredients: ["Ice", "2 1/2 ounces vodka", "1/2 ounce Cointreau or other triple sec", "1/4 ounce Pastis", "1/2 ounce fresh lemon juice", "1 maraschino cherry"]
# Recipe Instructions:
# [1] "Fill a cocktail shaker with ice.
# [2] Add the vodka, Cointreau, pastis and lemon juice and shake well.
# [3] Strain into a chilled martini glass and garnish with the maraschino cherry."
#
# Recipe Title: Seasoned Oven Fries
# Ingredients: ["2 medium baking potatoes", "2 teaspoons butter, melted", "2 teaspoons canola oil", "1/4 teaspoon seasoned salt", "Minced fresh parsley, optional"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# After the following examples, provide your response.
# Recipe Title: Brocolli Salad With Bacon & Craisons
# Ingredients: ["4 heads of Broccoli", "1/2 red onion", "1/2 lb. bacon", "1 cup cashews", "1 cup craisons", "1 cup mayo", "1/4 cup white sugar", "2 tbsp white wine vinegar"]
# Recipe Instructions:
# [1] "1. Cook bacon in skillet on medium heat until brown. Cool & crumble
# [2]
# [3] 2. Cut brocolli into bite size pieces, cut onion into bite size slices. Combine with bacon, craisons, cashews & mix.
# [4]
# [5] 3. Dressing - mix mayo, sugar, vinegar together until smooth. Add to salad, chill & serve"
#
# Recipe Title: 5-Minute Green Bean and Tuna Salad
# Ingredients: ["2 cups frozen whole green beans", "1 cup frozen corn", "2 cans (5 oz. each) white tuna in water, drained, flaked", "1 cup grape tomatoes", "1/4 cup KRAFT Zesty Italian Dressing", "1/2 cup KRAFT Grated Parmesan Cheese"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# After the following examples, provide your response.
# Recipe Title: Bulgur Turkey Manicotti
# Ingredients: ["1/4 cup bulgur", "2/3 cup boiling water", "3/4 pound lean ground turkey", "1 teaspoon dried basil", "1 teaspoon dried oregano", "1/4 teaspoon pepper", "1-1/2 cups 2% cottage cheese", "1 jar (24 ounces) meatless pasta sauce", "1 can (8 ounces) no-salt-added tomato sauce", "1/2 cup water", "1 package (8 ounces) manicotti shells", "1 cup shredded part-skim mozzarella cheese"]
# Recipe Instructions:
# [1] "Combine bulgur and boiling water; let stand, covered, until liquid is absorbed, about 30 minutes. Drain; squeeze dry.
# [2] Preheat oven to 350\u00b0. In a
# [3] , cook and crumble turkey over medium-high heat until no longer pink, 5-7 minutes. Stir in seasonings, cottage cheese and bulgur.
# [4] Mix pasta sauce, tomato sauce and 1/2 cup water. Spread 1 cup sauce mixture into a 13x9-in. baking dish coated with cooking spray. Fill uncooked manicotti shells with turkey mixture; place in prepared dish. Top with remaining sauce mixture.
# [5] Bake, covered, until bubbly and shells are tender, 70-75 minutes. Uncover; sprinkle with mozzarella cheese. Bake until cheese is melted, about 5 minutes."
#
# Recipe Title: Chicken Curry
# Ingredients: ["1/2 kg Chicken", "1 Red Onion or 8 small onions", "2 Tomatoes", "2 tsp Jeera", "2 tsp Cinnamon", "2 tbsp ginger-garlic", "1 tsp poppy seeds", "2 tbsp cashews", "5 slices cocunut"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# After the following examples, provide your response.
# Recipe Title: Romaine-Fennel Salad With Pear Dressing
# Ingredients: ["2/3-cup pear nectar", "3 T. seasoned rice vinegar", "1 T. olive oil", "1/2 t. freshly ground black pepper", "1 fennel bulb", "4 cups chopped romaine lettuce leaves", "2 small ripe Anjou Pears, cored and thinly sliced", "1/2 of a small red onion, thinly sliced and separated into rings", "1/4 cup broken pecans, toasted", "1 oz. Parmesan cheese"]
# Recipe Instructions:
# [1] "In a small bowl, whisk together pear nectar, vinegar, oil and black pepper. Set aside.
# [2] Cut off and discard upper stalks of fennel, reserving some feathery frowns for garish. Remove any outer layer that may be wilted. Cut a thin slice off of the fennel base. Cut the fennel in half lengthwise. Then cut crosswise into thin slices.
# [3] In a medium bowl, toss together sliced fennel and romaine leaves. Pour half of the dressing over greens and fennel and toss to coat.
# [4] Arrange salad on plates and top with pears, onion and pecans.
# [5] Use a vegetable peeler to thinly shave Parmesan cheese and top each salad with shaved cheese. Garnish with fennel fronds.
# [6] Drizzle with the remaining dressing."
#
# Recipe Title: Chicken Udon Stir Fry
# Ingredients: ["1 lb thin sliced chicken breast", "1 lb Stir fry vegetables including snow peas", "1/4 cup soy sauce", "1/4 cup sriracha sauce", "1 bunch green onions sliced", "1 each green and red peppers", "2 clove Garlic minced", "1/4 cup hoisen sauce", "2 tbsp ground ginger", "2 tbsp olive oil", "4 tbsp sesame oil", "1 packages Udon noodles", "1 Salt and pepper to taste"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# After the following examples, provide your response.
# Recipe Title: Taco Soup Recipe
# Ingredients: ["1 pound grnd beef", "1 lg. onion, minced", "2 (14 1/2 ounce.) cans whole tomatoes with liquid", "8 ounce. can tomato sauce", "6 ounce. can tomato paste", "2 (16 ounce.) cans pinto beans (liquid removed, you can also use pintos with jalapenos)", "4 ounce. can minced green chilies", "1 1/2 - 2 teaspoon grnd cumin", "1 teaspoon salt", "Grnd pepper to taste", "3 c. water"]
# Recipe Instructions:
# [1] "Brown grnd beef, and drain grease if necessary.
# [2] Combine beef with remaining ingredients and cook in an electric slow cooker at a simmer for 4 hrs on high.
# [3] to serve, add in any desired topping or possibly combination.
# [4] This freezes like a dream!
# [5] Note: If you want to zip up the spicing, use the jalapeno pintos and add in 1 garlic clove (pressed), 2 tsp.
# [6] warm green jalapeno salsa and 2 tsp.
# [7] of cumin instead of the 1 1/2 tsp.
# [8] in ingredient list above.
# [9] This soup can also be cooked conventionally instead of in a slow cooker.
# [10] If so, simmer for only 1 to 2 hrs to desired thickness."
#
# Recipe Title: Rosemary Leg Of Lamb
# Ingredients: ["4 garlic cloves, minced", "1 to 2 tablespoons minced fresh rosemary or 1 teaspoon dried rosemary, crushed", "1 teaspoon salt", "1/2 teaspoon pepper", "1 bone-in leg of lamb (7 to 9 pounds), trimmed", "1 teaspoon cornstarch", "1/4 cup beef broth"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# After the following examples, provide your response.
# Recipe Title: Madeleine for Those with Egg Allergies
# Ingredients: ["200 grams Pancake mix", "150 ml Milk", "1 tbsp Honey", "1/2 Lemon", "1 tbsp Butter"]
# Recipe Instructions:
# [1] "Melt the butter.
# [2] Preheat the oven.
# [3] Grate lemon zest and add only the yellow zest.
# [4] Squeeze the juice and add.
# [5] Combine all of the ingredients.
# [6] Pour into a mold, bake for 15 minutes at 355F/180C.
# [7] Adjust to suit your oven."
#
# Recipe Title: How To Make Pickled Red Onions
# Ingredients: ["1 large red onion, thinly sliced into half-moons", "2 cups apple cider vinegar", "1 bay leaf", "1 teaspoon pickling spice", "1/4 teaspoon crushed red pepper flakes (optional)"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# After the following examples, provide your response.
# Recipe Title: Parmesan & Garlic Fries
# Ingredients: ["5 cups frozen French-fried potatoes", "2 tablespoons olive oil", "3 to 4 garlic cloves, minced", "1/4 teaspoon salt", "1/4 cup grated Parmesan cheese"]
# Recipe Instructions:
# [1] "Preheat oven to 450\u00b0. Place potatoes in a large bowl. Mix oil, garlic and salt; toss with potatoes. Arrange in a single layer on a large
# [2] .
# [3] Bake 15-20 minutes or until golden brown, stirring once. Sprinkle with cheese; toss lightly. Serve immediately."
#
# Recipe Title: Cheese Soup
# Ingredients: ["4 tablespoons butter or margarine", "10 ounces soup, cream of chicken", "10 ounces soup, cream of celery", "1/2 can mayonnaise", "1 jar sharp cheddar cheese spread", "1 can chicken broth"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# After the following examples, provide your response.
# Recipe Title: White Chocolate Creme Brulee
# Ingredients: ["3 large egg yolks", "6 tablespoons sugar, divided", "1 cup heavy whipping cream", "2 ounces white baking chocolate, finely chopped", "1/4 teaspoon vanilla extract"]
# Recipe Instructions:
# [1] "In a small bowl, whisk egg yolks and 2 tablespoons sugar; set aside. In a small saucepan, combine the cream, chocolate and 2 tablespoons sugar. Heat over medium-low heat until chocolate is melted and mixture is smooth, stirring constantly.
# [2] Remove from the heat. Stir in vanilla. Stir a small amount of hot filling into egg yolk mixture; return all to the pan, stirring constantly.
# [3] Pour into two 10-oz. ramekins. Place in a baking pan. Add 1 in. of boiling water to pan. Bake, uncovered, at 325\u00b0 for 50-55 minutes or until center is set. Remove from water bath. Cool for 10 minutes. Refrigerate for at least 4 hours.
# [4] If using a creme brulee torch, sprinkle with remaining sugar. Heat sugar with the torch until caramelized. Serve immediately.
# [5] If broiling the custards, place ramekins on a
# [6] ; let stand at room temperature for 15 minutes. Sprinkle with remaining sugar. Broil 8 in. from the heat for 4-7 minutes or until sugar is caramelized. Refrigerate for 1-2 hours or until firm."
#
# Recipe Title: Crispy Baked Chickpeas
# Ingredients: ["1 can chickpeas", "kosher salt", "pepper", "olive oil", "sesame seeds for garnish"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# After the following examples, provide your response.
# Recipe Title: Peppermint & Mocha Coffee
# Ingredients: ["6 cups freshly brewed Nabob Tradition Coffee", "1-1/2 cups milk", "4 oz. Baker's Semi-Sweet Chocolate", "1 tsp. peppermint extract", "8 peppermint sticks"]
# Recipe Instructions:
# [1] "Cook coffee, milk and chocolate in large saucepan on low heat 5 to 7 min.
# [2] or until chocolate is melted and mixture is heated through, stirring occasionally.
# [3] Stir in extract.
# [4] Pour into mugs.
# [5] Add peppermint stick to each."
#
# Recipe Title: Mom's Apple Cobbler with Buttermilk Biscuit Topping Recipe
# Ingredients: ["4 tablespoons unsalted butter, plus more for buttering the baking dish", "6 large tart apples (such as Granny Smith, Pippin, or Northern Spy), peeled, cored, and cut into 1/2-inch chunks", "1/2 cup sugar", "1/2 cup fresh apple cider or unfiltered apple juice", "Grated zest and juice of 1 lemon", "1 teaspoon ground cinnamon", "1/2 teaspoon freshly grated or ground nutmeg", "Moms Buttermilk Biscuit Topping"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# After the following examples, provide your response.
# Recipe Title: Flake Yeast Salad Dressing
# Ingredients: ["2 T vinegar", "1/4 c soy sauce", "one clove garlic", "1/2 cup flake yeast", "pinch of dry mustard", "fresh ginger root"]
# Recipe Instructions:
# [1] "Add all ingredients to blender
# [2]
# [3] start blender and after a few seconds add very slowly:
# [4] 3/4 c oil until mix is thick
# [5] 1/8 c water until mix is thin
# [6] a little more oil until mix is thick enough"
#
# Recipe Title: Beet Tart
# Ingredients: ["1 1/2 cups flour", "1/2 tsp salt", "7 tbsp cold butter, chopped", "1 tbsp lemon juice", "4 oz spreadable cream cheese", "1 can (15 oz) baby beets, drained and cut into wedges", "1/4 cup arugula leaves", "1/4 cup chopped walnuts, toasted", "2 tbsp parsley leaves", "1 None lemon, peel finely grated", "2 tsp olive oil"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# After the following examples, provide your response.
# Recipe Title: Lots of Mushrooms! Just Microwave!
# Ingredients: ["1 pack, about 100 grams Enoki mushrooms", "50 grams Maitake (oyster) mushrooms", "2 tsp Ponzu", "2 tsp Soy sauce", "3 grams Bonito flakes", "1 Green onions, thinly sliced"]
# Recipe Instructions:
# [1] "Spread the enoki mushrooms out on the bottom of a deep heatproof dish.
# [2] Spread the maitake mushrooms on top, to cover the enoki mushrooms.
# [3] Cover with plastic wrap and microwave for about 3 minutes.
# [4] Take off the plastic wrap carefully so you don't burn yourself.
# [5] It looks like this.
# [6] Add the ponzu and soy sauce while the mushrooms are still piping hot.
# [7] Top with bonito flakes and green onion and serve.
# [8] Mix well before eating."
#
# Recipe Title: Kickapoo Cookies (No  Flour)
# Ingredients: ["3/4 cups Margarine", "1 cup Crunchy Peanut Butter", "1 cup White Sugar", "1 cup Brown Sugar", "2 whole Eggs", "1-1/2 teaspoon Vanilla", "1-3/4 teaspoon Baking Soda", "1/4 teaspoons Salt", "4 cups Rolled Oats", "2 cups Semis-sweet Chocolate Chips", "1 cup Sunflower Seeds"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# After the following examples, provide your response.
# Recipe Title: Roasted Balsamic Asparagus Bundles
# Ingredients: ["1 bunch Asparagus", "4 slices Bacon", "Olive Oil", "Balsamic Vinegar", "Freshly Ground Black Pepper", "Coarse Sea Salt"]
# Recipe Instructions:
# [1] "Preheat the oven to 425\u00b0F. Line a baking sheet with aluminum foil and spray with nonstick spray. Trim the tough ends from the asparagus, wash and pat dry.
# [2] Slice the bacon lengthwise into thirds. Working at an angle, wrap 4 or 5 asparagus spears around the middle with a strip of bacon and arrange them in a single layer on the baking sheet.
# [3] Moderately drizzle olive oil and balsamic over the entire sheet. Grind some pepper over the top, and sprinkle desired amount of salt. Roast for 5 minutes before checking. Give the pan a good shake to distribute the oils at this point. Roast for another 5-10 minutes, or until cooked to your preference.
# [4] Transfer to a plate and serve!"
#
# Recipe Title: White Chocolate, Peanut Butter and Jelly Pizza
# Ingredients: ["1/2 cup butter, softened", "1/2 cup crunchy peanut butter", "1/2 cup packed brown sugar", "1/3 cup granulated sugar", "1 egg", "1 tsp. vanilla", "1 cup flour", "1 cup BAKER'S Premium White Chocolate Morsels", "3/4 cup JET-PUFFED Miniature Marshmallows", "1/2 cup PLANTERS Dry Roasted Peanuts", "1/2 cup strawberry jelly"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# After the following examples, provide your response.
# Recipe Title: Easy Stir-Fried Chicken Thighs with Ginger
# Ingredients: ["400 grams Chicken thighs", "1 Onion", "1 Salt", "1 Pepper", "1 1/2 tbsp Katakuriko", "2 1/2 tbsp Soy sauce", "1 tbsp Vinegar", "2 tbsp Sugar", "1 tbsp Mirin", "2 tbsp Sake", "2 tsp Ginger (grated)", "1 Vegetable oil"]
# Recipe Instructions:
# [1] "Slice the chicken into bite-sized pieces.
# [2] Season with salt and pepper, and transfer to a plastic bag.
# [3] Add the katakuriko, and rub in.
# [4] Cut the onion in half lengthwise, and thinly cut crosswise against the fibers.
# [5] Thinly grease a frying pan with oil, and stir-fry the chicken and onion.
# [6] When the chicken starts to brown, cover with a lid, and steam-fry for 5 minutes over low heat.
# [7] Remove the lid, and wipe off the excess oil from the chicken with paper towels.
# [8] Swirl in the seasoning mixture, and continue stir-frying until the sauce thickens while shaking the pan."
#
# Recipe Title: Broiled Bluefish Fillets with Fennel Mayonnaise
# Ingredients: ["two 8-ounce skinless bluefish or mackerel fillets", "1 teaspoon fennel seeds", "1 large garlic clove", "1/2 teaspoon salt", "2 tablespoons mayonnaise", "1/2 tablespoon fresh lemon juice"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# After the following examples, provide your response.
# Recipe Title: Italian Style Brunch Cakes
# Ingredients: ["2 cups biscuit baking mix", "2/3 cup shredded Monterey Jack cheese", "2 teaspoons Italian-style seasoning", "1/2 cup diced red bell pepper", "1/4 cup sliced pepperoni sausage", "1/4 cup diced green onion", "1/2 cup diced tomatoes", "1/4 cup diced green bell pepper", "1/4 cup pizza sauce", "1/2 cup milk", "1/2 cup nonfat sour cream", "2 eggs, beaten"]
# Recipe Instructions:
# [1] "In a large bowl, combine baking mix, cheese, Italian-style seasoning, red bell pepper, pepperoni, green onion, tomatoes and green bell pepper.
# [2] In a separate bowl, stir together pizza sauce, milk, sour cream and eggs. Stir egg mixture into flour/vegetable mixture until all flour is moistened.
# [3] Heat a lightly oiled griddle or frying pan over medium high heat. Spoon the batter onto the griddle, using approximately 1 tablespoon for each pancake. Brown on both sides and serve hot."
#
# Recipe Title: Jeff'S Slow Cook Chicken W Roots
# Ingredients: ["1 free range chicken", "olive oil", "fresh thyme", "fresh rosemary", "4 large whole cloves garlic, peeled", "1 sweet onion", "4-6 carrots,", "12-16 fingerling potatoes", "1 turnip", "1 lemon", "Rub:", "2 tsp salt", "2 tsp paprika", "1 tsp cayenne pepper", "1/2 tsp black pepper"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# After the following examples, provide your response.
# Recipe Title: White Tea Island Mango & Peach Sangria
# Ingredients: ["2 cups water", "6 lipton white tea with island mango & peach flavors pyramid tea bag", "1/4 cup sugar", "2 cups pineapple juice", "1 cup mango sliced", "1 cup raspberries", "1 cup peaches sliced", "1 cup dry white wine", "1/4 cup orange liqueur"]
# Recipe Instructions:
# [1] "Pour boiling water over Lipton(R) White Tea with Island Mango & Peach Flavors Pyramid Tea Bags; cover and brew 5 minutes. Remove Tea Bags and squeeze, then stir in sugar; chill.
# [2]
# [3] In large pitcher, combine tea with remaining ingredients. Chill 2 hours."
#
# Recipe Title: Domino Potatoes With Sour Cream And Chives
# Ingredients: ["4 idaho potatoes large, peeled", "4 ounces clarified butter", "sea salt", "4 bay leaves", "1/2 cup sour cream", "1 tablespoon chives chopped"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# After the following examples, provide your response.
# Recipe Title: Snapper with Browned Butter and Capers
# Ingredients: ["2 tablespoons unsalted butter", "1 shallot, minced", "2 teaspoons fresh lemon juice", "2 tablespoons minced fresh parsley leaves", "1 tablespoon drained bottled capers, minced", "2 teaspoons finely chopped lemon pulp", "1 teaspoon freshly grated lemon zest", "two 1/2-pound red snapper fillets", "lemon slices for garnish"]
# Recipe Instructions:
# [1] "Preheat oven to 350F.
# [2] In a small skillet cook butter over moderate heat until it begins to brown and stir in shallot.
# [3] Cook shallot until softened but not browned, about 2 minutes.
# [4] Remove skillet from heat and stir in lemon juice.
# [5] In a small bowl stir together parsley, capers, lemon pulp, and zest.
# [6] Put fish fillets in a jelly-roll pan, skin sides down, and sprinkle with salt and pepper to taste.
# [7] Brush fillets with butter mixture and sprinkle with parsley mixture.
# [8] Bake fillets in middle of oven until just cooked through, about 12 minutes, and garnish with lemon slices."
#
# Recipe Title: PHILADELPHIA New York Cheesecake
# Ingredients: ["1 cup HONEY MAID Graham Cracker Crumbs", "3 Tbsp. sugar", "2 Tbsp. butter or margarine, melted", "5 pkg. (8 oz each) PHILADELPHIA Cream Cheese, softened", "1 cup sugar", "3 Tbsp. flour", "1 Tbsp. vanilla", "3 eggs", "1 cup BREAKSTONE'S or KNUDSEN Sour Cream"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# After the following examples, provide your response.
# Recipe Title: General Tso'S Chicken & Sweet Potato Hash
# Ingredients: ["1 box Crazy Cuizine General Tso's Chicken", "2 pounds Sweet Potatoes, diced", "1 cup Onion, diced", "1/2 cup Red Bell Pepper, diced", "4 cloves Garlic, minced", "2 tablespoons Olive Oil", "1 teaspoon Chinese Five Spice", "1/2 teaspoon Salt", "1/4 cup Green Onions, sliced"]
# Recipe Instructions:
# [1] "Preheat oven to 400 degrees.
# [2] Remove the sauce packet from the box of Crazy Cuizine General Tso's Chicken. Place under warm running water to thaw, then set aside.
# [3] Remove the bag of chicken, place on a baking sheet and toss with the sweet potatoes, onion, jalapeno, red bell pepper, garlic, olive oil, Chinese five spice and salt.
# [4] Place in the oven for 15-18 minutes.
# [5] Heat contents of sauce packet in a small saucepan over medium-low heat for 2 minutes, or until warm.
# [6] Pour the sauce over the chicken and sweet potato hash and toss to coat. Let stand for 2-3 minutes before serving. Top with green onions and serve."
#
# Recipe Title: Roasted Garlic
# Ingredients: ["garlic", "olive oil", "thyme or basil", "salt", "pepper"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# After the following examples, provide your response.
# Recipe Title: Bacon And Dried Tomato Scones
# Ingredients: ["3/4 cup dried tomatoes (not oil-packed)", "2-1/2 cups all-purpose flour", "1 Tbsp. baking powder", "1 tsp. dried basil, crushed", "1 tsp. dried oregano, crushed", "1/4 tsp. garlic salt", "3/4 cup butter, cut up", "8 slices bacon, crisp-cooked, drained, and crumbled", "1/4 cup sour cream", "2 eggs, lightly beaten", "2 Tbsp. milk", "1/2 cup shredded mozzarella cheese", "Crisp-cooked bacon, crumbled (optional)"]
# Recipe Instructions:
# [1] "Bake: 12 minutes
# [2] 1. Preheat oven to 400 degrees F. Place tomatoes in a bowl. Add enough boiling water to cover. Let stand 5 minutes. Drain well; chop tomatoes.
# [3]
# [4] 2. In large bowl combine flour, baking powder, basil, oregano, and garlic salt. Cut in butter until mixture resembles coarse crumbs. Stir in chopped tomatoes and bacon. Make a well in center of flour mixture; set aside. In small bowl combine sour cream, eggs, and milk; add all at once to flour mixture. Stir with a fork just until moistened. Turn dough out onto a lightly floured surface. Knead dough gently 10 to 12 strokes or until dough holds together. Divide in half. Pat or lightly roll each dough half to a 7-inch circle. Cut each circle in 8 wedges.
# [5]
# [6] 3. Place wedges 2 inches apart on a very large ungreased baking sheet. Bake for 5 minutes. Sprinkle tops of scones with cheese. Bake 7 to 8 minutes more or until tops are lightly browned. Serve warm. Top with additional crumbled bacon."
#
# Recipe Title: Asparagus With Salsa Verde and Scarlet Onions
# Ingredients: ["1 small red onion, sliced into thin rounds", "A few tablespoons white wine vinegar or champagne vinegar, more to taste", "Sea salt", "1 1/2 pounds asparagus", "1/4 cup chopped parsley", "2 tablespoons chopped tarragon", "1 tablespoon capers, rinsed", "1 wide band orange zest, finely slivered and blanched for 10 seconds", "4 to 5 tablespoons olive oil", "1/2 teaspoon Dijon mustard", "1 tablespoon orange juice", "Black pepper"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# After the following examples, provide your response.
# Recipe Title: Dee's Sausage Pasta Supper Recipe
# Ingredients: ["1/4 c. minced onion", "1/4 c. green pepper", "1/2 pound mushrooms (optional)", "2 c. broccoli", "1/4 teaspoon garlic pwdr", "1 teaspoon oregano", "1 pound sausage", "3 tbsp. butter", "1/2 c. Parmesan cheese"]
# Recipe Instructions:
# [1] "Stir fry the onion, green pepper, mushrooms and broccoli in 3 Tbsp.
# [2] butter till crisp-tender.
# [3] Add in the sausage cut into bite size pcs.
# [4] Heat through.
# [5] Stir in the Parmesan cheese.
# [6] Serve over buttered noodles."
#
# Recipe Title: Spaghetti Squash Saute
# Ingredients: ["cooking spray", "1 spaghetti squash, halved and seeded", "1/4 cup butter or margarine", "1 small onion, chopped", "2 cloves garlic, finely chopped", "salt and pepper to taste"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# After the following examples, provide your response.
# Recipe Title: BBQ Chicken
# Ingredients: ["1/4 cups White Vinegar", "3 Tablespoons Ketchup", "2 Tablespoons Brown Sugar", "1 Tablespoon Worcestershire Sauce", "1 Tablespoon Oil", "2 teaspoons Chili Powder", "1/2 teaspoons Dry Mustard", "1/2 teaspoons Salt", "1/4 teaspoons Cayenne Pepper", "2 pounds Chicken Breasts"]
# Recipe Instructions:
# [1] "Mix all ingredients together except chicken.
# [2] If grilling, pour half the mixture over the chicken to marinade up to 12 hours.
# [3] Use remaining mixture to baste chicken during grilling.
# [4] If cooking in the oven, pour sauce over chicken pieces in a covered baking dish.
# [5] Cook at 375 degrees for 50-60 minutes until chicken is firm and juices run clear."
#
# Recipe Title: Tinklee's Lemon Herb Chicken
# Ingredients: ["6 chicken breast", "1/4 cup lemon juice", "2 tbsp dijon mustard", "2 tbsp olive oil", "3 clove garlic -minced", "1 tsp oregano", "1/4 tsp black pepper"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# After the following examples, provide your response.
# Recipe Title: Biscochitos (Mexican Wedding Cookies) Recipe
# Ingredients: ["6 c. flour", "3 teaspoon baking pwdr", "1 teaspoon salt", "3 teaspoon anise", "2 c. lard", "2 Large eggs", "1 1/2 c. sugar", "6 to 7 tbsp. water"]
# Recipe Instructions:
# [1] "Combine all ingredients in a large mixing bowl and mix well.
# [2] Roll dough out on a floured surface and cut into circles with a round cookie cutter.
# [3] Place on an ungreased cookie sheet and bake at 400 degrees for 10 min.
# [4] While still hot, sprinkle with sugar and cinnamon.
# [5] Yields: 4 dozen."
#
# Recipe Title: Lamb Won Tons
# Ingredients: ["3/4 pound ground lamb", "2 1/2 teaspoons ground coriander", "3/4 teaspoon ground cinnamon", "2 1/4 teaspoons kosher salt", "3/4 teaspoon freshly ground black pepper", "3 tablespoons golden raisins", "3 tablespoons coarsely chopped pistachios", "34 won ton skins, 3 inches by 31/4 inches", "Vegetable oil for deep-frying"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# After the following examples, provide your response.
# Recipe Title: Homemade Noodles Recipe
# Ingredients: ["1 c. flour", "1 egg", "1/2 teaspoon salt", "1/4 teaspoon butter", "1/4 teaspoon baking pwdr", "2 1/2 tbsp. lowfat milk"]
# Recipe Instructions:
# [1] "In a bowl, place flour and make a well.
# [2] Drop remaining ingredients into well.
# [3] Mix with fork, then fingers till it form a very still dough.
# [4] Roll out on floured board till very thin.
# [5] Let stand till dry (2 hrs).
# [6] Cut as you desire.
# [7] Drop into chicken or possibly beef broth and cook 10 to 12 min."
#
# Recipe Title: Pistachio Pudding Cookies
# Ingredients: ["1/2 cups Butter, Softenend", "1/2 cups Sugar", "1/4 cups Vegetable Oil", "1/4 cups Water", "1 whole Egg", "2 packages Pistachio Flavored Pudding Mix (3.4oz Size)", "1 teaspoon Vanilla", "1/2 teaspoons Salt", "1 teaspoon Baking Powder", "2 cups Flour", "1/2 cups Chopped Pistachios", "1 cup White Chocolate Chips"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# After the following examples, provide your response.
# Recipe Title: Vegemite Ham and Salad Pita Pockets
# Ingredients: ["1 small white or wholemea pita bread, halved", "1 teaspoon VEGEMITE", "20g PHILADELPHIA Light Spreadable Cream Cheese", "30g sliced ham", "lettuce leaves", "sliced tomato", "sliced cucumber"]
# Recipe Instructions:
# [1] "OPEN out the pita bread carefully and spread inside each half with the Vegemite and Philly.
# [2] Top the Philly with the ham, lettuce, tomato and cucumber.
# [3] Wrap each half in plastic to retain freshness."
#
# Recipe Title: Danish Braid
# Ingredients: ["1/2 batch Danish pastry", "1 cup almond frangipane, recipe follows", "1 egg white", "Sliced almonds", "Water icing, recipe follows"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# After the following examples, provide your response.
# Recipe Title: Tuxedo Cake
# Ingredients: ["1 pkg. (2-layer size) devil's food cake mix", "1 pkg. (4-serving size) Jell-O Chocolate Instant Pudding", "1-1/2 pkg. (250 g each) Philadelphia Brick Cream Cheese, softened", "1/2 cup butter, softened", "1-1/2 tsp. vanilla", "6 cups icing sugar", "2 cups Cool Whip Whipped Topping (Do not thaw.)", "4 oz. Baker's Premium 70% Cacao Dark Chocolate"]
# Recipe Instructions:
# [1] "Heat oven to 350 degrees F.
# [2] Prepare cake batter and bake as directed on package for 2 (9-inch) round cake layers, blending dry pudding mix into batter before pouring into prepared pans.
# [3] Cool 10 min.
# [4] Loosen cakes from sides of pan with knife.
# [5] Invert onto wire racks; gently remove pans.
# [6] Cool cakes completely.
# [7] Meanwhile, beat cream cheese, butter and vanilla in large bowl with mixer until blended.
# [8] Gradually beat in sugar.
# [9] Cut each cake layer horizontally in half.
# [10] Stack on plate, spreading 3/4 cup cream cheese frosting between each layer.
# [11] Spread remaining frosting onto top and side of cake.
# [12] Microwave Cool Whip and chocolate in microwaveable bowl on HIGH 1-1/2 min., stirring after 1 min.
# [13] ; stir until chocolate is completely melted and mixture is well blended.
# [14] Cool 5 min.
# [15] Pour over cake, letting excess drip down side."
#
# Recipe Title: Roast Venison
# Ingredients: ["1 venison roast any cut", "1 teaspoon worchestershire sauce", "2 garlic cloves crushed", "1 onion small", "1 teaspoon parsley", "1 teaspoon celery powder", "1 Orange or grapefruit", "lemon fresh-squeezed is preferred"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# After the following examples, provide your response.
# Recipe Title: Grilled Brown Sugar Pork Chops
# Ingredients: ["1/2 cup brown sugar, firmly packed", "1/2 cup apple juice", "4 tablespoons vegetable oil", "1 tablespoon soy sauce", "1/2 teaspoon ground ginger", "salt and pepper to taste", "2 teaspoons cornstarch", "1/2 cup water", "6 boneless pork chops"]
# Recipe Instructions:
# [1] "Preheat an outdoor grill for high heat.
# [2] In a small saucepan, combine brown sugar, apple juice, oil, soy sauce, ginger, salt , and pepper. Bring to boil. Combine water and cornstarch in small bowl, and whisk into brown sugar mixture. Stir until thick.
# [3] Brush grate lightly with oil before placing pork chops on the grill. Cook over hot coals for 10 to 12 minutes, turning once. Brush with sauce just before removing chops from grill. Serve with remaining sauce."
#
# Recipe Title: Baked Cannelloni
# Ingredients: ["1 cup whole wheat flour", "2 teaspoons vegetable oil", "salt to taste", "2 cups vegetables Mixed boiled, finely chopped", "50 grams paneer", "1 onion medium, chopped", "1 teaspoon chili powder", "2 teaspoons vegetable oil", "salt to taste", "1 cup gravy Tomato", "2 tablespoons paneer grated"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# After the following examples, provide your response.
# Recipe Title: Cabbage with Ginger and Cumin
# Ingredients: ["1 tbsp. olive oil", "1 medium onion", "1 small head green cabbage", "2 tsp. grated peeled fresh ginger", "1/4 tsp. ground cumin", "1/2 tsp. salt"]
# Recipe Instructions:
# [1] "In 12-inch nonstick skillet, heat oil on medium 1 minute.
# [2] Add onion and cook 8 to 10 minutes or until tender and golden, stirring occasionally.
# [3] Add cabbage, ginger, cumin, and salt, and cook 11 to 14 minutes or until cabbage is tender-crisp, stirring occasionally.Nutritional information is based on a 1-cup serving."
#
# Recipe Title: Beverly'S Chicken
# Ingredients: ["1/2 cup bread crumbs", "1/2 cup Parmesan cheese", "2 eggs", "1 can french fried onions, crushed", "1 t paprika", "salt and pepper", "2 T milk", "1/3 stick butter, melted", "1 package chicken tenderloins"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# After the following examples, provide your response.
# Recipe Title: Laab Nuea (Ground Beef Salad)
# Ingredients: ["1 pound ground beef", "1/4 cup lime juice", "2 tablespoons fish sauce", "6 each shallots sliced", "2 tablespoons scallions, spring or green onions chopped", "2 tablespoons cilantro chopped", "2 tablespoons rice roasted, sticky", "15 each mint leaves"]
# Recipe Instructions:
# [1] "Combine the ground beef with the lime juice, fish sauce, galangal powder and shallots.
# [2] Heat a skillet and cook the ground beef mixture on medium-high heat for 5 minutes or until the beef is cooked.
# [3] Remove the skillet from the heat and add the chopped green onion and cilantro and the ground roasted rice.
# [4] Mix thoroughly so that everything is well combined.
# [5] Remove to a serving plate, spoon the ground pepper on the side of the plate if desired, and garnish with the mint leaves.
# [6] Serve with an accompaniment of raw vegetables, such as long string beans or snake beans, sliced cabbage, green leaf lettuce/Chinese lettuce, basil leaves, and swamp cabbage or spinach."
#
# Recipe Title: Cheesy Shrimp Meltaways
# Ingredients: ["1 (12 ounce) package English muffins", "1 (4.5 ounce) can small shrimp, drained", "1/2 cup butter, softened", "1 (5 ounce) jar processed cheese spread", "1 1/2 teaspoons mayonnaise", "1/2 teaspoon garlic powder", "1/2 teaspoon seasoned salt"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# After the following examples, provide your response.
# Recipe Title: Shrimp Pomodoro
# Ingredients: ["8 ounces uncooked thin spaghetti", "1 tablespoon olive oil", "3/4 pound uncooked shrimp (26-30 per pound), peeled and deveined", "2 cloves garlic, minced", "1/4 to 1/2 teaspoon crushed red pepper flakes", "1 can (14-1/2 ounces) petite diced tomatoes, undrained", "10 fresh basil leaves, torn", "1/2 teaspoon salt", "1/8 teaspoon pepper", "1/4 cup grated Parmesan cheese"]
# Recipe Instructions:
# [1] "Cook spaghetti according to package directions.
# [2] In a large skillet, heat oil over medium-high heat. Add shrimp; cook until shrimp begin to turn pink, 1-2 minutes. Add garlic and pepper flakes; cook 1 minute longer.
# [3] Add tomatoes; bring to a boil. Reduce heat; simmer, uncovered, until shrimp turn pink, 2-3 minutes, stirring occasionally. Remove from heat; stir in basil, salt and pepper. Serve with spaghetti and cheese."
#
# Recipe Title: Grilled Hearts Of Romaine With Blue Cheese Vinaigrette And Pickled Onions
# Ingredients: ["1 1/2 cups white wine vinegar", "1/2 cup sugar", "1/2 cup water", "3 Turkish bay leaves", "1/2 teaspoon dried crushed red pepper", "Coarse kosher salt", "1 to 1 1/4 pounds red onions, thinly sliced", "1/4 cup white wine vinegar", "1/2 teaspoon Dijon mustard", "1/2 cup olive oil", "1/2 cup crumbled blue cheese", "4 hearts of romaine, each quartered lengthwise Crumbled blue cheese (for garnish)"]
# Your response:
# Saving the dataset (0/1 shards):   0%|          | 0/1000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# ...
# [3] Set up an ice bath next to the stovetop.
# [4] Drop the asparagus into the boiling water and cook until crisp-tender, about l 1/2 minutes.
# [5] Remove and immediately submerge in the ice bath to cool for 5 minutes, moving the stalks frequently to be sure no hot spots remain; add more ice if it all melts.
# [6] Remove the asparagus and drain on a kitchen towel, then transfer to a large bowl.
# [7] Add the lemon zest and juice, orange zest, the garlic, parsley, mint, and olive oil and toss gently to mix well.
# [8] Arrange the spears on a platter and pour the mixture remaining in the bowl over them.
# [9] Sprinkle with the sea salt, and serve with a flourish."
#
# Recipe Title: Asparagus with Vin Santo Vinaigrette
# Ingredients: ["1 1/2 cups vin santo (about 375 milliliters)", "1 tablespoon lemon juice", "1 tablespoon Dijon mustard", "1/4 teaspoon kosher salt", "1/4 teaspoon freshly ground black pepper", "1/3 cup extra-virgin olive oil", "1 bunch asparagus, bottom ends trimmed", "6 leaves of Bibb lettuce", "1 hard boiled egg, sliced", "1/4 cup chopped toasted almonds"]
# Recipe Instructions:
# [1] "In a small saucepan over medium heat, reduce the vin santo to 1/3 cup, about 10 minutes.
# [2] In a small bowl, combine the reduced vin santo, lemon juice, mustard, salt, and pepper.
# [3] Whisk to combine, making sure the mustard is fully dissolved.
# [4] While whisking slowly drizzle in the olive oil.
# [5] Bring a large pot of salted water to a boil over high heat.
# [6] Add the asparagus.
# [7] Cook until just tender, about 3 minutes.
# [8] Transfer the asparagus to a bowl filled with ice water and let cool, about 3 minutes.
# [9] Remove from water and pat dry with paper towels.
# [10] Place the lettuce leaves on a serving platter and top with the asparagus, then the slices of hard boiled egg and chopped almonds.
# [11] Drizzle the entire platter with the vinaigrette.
# [12] Serve immediately."
#
# Recipe Title: Asparagus With Salsa Verde and Scarlet Onions
# Ingredients: ["1 small red onion, sliced into thin rounds", "A few tablespoons white wine vinegar or champagne vinegar, more to taste", "Sea salt", "1 1/2 pounds asparagus", "1/4 cup chopped parsley", "2 tablespoons chopped tarragon", "1 tablespoon capers, rinsed", "1 wide band orange zest, finely slivered and blanched for 10 seconds", "4 to 5 tablespoons olive oil", "1/2 teaspoon Dijon mustard", "1 tablespoon orange juice", "Black pepper"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# After the following examples, provide your response.
# Recipe Title: Spaghetti Squash With Chicken And Sun Dried Tomatoes
# Ingredients: ["1 Spaghetti Squash - roasted", "1/2 cup sun dried tomatoes in oil", "1/2 yellow onion - diced", "3 cloves garlic - chopped", "1 cup spinach", "1 chicken breast - diced and seasoned with salt and pepper", "2 tablespoons butter", "1/3 cup feta cheese", "Salt and Pepper to taste"]
# Recipe Instructions:
# [1] "To start, roast your butternut squash. Cut your squash in half, set your oven to 400 degrees fahrenheit, scoop out the seeds, and set your squash face down on a baking sheet. Bake for about 40 minutes or until the squash is easily pierced with a fork.
# [2] Scoop out one half of the squash per person.
# [3] Saute the sun dried tomatoes, onions and garlic until the onions are translucent. Add in your chicken and cook until the chicken is cooked through, about 5-7 minutes.
# [4] Add the spaghetti squash to the mixture and the butter.
# [5] Reduce the heat to medium and cover with a lid.
# [6] Cook until the squash is warm and the chicken is cooked.
# [7] Top with feta cheese and green onions and enjoy!"
#
# Recipe Title: Sauteed Yellow Squash
# Ingredients: ["1 tablespoon extra-virgin olive oil", "2 tablespoons butter", "1/2 red bell pepper, chopped", "2 small to medium yellow squash, sliced", "Salt and pepper", "2 tablespoons chopped parsley leaves", "2 tablespoons chopped chives or 2 scallions, optional"]
# Recipe Instructions:
# [1] "Preheat skillet over medium high heat.
# [2] Add oil, then butter.
# [3] When butter melts, add red peppers and squash.
# [4] Saute 12 to 14 minutes until squash is tender.
# [5] Add salt, pepper and parsley.
# [6] Add chives or scallions if you would like a layer of light onion flavor on the dish as well."
#
# Recipe Title: Pasta With Roasted Winter Squash And Ricotta Salata
# Ingredients: ["1 small butternut squash, about 1 1/2 pounds, peeled, seeded, and cut in 1/2-inch dice", "3 garlic cloves, unpeeled, lightly crushed", "Salt and freshly ground pepper", "2 teaspoons chopped fresh rosemary or sage (to taste)", "2 tablespoons extra virgin olive oil", "3/4 pound pasta, either long pasta like spaghetti, or penne", "2 ounces ricotta salata, grated, or 2 ounces crumbled goat cheese", "1 tablespoon chopped fresh parsley"]
# Recipe Instructions:
# [1] "1. Preheat the oven to 425\u00b0F. Cover a baking sheet with foil. In a bowl, toss the squash with the garlic, salt, pepper, rosemary or sage, and 1 tablespoon of the olive oil until all of the squash is coated with oil. Transfer to the baking sheet, place in the oven and roast for 30 minutes, or until tender and caramelized. Remove from the heat. Remove the garlic cloves and discard. Transfer the squash to a wide pasta bowl and add the cheese. Keep warm.
# [2]
# [3] 2. Bring a large pot of generously salted water to a boil and add the pasta. Cook al dente, following the timing instructions on the package but checking the pasta a minute or two before. Ladle about 1/2 cup cooking water from the pasta into the bowl with the squash and cheese and stir together.
# [4]
# [5] 3. When the pasta is ready, drain and toss with the squash mixture, the remaining tablespoon of olive oil, and the parsley. Serve hot."
#
# Recipe Title: Spaghetti Squash Saute
# Ingredients: ["cooking spray", "1 spaghetti squash, halved and seeded", "1/4 cup butter or margarine", "1 small onion, chopped", "2 cloves garlic, finely chopped", "salt and pepper to taste"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# After the following examples, provide your response.
# Recipe Title: Lemon Pepper Chicken
# Ingredients: ["1 cup lemon juice", "1/4 cup olive oil", "1/4 cup finely chopped onion", "3 cloves garlic minced", "1 tablespoon pepper Cracked block", "1 tablespoon brown sugar", "2 teaspoons grated lemon peel", "3/4 teaspoon salt", "4 chicken quarters about 2 1/2 pounds"]
# Recipe Instructions:
# [1] "1. Combine lemon juice, oil, onion, garlic, pepper, sugar, lemon peel and salt in small bowl; reserve 2 tablespoons marinade. Combine remaining marinade and chicken in large resealable plastic food storage bag. Seal bag; knead to coat. Refrigerate 4 hours or overnight.
# [2] 2. Remove chicken from marinade; discard marinade. Arrange chicken on microwavable plate; cover with waxed paper. Microwave at HIGH 5 minutes.
# [3] Turn and rearrange chicken. Cover and microwave at HIGH 5 minutes.
# [4] 3. Transfer chicken to grill. Grill covered over medium-hot coals 15 to 20 minutes or until chicken is no longer pink in center and juices run clear, turning several times and basting often with reserved marinade."
#
# Recipe Title: Tangy lemon chicken
# Ingredients: ["1 lb thin halfed chicken breast", "1 pinch coarse black peppercorn", "1 dash lemon zest", "1 dash salt and pepper", "1 tsp olive oil", "1 sprits of lemmon juice. (1 lemon half)"]
# Recipe Instructions:
# [1] "Slice each breast in half.
# [2] And lightly season each half breast
# [3] Coat pan with oil and let heat up slowly on med heat.
# [4] Drop in breast cooking fully and untill golden brownl
# [5] Let set for 5 mins and sprits with lemon juice and serve with your favorite side dish."
#
# Recipe Title: Chicken With Lemon-Basil Sauce
# Ingredients: ["3 tablespoons olive oil", "4 skinless boneless chicken breast halves", "3 tablespoons fresh lemon juice", "4 garlic cloves, chopped", "1 teaspoon (packed) grated lemon peel", "1 cup canned low-salt chicken broth", "1/2 cup chopped fresh basil or 1 tablespoon dried"]
# Recipe Instructions:
# [1] "Heat olive oil in heavy large skillet over medium-high heat. Sprinkle chicken with salt and pepper. Add chicken to skillet and saute until brown and cooked through, about 5 minutes Per side. Transfer chicken to platter; tent with foil.
# [2] Add lemon juice, garlic and lemon peel to same skillet. Stir over medium-high heat until fragrant, about 30 seconds. Add chicken broth; boil until reduced to sauce consistency, about 8 minutes. Mix basil into sauce. Season to taste with salt and pepper.
# [3] Spoon sauce over chicken and serve."
#
# Recipe Title: Tinklee's Lemon Herb Chicken
# Ingredients: ["6 chicken breast", "1/4 cup lemon juice", "2 tbsp dijon mustard", "2 tbsp olive oil", "3 clove garlic -minced", "1 tsp oregano", "1/4 tsp black pepper"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# After the following examples, provide your response.
# Recipe Title: Lamb Kofta
# Ingredients: ["1 lb lean ground lamb", "1 tsp salt", "1/2 tsp pepper", "1/2 cup minced onions", "1/2 cup fresh chopped parsley", "Olive oil (optional)"]
# Recipe Instructions:
# [1] "Grind the ground meat in a food processsor and add all the other ingredients and grind it well
# [2] And make into balls and thread on to skewers.
# [3] And grill or broil until done."
#
# Recipe Title: Lamb From Wine Food And Friends
# Ingredients: ["The Lamb:", "3 racks of lamb", "sea salt", "3 teaspoons freshly ground pepper", "3 tablespoons vegetable or olive oil", "3 teaspoons Dijon-style mustard", "6 tablespoons herb bread crumbs"]
# Recipe Instructions:
# [1] "Preheat the oven to 425\u00b0.
# [2] Trim the racks of lamb, removing excess fat and silver skin.
# [3] Season the racks with salt and pepper to taste.
# [4] Heat the oil in a heavy skillet over high heat. When the oil just begins to smoke, sear the meat well on both sides. Set the skillet in the oven.
# [5] Cook the racks of lamb for approximately 10-12 minutes for medium rare. Using tongs, turn the meat once while in the oven.
# [6] Remove the lamb from the pan and allow to rest 10 minutes before serving.
# [7] To Serve:
# [8]
# [9] Brush the mustard on the front of the racks of lamb and cover with a generous coating of the herb bread crumbs.
# [10] Return the lamb to a hot oven to heat and brown the bread crumbs, approximately 4-5 minutes.
# [11] Carve the racks into individual chops and place in pairs down the center of the serving platter.
# [12] Present the platter at tableside and serve on warm plates with the Gratin and other seasonal vegetables as desired."
#
# Recipe Title: Saltbush Lamb with Sweet Potato Smash
# Ingredients: ["4 each lamb backstraps on the bone", "2 large sweet potatoes, or yams", "1 x vegetable oil for frying", "1 pinch spices", "3 pinch thyme", "1 x black pepper", "2 bunches rapini (broccoli rabe)", "200 millilitres lamb jus", "4 each figs", "1 x beets jam"]
# Recipe Instructions:
# [1] "Remove the meat from the bone with a sharp, boning knife.
# [2] Season the lamb with wild thyme and tie it in place, back on the bone.
# [3] Pan sear the lamb to brown and cook it in a preheated oven for 8 minutes at 250C.
# [4] Remove the meat from the oven and rest for 8 minutes.
# [5] Peel the sweet potatoes and dice, steam in the microwave for about 10 minutes or until soft.
# [6] Using the same pan in which the lamb was cooked, add the sweet potato and a drizzle of olive oil and fry until the potato becomes crispy; add Fruit Spice and Alpine Pepper to taste.
# [7] Steam the broccolini and grill the figs.
# [8] Heat the jus and add a couple of pinches of Alpine Pepper."
#
# Recipe Title: Lamb Won Tons
# Ingredients: ["3/4 pound ground lamb", "2 1/2 teaspoons ground coriander", "3/4 teaspoon ground cinnamon", "2 1/4 teaspoons kosher salt", "3/4 teaspoon freshly ground black pepper", "3 tablespoons golden raisins", "3 tablespoons coarsely chopped pistachios", "34 won ton skins, 3 inches by 31/4 inches", "Vegetable oil for deep-frying"]
# Your response:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Write recipe instructions for the following recipe title and ingredient list.
# Each step should be numbered, and the number should precede the step text and be enclosed in square brackets (like [1] or [13]).
# After the following examples, provide your response.
# Recipe Title: Pistachio Bread
# Ingredients: ["1 (18.25 ounce) package yellow cake mix", "4 eggs", "1/4 cup vegetable oil", "2 tablespoons water", "1 (3 ounce) package instant pistachio pudding mix", "1 cup sour cream", "1/2 cup maraschino cherries", "1/2 teaspoon green food coloring", "1/2 teaspoon ground cinnamon", "2 tablespoons white sugar"]
# Recipe Instructions:
# [1] "Preheat oven to 350 degrees F (175 degrees C). Grease and flour two 9 x 5 inch loaf pans.
# [2] Mix together cake mix, eggs, oil, water, pudding mix, sour cream, cherries, and food coloring. Pour into prepared pans. In a small bowl, stir together cinnamon and sugar. Sprinkle tops of loaves with mixture.
# [3] Bake for 45 minutes. Cool."
#
# Recipe Title: Pistachio Wedding Cookies
# Ingredients: ["1 cup Butter, Softened", "1 cup Confectioners Sugar, Divided", "2 teaspoons Vanilla Extract", "1-3/4 cup All-purpose Flour", "3-1/2 ounces, weight Pistachio Instant Pudding Mix", "1/2 teaspoons Salt"]
# Recipe Instructions:
# [1] "In a large mixing bowl, cream butter. Beat in 1/2 cup sugar until fluffy. Add in vanilla extract.
# [2] In a medium bowl, combine flour, pudding mix and salt. Gradually mix flour mixture into wet ingredients until combined.
# [3] Divide dough in half and form into a ball. Wrap in plastic wrap and place in refrigerator for at least 1 hour.
# [4] Preheat oven to 350\u00b0F. Line baking sheets with parchment paper.
# [5] Remove dough from plastic wrap and make teaspoon-size balls. Place on baking sheets and press down on the balls, slightly spacing them about 1 inch apart.
# [6] Bake in preheated oven for 9-10 minutes. Don't overbake. Remove from oven and let them sit on baking sheet for about 5 minutes. While cookies are still, warm toss them in remaining confectioners sugar and set on wire rack until cooled completely.
# [7] Store in airight containers."
#
# Recipe Title: Pistachio Cake
# Ingredients: ["1 package Yellow Cake Mix (18.25 Oz)", "1 package Instant Pistachio Pudding Mix (3.4 Oz)", "4 whole Eggs", "1-1/2 cup Water", "1/4 cups Vegetable Oil", "1/2 teaspoons Almond Extract"]
# Recipe Instructions:
# [1] "Preheat oven to 350 degrees F (175 degrees C). Grease and flour a 10-inch tube pan.
# [2] In a large bowl mix together cake mix and pudding mix. Make a well in the center and pour in eggs, water, oil, and almond extract. Blend ingredients, then beat for 2 minutes at medium speed.
# [3] Pour into the prepared 10-inch tube pan. Bake in the preheated oven for 50 to 55 minutes, or until cake springs back when lightly pressed. Cool in the pan 15 minutes. Turn out onto a wire rack and cool completely."
#
# Recipe Title: Pistachio Pudding Cookies
# Ingredients: ["1/2 cups Butter, Softenend", "1/2 cups Sugar", "1/4 cups Vegetable Oil", "1/4 cups Water", "1 whole Egg", "2 packages Pistachio Flavored Pudding Mix (3.4oz Size)", "1 teaspoon Vanilla", "1/2 teaspoons Salt", "1 teaspoon Baking Powder", "2 cups Flour", "1/2 cups Chopped Pistachios", "1 cup White Chocolate Chips"]
# Your response:

# %% [markdown]
# ### Fine-Tuned Evaluation

# %%
small_test = small_test.map(lambda x: {"examples": ""})

# %%
generated_dataset_ft = small_test.map(
    generate_instruction_batch,
    batched=True,
    batch_size=BATCH_SIZE,
    fn_kwargs={"cot": False, 'model':model_ft, 'tokenizer':tokenizer}
)
generated_dataset_ft.save_to_disk(f'{recipe_nlg_data_path}/ft_generated_1k_5e_3')
# Out:
# Parameter 'fn_kwargs'={'cot': False, 'model': PeftModelForCausalLM(
#   (base_model): LoraModel(
#     (model): MistralForCausalLM(
#       (model): MistralModel(
#         (embed_tokens): Embedding(32002, 4096)
#         (layers): ModuleList(
#           (0-27): 28 x MistralDecoderLayer(
#             (self_attn): MistralAttention(
#               (q_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#               (k_proj): Linear4bit(in_features=4096, out_features=1024, bias=False)
#               (v_proj): Linear4bit(in_features=4096, out_features=1024, bias=False)
#               (o_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#             )
#             (mlp): MistralMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (act_fn): SiLU()
#             )
#             (input_layernorm): MistralRMSNorm((4096,), eps=1e-05)
#             (post_attention_layernorm): MistralRMSNorm((4096,), eps=1e-05)
#           )
#           (28-31): 4 x MistralDecoderLayer(
#             (self_attn): MistralAttention(
#               (q_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=4096, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (k_proj): Linear4bit(in_features=4096, out_features=1024, bias=False)
#               (v_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=1024, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (o_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#             )
#             (mlp): MistralMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (act_fn): SiLU()
#             )
#             (input_layernorm): MistralRMSNorm((4096,), eps=1e-05)
#             (post_attention_layernorm): MistralRMSNorm((4096,), eps=1e-05)
#           )
#         )
#         (norm): MistralRMSNorm((4096,), eps=1e-05)
#         (rotary_emb): MistralRotaryEmbedding()
#       )
#       (lm_head): Linear(in_features=4096, out_features=32002, bias=False)
#     )
#   )
# ), 'tokenizer': LlamaTokenizerFast(name_or_path='teknium/OpenHermes-2.5-Mistral-7B', vocab_size=32000, model_max_length=1000000000000000019884624838656, is_fast=True, padding_side='left', truncation_side='right', special_tokens={'bos_token': '<s>', 'eos_token': '<|im_end|>', 'unk_token': '<unk>', 'pad_token': '<|im_end|>'}, clean_up_tokenization_spaces=False, added_tokens_decoder={
# 	0: AddedToken("<unk>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	1: AddedToken("<s>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	2: AddedToken("</s>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32000: AddedToken("<|im_end|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32001: AddedToken("<|im_start|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# }
# )} of the transform datasets.arrow_dataset.Dataset._map_single couldn't be hashed properly, a random hash was used instead. Make sure your transforms and parameters are serializable with pickle or dill for the dataset fingerprinting and caching to work. If you reuse this transform, the caching mechanism will consider it to be different from the previous calls and recompute everything. This warning is only showed once. Subsequent hashing failures won't be showed.
# WARNING:datasets.fingerprint:Parameter 'fn_kwargs'={'cot': False, 'model': PeftModelForCausalLM(
#   (base_model): LoraModel(
#     (model): MistralForCausalLM(
#       (model): MistralModel(
#         (embed_tokens): Embedding(32002, 4096)
#         (layers): ModuleList(
#           (0-27): 28 x MistralDecoderLayer(
#             (self_attn): MistralAttention(
#               (q_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#               (k_proj): Linear4bit(in_features=4096, out_features=1024, bias=False)
#               (v_proj): Linear4bit(in_features=4096, out_features=1024, bias=False)
#               (o_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#             )
#             (mlp): MistralMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (act_fn): SiLU()
#             )
#             (input_layernorm): MistralRMSNorm((4096,), eps=1e-05)
#             (post_attention_layernorm): MistralRMSNorm((4096,), eps=1e-05)
#           )
#           (28-31): 4 x MistralDecoderLayer(
#             (self_attn): MistralAttention(
#               (q_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=4096, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (k_proj): Linear4bit(in_features=4096, out_features=1024, bias=False)
#               (v_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=1024, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (o_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#             )
#             (mlp): MistralMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (act_fn): SiLU()
#             )
#             (input_layernorm): MistralRMSNorm((4096,), eps=1e-05)
#             (post_attention_layernorm): MistralRMSNorm((4096,), eps=1e-05)
#           )
#         )
#         (norm): MistralRMSNorm((4096,), eps=1e-05)
#         (rotary_emb): MistralRotaryEmbedding()
#       )
#       (lm_head): Linear(in_features=4096, out_features=32002, bias=False)
#     )
#   )
# ), 'tokenizer': LlamaTokenizerFast(name_or_path='teknium/OpenHermes-2.5-Mistral-7B', vocab_size=32000, model_max_length=1000000000000000019884624838656, is_fast=True, padding_side='left', truncation_side='right', special_tokens={'bos_token': '<s>', 'eos_token': '<|im_end|>', 'unk_token': '<unk>', 'pad_token': '<|im_end|>'}, clean_up_tokenization_spaces=False, added_tokens_decoder={
# 	0: AddedToken("<unk>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	1: AddedToken("<s>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	2: AddedToken("</s>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32000: AddedToken("<|im_end|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32001: AddedToken("<|im_start|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# }
# )} of the transform datasets.arrow_dataset.Dataset._map_single couldn't be hashed properly, a random hash was used instead. Make sure your transforms and parameters are serializable with pickle or dill for the dataset fingerprinting and caching to work. If you reuse this transform, the caching mechanism will consider it to be different from the previous calls and recompute everything. This warning is only showed once. Subsequent hashing failures won't be showed.
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
#
# Recipe Title: Orange Cookies Iii
# Ingredients: ["1 cup shortening", "2 cups white sugar", "2 eggs", "1 cup buttermilk", "1/2 cup orange juice", "2 tablespoons orange zest", "4 1/2 cups all-purpose flour", "2 teaspoons baking powder", "1 teaspoon salt", "1/2 teaspoon baking soda", "1/4 cup butter", "4 cups confectioners' sugar", "3 tablespoons thawed orange juice concentrate"]
# Recipe Instructions:

# %%
generated_dataset_ft = one_shot.map(
    generate_instruction_batch,
    batched=True,
    batch_size=BATCH_SIZE,
    fn_kwargs={"cot": False, 'model':model_ft, 'tokenizer':tokenizer}
)
generated_dataset_ft.save_to_disk(f'{recipe_nlg_data_path}/ft_generated_1k_5e_one_shot')

# %%
generated_dataset_ft = two_shot.map(
    generate_instruction_batch,
    batched=True,
    batch_size=BATCH_SIZE,
    fn_kwargs={"cot": False, 'model':model_ft, 'tokenizer':tokenizer}
)
generated_dataset_ft.save_to_disk(f'{recipe_nlg_data_path}/ft_generated_1k_5e_two_shot')

# %%
generated_dataset_ft = three_shot.map(
    generate_instruction_batch,
    batched=True,
    batch_size=BATCH_SIZE,
    fn_kwargs={"cot": False, 'model':model_ft, 'tokenizer':tokenizer}
)
generated_dataset_ft.save_to_disk(f'{recipe_nlg_data_path}/ft_generated_1k_5e_three_shot')

# %%
generated_dataset_ft = one_shot_ret.map(
    generate_instruction_batch,
    batched=True,
    batch_size=BATCH_SIZE,
    fn_kwargs={"cot": False, 'model':model_ft, 'tokenizer':tokenizer}
)
generated_dataset_ft.save_to_disk(f'{recipe_nlg_data_path}/ft_generated_1k_5e_one_shot_retrieval')

# %%
generated_dataset_ft = two_shot_ret.map(
    generate_instruction_batch,
    batched=True,
    batch_size=BATCH_SIZE,
    fn_kwargs={"cot": False, 'model':model_ft, 'tokenizer':tokenizer}
)
generated_dataset_ft.save_to_disk(f'{recipe_nlg_data_path}/ft_generated_1k_5e_two_shot_retrieval')

# %%
generated_dataset_ft = three_shot_ret.map(
    generate_instruction_batch,
    batched=True,
    batch_size=BATCH_SIZE,
    fn_kwargs={"cot": False, 'model':model_ft, 'tokenizer':tokenizer}
)
generated_dataset_ft.save_to_disk(f'{recipe_nlg_data_path}/ft_generated_1k_5e_three_shot_retrieval')

# %% [markdown]
# ### Test Output

# %%
generated_dataset_base_test = small_test.select([1,2]).map(
    generate_instruction_batch,
    batched=True,
    batch_size=2,
    fn_kwargs={"cot": False, "model": model, "tokenizer": tokenizer}
)
# Out:
# Map:   0%|          | 0/2 [00:00<?, ? examples/s]
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Enclose your recipe instructions in <instructions> tags and number each step.
# Examples: None
# Title: Tarragon Chicken Salad
# Ingredients: ["1/4 cup MIRACLE WHIP FREE Dressing", "1/4 tsp. dried tarragon leaves", "3 oz. , cubed", "1 cup red or green grapes, seedless Target 1 lb For $2.99 thru 02/06", "1/2 whole wheat pita bread round", "2 SNACKWELL'S Sugar Free Shortbread Cookies", "4 fl oz (1/2 cup) orange juice"]
# Your response:
