# %% [markdown]
# ## Setup

# %% [markdown]
# ### Configure Environment

# %%
# !pip install -U bitsandbytes

# !pip install -U transformers accelerate
# !pip install evaluate rouge_score
# Out:
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.46.1-py3-none-manylinux_2_24_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: torch<3,>=2.2 in /usr/local/lib/python3.11/dist-packages (from bitsandbytes) (2.6.0+cu124)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from bitsandbytes) (2.0.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (4.14.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch<3,>=2.2->bitsandbytes)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch<3,>=2.2->bitsandbytes)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch<3,>=2.2->bitsandbytes)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch<3,>=2.2->bitsandbytes)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch<3,>=2.2->bitsandbytes)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch<3,>=2.2->bitsandbytes)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch<3,>=2.2->bitsandbytes)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch<3,>=2.2->bitsandbytes)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch<3,>=2.2->bitsandbytes)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch<3,>=2.2->bitsandbytes)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<3,>=2.2->bitsandbytes) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<3,>=2.2->bitsandbytes) (3.0.2)
# Downloading bitsandbytes-0.46.1-py3-none-manylinux_2_24_x86_64.whl (72.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 MB 34.4 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 92.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 99.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 56.3 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.7 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 11.4 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 41.0 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 20.1 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.8 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 98.1 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, bitsandbytes
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed bitsandbytes-0.46.1 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.53.1)
# Collecting transformers
#   Downloading transformers-4.53.2-py3-none-any.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: accelerate in /usr/local/lib/python3.11/dist-packages (1.8.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.33.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from accelerate) (2.6.0+cu124)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (2025.3.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (4.14.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (1.1.5)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.7.9)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.2)
# Downloading transformers-4.53.2-py3-none-any.whl (10.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 140.0 MB/s eta 0:00:00
# Installing collected packages: transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.53.1
#     Uninstalling transformers-4.53.1:
#       Successfully uninstalled transformers-4.53.1
# Successfully installed transformers-4.53.2
# Collecting evaluate
#   Downloading evaluate-0.4.5-py3-none-any.whl.metadata (9.5 kB)
# Collecting rouge_score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from evaluate) (2.14.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from evaluate) (2.0.2)
# Requirement already satisfied: dill in /usr/local/lib/python3.11/dist-packages (from evaluate) (0.3.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from evaluate) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from evaluate) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.11/dist-packages (from evaluate) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from evaluate) (3.5.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.11/dist-packages (from evaluate) (0.70.15)
# Requirement already satisfied: fsspec>=2021.05.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (2025.3.2)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from evaluate) (0.33.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from evaluate) (24.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from rouge_score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (from rouge_score) (3.9.1)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.11/dist-packages (from rouge_score) (1.17.0)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.0.0->evaluate) (18.1.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets>=2.0.0->evaluate) (3.11.15)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.0.0->evaluate) (6.0.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.7.0->evaluate) (3.18.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.14.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.7.0->evaluate) (1.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (2025.7.9)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk->rouge_score) (8.2.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk->rouge_score) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk->rouge_score) (2024.11.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->evaluate) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.20.1)
# Downloading evaluate-0.4.5-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 370.2 kB/s eta 0:00:00
# Building wheels for collected packages: rouge_score
#   Building wheel for rouge_score (setup.py) ... done
#   Created wheel for rouge_score: filename=rouge_score-0.1.2-py3-none-any.whl size=24934 sha256=5fd0fcc2f386e661cdcde2db073bdac1b324da7f0e8e2c61a44275dc6c899f7e
#   Stored in directory: /root/.cache/pip/wheels/1e/19/43/8a442dc83660ca25e163e1bd1f89919284ab0d0c1475475148
# Successfully built rouge_score
# Installing collected packages: rouge_score, evaluate
# Successfully installed evaluate-0.4.5 rouge_score-0.1.2

# %% [markdown]
# ### Imports

# %%
# ✅ Confirm install
import torch
from transformers import (
    AutoTokenizer,
    AutoModelForCausalLM,
    BitsAndBytesConfig
)

from datasets import load_from_disk
from huggingface_hub import login
import evaluate

from google.colab import drive
import os

import pandas as pd
import re

# %% [markdown]
# ### Mount Drive

# %%
root = '/content/drive'

# %%
drive.mount(root)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Login to Hugging Face

# %%
os.environ['HF_TOKEN'] = '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'
login(token=os.environ["HF_TOKEN"])
# Out:
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# WARNING:huggingface_hub._login:Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.

# %% [markdown]
# ### Load Dataset

# %%
recipe_nlg_data_path = f'{root}/MyDrive/NLP-266/Project/RecipeNLG'

# %%
dataset = load_from_disk(f'file://{recipe_nlg_data_path}/processed_recipe_nlg_dataset')

print(dataset)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['title', 'ingredients', 'directions', 'source', 'NER', 'n_ingredients', 'n_steps', 'n_ner', 'domain', 'avg_step_length', 'total_step_length'],
#         num_rows: 349677
#     })
#     validation: Dataset({
#         features: ['title', 'ingredients', 'directions', 'source', 'NER', 'n_ingredients', 'n_steps', 'n_ner', 'domain', 'avg_step_length', 'total_step_length'],
#         num_rows: 3670
#     })
#     test: Dataset({
#         features: ['title', 'ingredients', 'directions', 'source', 'NER', 'n_ingredients', 'n_steps', 'n_ner', 'domain', 'avg_step_length', 'total_step_length'],
#         num_rows: 3671
#     })
#     prompt: Dataset({
#         features: ['title', 'ingredients', 'directions', 'source', 'NER', 'n_ingredients', 'n_steps', 'n_ner', 'domain', 'avg_step_length', 'total_step_length'],
#         num_rows: 10000
#     })
# })

# %% [markdown]
# ### Globals

# %%
SYSTEM_PROMPT = """
You are an expert in generating recipe instructions from the recipe title and ingredient list.
""".strip()

PROMPT_HPS = {
  'do_sample': True,
  'temperature': 0.7,
  'top_p': 1.0,
  'max_new_tokens': 256,
  'stop_sequences':None,
  'repetition_penalty': 1.1,
  'use_cache': True
}

COT_PROMPT = """
Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?

Only generate the reasoning in this response, the recipe instructions will be generated in a later response.
Enclose your reasoning in <reasoning> tags.
""".strip()

BATCH_SIZE = 32

# %% [markdown]
# ### Model Config

# %%
quantization_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_use_double_quant=True,
    bnb_4bit_compute_dtype=torch.float16,
    llm_int8_enable_fp32_cpu_offload=True
)

# %%
model_id = "teknium/OpenHermes-2.5-Mistral-7B"

tokenizer = AutoTokenizer.from_pretrained(model_id, padding_side='left')
tokenizer.pad_token = tokenizer.eos_token
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/51.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/101 [00:00<?, ?B/s]

# %%
from peft import PeftModel, PeftConfig

adapter_path = f'{recipe_nlg_data_path}/qlora_1k_test_5e'

# %%
from peft import PeftModel, PeftConfig

config = PeftConfig.from_pretrained(adapter_path)


base_model = AutoModelForCausalLM.from_pretrained(
    config.base_model_name_or_path,
    return_dict=True,
    torch_dtype=torch.float16,
    device_map="auto",
    quantization_config=quantization_config
)

model_ft = PeftModel.from_pretrained(base_model, adapter_path)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
ft_generation_save_path = f'file://{recipe_nlg_data_path}/Generated_Data/ft_generated_2k'

# %%
model = AutoModelForCausalLM.from_pretrained(
    model_id,
    force_download=True,
    torch_dtype=torch.float16,
    trust_remote_code=True,
    quantization_config=quantization_config,
    device_map="auto"
)
# Out:
# config.json:   0%|          | 0.00/624 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/624 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/4.54G [00:00<?, ?B/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.94G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/120 [00:00<?, ?B/s]

# %% [markdown]
# ## Code

# %% [markdown]
# ### Generation Helpers

# %%
def extract_text(text, tag):
    match_ = re.search(f"<{tag}>(.*?)<{tag}>(.*?)</{tag}>", text, re.DOTALL | re.IGNORECASE)
    output = match_.groups()[-1].strip() if match_ else None

    if output:
      return output
    else:
      end = text.find("Your response:")
      return text[end:].strip()

def form_example(row):
    direction_list = row['directions'].translate(str.maketrans('', '', '[]')).split('", "')
    directions = '\n'.join([f'{i+1}. {direction}' for i, direction in enumerate(direction_list)])

    return f'''Recipe Title: {row['title']}
Ingredients: {row['ingredients']}
Recipe Instructions:
{directions}
'''


def form_examples(row, prompt_set, n_prompts, retrieved=False):
    # For each example_id, select from the prompt set
    if retrieved:
        example_ids = row['retrieval_neighbors'][:n_prompts] # changed
    else:
        example_ids = prompt_set.shuffle().select(range(n_prompts))['prompt_id']

    examples = prompt_set.select(example_ids)

    # For each selection
    return {"examples": ['\n'.join([form_example(row) for i, row in enumerate(examples)])]}


def form_transfer_prompt(title, ingredients, reasoning):

    transfer_prompt = f"""
    Write recipe instructions for the following recipe title and ingredient list.
    Use the provided reasoning to inform your response.
    Enclose your recipe instructions in <instructions> tags and number each step.
    Recipe Title: {title}
    Ingredients: {ingredients}
    Reasoning: {reasoning}
    Your response:
    """.strip()

    return transfer_prompt

def generate_instruction_batch(batch, model=None, tokenizer=None, cot=False, examples=None):
    nl = '\n'
    if cot:
        prompts = [form_transfer_prompt(title, ingredients, reasoning)
        for title, ingredients, reasoning
        in zip(batch['title'], batch['ingredients'], batch['reasoning'])
        ]
    else:
        prompts = [
        f"""{SYSTEM_PROMPT}
Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
{examples}
Recipe Title: {title}
Ingredients: {ingredients}
Recipe Instructions:"""
            for title, ingredients, examples in zip(batch['title'], batch['ingredients'], batch['examples'])
        ]

    print(prompts[0])

    inputs = tokenizer(
        prompts,
        return_tensors="pt",
        padding=True,
        truncation=True
    ).to(model.device)

    hps = PROMPT_HPS.copy()

    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            **hps,
            pad_token_id=tokenizer.pad_token_id
        )

    decoded = tokenizer.batch_decode(outputs, skip_special_tokens=True)

    return {'generated': decoded}#[extract_text(decoded_example, "instructions") for decoded_example in decoded]}



def generate_reason_batch(batch, model=None, tokenizer=None, cot_prompt=""):
    nl = '\n'
    prompts = [
        f"""{SYSTEM_PROMPT}{nl + cot_prompt if cot_prompt else ""}
Recipe Title: {title}
Ingredients: {ingredients}
Recipe Instructions:"""
        for title, ingredients in zip(batch['title'], batch['ingredients'])
    ]

    print(prompts[0])

    inputs = tokenizer(
        prompts,
        return_tensors="pt",
        padding=True,
        truncation=True
    ).to(model.device)

    hps = PROMPT_HPS.copy()

    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            **hps,
            pad_token_id=tokenizer.pad_token_id
        )

    decoded = tokenizer.batch_decode(outputs, skip_special_tokens=True)
    return {'reasoning': [extract_text(decoded_example, "reasoning") for decoded_example in decoded]}

# %%
s = dataset['validation'][0]

print(form_examples([0, 1], dataset['validation']))
# Out:
# Example 1: Recipe Title: Classic Deviled Eggs
# Ingredients: ["12 Eggland's Best hard cooked eggs", "2/3 cup lowfat Mayonnaise", "1 teaspoon Mustard", "1/2 teaspoon Salt", "2 tablespoons Paprika, for garnish"]
# Your response: <instructions>["Cut eggs in half lengthwise, and remove the yolks. Mash yolks with a fork and add mayonnaise, mustard and salt.", "Put the yolk mixture into a plastic baggie and snip the end off one corner.", "Pipe the mixture into the whites.", "Sprinkle with paprika, if desired.", "Cover and chill for at least one hour.", "Vegetarian, Low Fat, Ready in 5 minutes, recipe by Eggland's Best", "37;", "2g (8% calories from fat);", "3g;", "1g;", "trace;", "88mg;", "79mg."]</instructions>
#
# Example 2: Recipe Title: Mesclun Salad With Roasted Tofu
# Ingredients: ["1 (12.3-ounce) package reduced-fat firm tofu, drained", "2 teaspoons dry sherry", "2 teaspoons low-sodium soy sauce", "1 teaspoon dark sesame oil", "8 cups gourmet salad greens", "1 cup (1/4-inch-thick) slices peeled cucumber", "1/4 cup chopped green onions", "2 tablespoons fresh lemon juice", "1 teaspoon olive oil", "1 teaspoon red wine vinegar", "1/4 teaspoon sugar", "1/4 teaspoon salt", "1/4 teaspoon black pepper", "1 garlic clove, minced"]
# Your response: <instructions>["Cut the tofu lengthwise into 4 slices. Place the slices on several layers of paper towels; cover with additional paper towels. Let stand 5 minutes. Cut each slice diagonally into 2 triangles. Place the tofu in a shallow baking dish. Combine the sherry, soy sauce, and sesame oil in a small bowl. Pour over tofu, and refrigerate 20 minutes.", "Preheat oven to 450\u00b0.", "Bake at 450\u00b0 for 25 minutes. Cool to room temperature; chill 30 minutes.", "Combine the greens, cucumber, and onions. Combine the juice and remaining ingredients; stir with a whisk. Drizzle juice mixture over greens, and toss well to coat. Place 2 cups salad on each of 4 plates; top each portion with 2 tofu triangles."]</instructions>

# %% [markdown]
# ### Form Test Set

# %%
#small_n = 1000
#small_test = dataset['test'].shuffle(seed=42).select(range(small_n))
#small_test.save_to_disk(f'{recipe_nlg_data_path}/test_1k')
small_test = load_from_disk(f'file://{recipe_nlg_data_path}/test_1k')

# %% [markdown]
# ## Experiments

# %% [markdown]
# ### OOB Generation

# %%
BATCH_SIZE = 32

# %%
BATCH_SIZE = 32
generated_dataset_oob_TEST = small_test.select([1,2]).map(
    generate_instruction_batch,
    batched=True,
    batch_size=BATCH_SIZE,
    fn_kwargs={"cot": False, "model": model, "tokenizer": tokenizer}
)


#generated_dataset_oob.save_to_disk(f'{recipe_nlg_data_path}/oob_generated')
# Out:
# Map:   0%|          | 0/2 [00:00<?, ? examples/s]
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Enclose your recipe instructions in <instructions> tags and number each step.
# Examples: None
# Title: Tarragon Chicken Salad
# Ingredients: ["1/4 cup MIRACLE WHIP FREE Dressing", "1/4 tsp. dried tarragon leaves", "3 oz. , cubed", "1 cup red or green grapes, seedless Target 1 lb For $2.99 thru 02/06", "1/2 whole wheat pita bread round", "2 SNACKWELL'S Sugar Free Shortbread Cookies", "4 fl oz (1/2 cup) orange juice"]
# Your response:
# 'You are an expert in generating recipe instructions from the recipe title and ingredient list.\nEnclose your recipe instructions in <instructions> tags and number each step.\nExamples: None\nTitle: Tarragon Chicken Salad\nIngredients: ["1/4 cup MIRACLE WHIP FREE Dressing", "1/4 tsp. dried tarragon leaves", "3 oz. , cubed", "1 cup red or green grapes, seedless Target 1 lb For $2.99 thru 02/06", "1/2 whole wheat pita bread round", "2 SNACKWELL\'S Sugar Free Shortbread Cookies", "4 fl oz (1/2 cup) orange juice"]\nYour response:\n<instructions>\n1. In a small bowl, mix together the Miracle Whip dressing and dried tarragon leaves. Set aside.\n2. In a separate bowl, combine the cubed chicken, grapes, and half of the dressing mixture from step 1. Mix well to coat all ingredients evenly.\n3. Cut the whole wheat pita bread into triangles or squares. Serve with the chicken salad as desired.\n4. Garnish the plate with two Snackwell\'s sugar-free shortbread cookies.\n5. Pour the remaining orange juice over the chicken salad just before serving for added moisture and flavor.\n</instructions>'

# %%
from pprint import pprint

pprint(generated_dataset_oob_TEST['generated'][0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-16-786275410.py in <cell line: 0>()
#       1 from pprint import pprint
#       2
# ----> 3 pprint(generated_dataset_oob_TEST['generated'][0])
#
# NameError: name 'generated_dataset_oob_TEST' is not defined

# %% [markdown]
# ### CoT Generation

# %%
cot_prompt = """
Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?

Only generate the reasoning in this response, the recipe instructions will be generated in a later response.
Enclose your reasoning in <reasoning> tags.
""".strip()

generated_dataset_cot_reasoning = small_test.map(
    generate_reason_batch,
    batched=True,
    batch_size=BATCH_SIZE,
    fn_kwargs={"cot": cot_prompt, "model": model, "tokenizer": tokenizer}
)
# Out:
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
# You are an expert in generating recipe instructions.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response, the recipe instructions will be generated in a later response.
# Enclose your reasoning in <reasoning> tags.
# Title: Orange Cookies Iii
# Ingredients: ["1 cup shortening", "2 cups white sugar", "2 eggs", "1 cup buttermilk", "1/2 cup orange juice", "2 tablespoons orange zest", "4 1/2 cups all-purpose flour", "2 teaspoons baking powder", "1 teaspoon salt", "1/2 teaspoon baking soda", "1/4 cup butter", "4 cups confectioners' sugar", "3 tablespoons thawed orange juice concentrate"]
# Your response:
# You are an expert in generating recipe instructions.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response, the recipe instructions will be generated in a later response.
# Enclose your reasoning in <reasoning> tags.
# Title: Creamy Roasted Garlic And Almond Soup
# Ingredients: ["3 garlic bulbs", "1 onion chopped", "4 tablespoons olive oil", "creme fraiche 30 cl.", "4 1/4 cups chicken stock", "10 cups sourdough bread", "2 tablespoons white vinegar", "1 3/8 cups almonds peeled", "salt", "pepper", "water 25 cl.", "3 oranges peeled and sectioned", "cilantro", "mint"]
# Your response:
# You are an expert in generating recipe instructions.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response, the recipe instructions will be generated in a later response.
# Enclose your reasoning in <reasoning> tags.
# Title: Skillet Pasta Florentine
# Ingredients: ["3 cups uncooked spiral pasta", "1 large egg, lightly beaten", "2 cups 2% cottage cheese", "1-1/2 cups reduced-fat ricotta cheese", "1 package (10 ounces) frozen chopped spinach, thawed and squeezed dry", "1 cup shredded part-skim mozzarella cheese, divided", "1 teaspoon each dried parsley flakes, oregano and basil", "1 jar (14 ounces) meatless spaghetti sauce", "2 tablespoons grated Parmesan cheese"]
# Your response:
# You are an expert in generating recipe instructions.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response, the recipe instructions will be generated in a later response.
# Enclose your reasoning in <reasoning> tags.
# Title: Roasted Pacific Cod With Spring Vegetables And Mint
# Ingredients: ["4 (6-ounces) pieces skinless Pacific cod or hake fillet (1 inch thick)", "4 tablespoons extra-virgin olive oil, divided, plus additional for drizzling", "1 bunch scallions, cut into 1-inch pieces", "1/2 pound zucchini (about 2 medium), cut into 1/2-inch-thick half-moons", "1 (9-ounces) package frozen artichoke hearts, thawed", "1 cup frozen peas, thawed", "1 head romaine, thinly sliced crosswise", "1/4 cup water", "1/4 cup mint leaves, coarsely chopped"]
# Your response:
# You are an expert in generating recipe instructions.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response, the recipe instructions will be generated in a later response.
# Enclose your reasoning in <reasoning> tags.
# Title: Chickpea Feta Salad over Greens
# Ingredients: ["3 tablespoons olive oil", "1/2 teaspoon grated lemon zest, plus 3 tablespoons lemon juice", "Kosher salt and freshly ground black pepper", "5 cups mixed greens (about 10 ounces)", "1 cup grape tomatoes, halved lengthwise", "One 15-ounce can chickpeas, drained", "2 kirby cucumbers, sliced into half-moons", "1 large shallot, chopped", "1/2 cup crumbled plain or herbed feta, crumbled"]
# Your response:
# You are an expert in generating recipe instructions.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response, the recipe instructions will be generated in a later response.
# Enclose your reasoning in <reasoning> tags.
# Title: Coffee-Almond Rice Pudding
# Ingredients: ["1 cup uncooked rice", "1-1/2 cups water", "1 qt. (4 cups) milk", "1/2 cup sugar", "2 Tbsp. MAXWELL HOUSE Instant Coffee", "2 Tbsp. grated orange zest Safeway 1 lb For $0.79 thru 02/09", "1/2 cup PLANTERS Slivered Almonds, toasted", "1 cup thawed COOL WHIP Whipped Topping"]
# Your response:
# You are an expert in generating recipe instructions.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response, the recipe instructions will be generated in a later response.
# Enclose your reasoning in <reasoning> tags.
# Title: Tomato, Mozzarella and Basil Salad
# Ingredients: ["2 tablespoons extra-virgin olive oil", "6 tablespoons balsamic vinegar", "2 teaspoons minced garlic", "1/2 teaspoon English dry mustard", "1/4 teaspoon sugar", "Salt, to taste", "Pepper, to taste", "2 large vine-ripened tomatoes, cut into 1/4-inch-thick slices", "1/2 pound mozzarella cheese (preferrably fresh), cut into 1/4-inch-thick slices", "10 large fresh basil leaves, sliced thin"]
# Your response:
# You are an expert in generating recipe instructions.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response, the recipe instructions will be generated in a later response.
# Enclose your reasoning in <reasoning> tags.
# Title: Jumbo Chocolate Chip Cookies
# Ingredients: ["2/3 cup shortening", "2/3 cup butter, softened", "1 cup sugar", "1 cup packed brown sugar", "2 large eggs, room temperature", "2 teaspoons vanilla extract", "3-1/2 cups all-purpose flour", "1 teaspoon baking soda", "1 teaspoon salt", "2 cups (12 ounces) semisweet chocolate chips", "1 cup chopped pecans"]
# Your response:
# You are an expert in generating recipe instructions.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response, the recipe instructions will be generated in a later response.
# Enclose your reasoning in <reasoning> tags.
# Title: Norwegian Potato Klub
# Ingredients: ["6 slices bacon", "2 cups all-purpose flour", "1/2 teaspoon baking powder", "10 medium potatoes, peeled and shredded", "2 teaspoons salt"]
# Your response:
# You are an expert in generating recipe instructions.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response, the recipe instructions will be generated in a later response.
# Enclose your reasoning in <reasoning> tags.
# Title: Dry-Aged Strip Steaks Without Drying Or Aging
# Ingredients: ["1 1/2 ounces dried porcini mushrooms", "1/2 teaspoon granulated white sugar", "1/2 teaspoon ground white pepper", "2 10-ounce boneless New York strip steaks, about 1 inch thick", "2 tablespoons soy sauce (gluten-free if that is a concern)", "3 tablespoons unsalted butter", "2 tablespoons balsamic vinegar"]
# Your response:
# You are an expert in generating recipe instructions.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response, the recipe instructions will be generated in a later response.
# Enclose your reasoning in <reasoning> tags.
# Title: Brazilian Summer Plantain Stew (Moqueca)
# Ingredients: ["4 large plantains, peeled and cut into thick slices on the diagonal", "2 limes, juice", "3 garlic cloves, finely chopped", "1 red onion, sliced", "1 long red chilli, finely chopped, seeds removed", "1 green pepper, sliced", "1 red pepper, sliced", "6 tomatoes, diced", "1.5 teaspoons sweet paprika", "150 milliliters coconut milk", "250 milliliters vegetable stock", "1 cup cilantro, roughly chopped (reserve a little for garnish)", "Large spoonful of cooked rice, for serving (optional)"]
# Your response:
# You are an expert in generating recipe instructions.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response, the recipe instructions will be generated in a later response.
# Enclose your reasoning in <reasoning> tags.
# Title: Easy Sobameshi - Yakisoba Noodles and Rice
# Ingredients: ["1 pack Steamed Chinese style or yakisoba noodles", "100 grams or (to taste) Pork", "1/2 Onion", "1/4 Carrot", "2 Green peppers", "1 bowlful Plain cooked rice", "1 dash Chopped green onion (for garnish)", "1 dash Sake", "2 handfuls Bonito flakes (fine)", "2 tbsp Japanese Worcestershire-style sauce", "2 tbsp Tonkatsu sauce (Japanese style Worcestershire sauce or steak sauce)", "1 tbsp Ketchup", "1 tbsp Vegetable oil"]
# Your response:
# You are an expert in generating recipe instructions.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response, the recipe instructions will be generated in a later response.
# Enclose your reasoning in <reasoning> tags.
# Title: Italian Turkey With Polenta
# Ingredients: ["Cooking spray", "1/2 pound ground turkey breast", "1 garlic clove, minced", "1 (15-ounce) can stewed tomatoes, undrained and chopped", "1 teaspoon dried Italian seasoning", "1/4 teaspoon ground red pepper", "1 (16-ounce) tube polenta", "1/4 cup shredded fresh Parmesan cheese"]
# Your response:
# You are an expert in generating recipe instructions.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response, the recipe instructions will be generated in a later response.
# Enclose your reasoning in <reasoning> tags.
# Title: New Year'S Brunch: Black Truffle Fettuccine Recipe
# Ingredients: ["10 ounces of dried egg fettuccine", "3/4 cup heavy cream", "3 ounces black truffle butter (D'Artagnan)", "Pinch of freshly ground nutmeg", "Salt and pepper"]
# Your response:
# You are an expert in generating recipe instructions.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response, the recipe instructions will be generated in a later response.
# Enclose your reasoning in <reasoning> tags.
# Title: Oatmeal Cookie Drops with Milk Chocolate and Almonds
# Ingredients: ["2 each chocolate bars with almonds, 7 ounces each", "3/4 cup butter or margarine, softened", "1/2 cup brown sugar, light packed", "1/2 cup sugar granulated", "3 tablespoons corn syrup, light", "2 large eggs", "1 teaspoon vanilla extract", "1/2 teaspoon almond extract", "2 1/4 cups flour, all-purpose", "1 teaspoon baking soda", "1/2 teaspoon salt", "1 1/2 cups rolled oats old-fashioned", "1/2 cup almonds toasted, chopped"]
# Your response:
# You are an expert in generating recipe instructions.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response, the recipe instructions will be generated in a later response.
# Enclose your reasoning in <reasoning> tags.
# Title: Potato Bacon Frittata Recipe
# Ingredients: ["8 ounce. bacon, diced", "2 lg. potatoes, peeled & cubed", "1/4 c. minced onion", "1/4 c. diced green pepper", "1/4 teaspoon pepper", "1 teaspoon salt, divided", "6 Large eggs", "1 c. shredded Swiss (or possibly American) cheese", "1 c. lowfat milk", "1/3 c. Bisquick", "2 tbsp. melted butter"]
# Your response:
# You are an expert in generating recipe instructions.
# Before writing the recipe instructions, first think step by step through the logic for all ingredients: what ingredients are needed, in what order tasks must be done, and how long each step takes.
# Are there any dependencies like marinating, chopping, or cooking that must be done before certain steps?
#
# Only generate the reasoning in this response, the recipe instructions will be generated in a later response.
# Enclose your reasoning in <reasoning> tags.
# Title: Whole Wheat Banana Date And Peanut Loaf
# Ingredients: ["1 1/2 cups whole wheat self-rising flour", "1 cup wheatgerm", "1/2 cup raw sugar", "1 1/2 cups pitted dates, chopped", "8 tbsp (1 stick) butter, melted", "1/4 cup milk", "2 None eggs, lightly beaten", "3 None bananas, mashed", "1/4 cup unsalted roasted peanuts"]
# Your response:

# %%
generated_dataset_cot_instructions = generated_dataset_cot_reasoning.map(
    generate_instruction_batch,
    batched=True,
    batch_size=BATCH_SIZE,
    fn_kwargs={"cot": True, "model": model, "tokenizer": tokenizer}
)
generated_dataset_cot_instructions.save_to_disk(f'{recipe_nlg_data_path}/oob_cot_generated')
# Out:
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
# Write recipe instructions for the following recipe title and ingredient list.
#     Use the provided reasoning to inform your response.
#     Enclose your recipe instructions in <instructions> tags and number each step.
#     Recipe Title: Orange Cookies Iii
#     Ingredients: ["1 cup shortening", "2 cups white sugar", "2 eggs", "1 cup buttermilk", "1/2 cup orange juice", "2 tablespoons orange zest", "4 1/2 cups all-purpose flour", "2 teaspoons baking powder", "1 teaspoon salt", "1/2 teaspoon baking soda", "1/4 cup butter", "4 cups confectioners' sugar", "3 tablespoons thawed orange juice concentrate"]
#     Reasoning: Your response:
# <reasoning>
# First, we gather all the necessary ingredients to make the cookies. We have 1 cup of shortening, 2 cups of white sugar, 2 eggs, 1 cup of buttermilk, 1/2 cup of orange juice, 2 tablespoons of orange zest, 4 1/2 cups of all-purpose flour, 2 teaspoons of baking powder, 1 teaspoon of salt, 1/2 teaspoon of baking soda, 1/4 cup of butter, 4 cups of confectioners' sugar, and 3 tablespoons of thawed orange juice concentrate.
#
# Next, we preheat our oven to 350 degrees F (175 degrees C) and line baking sheets with parchment paper. This step ensures that our cookies will bake evenly and not stick to the sheets.
#
# Then, we cream together the shortening and sugar in a large mixing bowl until light and fluffy. This step is important as it incorporates air into the mixture which helps create a tender cookie texture.
#
# Afterwards, we beat in the eggs, one at a time, making sure to fully incorporate each egg before adding the next.
#
# We then mix in the buttermilk, orange juice, orange zest, flour, baking powder, salt, and baking soda alternately into the butter mixture. Starting and ending with the flour mixture, we add the dry ingredients in three parts and the wet ingredients in two parts, ensuring that everything is mixed well after each addition.
#
# Once the dough is ready, we drop by rounded tablespoons onto the prepared baking sheets. This step is crucial as it determines the size and shape of our cookies.
#
# After placing the dough on the baking sheet, we bake the cookies at 350 degrees F (175 degrees C) for 12 to 15 minutes or until lightly browned. Baking time can vary depending on your oven and the size of the cookies, so it is important to keep an eye on them while they bake.
#
# Once the cookies are done, we remove them from the oven and allow them to cool completely on wire racks before frosting. Frosting warm cookies may result in the frosting melting and becoming less stable.
#
# Finally, in a medium saucepan over low heat, melt the butter and
#     Your response:
# Write recipe instructions for the following recipe title and ingredient list.
#     Use the provided reasoning to inform your response.
#     Enclose your recipe instructions in <instructions> tags and number each step.
#     Recipe Title: Creamy Roasted Garlic And Almond Soup
#     Ingredients: ["3 garlic bulbs", "1 onion chopped", "4 tablespoons olive oil", "creme fraiche 30 cl.", "4 1/4 cups chicken stock", "10 cups sourdough bread", "2 tablespoons white vinegar", "1 3/8 cups almonds peeled", "salt", "pepper", "water 25 cl.", "3 oranges peeled and sectioned", "cilantro", "mint"]
#     Reasoning: Firstly, preheat the oven to 400 degrees Fahrenheit.
# Then, slice off the top of each garlic bulb to expose the cloves, drizzle with olive oil and wrap tightly in aluminum foil. Set aside.
# Next, in a large pot, heat the remaining olive oil over medium-high heat. Add the chopped onion and cook until softened, about 5 minutes.
# Once the garlic is roasted, remove from the oven and let cool slightly. Then, squeeze out the garlic cloves and add them to the pot with the onion.
# Add the chicken stock to the pot and bring to a boil.
# While the soup is heating, cube the bread and set aside.
# Once the soup has reached a boil, add the cubed bread, crème fraîche, vinegar, salt, and pepper. Reduce heat to low and simmer for 30 minutes.
# While the soup is simmering, toast the almonds in a dry skillet over medium heat until golden brown, about 5 minutes. Let cool, then chop finely.
# Remove the soup from the heat and use an immersion blender to puree until smooth. If the soup is too thick, add water until desired consistency is achieved.
# To serve, ladle the soup into bowls and top with the chopped almonds, orange sections, and a sprinkle of chopped mint and cilantro. Season with additional salt and pepper if desired.
#     Your response:
# Write recipe instructions for the following recipe title and ingredient list.
#     Use the provided reasoning to inform your response.
#     Enclose your recipe instructions in <instructions> tags and number each step.
#     Recipe Title: Skillet Pasta Florentine
#     Ingredients: ["3 cups uncooked spiral pasta", "1 large egg, lightly beaten", "2 cups 2% cottage cheese", "1-1/2 cups reduced-fat ricotta cheese", "1 package (10 ounces) frozen chopped spinach, thawed and squeezed dry", "1 cup shredded part-skim mozzarella cheese, divided", "1 teaspoon each dried parsley flakes, oregano and basil", "1 jar (14 ounces) meatless spaghetti sauce", "2 tablespoons grated Parmesan cheese"]
#     Reasoning: Firstly, we need to cook the pasta according to package directions until al dente. This should take about 8 minutes.
# Once the pasta is cooked, drain it and set aside.
# Next, heat a nonstick skillet over medium heat. Add the meatless spaghetti sauce and bring it to a simmer. Let it simmer for about 5 minutes, stirring occasionally.
# While the sauce is simmering, prepare the spinach mixture. In a bowl, combine the cottage cheese, ricotta cheese, egg, spinach, 3/4 cup of the mozzarella cheese, and the dried herbs. Mix well.
# Add the cooked pasta to the skillet with the sauce and toss to coat the pasta evenly. Then, add the spinach mixture to the skillet and continue tossing until everything is combined.
# Sprinkle the remaining 1/4 cup of mozzarella cheese and the Parmesan cheese over the top of the pasta mixture.
# Now, reduce heat to low and cover the skillet. Allow it to cook for another 5 minutes, or until the cheeses have melted and the pasta is heated through.
#     Your response:
# Write recipe instructions for the following recipe title and ingredient list.
#     Use the provided reasoning to inform your response.
#     Enclose your recipe instructions in <instructions> tags and number each step.
#     Recipe Title: Roasted Pacific Cod With Spring Vegetables And Mint
#     Ingredients: ["4 (6-ounces) pieces skinless Pacific cod or hake fillet (1 inch thick)", "4 tablespoons extra-virgin olive oil, divided, plus additional for drizzling", "1 bunch scallions, cut into 1-inch pieces", "1/2 pound zucchini (about 2 medium), cut into 1/2-inch-thick half-moons", "1 (9-ounces) package frozen artichoke hearts, thawed", "1 cup frozen peas, thawed", "1 head romaine, thinly sliced crosswise", "1/4 cup water", "1/4 cup mint leaves, coarsely chopped"]
#     Reasoning: First, gather all the ingredients required for the recipe:
# - 4 (6-ounces) pieces of skinless Pacific cod or hake fillet (1 inch thick)
# - 4 tablespoons extra-virgin olive oil, divided
# - 1 bunch scallions, cut into 1-inch pieces
# - 1/2 pound zucchini (about 2 medium), cut into 1/2-inch-thick half-moons
# - 1 (9-ounces) package frozen artichoke hearts, thawed
# - 1 cup frozen peas, thawed
# - 1 head romaine, thinly sliced crosswise
# - 1/4 cup water
# - 1/4 cup mint leaves, coarsely chopped
# Next, preheat the oven to 400°F. Place the fish on a baking sheet and brush with 2 tablespoons of olive oil. Season with salt and pepper and roast for about 8 minutes until cooked through.
# While the fish is cooking, heat the remaining 2 tablespoons of olive oil over medium heat in a large frying pan. Add the scallions and cook until softened, about 3 minutes. Then add the zucchini and cook for another 5 minutes until it's tender but still holds its shape. Add the artichoke hearts, peas, and 1/4 cup of water to the pan, and cook for another minute. Remove from heat and set aside.
# Finally, arrange the sliced romaine on plates and spoon the vegetable mixture over top. Top each plate with a piece of roasted fish and sprinkle with chopped mint leaves. Drizzle with additional olive oil if desired.
#     Your response:
# Write recipe instructions for the following recipe title and ingredient list.
#     Use the provided reasoning to inform your response.
#     Enclose your recipe instructions in <instructions> tags and number each step.
#     Recipe Title: Chickpea Feta Salad over Greens
#     Ingredients: ["3 tablespoons olive oil", "1/2 teaspoon grated lemon zest, plus 3 tablespoons lemon juice", "Kosher salt and freshly ground black pepper", "5 cups mixed greens (about 10 ounces)", "1 cup grape tomatoes, halved lengthwise", "One 15-ounce can chickpeas, drained", "2 kirby cucumbers, sliced into half-moons", "1 large shallot, chopped", "1/2 cup crumbled plain or herbed feta, crumbled"]
#     Reasoning: First, you need to gather all the necessary ingredients: 3 tablespoons of olive oil, ½ teaspoon of grated lemon zest, 3 tablespoons of lemon juice, 5 cups of mixed greens (about 10 ounces), 1 cup of grape tomatoes, halved lengthwise, one 15-ounce can of chickpeas, drained, 2 kirby cucumbers, sliced into half-moons, and ½ cup of crumbled plain or herbed feta.
#
# Next, you'll want to prepare the dressing. In a small bowl, mix together the olive oil, grated lemon zest, lemon juice, and a pinch of kosher salt and freshly ground black pepper to taste. This can be done ahead of time if desired, but should be made fresh for best flavor.
#
# Then, on a serving platter or individual plates, arrange the mixed greens as the base. Scatter the grape tomatoes over the top of the greens.
#
# Afterward, prepare the chickpea mixture. In a medium bowl, combine the drained chickpeas, sliced kirby cucumbers, and chopped shallot. Add about two tablespoons of the prepared dressing to the chickpea mixture and toss until well coated. The chickpea mixture can also be prepared ahead of time.
#
# Finally, spoon the chickpea mixture over the greens and tomatoes on the plate or platter, sprinkle crumbled feta cheese over the top, and serve immediately.
#     Your response:
# Write recipe instructions for the following recipe title and ingredient list.
#     Use the provided reasoning to inform your response.
#     Enclose your recipe instructions in <instructions> tags and number each step.
#     Recipe Title: Coffee-Almond Rice Pudding
#     Ingredients: ["1 cup uncooked rice", "1-1/2 cups water", "1 qt. (4 cups) milk", "1/2 cup sugar", "2 Tbsp. MAXWELL HOUSE Instant Coffee", "2 Tbsp. grated orange zest Safeway 1 lb For $0.79 thru 02/09", "1/2 cup PLANTERS Slivered Almonds, toasted", "1 cup thawed COOL WHIP Whipped Topping"]
#     Reasoning: First, we need to cook the rice with water. While the rice is cooking, we can prepare the milk mixture by heating it up on the stove top. Once the rice is cooked, we can mix in the sugar and then add the instant coffee granules. The mixture should be stirred until the coffee has dissolved. Next, we can add in the grated orange zest and stir again. The toasted almonds can then be mixed into the rice mixture. Finally, the cool whip whipped topping can be folded into the rice mixture until well combined.
#     Your response:
# Write recipe instructions for the following recipe title and ingredient list.
#     Use the provided reasoning to inform your response.
#     Enclose your recipe instructions in <instructions> tags and number each step.
#     Recipe Title: Tomato, Mozzarella and Basil Salad
#     Ingredients: ["2 tablespoons extra-virgin olive oil", "6 tablespoons balsamic vinegar", "2 teaspoons minced garlic", "1/2 teaspoon English dry mustard", "1/4 teaspoon sugar", "Salt, to taste", "Pepper, to taste", "2 large vine-ripened tomatoes, cut into 1/4-inch-thick slices", "1/2 pound mozzarella cheese (preferrably fresh), cut into 1/4-inch-thick slices", "10 large fresh basil leaves, sliced thin"]
#     Reasoning: Step 1: Combine the dressing ingredients: In a small bowl, whisk together 2 tablespoons of extra-virgin olive oil, 6 tablespoons of balsamic vinegar, 2 teaspoons of minced garlic, 1/2 teaspoon of English dry mustard, 1/4 teaspoon of sugar, salt to taste, and pepper to taste. This can be done ahead of time and stored at room temperature until ready to use. The time it takes for this step is approximately 5 minutes.
# Step 2: Prepare the vegetables: Cut 2 large vine-ripened tomatoes into 1/4-inch-thick slices and set aside. Cut 1/2 pound of mozzarella cheese (preferably fresh) into 1/4-inch-thick slices and set aside. Slice 10 large fresh basil leaves thinly and set aside. This step should take around 5 minutes.
# Step 3: Assemble the salad: On a platter or individual plates, arrange the tomato and mozzarella slices alternately. Drizzle the dressing over the salad. Sprinkle the sliced basil leaves over the top. This step should take about 3 minutes.
#     Your response:
# Write recipe instructions for the following recipe title and ingredient list.
#     Use the provided reasoning to inform your response.
#     Enclose your recipe instructions in <instructions> tags and number each step.
#     Recipe Title: Jumbo Chocolate Chip Cookies
#     Ingredients: ["2/3 cup shortening", "2/3 cup butter, softened", "1 cup sugar", "1 cup packed brown sugar", "2 large eggs, room temperature", "2 teaspoons vanilla extract", "3-1/2 cups all-purpose flour", "1 teaspoon baking soda", "1 teaspoon salt", "2 cups (12 ounces) semisweet chocolate chips", "1 cup chopped pecans"]
#     Reasoning: The first step is to preheat the oven to 375°. This needs to be done before anything else can be done as it sets the temperature for baking the cookies.
# Next, cream together the shortening and butter with the sugars until light and fluffy. This needs to be done before adding the other wet ingredients so they get evenly distributed.
# Then add the eggs one at a time, beating well after each addition. This ensures that the eggs are fully incorporated into the batter.
# After that, stir in the vanilla extract. This step doesn't take much time but it adds flavor to the dough.
# Now combine the dry ingredients - flour, baking soda, and salt. Mix them together before adding them to the wet ingredients. Make sure to mix them well to ensure even distribution of the leavening agents.
# Once the dry ingredients are mixed, gradually add the dry mixture to the creamed mixture and mix until just combined. Do not overmix or the cookies will become tough.
# Then fold in the chocolate chips and pecans. This step ensures that the chocolate chips and pecans are evenly distributed throughout the cookie dough.
# Using an ice cream scoop, drop rounded tablespoons of dough onto ungreased baking sheets. Space them about 2 inches apart as they will spread while baking.
# Bake at 375° for 8-10 minutes or until golden brown. Remember to keep an eye on them so they don't burn.
# Let cool on wire racks. This allows the cookies to cool down and firm up before handling.
#     Your response:
# Write recipe instructions for the following recipe title and ingredient list.
#     Use the provided reasoning to inform your response.
#     Enclose your recipe instructions in <instructions> tags and number each step.
#     Recipe Title: Norwegian Potato Klub
#     Ingredients: ["6 slices bacon", "2 cups all-purpose flour", "1/2 teaspoon baking powder", "10 medium potatoes, peeled and shredded", "2 teaspoons salt"]
#     Reasoning: First, you will need to cook the bacon until crispy. This can take around 15 minutes. Once the bacon is cooked, set it aside on a paper towel-lined plate to drain excess oil.
# While the bacon is cooking, you can prepare the dough. In a bowl, mix together the flour, baking powder, and 1 teaspoon of salt. Then, gradually add water to the mixture while stirring until a soft dough forms. This typically takes around 3-4 minutes.
# Next, you can start boiling the potatoes. This can take around 15-20 minutes depending on the size of the potatoes. Once they are tender enough, drain them thoroughly using a colander.
# Now, you can crumble the cooked bacon and add it to the potato mixture. Mix well so that the bacon is evenly distributed throughout the potatoes. Taste and adjust seasoning if necessary with the remaining 1 teaspoon of salt.
# Finally, roll out the dough into 6 equal portions and shape them into round disks. Place about 2 tablespoons of the potato and bacon mixture onto the center of each disk. Fold the dough over the filling and press the edges to seal the edges tightly. Make sure there are no gaps where the filling could leak out during cooking.
# The filled dumplings are now ready for frying or boiling. To fry, heat oil in a pan over medium-high heat and fry the dumplings until golden brown on both sides. To boil, bring a large pot of salted water to a boil and gently drop the dumplings into the water. Cook until they float to the surface, then cook for 2 more minutes. Serve warm with sour cream or applesauce on the side.
#     Your response:
# Write recipe instructions for the following recipe title and ingredient list.
#     Use the provided reasoning to inform your response.
#     Enclose your recipe instructions in <instructions> tags and number each step.
#     Recipe Title: Dry-Aged Strip Steaks Without Drying Or Aging
#     Ingredients: ["1 1/2 ounces dried porcini mushrooms", "1/2 teaspoon granulated white sugar", "1/2 teaspoon ground white pepper", "2 10-ounce boneless New York strip steaks, about 1 inch thick", "2 tablespoons soy sauce (gluten-free if that is a concern)", "3 tablespoons unsalted butter", "2 tablespoons balsamic vinegar"]
#     Reasoning: The first step would be to rehydrate the dried porcini mushrooms. This can be done by placing them in a bowl and pouring boiling water over them until they are covered. Letting them sit for at least 20 minutes will allow the mushrooms to soften and absorb the liquid.
# After the mushrooms have been rehydrated, they should be strained and reserving the soaking liquid for use later in the recipe. The mushrooms can then be chopped finely.
# Next, create a marinade by combining the chopped mushrooms, soy sauce, balsamic vinegar, sugar, and white pepper in a small mixing bowl. Mix well to combine all ingredients.
# Now, season both sides of the steaks with salt and place them in a shallow dish or resealable plastic bag. Pour the marinade over the steaks, making sure they are fully coated. If using a plastic bag, seal it tightly and refrigerate for at least 4 hours, or up to 12 hours. If using a shallow dish, cover the dish with plastic wrap and refrigerate for at least 4 hours, or up to 12 hours.
# Once the steaks have finished marinating, preheat the oven to 450°F. Heat a cast iron skillet or griddle on high heat. When the skillet is hot, add the butter and let it melt. Cook the steaks in the skillet for about 2-3 minutes per side, until browned on the outside but still slightly pink in the center. Then transfer the skillet to the preheated oven and cook the steaks for another 3-4 minutes for medium-rare, or longer if desired.
# Remove the skillet from the oven and let the steaks rest for about 5 minutes before slicing and serving. Use the reserved soaking liquid as a sauce, if desired.
#     Your response:
# Write recipe instructions for the following recipe title and ingredient list.
#     Use the provided reasoning to inform your response.
#     Enclose your recipe instructions in <instructions> tags and number each step.
#     Recipe Title: Brazilian Summer Plantain Stew (Moqueca)
#     Ingredients: ["4 large plantains, peeled and cut into thick slices on the diagonal", "2 limes, juice", "3 garlic cloves, finely chopped", "1 red onion, sliced", "1 long red chilli, finely chopped, seeds removed", "1 green pepper, sliced", "1 red pepper, sliced", "6 tomatoes, diced", "1.5 teaspoons sweet paprika", "150 milliliters coconut milk", "250 milliliters vegetable stock", "1 cup cilantro, roughly chopped (reserve a little for garnish)", "Large spoonful of cooked rice, for serving (optional)"]
#     Reasoning: Firstly, you'll need to gather all your ingredients, including 4 large plantains, 2 limes, 3 garlic cloves, 1 red onion, 1 long red chilli, 1 green pepper, 1 red pepper, 6 tomatoes, 1.5 teaspoons sweet paprika, 150 milliliters coconut milk, 250 milliliters vegetable stock, and 1 cup cilantro. Once everything is prepared, start by peeling and cutting the plantains into thick slices on the diagonal. Next, juice the limes and set aside. Then, move on to the garlic, red onion, red chilli, green pepper, and red pepper. Finely chop the garlic, slice the red onion, and remove the seeds from the red chilli while finely chopping it. Slice the green pepper and red pepper. Now it's time to dice the tomatoes. Afterward, cook the rice according to package directions. In a separate pot, heat the vegetable stock and coconut milk together. When all these preparations are complete, it's time to combine the ingredients in a pan and simmer until the stew reaches your desired thickness. Finally, add the reserved cilantro for garnish and serve with the cooked rice.
#     Your response:
# Write recipe instructions for the following recipe title and ingredient list.
#     Use the provided reasoning to inform your response.
#     Enclose your recipe instructions in <instructions> tags and number each step.
#     Recipe Title: Easy Sobameshi - Yakisoba Noodles and Rice
#     Ingredients: ["1 pack Steamed Chinese style or yakisoba noodles", "100 grams or (to taste) Pork", "1/2 Onion", "1/4 Carrot", "2 Green peppers", "1 bowlful Plain cooked rice", "1 dash Chopped green onion (for garnish)", "1 dash Sake", "2 handfuls Bonito flakes (fine)", "2 tbsp Japanese Worcestershire-style sauce", "2 tbsp Tonkatsu sauce (Japanese style Worcestershire sauce or steak sauce)", "1 tbsp Ketchup", "1 tbsp Vegetable oil"]
#     Reasoning: Your response: <reasoning>
# First, gather all the ingredients: one pack of steamed Chinese style or yakisoba noodles, 100 grams or to taste pork, half an onion, 1/4 carrot, 2 green peppers, plain cooked rice, chopped green onion for garnish, sake, bonito flakes, Japanese Worcestershire-style sauce, tonkatsu sauce, ketchup, and vegetable oil.
#
# Next, prepare the ingredients by slicing the pork, dicing the onion, shredding the carrot, and slicing the green peppers. These steps can take approximately 5-10 minutes depending on your knife skills.
#
# Afterwards, heat up the pan with the vegetable oil and cook the pork until it is slightly browned. This process should take about 3-5 minutes.
#
# Once the pork is slightly browned, add the onions into the pan and cook them until they become translucent. This step usually takes around 3-5 minutes as well.
#
# Then, add in the shredded carrots and continue cooking for another 2 minutes.
#
# Subsequently, incorporate the green peppers and cook for another 2 minutes.
#
# Now, add the cooked rice into the pan and mix everything together, making sure that the vegetables and meat are evenly distributed throughout the mixture. Cook for about 2-3 minutes.
#
# Following that, pour in the sauces - Japanese Worcestershire-style sauce, tonkatsu sauce, and ketchup - as well as the sake. Mix the contents of the pan well so that the flavors are incorporated.
#
# Finally, introduce the steamed Chinese style or yakisoba noodles into the pan, breaking them apart with your spatula to ensure that they're evenly coated in the sauce and mixed with the other ingredients. Continue cooking for another 1-2 minutes.
#
# Serve hot and top with bonito flakes and chopped green onion for garnish.
#
# The entire process should take approximately 20-30 minutes, depending on the time taken for cooking each ingredient. The noodles need to be heated through, but they do not require extensive cooking as they have been pre-cooked and only need
#     Your response:
# Write recipe instructions for the following recipe title and ingredient list.
#     Use the provided reasoning to inform your response.
#     Enclose your recipe instructions in <instructions> tags and number each step.
#     Recipe Title: Italian Turkey With Polenta
#     Ingredients: ["Cooking spray", "1/2 pound ground turkey breast", "1 garlic clove, minced", "1 (15-ounce) can stewed tomatoes, undrained and chopped", "1 teaspoon dried Italian seasoning", "1/4 teaspoon ground red pepper", "1 (16-ounce) tube polenta", "1/4 cup shredded fresh Parmesan cheese"]
#     Reasoning: First, preheat the oven to 375°F. Next, prepare the turkey mixture by spraying a skillet with cooking spray and heating it over medium heat. Add the ground turkey breast and cook until browned, breaking it apart as it cooks. When the turkey is cooked, add the minced garlic, stewed tomatoes, Italian seasoning, and ground red pepper to the skillet and stir to combine. Let it simmer for about 10 minutes, until the sauce thickens. While the sauce is simmering, slice the polenta into 1/2 inch rounds. Microwave the polenta slices on high for about 2 minutes until heated through. Spray a baking sheet with cooking spray and place the polenta slices on it. Bake in the preheated oven for about 15 minutes until crispy. Finally, top the polenta slices with the turkey mixture and sprinkle with shredded Parmesan cheese. Serve hot.
#     Your response:
# Write recipe instructions for the following recipe title and ingredient list.
#     Use the provided reasoning to inform your response.
#     Enclose your recipe instructions in <instructions> tags and number each step.
#     Recipe Title: New Year'S Brunch: Black Truffle Fettuccine Recipe
#     Ingredients: ["10 ounces of dried egg fettuccine", "3/4 cup heavy cream", "3 ounces black truffle butter (D'Artagnan)", "Pinch of freshly ground nutmeg", "Salt and pepper"]
#     Reasoning: - First, bring a large pot of salted water to a boil.
# - Add the dried egg fettuccine to the boiling water and cook according to package directions until al dente.
# - While the pasta is cooking, heat the heavy cream in a small saucepan over medium heat until it begins to simmer.
# - Remove the saucepan from heat and whisk in the black truffle butter until melted and combined.
# - Add a pinch of freshly ground nutmeg and season with salt and pepper to taste.
# - Drain the cooked pasta and add it to the creamy truffle sauce. Toss to coat the pasta evenly.
# - Serve immediately, garnished with additional shaved black truffles if desired.
#     Your response:
# Write recipe instructions for the following recipe title and ingredient list.
#     Use the provided reasoning to inform your response.
#     Enclose your recipe instructions in <instructions> tags and number each step.
#     Recipe Title: Oatmeal Cookie Drops with Milk Chocolate and Almonds
#     Ingredients: ["2 each chocolate bars with almonds, 7 ounces each", "3/4 cup butter or margarine, softened", "1/2 cup brown sugar, light packed", "1/2 cup sugar granulated", "3 tablespoons corn syrup, light", "2 large eggs", "1 teaspoon vanilla extract", "1/2 teaspoon almond extract", "2 1/4 cups flour, all-purpose", "1 teaspoon baking soda", "1/2 teaspoon salt", "1 1/2 cups rolled oats old-fashioned", "1/2 cup almonds toasted, chopped"]
#     Reasoning: To start with, we need to gather all the necessary ingredients. We'll need two chocolate bars with almonds, weighing 7 ounces each, butter or margarine, softened, brown sugar (light packed), granulated sugar, corn syrup (light), two large eggs, vanilla extract, almond extract, all-purpose flour, baking soda, salt, old-fashioned rolled oats, and toasted almonds (chopped).
#
# Next, we'll want to preheat the oven to 350 degrees Fahrenheit, so that it's ready when we get to the baking stage.
#
# Once all the ingredients are together, we can begin mixing the wet ingredients together. This includes creaming the butter or margarine, adding the brown sugar, granulated sugar, and corn syrup, then beating in the eggs one at a time until they are well mixed. Following that, we can add the vanilla extract and almond extract.
#
# While the wet ingredients are being mixed, we can also prepare the dry ingredients. In a separate bowl, mix together the all-purpose flour, baking soda, and salt.
#
# Now comes the part where we combine the wet and dry ingredients. We'll gradually add the dry ingredients to the wet ingredients and mix them together until they form a dough. Then, we can fold in the rolled oats.
#
# After the dough is prepared, we can chop up the chocolate bars with almonds into small pieces and fold them into the dough as well.
#
# Finally, we can shape the dough into cookie drop shapes using our hands or a cookie scoop, place them onto a greased baking sheet, and bake for approximately 10-12 minutes or until lightly golden brown. Once baked, we can let them cool on the baking sheet for a few minutes before transferring them to a wire rack to cool completely.
#
# We'll want to make sure we have toasted and chopped the almonds beforehand, as they're added last to the dough. Also, the cookie dough needs to be chilled for at least 30 minutes before baking, so we should plan accordingly.
#     Your response:
# Write recipe instructions for the following recipe title and ingredient list.
#     Use the provided reasoning to inform your response.
#     Enclose your recipe instructions in <instructions> tags and number each step.
#     Recipe Title: Potato Bacon Frittata Recipe
#     Ingredients: ["8 ounce. bacon, diced", "2 lg. potatoes, peeled & cubed", "1/4 c. minced onion", "1/4 c. diced green pepper", "1/4 teaspoon pepper", "1 teaspoon salt, divided", "6 Large eggs", "1 c. shredded Swiss (or possibly American) cheese", "1 c. lowfat milk", "1/3 c. Bisquick", "2 tbsp. melted butter"]
#     Reasoning: First, preheat the oven to 350 degrees F. Next, cook the diced bacon in a large non-stick skillet over medium heat until browned and crispy. Use a slotted spoon to remove the cooked bacon and set it aside on a paper towel-lined plate to drain.
# Then, in the same skillet, combine the cubed potatoes with 1/2 teaspoon of salt and cook them over medium-high heat for about 10 minutes or until they are tender enough to pierce easily with a fork. After the potatoes have finished cooking, add the minced onion and diced green pepper to the skillet and continue cooking for another 3-4 minutes until the vegetables are softened. Add the cooked bacon back to the skillet and mix everything together. Turn off the heat and let the mixture cool for a few minutes.
# While the potato mixture is cooling, in a separate bowl whisk together the eggs, 1/2 teaspoon of salt, milk, and Bisquick until well combined. Then, stir in the shredded cheese.
# Pour the egg mixture over the potato mixture in the skillet, gently mixing everything together. Then pour the mixture into a lightly greased 9-inch round baking dish. Drizzle the melted butter over the top of the mixture.
# Bake the frittata in the preheated oven for 30-35 minutes or until the center is set and the top is golden brown. Let the frittata cool for a few minutes before serving.
#     Your response:
# Write recipe instructions for the following recipe title and ingredient list.
#     Use the provided reasoning to inform your response.
#     Enclose your recipe instructions in <instructions> tags and number each step.
#     Recipe Title: Whole Wheat Banana Date And Peanut Loaf
#     Ingredients: ["1 1/2 cups whole wheat self-rising flour", "1 cup wheatgerm", "1/2 cup raw sugar", "1 1/2 cups pitted dates, chopped", "8 tbsp (1 stick) butter, melted", "1/4 cup milk", "2 None eggs, lightly beaten", "3 None bananas, mashed", "1/4 cup unsalted roasted peanuts"]
#     Reasoning: First, preheat oven to 350°F and prepare a loaf pan with non-stick spray. In a large mixing bowl, combine the self-rising whole wheat flour and wheatgerm. In a separate bowl, mix together the melted butter and raw sugar until well combined. Then add the lightly beaten eggs to the butter and sugar mixture and mix again. Next, take the mashed bananas and mix them into the wet ingredients until fully incorporated. Add the chopped dates and roasted peanuts into the dry ingredient mixture and stir. Finally, pour the wet ingredients into the dry and mix thoroughly, adding milk as needed to make a smooth consistency. Once mixed, pour the batter into the prepared loaf pan, filling it about three-quarters full. Bake in the preheated oven for approximately one hour, or until a toothpick inserted into the center of the bread comes out clean. Allow the loaf to cool completely before slicing and serving.
#     Your response:
# Write recipe instructions for the following recipe title and ingredient list.
#     Use the provided reasoning to inform your response.
#     Enclose your recipe instructions in <instructions> tags and number each step.
#     Recipe Title: Turkey Meat Balls
#     Ingredients: ["1 pound Ground Turkey", "1 whole Egg", "1 Tablespoon Lipton Onion Soup Mix", "1/4 teaspoons Garlic Powder", "1/4 teaspoons Ground Black Pepper", "1/4 teaspoons Salt", "3 Tablespoons Parmesan Cheese", "12 pieces Ritz Crackers", "3 Tablespoons Tomato Sauce", "3 Tablespoons Bread Crumbs", "2 Tablespoons Olive Oil"]
#     Reasoning: To begin making turkey meatballs, start by preheating the oven to 350 degrees Fahrenheit. This will ensure that the meatballs cook evenly and thoroughly. While the oven is preheating, combine the ground turkey with the egg in a large mixing bowl. The egg acts as a binder for the meat, which is crucial for the meatballs' shape and structure.
# Once the turkey and egg mixture is well combined, add the Lipton onion soup mix, garlic powder, black pepper, and salt. These seasonings will add flavor to the meatballs. After mixing the seasonings into the turkey mixture, add the parmesan cheese and crumble the Ritz crackers into the mixture. The crackers add texture and help the meatballs hold their shape during cooking.
# Next, roll the turkey mixture into small, round balls and place them on a baking sheet lined with parchment paper. Make sure to space them apart so they don't touch while baking. In a small bowl, combine the tomato sauce and breadcrumbs to create a sauce for the meatballs. Brush the mixture over the meatballs with a pastry brush or spoon.
# Finally, drizzle the olive oil over the top of the meatballs. This will help them brown and crisp up during baking. Place the baking sheet in the preheated oven and bake for about 20-25 minutes until the meatballs are cooked through and golden brown. Serve hot and enjoy!
#     Your response:
# Write recipe instructions for the following recipe title and ingredient list.
#     Use the provided reasoning to inform your response.
#     Enclose your recipe instructions in <instructions> tags and number each step.
#     Recipe Title: Maple Leaf Sazerac From Minetta Tavern
#     Ingredients: ["1 3/4 oz. Rittenhouse rye whiskey", "1/2 oz. Demerara", "1/4 oz. Sortilege maple liqueur", "3 dashes Peychaud's Bitters", "2 dashes Angostura bitters", "1 oz. Absinthe, used as rinse"]
#     Reasoning: Firstly, gather all of the required ingredients - Rittenhouse rye whiskey, Demerara, Sortilege maple liqueur, Peychaud's Bitters, Angostura Bitters, and Absinthe. Start by rinsing a chilled glass with the Absinthe, swirling it around to coat the inside of the glass and then discarding the excess liquid. In a separate mixing glass or shaker filled with ice, combine the Rittenhouse rye whiskey, Demerara, Sortilege maple liqueur, Peychaud's Bitters, and Angostura Bitters. Stir well to ensure even distribution of the flavors. Once well-mixed, strain the liquid from the mixing glass or shaker into the Absinthe-rinsed glass over ice. Garnish with a lemon twist, if desired, and enjoy!
#     Your response:
# Write recipe instructions for the following recipe title and ingredient list.
#     Use the provided reasoning to inform your response.
#     Enclose your recipe instructions in <instructions> tags and number each step.
#     Recipe Title: Strawberries with Cassis
#     Ingredients: ["6 1-pint baskets strawberries, hulled and halved or quartered (depending on size of berries)", "1 1/4 cups creme de cassis liqueur", "1/3 cup sugar", "2 tablespoons fresh lemon juice", "3 cups chilled whipping cream", "3 tablespoons powdered sugar"]
#     Reasoning: Firstly, we need to gather all the required ingredients which include 6 pints of strawberries, creme de cassis liqueur, sugar, fresh lemon juice, whipping cream, and powdered sugar. We begin by hulling and halving or quartering the strawberries depending on their size. This step is important as it ensures even coating and distribution of the other ingredients. Secondly, we prepare the syrup by mixing together sugar and water in a saucepan over medium heat until the sugar dissolves. Afterwards, we remove the pan from heat and stir in the creme de cassis and fresh lemon juice. The mixture is then left to cool. In parallel, we whip the cream and powdered sugar together until stiff peaks form. This step should be done just before serving so that the whipped cream remains fresh. Finally, we mix the strawberries with the cooled syrup and serve them in individual dishes, topped with a dollop of the whipped cream.
#     Your response:
# Write recipe instructions for the following recipe title and ingredient list.
#     Use the provided reasoning to inform your response.
#     Enclose your recipe instructions in <instructions> tags and number each step.
#     Recipe Title: PHILADELPHIA Chocolate Cheesecakes for Two
#     Ingredients: ["60 g Philadelphia Brick Cream Cheese, softened", "1 oz. Baker's Semi-Sweet Chocolate, melted", "1 Tbsp. sugar", "1/2 cup thawed Cool Whip Whipped Topping", "2 Oreo Cookies"]
#     Reasoning: We will need to make sure that all of our ingredients are ready before we start making the cheesecake. We'll start by preparing the cream cheese by softening it. This can take around 30 minutes if left at room temperature. While waiting for the cream cheese to soften, we should prepare the chocolate by melting it over low heat on the stove top or using a microwave until smooth. It may take around 5 minutes to melt the chocolate. After the chocolate is melted, we can then prepare the sugar by measuring out 1 tablespoon of sugar and setting it aside. Next, we can get our Cool Whip Whipped Topping and allow it to thaw in the refrigerator for about 2-3 hours or until soft. Finally, we can crush two Oreo cookies into small crumbs which can be done quickly in a food processor or by placing them in a plastic bag and using a rolling pin to crush them.
#     Your response:
# Write recipe instructions for the following recipe title and ingredient list.
#     Use the provided reasoning to inform your response.
#     Enclose your recipe instructions in <instructions> tags and number each step.
#     Recipe Title: Hot & Sour Soup
#     Ingredients: ["3 inches Ginger (thinly shredded)", "2 Carrot (shredded)", "1 Chicken Breast", "1 bunch Coriander", "1 bunch Shitake Mushroom (thinly shredded)", "2 egg (beaten)", "1 tsp chili powder", "1 liter boiling water", "1 tsp sesame oil", "1 vinegar", "1 soya sauce", "1 red chili (optional)"]
#     Reasoning: Firstly, we need to prepare all the ingredients. This means we need to thinly shred the ginger, carrots and shitake mushrooms. We also need to chop up the chicken breast into small pieces, beat two eggs, and finely chop the coriander leaves. If desired, we can also chop up one red chili.
# Next, we need to have a pot ready with 1 liter of boiling water. Once the water is boiling, we add in the shredded ginger, carrots, shitake mushrooms, and the chicken breast pieces. Let it cook for about 5-10 minutes until the chicken is cooked through.
# Then, we add in the beaten eggs and let them cook for another minute or until they’re set. After that, we turn off the heat and add in the soy sauce, vinegar, chili powder and sesame oil. We stir everything together to ensure that the flavors mix well.
# Finally, we garnish the soup with the chopped coriander leaves. The soup is now ready to serve!
#     Your response:
# Write recipe instructions for the following recipe title and ingredient list.
#     Use the provided reasoning to inform your response.
#     Enclose your recipe instructions in <instructions> tags and number each step.
#     Recipe Title: Delicious Kabocha Squash and Spinach Soup
#     Ingredients: ["1/4 Kabocha squash", "1/2 bunch Spinach", "200 ml Milk", "2 tbsp Hot water", "1 Consomme soup stock cube", "1 heaped teaspoon) (if using consomme granules"]
#     Reasoning: Your response:
# <reasoning>
# Step 1: Start by preparing the Kabocha squash. Cut it into small pieces, about 1 inch in size. This should take around 5 minutes. Keep aside.
#
# Reasoning: Chopping the squash into small pieces allows it to cook more evenly and quickly. It's also easier to blend later on.
#
# Step 2: Next, chop the spinach. The leaves should be finely chopped while the stems can be left longer or chopped into smaller pieces as per preference. This should take around 3-4 minutes. Keep aside.
#
# Reasoning: Finely chopping the spinach helps distribute its flavor and nutrition throughout the soup. If stems are left longer, they can be removed before serving if desired.
#
# Step 3: In a pot, heat up some oil over medium heat. When hot, add the chopped Kabocha squash and sauté until slightly browned. This should take around 8-10 minutes.
#
# Reasoning: Sautéing the squash adds depth of flavor and browning brings out its natural sweetness.
#
# Step 4: Add the chopped spinach to the pot with the sautéed squash. Stir well and cook for another 2 minutes until spinach is wilted. Turn off the heat.
#
# Reasoning: Cooking the spinach along with the squash helps retain its bright green color and ensures even cooking. The residual heat from the pot will continue to cook the vegetables without burning them.
#
# Step 5: In a separate bowl or cup, dissolve the consomme soup stock cube or granules in 2 tablespoons of hot water. Set aside.
#
# Reasoning: Dissolving the stock cube or granules in hot water enhances their flavor and ensures even distribution in the soup.
#
# Step 6: Transfer the cooked vegetables to a blender or food processor and blend until smooth. This should take around 2-3 minutes.
#
# Reasoning: Blending the vegetables creates a creamy texture and makes the soup easier to swallow.
#
# Step 7: Pour the blended vegetable mixture back into the pot. Add the milk and the dissolved consomme mixture. Heat over low heat, stirring occasionally, until heated through. This should take around 5 minutes.
#
# Reasoning: Heating the soup
#     Your response:
# Write recipe instructions for the following recipe title and ingredient list.
#     Use the provided reasoning to inform your response.
#     Enclose your recipe instructions in <instructions> tags and number each step.
#     Recipe Title: Balsamic Roasted Fall Vegetables
#     Ingredients: ["1/4 cups Extra Virgin Olive Oil", "2 Tablespoons Balsamic Vinegar", "2 teaspoons Honey", "1 teaspoon Dijon Mustard", "2-1/2 pounds Assorted Vegetables, Cut Into 1/2 Inch Cubes Or Rounds (I Used Butternut Squash, Carrots, And Sunchokes But Sweet Potatoes, Zucchini, Squash, Eggplant Or Mushrooms Would Be Great)", "1 whole Red Onion, Chopped", "Salt And Pepper"]
#     Reasoning: 1. Preheat oven to 425 degrees F.
# 2. In a large bowl, whisk together extra virgin olive oil, balsamic vinegar, honey, and dijon mustard to make a dressing.
# 3. Add the chopped vegetables and red onion to the bowl with the dressing and toss until well coated.
# 4. Spread the vegetable mixture evenly on a baking sheet.
# 5. Season the vegetables with salt and pepper to taste.
# 6. Roast in preheated oven for about 30-35 minutes, stirring halfway through, until the vegetables are tender and caramelized.
# 7. Remove from oven and serve immediately.
#     Your response:
# Write recipe instructions for the following recipe title and ingredient list.
#     Use the provided reasoning to inform your response.
#     Enclose your recipe instructions in <instructions> tags and number each step.
#     Recipe Title: Piri-Piri Chicken
#     Ingredients: ["8 cloves garlic minced", "3 lemons juiced, plus wedges to serve", "1/3 cup whiskey", "1 fresh bay leaf", "2 teaspoons sweet paprika", "1/4 cup olive oil", "4 chicken breasts skin-on", "1 red onion thinly sliced into rings", "1 pound cherry tomatoes", "4 red chilies long", "8 slices ciabatta bread", "2 tablespoons olive oil", "1/2 lemon juiced", "1 red chili long, finely chopped", "1 clove garlic minced"]
#     Reasoning: Step 1: Prepare the marinade
#     - In a medium bowl, mix together the garlic, juice from three lemons, whiskey, bay leaf, sweet paprika, and 1/4 cup of olive oil. This will take approximately 2 minutes.
# Step 2: Marinate the chicken
#     - Place the chicken breasts in a large resealable plastic bag or container. Pour the prepared marinade over the chicken, making sure it is well coated. Seal the bag or container and refrigerate for at least 4 hours or overnight. This will take at least 4 hours up to overnight.
# Step 3: Preheat the grill
#     - Preheat your grill to medium-high heat. This will take about 10 minutes.
# Step 4: Cook the chicken
#     - Remove the chicken from the marinade and discard the marinade. Grill the chicken breasts, skin side down, for about 6-8 minutes per side, or until fully cooked. This will take about 15-20 minutes total.
# Step 5: Prepare the vegetables
#     - While the chicken is cooking, prepare the vegetables. Toss the sliced red onion, cherry tomatoes, and long red chilies in a bowl. Set aside. This will take about 2 minutes.
# Step 6: Toast the bread
#     - Brush the ciabatta slices with 2 tablespoons of olive oil and grill them for about 2 minutes per side, or until golden brown and crispy. Squeeze 1/2 lemon over the toasted bread and sprinkle with finely chopped red chili and minced garlic. This will take about 4-6 minutes.
# Step 7: Assemble the sandwiches
#     - Once the chicken is cooked, slice it into pieces and add it to the bowl with the grilled vegetables. Mix well and then divide the mixture between the toasted ciabatta slices. Serve immediately with lemon wedges on the side. This will take about 2 minutes.
#     Your response:
# Write recipe instructions for the following recipe title and ingredient list.
#     Use the provided reasoning to inform your response.
#     Enclose your recipe instructions in <instructions> tags and number each step.
#     Recipe Title: Rich Chocolate Rum Cookies
#     Ingredients: ["1 1/4 cups all-purpose flour", "1 1/2 teaspoons baking powder", "1/2 teaspoon salt", "1/2 cup ground hazelnuts (about 1/2 cup shelled nuts)", "12 ounces fine-quality bittersweet chocolate (not unsweetened)", "1/2 stick (1/4 cup) unsalted butter", "1/4 cup dark rum", "2 large eggs", "about 1/4 cup confectioners' sugar for sprinkling cookies"]
#     Reasoning: Firstly, gather all the necessary ingredients which include 1 1/4 cups of all-purpose flour, 1 1/2 teaspoons of baking powder, 1/2 teaspoon of salt, 1/2 cup of ground hazelnuts, 12 ounces of fine-quality bittersweet chocolate (not unsweetened), 1/2 stick (1/4 cup) of unsalted butter, 1/4 cup of dark rum, 2 large eggs, and about 1/4 cup of confectioners' sugar for sprinkling the cookies.
# Next, preheat your oven to 350 degrees Fahrenheit.
# Then, in a medium bowl, whisk together the flour, baking powder, and salt. This is important as it ensures that the cookies will have the right texture and rise properly during baking.
# After that, in another bowl, melt the chocolate and butter in a double boiler or microwave until smooth. This step ensures that the chocolate and butter are well combined and creates a smooth base for the cookie dough.
# Next, stir in the rum and then add the eggs one at a time, beating well after each addition. Mixing the wet ingredients ensures a moist and tender cookie.
# Now, add the chocolate mixture to the flour mixture, stirring just until blended. The dry mixture should be fully incorporated into the wet mixture, but do not overmix.
# Following that, fold in the ground hazelnuts. This step adds texture and depth of flavor to the cookies.
# Finally, drop rounded tablespoons of the cookie dough onto ungreased baking sheets, spacing them about 2 inches apart. Bake in the middle of the oven until the cookies are firm around the edges but still slightly soft in the center, about 12 minutes. Cool on the baking sheets for 5 minutes, then transfer to racks to cool completely. Once the cookies are cool, you can sprinkle them with confectioners' sugar for decoration.
#     Your response:
# Write recipe instructions for the following recipe title and ingredient list.
#     Use the provided reasoning to inform your response.
#     Enclose your recipe instructions in <instructions> tags and number each step.
#     Recipe Title: Mashed Potato Leek Soup Recipe
#     Ingredients: ["2 cups mashed potatoes (herbs, butter, anything you put in them)", "3 cups clean, chopped leeks", "1 medium stalk celery, chopped", "1 large carrot, chopped", "4 cups water", "1 1/2 teaspoon salt", "1 cup milk (as needed)", "fresh ground pepper"]
#     Reasoning: First, gather all the ingredients which include 2 cups of mashed potatoes (preferably with herbs and butter), 3 cups of cleaned and chopped leeks, 1 medium-sized stalk of celery chopped, 1 large carrot also chopped, 4 cups of water, 1 and a half teaspoons of salt, 1 cup of milk as needed, and freshly ground pepper.
# Next, heat up a large pot on medium heat and add the chopped leeks. Saute the leeks for about 5 minutes until they become tender. Then, add the chopped celery and carrots to the pot and continue sautéing for another 5 minutes.
# After that, pour in the 4 cups of water and bring it to a boil. Once boiling, reduce the heat to low and let it simmer for 10-15 minutes or until the vegetables are cooked through.
# Once the vegetables are cooked, use a blender to puree the mixture until smooth. If necessary, you can add some of the mashed potatoes at this stage to thicken the soup. Return the pureed mixture back to the pot.
# Then, add the mashed potatoes, salt, and milk to the pot and stir everything together. Let it cook for 2-3 minutes more just so that everything is heated through.
# Finally, sprinkle freshly ground pepper over the soup and serve hot.
#     Your response:
# Write recipe instructions for the following recipe title and ingredient list.
#     Use the provided reasoning to inform your response.
#     Enclose your recipe instructions in <instructions> tags and number each step.
#     Recipe Title: Chocolate Puddles
#     Ingredients: ["1 cup butter, softened", "1 cup sugar", "1 cup packed brown sugar", "2 large eggs", "2 teaspoons vanilla extract", "3 cups all-purpose flour", "3/4 cup baking cocoa", "1 teaspoon baking soda", "1 cup white baking chips", "1/2 cup plus 2 tablespoons sweetened condensed milk", "3/4 cup finely chopped mixed nuts"]
#     Reasoning: First, we need to gather all necessary ingredients: 1 cup of softened butter, 1 cup of sugar, 1 cup of packed brown sugar, 2 large eggs, 2 teaspoons of vanilla extract, 3 cups of all-purpose flour, 3/4 cup of baking cocoa, 1 teaspoon of baking soda, 1 cup of white baking chips, 1/2 cup plus 2 tablespoons of sweetened condensed milk, and 3/4 cup of finely chopped mixed nuts.
# Next, we need to preheat our oven at 350 degrees Fahrenheit (175 degrees Celsius) and prepare a cookie sheet with parchment paper or a silicone baking mat.
# Then we can start on the recipe itself. We begin by creaming together the butter and both sugars until light and fluffy in a large mixing bowl. This should take about 5 minutes using an electric mixer.
# After that, we add the eggs one at a time, beating well after each addition. Next, we stir in the vanilla extract.
# In a separate bowl, whisk together the flour, baking cocoa, and baking soda. Gradually add this dry mixture to the wet mixture, mixing until just combined.
# Once the dough is prepared, we can use a spoon or cookie scoop to drop rounded tablespoons onto the prepared cookie sheet. We then bake these for 8 to 10 minutes, or until they're set around the edges but still slightly soft in the centers.
# While the cookies are baking, we can prepare the chocolate filling. In a small saucepan, combine the white baking chips and sweetened condensed milk over low heat. Stir constantly until smooth and fully melted, which should take about 5 minutes. Remove from heat and let cool slightly.
# When the cookies have cooled for a few minutes, we can make an indentation in the center of each cookie with a spoon or thumb. While the indentation is still warm, we can fill it with the chocolate filling and sprinkle with finely chopped mixed nuts if desired.
#     Your response:
# Write recipe instructions for the following recipe title and ingredient list.
#     Use the provided reasoning to inform your response.
#     Enclose your recipe instructions in <instructions> tags and number each step.
#     Recipe Title: American 25
#     Ingredients: ["1 ounce bonded apple brandy, preferably Lairds", "1/4 ounce smoky Scotch (Peat Monster and Laphroaig 10-year-old are good options)", "1/2 ounce fresh lemon juice", "1/2 ounce simple syrup (see note)", "3 to 4 ounces Champagne", "Lemon twist"]
#     Reasoning: <instruction>First, gather all of the ingredients listed above.</instruction>
# <instruction>Next, measure out the required amounts of apple brandy, scotch, lemon juice, and simple syrup into separate containers or small glasses.</instruction>
# <instruction>After measuring out the liquid ingredients, prepare the simple syrup if you haven't already made it. To make simple syrup, combine equal parts sugar and water in a saucepan over medium heat until the sugar is dissolved. Once cooled, pour into a container for use in the cocktail.</instruction>
# <instruction>While waiting for the simple syrup to cool, begin preparing the lemon twist garnish. Using a sharp knife, cut a thin strip of lemon peel, ensuring that there is no pith (the white, bitter part) included. Squeeze the lemon twist over a lit flame or a bar spoon to char the edges slightly, which will enhance the aroma and flavor.</instruction>
# <instruction>Once everything is prepared, fill a shaker with ice and add the measured amounts of apple brandy, scotch, lemon juice, and simple syrup. Shake vigorously for about 15 seconds to chill and dilute the mixture.</instruction>
# <instruction>Strain the chilled mixture into a flute or champagne glass filled with fresh ice, then top off with chilled Champagne. Garnish with the lemon twist by expressing the oils from the twist over the drink and placing it on the rim of the glass.</instruction>
# <dependency>Note: If you don't have a simple syrup available, you can make it by combining equal parts granulated sugar and water in a saucepan over medium heat. Stir until the sugar has completely dissolved, then let it cool before using.</dependency>
#     Your response:
# Write recipe instructions for the following recipe title and ingredient list.
#     Use the provided reasoning to inform your response.
#     Enclose your recipe instructions in <instructions> tags and number each step.
#     Recipe Title: Broccoli Casserole
#     Ingredients: ["2 boxes Chopped Broccoli", "1 can Cream Of Mushroom Soup", "1 cup Mayonnaise", "2 whole Eggs, Beaten", "1 whole Medium Onion, Chopped Finely", "1 cup Sharp Cheddar Cheese, Grated", "1/4 sticks Butter, Melted", "1/8 packages Pepperidge Farm Dressing"]
#     Reasoning: Your response:
# <reasoning>
# We start by preheating our oven to 350°F (175°C). While the oven is heating up, we can begin preparing the broccoli. We take two boxes of chopped broccoli and place them into a large mixing bowl. Next, we open a can of cream of mushroom soup and pour it over the chopped broccoli. The mayonnaise goes into the same mixing bowl along with the beaten eggs. Now, we add in the chopped onion and half of the grated cheddar cheese. Mix everything together until well combined.
# Next, we move onto preparing the dressing. We'll take one-eighth of the Pepperidge Farm dressing and mix it in with our broccoli mixture. Once that's done, we'll transfer the mixture into a greased baking dish. We'll spread the remaining grated cheddar cheese over the top, and then drizzle the melted butter evenly over the cheese. Finally, we'll place the casserole into the preheated oven and bake for about 35-40 minutes, or until the top is golden brown and the broccoli is cooked through. Once finished, we can remove the casserole from the oven, let it cool slightly, and then serve hot.<reasoning>
#     Your response:
# Write recipe instructions for the following recipe title and ingredient list.
#     Use the provided reasoning to inform your response.
#     Enclose your recipe instructions in <instructions> tags and number each step.
#     Recipe Title: Southern Style Oven "Fried" Chicken
#     Ingredients: ["Ingredients", "3 spray(s) Cooking spray", "1 pound(s) Chicken, breast, raw, without skin, without bone, four 4-oz pieces", "1/2 tsp Salt, table, divided, or to taste", "1/4 tsp Cayenne pepper, divided, or to taste", "1/3 cup(s) Flour, white", "3 oz Milk, buttermilk, low-fat (1%)", "1/2 cup(s) Corn flakes crumbs"]
#     Reasoning: First, preheat the oven to 400°F. The chicken needs to be cooked at this temperature to ensure it is fully cooked and safe to eat.
# Next, season the chicken with half of the salt and cayenne pepper. This allows the chicken to absorb the flavors while it rests.
# While the chicken is resting, crush the corn flakes until they resemble breadcrumbs. This can take a few minutes depending on the consistency desired.
# In a shallow dish, mix together the flour and remaining salt and cayenne pepper. This creates the coating for the chicken.
# Dip each piece of chicken into the buttermilk, then coat evenly with the flour mixture. This step ensures that the chicken is thoroughly coated and crispy when baked.
# Spray a baking sheet with cooking spray. This prevents the chicken from sticking to the pan during baking.
# Place the coated chicken pieces on the prepared baking sheet. Make sure they are not touching so they cook evenly.
# Bake the chicken for about 20-25 minutes, or until the internal temperature reaches 165°F as measured with a thermometer. This ensures that the chicken is fully cooked and safe to eat.
#     Your response:

# %% [markdown]
# ### Few-Shot Evaluation

# %%
# Determine few-shot prompt

embed_dataset = load_from_disk(f'file://{recipe_nlg_data_path}/test_retrieval_embeddings')

# %%
embed_dataset['test']['retrieval_neighbors'][0]
# Out:
# [1773, 2235, 525]

# %%
TEST_SIZE = 1000

# %%
three_shot = embed_dataset['test'].shuffle().select(range(TEST_SIZE)).map(form_examples, fn_kwargs={"prompt_set": embed_dataset['retrieval'], "n_prompts": 3})
two_shot = embed_dataset['test'].shuffle().select(range(TEST_SIZE)).map(form_examples, fn_kwargs={"prompt_set": embed_dataset['retrieval'], "n_prompts": 2})
one_shot = embed_dataset['test'].shuffle().select(range(TEST_SIZE)).map(form_examples, fn_kwargs={"prompt_set": embed_dataset['retrieval'], "n_prompts": 1})
three_shot_ret = embed_dataset['test'].shuffle().select(range(TEST_SIZE)).map(form_examples, fn_kwargs={"prompt_set": embed_dataset['retrieval'], "n_prompts": 3, "retrieved": True})
two_shot_ret = embed_dataset['test'].shuffle().select(range(TEST_SIZE)).map(form_examples, fn_kwargs={"prompt_set": embed_dataset['retrieval'], "n_prompts": 2, "retrieved": True})
one_shot_ret = embed_dataset['test'].shuffle().select(range(TEST_SIZE)).map(form_examples, fn_kwargs={"prompt_set": embed_dataset['retrieval'], "n_prompts": 1, "retrieved": True})
# Out:
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]

# %%
generated_dataset_one_shot_instructions = one_shot.map(
    generate_instruction_batch,
    batched=True,
    batch_size=BATCH_SIZE,
    fn_kwargs={"cot": False, "model": model, "tokenizer": tokenizer, "examples": 1}
)
generated_dataset_one_shot_instructions.save_to_disk(f'{recipe_nlg_data_path}/Generated_Data/oob_one_shot_generated')
# Out:
# Map:   0%|          | 0/3671 [00:00<?, ? examples/s]
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
# ['Recipe Title: Gramma\'S Banana Bread \nIngredients: ["3 medium bananas", "1 1/2 cups flour sifted", "1 cup sugar", "1 egg", "1/3 cup melted shortening", "1 tsp. baking soda", "1 tsp. vanilla", "salt"]\nRecipe Instructions:\n1. "Preheat oven to 350 degrees.\n2. Mash bananas and add wet ingredients.\n3. Mix dry ingredients in a seperate bowl.\n4. Coming dry and wet ingredients.\n5. Grease loaf pan with crisco and add ingredients.\n6. Cook for 45min, or until done."\n']
# Recipe Title: Dinah'S Stuffed Mushrooms
# Ingredients: ["20 fresh mushrooms, stems removed", "2 (6.5 ounce) cans minced clams, drained", "2 cloves garlic, peeled and minced", "1/2 cup grated Parmesan cheese", "1 small onion, finely chopped", "3/4 cup dry bread crumbs", "1/2 cup chopped green bell pepper", "2 tablespoons dried parsley", "2 tablespoons Italian-style seasoning", "ground black pepper to taste", "1 1/2 cups butter, melted", "1/2 cup shredded mozzarella cheese"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
# ['Recipe Title: Nut Cheese Ball\nIngredients: ["8 ounces sharp cheddar cheese shredded", "8 ounces swiss cheese shredded", "1 cream cheese 8-oz. softened", "2 teaspoons worcestershire sauce", "1/2 teaspoon paprika", "1/2 teaspoon garlic salt", "1 cup chopped nuts"]\nRecipe Instructions:\n1. "Place cheddar cheese, swiss cheese, cream cheese, worcestershire sauce, paprika, and garlic salt in a bowl.\n2. Beat until well blended.\n3. Shape mixture into ball.\n4. Refrigerate for 2-3 hours.\n5. Roll ball in chopped nuts.\n6. Wrap in waxed paper and refrigerate until serving time.\n7. Serve with raw veggies or your favorite crackers."\n']
# Recipe Title: Roasted Cauliflower
# Ingredients: ["2 teaspoons olive oil", "2 medium onions, quartered", "5 garlic cloves, halved", "4 cups cauliflower florets (about 1 1/2 pounds)", "Cooking spray", "1 tablespoon water", "1 tablespoon Dijon mustard", "1/2 teaspoon salt", "1/4 teaspoon freshly ground black pepper", "1 tablespoon chopped fresh flat-leaf parsley"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
# ['Recipe Title: Bite-Sized Cauliflower Biscuits\nIngredients: ["2 cups cauliflower florets", "1 tablespoon skim milk", "2 tablespoons butter", "1/4 cup cheese shredded", "2 egg whites", "salt", "ground black pepper"]\nRecipe Instructions:\n1. "Preheat the oven to 190 degrees Celsius.\n2. Steam the cauliflower above boiling water for about 5 minutes.\n3. Remove the cauliflower and add the florets to a food processor with milk and butter. Mix well.\n4. Add the cheese and mix until it reaches a texture similar to thick oatmeal.\n5. Pour the mixture into a container and place it in the refrigerator for 10 minutes.\n6. Beat the egg whites until stiff peaks form.\n7. Put the cauliflower mixture into a large mold. Add 1 tablespoon of egg whites and mix it together. Add the rest of the egg white mixture and carefully mix everything together.\n8. Fill a pastry sleeve with the mixture (use a round and wide bakery cone) and squeeze out thick biscuit-shaped pieces, about 2 cm long, onto a baking sheet.\n9. Place the baking sheet in the oven and bake for 15 to 20 minutes. Once the biscuits are somewhat firm, they were ready to be served."\n']
# Recipe Title: Grilled Salmon Steaks with Lime Butter
# Ingredients: ["1/2 cup (1 stick) butter, melted", "1/4 cup lime juice", "1 tablespoon pepper", "4 9-ounce salmon steaks", "Lime wedges"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
# ['Recipe Title: Blueberry And Orange Clafouti Recipe\nIngredients: ["1 pun of blueberries", "1 x Orange, cut into segments, save the juice and zest", "3 x Large eggs Icing sugar", "1/2 pt Lowfat milk", "4 ounce Flour Vanilla essence"]\nRecipe Instructions:\n1. "Mix the flour and the lowfat milk in one bowl and beat the Large eggs together in another.\n2. Mix the icing sugar and beaten Large eggs in with the flour and lowfat milk and a few drops of vanilla essence.\n3. Lightly grease two oven proof dishes (10cm diameter - 3 cm deep) and place the blueberries, orange segments, juice and zest in them.\n4. Pour the batter over the top and place in a fairly warm oven for about 30 min.\n5. Remove from the oven and sprinkle some icing sugar over the top.\n6. Serve with creme frais or possibly mascarpone."\n']
# Recipe Title: Broccoli Casserole
# Ingredients: ["2 pounds broccoli florets fresh, cut into florets", "1 each soup, cream of mushroom 10-3/4 oz can, condensed, undiluted", "1/2 cup mayonnaise", "2 cups cheddar cheese", "1 tablespoon lemon juice", "1 x seasoned dry bread crumbs"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
# ['Recipe Title: Tiny Tuna Delights\nIngredients: ["1 egg", "2 cans (120 g each) chunk light tuna in water, drained, flaked", "1 pkg. (120 g) Stove Top Stuffing Mix for Chicken", "3/4 cup water", "1 stalk celery, finely chopped", "2 green onions, chopped", "1/3 cup Miracle Whip made with Olive Oil Spread*", "1/4 lb. (115 g) Velveeta Process Cheese Product, cut into 12 cubes"]\nRecipe Instructions:\n1. "Heat oven to 400 degrees F.\n2. Mix all ingredients except Velveeta until blended; spoon into 12 muffin pan cups sprayed with cooking spray.\n3. Press 1 Velveeta cube into centre of tuna mixture in each cup, completely enclosing Velveeta cube.\n4. Bake 15 min.\n5. or until golden brown.\n6. Cool 5 min.\n7. before removing from pan to serve."\n']
# Recipe Title: Linguine with Winter Pesto
# Ingredients: ["2 1/2 cups lightly packed Italian parsley leaves", "3/4 cup olive oil", "1/2 cup toasted pine nuts", "2 teaspoons fresh thyme leaves or 3/4 teaspoons dried, crumbled", "1 teaspoon minced fresh rosemary or 1/2 teaspoon dried, crumbled", "1 medium garlic clove", "1/3 cup freshly grated Parmesan cheese", "12 ounces linguine pasta", "1/3 cup chopped toasted pine nuts"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
# ['Recipe Title: Manuka Honey Ice Cream\nIngredients: ["2 cans full-fat Thai coconut milk", "Scant 1/4 cup, plus 2 tablespoons Manuka honey", "2 tablespoons bee pollen", "1/2 teaspoon xanthan gum or 1 tablespoon arrowroot powder", "Pinch of sea salt", "1 tablespoon vanilla extract (optional)"]\nRecipe Instructions:\n1. "Blend coconut milk, 1/4 cup Manuka honey, 1 tablespoon bee pollen, xanathan gum, salt and vanilla (if using) in a blender until smooth.\n2. Chill well in the refrigerator for several hours or overnight.\n3. Process in an ice cream machine according to the manufacturer\'s instructions.\n4. Spoon 1/3 of the ice cream into a chilled container, even it out and drizzle some of the remaining 2 tablespoons Manuka honey.\n5. Sprinkle with some of the remaining bee pollen.\n6. Repeat with the rest of the ingredients.\n7. Freeze for at least 4 hours or overnight.\n8. Let sit at room temperature for 10 to 15 minutes before scooping and serving."\n']
# Recipe Title: Dulce De Leche Ice Cream
# Ingredients: ["2 cups whole milk", "1 cup heavy cream", "1 pound", "(about 1 2/3 cups; preferably La Salamandra brand)", "1/8 teaspoon pure vanilla extract", "3/4 cup chopped pecans (2 1/2 to 3 oz),", "an ice cream maker"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
# ['Recipe Title: Warm Lamb Salad\nIngredients: ["2 whole Lamb Chops", "1 teaspoon Salt And Pepper Blend, To Taste", "1/4 cups Slivered Almonds", "1 whole Ripe Mango", "2 Tablespoons Cilantro, Chopped", "1/2 cups Mayonnaise", "4 cups Garden Greens", "1 cup Pitted Black Olives", "1/4 cups Feta Cheese"]\nRecipe Instructions:\n1. "Season the lamb with salt and pepper. Grill until a little pink is left.\n2. Toasted the almonds in a 350\\u00b0F degree oven for 10-15 minutes.\n3. Peel and pit the mangos. Cut into cubes. Finely chop the cilantro.\n4. Add the mangos, mayonnaise and cilantro to a blender and blend until smooth. Add salt and pepper to taste.\n5. Chop the lamb into strips and assemble the salad, olives, lamb, and feta cheese on a plate. Drizzle with the mango aioli. Serve immediately."\n']
# Recipe Title: Asparagus With Garlic And Balsamic Reduction
# Ingredients: ["1 pound asparagus spears, trimmed", "Cooking spray", "2 tablespoons sliced garlic", "1 teaspoon olive oil", "1/2 cup balsamic vinegar", "1/2 teaspoon kosher salt", "1/2 teaspoon black pepper"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
# ['Recipe Title: Round Roast (Rare) Recipe\nIngredients: ["3 to 3 1/2 pound top or possibly bottom round roast", "Salt", "Pepper", "Garlic pwdr", "1 onion sliced"]\nRecipe Instructions:\n1. "To taste.\n2. Trim away all visible fat.\n3. Sprinkle with salt, pepper and garlic pwdr.\n4. Place a few slices of onion on top and underneath.\n5. Roast in a preheated oven at 450 degrees for 1 hour.\n6. Remove from oven and allow to stand for 10 min before slicing."\n']
# Recipe Title: Canned  Rueben
# Ingredients: ["12 ounces elbow macaroni", "1 (10.75 ounce) can condensed cream of mushroom soup", "6 ounces shredded mozzarella cheese", "12 ounces sauerkraut", "1 (12 ounce) can corned beef"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
# ['Recipe Title: Banana Bread Lite\nIngredients: ["1 cup sugar", "1 (8-ounce) package fat-free cream cheese", "1 cup mashed ripe banana (about 2 medium)", "2 large eggs", "2 cups reduced-fat baking mix (such as Bisquick)", "1/2 cup chopped walnuts", "Cooking spray"]\nRecipe Instructions:\n1. "Preheat oven to 350\\u00b0.\n2. Place sugar and cream cheese in a large bowl; beat with a mixer at medium speed until light and fluffy. Add banana and eggs; beat until well blended. Add the baking mix and walnuts, and stir just until moist.\n3. Pour batter into a 9-inch loaf pan coated with cooking spray; bake at 350\\u00b0 for 45 minutes. Tent bread with foil, and bake an additional 15 minutes.or until a wooden pick inserted in center comes out clean. Cool in pan 10 minutes on a wire rack; remove from pan. Cool completely on wire rack."\n']
# Recipe Title: Carrot "Pasta" With Hot Peppered Raisins
# Ingredients: ["1 box plain or falvored quick cooking couscous", "2 tablespoons light vegetable oil", "2 tablespoons unsalted butter", "2 large shallots, minced", "A 1-inch piece fresh ginger, peeled and finely chopped", "8 ounces golden raisins", "1/4 teaspoon hot red pepper flakes, or more to taste", "10 large carrots, preferably California grown core; discard cores", "2 cups heavy cream", "1-1/2 cups light vegetable broth", "1 cup thawed petite peas", "kosher salt and freshly ground black pepper, to taste"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
# ['Recipe Title: Spring Pea And Farro Soup\nIngredients: ["1/2 cup pancetta, small dice", "2 teaspoons unsalted butter", "1 cup yellow onion, trimmed, peeled and small dice", "4 cups beef stock", "1 1/2 cups fresh peas", "1 cup cooked farro or brown rice, see note in headnote", "kosher salt and fresh ground pepper", "lots of fresh ground black pepper", "flat leaf parsley, minced"]\nRecipe Instructions:\n1. "Add the butter and the pancetta to a pan over medium heat. Render the pancetta until it just starts to get crispy while being careful not to burn the butter. You may need to reduce the heat to do this but be patient.\n2. Add the onions, season them with salt and pepper. Now continue cooking the onions, stirring occasionally, till they are soft.\n3. Add the broth and farro. Turn the heat up if you need to and bring the pot to a boil. Add the peas, taste the broth and season it as necessary.\n4. Add the parsley and cook the soup until the peas are just tender. Be careful not to overcook the peas.\n5. Serve immediately garnishing the soup with more fresh ground black pepper."\n']
# Recipe Title: Avocado Hummus
# Ingredients: ["16 ounces chickpeas", "2 avocados cored and peeled", "1/4 cup olive oil", "1/4 cup lime juice", "1/2 teaspoon minced garlic", "3 tablespoons tahini", "salt to taste", "pepper to taste", "tomato chopped, for garnish", "onion chopped, for garnish", "cilantro for garnish"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
# ['Recipe Title: Chocolate-Hazelnut Mousse & Banana Mini Pudding Parfaits\nIngredients: ["Vanilla Mousse", "Philadelphia Brick Cream Cheese, softened", "1 cup heavy cream", "1/4 cup Jell-O Vanilla Instant Pudding", "2 cups prepared whipped topping", "Chocolate-Hazelnut Mousse", "Philadelphia Brick Cream Cheese, softened", "1 cup chocolate-hazelnut spread", "2 cups prepared whipped topping", "Assembly", "8 each bananas, each cut into 16 slices", "1 full sheet chocolate sheet cake, cut into 1-1/2-inch rounds", "2 cups prepared whipped topping"]\nRecipe Instructions:\n1. "Vanilla Mousse: Beat cream cheese and cream with mixer until well blended.\n2. Add dry pudding mix; beat until well blended.\n3. Fold in whipped topping.\n4. Chocolate-Hazelnut Mousse: Beat cream cheese and chocolate-hazelnut spread with mixer until well blended.\n5. Fold in whipped topping.\n6. For each serving: Spoon or pipe 2-1/2 Tbsp.\n7. (37 mL) Vanilla Mousse into 4-oz.\n8. (125-mL) 2-inch wide glass; cover with layers of 3 banana slices, 1 cake round, 2-1/2 Tbsp.\n9. (37 mL) Chocolate-Hazelnut Mousse, 1 Tbsp.\n10. (15 mL) whipped topping and 1 banana slice."\n']
# Recipe Title: Shrimp Cakes
# Ingredients: ["1/2 cup mayonnaise", "1 tablespoon hot sauce", "1 pound shelled and deveined shrimp, chopped", "3/4 cup panko", "2 large eggs", "3 tablespoons finely chopped scallions", "1 teaspoon finely grated lemon zest", "3/4 teaspoon smoked paprika", "1 teaspoon salt", "1/2 teaspoon pepper", "1/4 cup extra-virgin olive oil", "Lemon wedges, for serving"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
# ['Recipe Title: Quiche With Bacon \nIngredients: ["2 T. butter", "1 1/2 C. shredded cheese, (Swiss, cheddar, Mozzarella,or Mexican blend)", "6 eggs, beaten", "1 1/2 C. milk", "1/2 tsp. salt", "1/2 tsp. pepper", "1/4 tsp. dried basil", "1 lb. bacon, or (2 C. ham, chopped)", "1/2 red bell pepper", "1/2 green bell pepper", "1 small onion, chopped", "10 oz. pkg. frozen chopped spinach thawed (well drained, squeeze in paper towels), optional"]\nRecipe Instructions:\n1. "Preheat oven to 350 degrees.\n2. Cut bacon into halves.\n3. Fry bacon and crumble (or ham)\n4. Fry onion, and bell peppers in butter.\n5. Beat eggs and add all ingredients\n6. Place in quiche dish.\n7. Add spinach if desired.\n8. Cover with cheeses. Bake 350 degrees 50-60 min. until toothpick comes out clean. Let sit 10 min. before cutting."\n']
# Recipe Title: Dry-Aged Strip Steaks Without Drying Or Aging
# Ingredients: ["1 1/2 ounces dried porcini mushrooms", "1/2 teaspoon granulated white sugar", "1/2 teaspoon ground white pepper", "2 10-ounce boneless New York strip steaks, about 1 inch thick", "2 tablespoons soy sauce (gluten-free if that is a concern)", "3 tablespoons unsalted butter", "2 tablespoons balsamic vinegar"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
# ['Recipe Title: Tofu with Tomatoes and Balsamic Vinegar\nIngredients: ["1 (14 ounce) package extra firm tofu, sliced", "1 (14.5 ounce) can diced tomatoes with basil, garlic, and oregano", "1/4 cup balsamic vinegar", "1 tablespoon vegetable oil", "2 green bell pepper, chopped", "1/2 onion, chopped", "1/4 teaspoon garlic powder", "salt to taste"]\nRecipe Instructions:\n1. "Place tofu slices between two clean towels; allow tofu to drain, about 10 minutes.\n2. Cut tofu into bite-size pieces and transfer to a bowl.\n3. Stir in tomatoes and balsamic vinegar; marinate for 20 minutes.\n4. Heat vegetable oil in a large skillet over medium heat; cook and stir bell peppers and onion until just tender, about 5 minutes.\n5. Add tofu mixture, garlic powder, and salt.\n6. Cover and reduce heat to medium-low; simmer until heated through, about 5 minutes more."\n']
# Recipe Title: Pureed Artichoke Crostini with Lime Salt
# Ingredients: ["1 tablespoon olive oil", "12 ounces frozen artichoke hearts, thawed and patted dry", "2 cups baby spinach", "3 cloves garlic, 2 chopped, 1 left whole", "2 tablespoons plus 1 teaspoon freshly squeezed lemon juice", "1/4 cup grated Parmigiano-Reggiano", "3 tablespoons crumbled feta cheese", "2 tablespoons fresh flat-leaf parsley leaves", "1/4 teaspoon kosher salt", "Freshly ground black pepper", "2 tablespoons sea salt flakes", "1 lime, zested", "1 baguette, sliced into 16 rounds and toasted", "4 radishes, very thinly sliced, for garnish"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
# ['Recipe Title: French Toast Bites\nIngredients: ["6 slices Bread (use The Ends Of The Loaf)", "3 whole Eggs", "3 Tablespoons Milk", "2 teaspoons Ground Cinnamon", "1/2 teaspoons Ground Nutmeg", "1 Tablespoon Brown Sugar", "1 Tablespoon Butter (or Margarine), Plus More To Taste", "Maple Syrup To Taste"]\nRecipe Instructions:\n1. "Cut bread into bite-sized pieces.\n2. In a medium or large mixing bowl, beat eggs, milk, cinnamon, nutmeg and brown sugar until combined. Toss bread cubes into egg mixture to coat.\n3. In a medium skillet, melt butter over medium-high heat. Add coated bread cubes and cook until well done. If desired, melt more butter and toss bread to coat.\n4. Add maple syrup to coat or drench (depends on your taste)."\n']
# Recipe Title: Strawberry Donut Holes
# Ingredients: ["5 cups Vegetable Oil", "2 cups Flour", "4 Tablespoons Sugar", "1-1/2 Tablespoon Baking Powder", "1/2 teaspoons Salt", "1/4 teaspoons Nutmeg", "1/4 teaspoons Cinnamon", "1 cup Milk", "1 Egg", "1 teaspoon Vanilla", "1/4 cups Melted Butter", "1 cup Diced Strawberries", "1 cup Powdered Sugar"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
# ['Recipe Title: Almost Fat Free Chocolate Cupcakes Recipe\nIngredients: ["1 1/3 c. All-purpose flour", "1/2 c. Unsweetened cocoa pwdr", "1 1/2 tsp Baking pwdr", "1 1/2 tsp Baking soda", "2 tsp Salt", "3/4 c. Packed dark brown sugar", "1/4 c. Cinnamon applesauce", "1 x Egg", "1 x Egg white", "1 Tbsp. Oil", "1 tsp Vanilla extract", "2/3 c. Skim lowfat milk Powdered sugar, optional"]\nRecipe Instructions:\n1. "Preheat oven to 350F.\n2. Line 12 muffin c. with paper liners.\n3. Combine flour, cocoa, baking pwdr, soda and salt.\n4. Beat the next six ingredients till combined, about 1 minute.\n5. Stir in flour mix alternately with lowfat milk till just combined.\n6. Pour batter into muffin c.. Bake 22-25 min or possibly till toothpick comes out clean.\n7. Remove cupcakes from pan; cold on wire rack 30 min.\n8. Sprinkle with sugar, if you like.\n9. from Woman\'s World November 28,"\n']
# Recipe Title: My Spicy Cheesy Potatoe Salad
# Ingredients: ["200 grams Chopped boiled new potatoes", "1 tsp Shallot chopped fine", "1 pinch Salt and pepper", "3 tbsp Mayonaise", "1 tsp Level paprika", "2 tbsp Level of Chedder Cheese"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
# ['Recipe Title: Date Bars\nIngredients: ["1 1/2 cups chopped dates", "1 cup whole wheat self-rising flour", "1/2 cup self-rising flour", "1/2 cup packed brown sugar", "1/2 cup rolled oats", "1 cup plain yogurt", "2 None eggs, lightly beaten", "1/3 cup light olive oil"]\nRecipe Instructions:\n1. "Preheat the oven to 400\\u00b0F. Grease a foil-lined 11 x 7 inch baking pan, extending the foil over long sides for handles.\n2. Combine dates, flours, brown sugar and oats in a large bowl. Stir in combined yogurt, eggs and olive oil until just combined. Spoon into prepared pan.\n3. Bake for 20 mins, until golden. Cool in pan for 5 mins. Remove from pan; cool completely on a wire rack."\n']
# Recipe Title: Florentine Cookies
# Ingredients: ["1/4 pound butter, room temperature", "1 cup sugar", "1 large egg", "1 teaspoon vanilla extract", "1/4 teaspoon baking soda", "Pinch salt", "1 cup quick cooking oats", "1 cup pecan pieces"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
# ['Recipe Title: Diet Menu Tofu Okonomiyaki\nIngredients: ["1/2 Cabbage", "1 block Firm tofu", "1 tsp Dashi stock granules", "1 dash Umami seasoning", "1 Egg", "1 tbsp Katakuriko"]\nRecipe Instructions:\n1. "Put the cabbage in a food processor to finely chop.\n2. Transfer into a bowl.\n3. Crumble in the tofu, and mix.\n4. Add the ingredients, and mix some more.\n5. Heat olive oil in a frying pan.\n6. Arrange the shapes of okonomiyaki and pan-fry over medium-low heat.\n7. If you are using a non-stick frying pan, cook them without oil.\n8. Flip the Step 3 okonomiyaki and cover with a lid to steam-fry.\n9. It will be done within 3-5 minutes."\n']
# Recipe Title: Meatball Stew with Dumplings
# Ingredients: ["1 recipe meatballs", "10 1/2 ounces soup, cream of celery condensed", "1/4 cup sour cream dairy", "16 ounces vegetables", "15 ounces potatoes drained and cut in cubes", "1 x dumplings egg or parsley", "2 cups biscuit baking mix (bisquick)", "2 large eggs lg.", "2 tablespoons milk", "2 cups biscuit baking mix (bisquick)", "2 tablespoons parsley flakes", "23 cup milk"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
# ['Recipe Title: French Canadian Shepherd\'s Pork Pie with Variations\nIngredients: ["4 cups mashed potatoes", "1-1/4 lb. can creamed corn (540 mL)", "1 lb. leftover cooked pork (ground) seasoned to taste", "1 md. onion, chopped and fried", "3 knobs of butter"]\nRecipe Instructions:\n1. "Preheat oven to 350 F. In a saucepan, cook potatoes and mash them.\n2. Season the potatoes to taste with salt and pepper.\n3. Grind your leftover pork and add chopped fried onion.\n4. Season with your favorite spices.\n5. Such as rosemary, thyme, marjoram, parsley, pepper, savory or garlic.\n6. In a small saucepan, heat creamed corn.\n7. In an oven proof dish, alternate layers of mashed potatoes, creamed corn, and ground pork, finishing with a layer of mashed potatoes.\n8. Dot with knobs of butter and bake in oven for 20 to 30 minutes or until potatoes are crusty and golden brown.\n9. Serves 4.\n10. VARIATIONS: Replace creamed corn with 2 cups applesauce.\n11. Garnish with thin slices of apple sauteed in butter.\n12. Replace creamed corn with 19 oz.\n13. can asparagus coarsely chopped.\n14. Whats Cooking"\n']
# Recipe Title: Grandma Kline's Biscuits Supreme For Strawberry Shortcake Recipe
# Ingredients: ["2 c. flour", "1/2 teaspoon salt", "1/2 teaspoon cream of tartar", "4 teaspoon baking pwdr", "2 teaspoon sugar", "1/2 c. shortening", "2/3 c. lowfat milk"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
# ['Recipe Title: Three-Cheese Pizza with Pancetta and Mushrooms\nIngredients: ["Pizza dough", "1/2 cup purchased marinara sauce", "1 cup coarsely grated Fontina cheese", "1/2 cup finely grated Parmesan cheese", "1/3 cup coarsely grated mozzarella cheese", "2 ounces crimini (baby bella) mushrooms, thinly sliced", "2 ounces thinly sliced pancetta (Italian bacon), coarsely chopped"]\nRecipe Instructions:\n1. "Preheat oven to 475F.\n2. Line 2 large baking sheets with parchment.\n3. Divide dough in half.\n4. Roll out 1 half on lightly floured surface to 131/2x81/2-inch rectangle.\n5. Transfer to 1 baking sheet.\n6. Repeat with second half.\n7. Spread 1/4 cup marinara sauce over each pizza, leaving 1/2-inch border.\n8. Sprinkle cheeses over, then mushrooms and pancetta.\n9. Sprinkle with salt and generous amount of pepper.\n10. Bake pizzas until brown on bottom and cheese is melted, about 15 minutes.\n11. Cut each pizza crosswise into rectangles."\n']
# Recipe Title: Caldo de Res Recipe eratosthanes
# Ingredients: ["2-5 1 in. thick beef shanks depending on size", "2 med. yellow squash", "2 med. zucchini", "1 small cabbage or 1/2 large cabbage, cut into 2 in. pieces", "2 med. potatoes or a decent size jicama (optional", "1 cn corn, or 2 whole ears (optional)", "1 cn crushed tomatoes", "4-6 cloves garlic", "4 Guajillo chilie", "2 chipotles", "2 Tb chile powder", "2 t ground cumin(comino) or 1 t fresh ground cumin", "1 block Knorrs beef bullion", "salt and pepper to taste"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
# ['Recipe Title: Skinny Blended Raspberry Lemon Mojitos\nIngredients: ["3/4 cups Fresh Blueberries", "4 ounces, fluid White Rum", "2 ounces, fluid Water", "2 cups Frozen Raspberries", "6 cups Ice Cubes", "1/2 cups Fresh Lemon Juice + More For Rimming", "1/4 cups Fresh Mint", "2 Tablespoons Truvia, Or To Taste + More For Rimming"]\nRecipe Instructions:\n1. "1. Place the blueberries in a medium bowl and lightly mash them with a muddler. Leave some a bit chunky for texture. Set aside.\n2. 2. Combine all the remaining ingredients in a blender and blend until icy and smooth. This drink is very thick, so you may need to stop your blender and scrape down the sides every so often.\n3. 3. Optional rimming: Pour some lemon juice into a medium sized, shallow bowl and pour some truvia into a small, shallow plate. Put the rim of each cup into the lemon juice, followed by the Truvia. Twist the cup around in the Truvia until the outside is rimmed. Repeat with remaining glasses.\n4. 4. Pour (or spoon) the mojito into the cups and top with the muddled blueberries.\n5. 5. Drink up friends."\n']
# Recipe Title: Olive & Tomato Braised Chicken
# Ingredients: ["2 Tbsp. canola oil", "24 each boneless skinless chicken thighs (4 oz./115 g each)", "1-1/2 cups Kraft Balsamic Vinaigrette Dressing, divided", "1-1/2 qt. onions, chopped Safeway 3 lb For $2.99 thru 02/09", "2 Tbsp. garlic, minced", "4-1/2 qt. canned no-salt-added diced tomatoes, undrained", "3/4 cup Kalamata olives, finely chopped", "3/4 cup fresh basil, chopped"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
# ['Recipe Title: Cottage Cheese Pancakes\nIngredients: ["1 cup Cottage Cheese", "4 whole Eggs, Divided", "1/4 cups Flour", "1/4 cups Butter", "1/2 cups Sugar", "13 cups Orange Juice", "2 Tablespoons Orange Zest", "2 Tablespoons Lemon Juice"]\nRecipe Instructions:\n1. "Preheat skillet to medium heat.\n2. Mix cottage cheese, 3 eggs, and flour in a bowl.\n3. When skillet is preheated, pour a small amount of batter onto the skillet.\n4. (They are too hard to flip if you make them large.)\n5. When they look glossy, flip over and cook for 1 minute more.\n6. Serve with orange sauce.\n7. To make the sauce, melt butter in the microwave and mix together with the sugar in a cool sauce pan (without heat).\n8. Add remaining egg, beaten, and mix well.\n9. Turn heat to medium and add the orange juice, zest, and lemon juice while stirring constantly.\n10. Cook over medium-low heat for about 5 to 10 minutes until slightly thick.\n11. Pour over pancakes and enjoy with powdered sugar on top."\n']
# Recipe Title: Grandma'S Italian Sauce
# Ingredients: ["1 can crushed tomatoes", "1 cup plum tomatoes diced", "3 tablespoons olive oil", "2 cloves garlic", "1/2 cup fresh parsley", "6 leaves basil chopped", "1/2 cup red wine", "pepper"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
# ['Recipe Title: Banana Fritters Iii\nIngredients: ["2 quarts oil for frying", "1 cup all-purpose flour", "1 1/4 teaspoons baking powder", "1/4 teaspoon salt", "1 egg, beaten", "2 cups milk", "2 teaspoons canola oil", "3 bananas, mashed", "1 tablespoon lemon juice", "2 tablespoons confectioners\' sugar"]\nRecipe Instructions:\n1. "Heat oil in deep-fryer to 375 degrees F (190 degrees C).\n2. In a large bowl, mix flour, baking powder and salt.\n3. In a medium bowl, mix egg, milk and canola oil. Stir into the flour mixture. Mix in bananas and lemon juice. When thoroughly mixed, form mixture into about 10 balls.\n4. In batches, fry balls in the prepared oil 5 minutes, or until lightly browned. Drain on paper towels, and sprinkle with confectioners\' sugar."\n']
# Recipe Title: Strawberry Rhubarb Crisp
# Ingredients: ["3 1/2 cups (875 mL) strawberries, hulled and halved or quartered, depending on size", "3 cups (750 mL) sliced fresh rhubarb", "3/4 cup (175 mL) granulated sugar", "3 tbsp (45 mL) cornstarch", "1 tsp (5 mL) lightly packed grated orange zest", "1 tbsp (15 mL) orange juice", "1 recipe Cinnamon Sugar Crumb Topping", "8-inch (2 L) square glass baking dish, greased"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
# ['Recipe Title: Deep Sea\nIngredients: ["1 to 1 1/2 ounces gin", "1 to 1 1/2 ounces dry vermouth", "2 dashes Pernod", "1/4 teaspoon superfine sugar", "3 or 4 ice cubes", "Twist lemon peel", "Dash orange bitters", "Olive"]\nRecipe Instructions:\n1. "Combine all ingredients, except peel, in a mixing glass and stir well.\n2. Strain into a cocktail glass; drop in peel.\n3. Add olive for garnish."\n']
# Recipe Title: Spicy Peanut Sauce
# Ingredients: ["1 heaping tablespoon peanut butter", "1 1/2 teaspoons balsamic vinegar", "1 tablespoon soy sauce", "1 teaspoon honey", "1/2 teaspoon Chinese hot red chili paste", "1/2 teaspoon hot chili oil", "2 tablespoons red wine", "1 teaspoon lime juice or margarita mix", "Vegetable oil, to thin if necessary", "3 tablespoons water"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
# ['Recipe Title: Blackberry Spritzer\nIngredients: ["1 pint blackberries, plus more for garnish", "1 cup fresh basil leaves, plus 4 leaves for garnish", "1 cup club soda", "1/2 cup vodka", "1/4 cup creme de cassis", "1/4 cup fresh lime juice", "1/4 cup agave"]\nRecipe Instructions:\n1. "Special equipment: 4 chilled martini glasses and 4 cocktail picks\n2. Muddle the blackberries and basil in a pitcher.\n3. Add the club soda, vodka, cassis, lime juice and agave and stir to combine.\n4. Chill for at least 1 hour and until ready to serve.\n5. Thread a basil leaf and blackberry onto each cocktail pick.\n6. Serve the spritzers over ice and garnish with the cocktail picks."\n']
# Recipe Title: Ratatouille, Second Time Around
# Ingredients: ["Half of ratatouille (see above)", "Lemon zest and juice to taste", "Salt and crushed red pepper", "Washed lettuce leaves, torn into bitesized pieces", "Cans of tuna fish or strips of smoked chicken breast", "Slivered pitted cured black olives", "Basil chiffonade"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
# ['Recipe Title: Leek, Potato and Asparagus Soup\nIngredients: ["2 tablespoons vegetable oil or olive oil", "1/4 stick (1 ounce) butter", "2 large leeks, washed and chopped (you can use the green tops, but wash them well since they are quite sandy)", "1 celery stalk, chopped", "1 large onion, chopped", "2 large potatoes, peeled and cut into 1-inch cubes", "1 1/2 cups water", "1/2 to 3/4 pound asparagus, cut into 1/2-inch pieces, with tips intact", "2 cups milk", "1/2 cup heavy cream", "Salt and freshly ground black pepper to taste", "3 whole green onions, chopped, for garnish"]\nRecipe Instructions:\n1. "Put the oil, butter, leeks, celery and onion in a large pot.\n2. Cover and cook about 8 minutes, stirring every minute or so, until the onion is translucent and the leeks have softened.\n3. Add the potatoes and water.\n4. Bring to a boil, lower the heat to medium, and cook until the potatoes are soft, about 12 to 15 minutes.\n5. Add the asparagus, milk and cream.\n6. Stir and cook, covered, at least 5 minutes longer.\n7. Season with salt and pepper, and sprinkle the chopped green onions on top of the soup just before serving.\n8. Wonderful soup!"\n']
# Recipe Title: Chewy Ginger Snap Cookies
# Ingredients: ["3/4 cups Vegetable Shortening", "3/4 cups Granulated Sugar, Divided", "1/2 cups Packed Light Brown Sugar", "1 whole Large Egg", "1/4 cups Unsulfered Molasses", "2 cups All-purpose Flour", "1 teaspoon Baking Powder", "1 teaspoon Baking Soda", "1 Tablespoon Ground Ginger", "1 teaspoon Ground Cinnamon", "1/2 teaspoons Ground Cloves", "1/4 teaspoons Salt", "1/4 cups Granulated Sugar For Decoration"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
# ['Recipe Title: Shigoku Oysters with Ricard Mignonette\nIngredients: ["1/2 c. champagne vinegar", "1/2 c. dry white wine", "4 tsp. Ricard", "4 tsp. shallot, brunoise", "Kosher salt", "24 Shigoku oysters", "Ice, for serving", "1 lemon, cut into wedges"]\nRecipe Instructions:\n1. "Combine champagne vinegar, white wine, Ricard and shallot in a bowl, season with salt to taste.\n2. Open oysters and place on a bed of ice.\n3. Serve with lemon wedges and the mignonette."\n']
# Recipe Title: Fish and Chips in Parchment
# Ingredients: ["1- 1/4 pound Baking Potatoes Or Baby Potatoes, Very Thinly Sliced", "4 teaspoons Olive Oil", "Salt And Pepper", "1- 1/2 pound Firm White Fish Such As Cod, Cut Into 4 Portions", "1/2 whole Lemon, Very Thinly Sliced", "8 Tablespoons White Wine", "2 Tablespoons Chopped Fresh Dill", "1 Tablespoon Drained Capers"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
# ['Recipe Title: Basic Risotto \nIngredients: ["5 oz. (3/4 cup) arborio rice", "4 to 6 cups chicken broth", "1/2 tablespoon olive oil", "6 cloves garlic - minced", "2 large shallots - minced", "1/4 cup parmesan cheese"]\nRecipe Instructions:\n1. "In a large non-stick skillet gently brown the garlic and onion in the oil. Add the rice and toast over very low heat, stirring constantly, for about 2 minutes.\n2. \n3. Add about half the boiling broth to the mixture and cook over low heat, stirring occasionally. When most of the liquid has been absorbed, continue adding remaining broth little by little.\n4. \n5. After each addition of liquid let the rice absorb the broth and thicken while you stir.\n6. \n7. Just before the rice is finished, add the parmesan cheese and stir to incorporate."\n']
# Recipe Title: Balsamic Glazed Sausages With Salad
# Ingredients: ["1/2 loaf French bread, torn into bite-sized pieces", "1 lb sausage links", "1/3 cup plus 1 tbsp balsamic vinegar", "1 tbsp honey", "2 tbsp coarse grain mustard", "2 tbsp extra-virgin olive oil", "4 oz baby spinach leaves", "1 pint cherry tomatoes, haIved", "1 small cucumber, seeded and cut into 3/4-inch pieces", "1 small red onion, thinly sliced"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
# ['Recipe Title: Chicken Salad\nIngredients: ["1/2 cup toasted walnuts", "1/4 cup dried cranberries", "1 teaspoon Dijon mustard", "1 teaspoon sugar", "2 celery ribs, diced", "2 scallions, thinly sliced up to the pale green parts", "Salt and freshly ground black pepper", "1 cup mayonnaise", "Two 8-ounce dry or leftover cooked chicken breasts, cut into chunks (see Cook\'s Note)", "Bibb lettuce leaves, for serving", "Balsamic reduction, store-bought or homemade, for serving"]\nRecipe Instructions:\n1. "Mix the walnuts, cranberries, mustard, sugar, celery, scallions and some salt and pepper together in a large bowl.\n2. Let the flavors meld for 10 minutes.\n3. Add in the mayo and mix until incorporated.\n4. Adjust the seasoning if necessary.\n5. Add in the chicken.\n6. Let the mixture sit in the fridge for at least 1 hour before serving, overnight preferred.\n7. Serve on lettuce leaves and drizzle with balsamic reduction."\n']
# Recipe Title: Chicken Chili
# Ingredients: ["1 1/4 cups reduced-sodium chicken broth (10 fluid ounces)", "1 (14- to 15-ounce) can stewed tomatoes", "4 dried New Mexican or guajillo chiles, stems and seeds discarded and chiles torn into pieces", "1 (3/4-inch-thick) crosswise slice of a medium white onion", "2 garlic cloves, peeled", "1/2 cup coarsely chopped fresh cilantro", "1/4 cup dry-roasted peanuts", "1 teaspoon ground cumin", "1/4 teaspoon salt, or to taste", "2 tablespoons olive oil", "1 rotisserie-cooked chicken (2 pounds)", "1 (15-ounce) can pink beans in sauce (preferably Goya)", "Garnish: chopped fresh cilantro; sour cream"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
# ['Recipe Title: King Ranch Chicken Casserole\nIngredients: ["1 pound chicken breast halves, boneless, skinless cut into small pieces", "2 cans soup, cream of mushroom", "1 can tomatoes, canned rotel", "2 cups cheddar cheese shredded", "1 Bag corn chips flavoured"]\nRecipe Instructions:\n1. "In non-stick pan stir-fry chicken pieces until done.\n2. Mix together soups and tomatoes in large bowl.\n3. Take 11x7 glass baking dish.\n4. Spray with Pam (or grease).\n5. Break up enough corn chips to cover bottom of dish.\n6. Layer on 1/2 of chicken, then 1/2 of cheese, then 1/2 of soup mixture.\n7. Layer same way again, chips, chicken, cheese, soup.\n8. If you have any Doritos and cheese left, sprinkle them over the top.\n9. Bake at 350F (180C).\n10. for 1 hour.\n11. On the side serve sour cream, tomatoes, lettuce, and salsa."\n']
# Recipe Title: Mozzarella Beef Pizza Loaf
# Ingredients: ["1-1/2 lb. lean ground beef King Sooper's 1 lb For $3.99 thru 02/09", "1-1/2 cups Classico di Napoli Tomato & Basil Pasta Sauce", "1 tsp. dried oregano leaves", "2 each: onions and red peppers, chopped", "2 cups broccoli florets", "1 Tbsp. oil", "1 14-inch loaf Italian bread, cut in half horizontally", "1 cup each: grated Cracker Barrel Mozzarella Cheese and KRAFT CRACKER BARREL Cheddar Cheese"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
# ['Recipe Title: Poached Eggs with Herb Mayonnaise\nIngredients: ["1/2 tablespoon tarragon vinegar", "Salt", "Pepper", "1 cup hazelnut oil, plus 1 tablespoon", "1 teaspoon fresh tarragon, chopped", "1 teaspoon chives, chopped", "1 teaspoon fresh marjoram, chopped", "2 cups mixed lettuces, rinsed and dried", "2 teaspoons champagne vinegar", "3 eggs, poached until yolk is almost set, in a bowl of cold water"]\nRecipe Instructions:\n1. "In a bowl, whisk together the vinegar and salt and pepper, to taste.\n2. Drizzle in the hazelnut oil, gradually at first, whisking, to form an emulsion.\n3. Then add oil at a faster rate, whisking to retain the emulsion.\n4. When one cup of the oil has been incorporated into the mayonnaise, stir in the herbs.\n5. Pile the lettuce on a plate in a mound, drizzle it with 1 tablespoon of oil and 2 teaspoons of vinegar.\n6. Remove the eggs from the bowl with a slotted spoon, lightly dry them with a paper towel, trim off loose strands of egg white, and place the eggs on the lettuce.\n7. Spoon a dollop of herbed mayonnaise on each egg.\n8. Recommended Drink: Pol Roger Brut Champagne, Non-Vintage"\n']
# Recipe Title: French Dip Sandwich
# Ingredients: ["11/2 pounds sirloin, sliced across the grain on the diagonal bias until very thin", "Salt and freshly ground pepper to taste", "2 tablespoons olive oil, plus additional for sauteing", "2 tablespoons unsalted butter", "1/3 cup minced shallots", "2 cloves garlic, minced fine", "1 teaspoon minced fresh thyme", "1/2 cup dry white wine", "1 1/2 cups beef stock or canned beef broth", "4 French rolls, split and lightly toasted"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
# ['Recipe Title: Mini Cheesecakes From Philadelphia®\nIngredients: ["1 cup HONEY MAID Graham Cracker Crumbs", "2 tablespoons sugar", "3 tablespoons butter or margarine, melted", "3 (8 ounce) packages PHILADELPHIA Cream Cheese, softened", "3/4 cup sugar", "1 teaspoon vanilla", "3 eggs", "1 cup whipping cream", "2 cups blueberries", "1 tablespoon lemon zest"]\nRecipe Instructions:\n1. "Heat oven to 325 degrees F.\n2. Mix graham crumbs, 2 Tbsp. sugar and butter; press onto bottoms of 18 paper-lined muffin pan cups.\n3. Beat cream cheese, remaining 3/4 cup sugar and vanilla with mixer until blended. Add eggs, 1 at a time, mixing on low speed after each just until blended. Pour over crusts.\n4. Bake 25 to 30 min. or until centers are almost set. Cool completely. Refrigerate 2 hours.\n5. Beat whipping cream with mixer on high speed until stiff peaks form; spread gently onto cheesecakes. Top with blueberries and lemon zest."\n']
# Recipe Title: Sweet Glazed Carrots
# Ingredients: ["8 medium carrots, diagonally sliced", "1/2 cup KRAFT Classic CATALINA Dressing", "2 Tbsp. brown sugar", "2 Tbsp. LEA & PERRINS Worcestershire Sauce", "2 Tbsp. chopped fresh parsley"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
# ['Recipe Title: Fiesta in a Skillet\nIngredients: ["1 lb. extra-lean ground beef", "1 red pepper, chopped", "3 green onions, chopped", "2 cups water", "1-1/2 cups red salsa, divided", "1 fresh jalapeno pepper, seeded, chopped", "1-1/2 cups elbow macaroni, uncooked", "1 cup frozen corn", "1 cup KRAFT Mexican Style Shredded Four Cheese with a TOUCH OF PHILADELPHIA", "1 Tbsp. chopped fresh cilantro"]\nRecipe Instructions:\n1. "Brown meat with red peppers and onions in large nonstick skillet.\n2. Stir in water, 1 cup salsa and jalapeno peppers; bring to boil.\n3. Stir in macaroni; cover.\n4. Simmer on medium-low heat 10 to 12 min.\n5. or until macaroni is tender, stirring occasionally and adding corn for the last 5 min.\n6. Remove from heat.\n7. Stir in remaining salsa.\n8. Top with cheese; cover.\n9. Let stand 2 min.\n10. or until melted.\n11. Sprinkle with cilantro."\n']
# Recipe Title: Orange Baked Chicken
# Ingredients: ["1 (4 pound) whole chicken, cut lengthwise", "1 orange, sliced into rounds", "2 pounds potatoes", "1 pound carrots", "2 small onions, quartered", "2 stalks celery, chopped", "1/3 cup chicken broth", "salt and pepper to taste"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
# ['Recipe Title: Beef Braised In Dark Beer\nIngredients: ["1 tbsp extra virgin olive oil", "4 1/2 lbs beef chuck or other stewing beef, cubed", "2 tbsp unsalted butter", "4 medium onions, thinly sliced", "1 tbsp brown sugar", "2 tbsp red wine vinegar", "2 None thick slices bread, crusts removed", "2 tbsp wholegrain mustard", "3 1/3 cups dark beer (stout)", "2 None bay leaves"]\nRecipe Instructions:\n1. "Preheat the oven to 300\\u00b0F.\n2. Heat oil in a Dutch oven on high heat. Season beef. Brown in batches for 3-4 mins. Remove and set aside.\n3. Melt butter in same pan on medium heat. Saute onions for 5 mins, until tender and golden. Add brown sugar and cook, stirring, for 3-4 mins, until caramelized. Stir in vinegar and cook for 1-2 mins, until evaporated. Remove and set aside.\n4. Spread bread with mustard. Tear into 3 equal pieces. Pour 2 cups of beer into the pan. Bring to a boil, scraping bottom of pan. Return half of meat to the pan. Top with onions. Top with bread, mustard side-up, and bay leaves. Finish with remaining beef.\n5. Adding remaining beer to nearly cover meat. Bring to a simmer. Cover with parchment paper and lid.\n6. Bake for 3 hours, until beef is tender."\n']
# Recipe Title: Mushroom Broccoli Salad
# ...
# Recipe Title: Bret Favre's Mother's Cajun Chili Recipe
# Ingredients: ["2 lb Grnd chuck", "1 can (12-ounce) tomato juice (more if needed)", "1 can (10.5-ounce) diced tomatoes with green chilies", "1 x Green bell pepper, diced", "1 x Onion, minced", "1 can (16-ounce) kidney beans", "1 can (12-ounce) beer", "4 x -(up to)", "6 Tbsp. Commercial chili pwdr", "1 tsp Salt Diced cheddar cheese and fritos, for garnish"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
# ['Recipe Title: BBQ Bhuna Chicken\nIngredients: ["1/4 cup Bull\'s-Eye Chicken & Rib Renegade Barbecue Sauce", "1 tsp. each ground coriander, ground cumin, garam masala, and corn starch", "1/2 tsp. red chili powder or cayenne pepper", "1 lb. (450 g) boneless skinless chicken breasts, cut into bite-size pieces", "1 Tbsp. oil", "1/2 cup finely chopped yellow cooking onions King Sooper\'s 1 lb For $0.99 thru 02/09", "1 Tbsp. finely grated gingerroot", "2 cloves garlic, finely grated", "1/2 tsp. cumin seed", "2 green onions, thinly sliced", "2 Tbsp. chopped fresh coriander (cilantro)", "2 Tbsp. fresh lemon juice Safeway 4 ct For $5.00 thru 02/09"]\nRecipe Instructions:\n1. "Mix barbecue sauce, ground coriander, cumin, garam masala, corn starch and chili powder until blended.\n2. Add to chicken in large bowl; toss to coat.\n3. Heat oil in large skillet on medium-high heat.\n4. Add next 4 ingredients; cook and stir 5 min.\n5. or until onions are crisp-tender.\n6. Add chicken mixture; cook 10 min.\n7. or until chicken is done and sauce is thickened, stirring frequently.\n8. Remove skillet from heat.\n9. Stir in remaining ingredients."\n']
# Recipe Title: Sesame Oil Chicken
# Ingredients: ["1/2 chicken (about 500g), cut to small pieces (you can also use drumlettes or chicken thighs)", "2 tbsp sesame oil", "1 tbsp cooking oil", "5 slices ginger sliced to thin strips", "Chinese wine", "(A) Seasonings", "50ml water", "1 tsp dark soy", "1/2 tsp light soy"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
# ['Recipe Title: Candied Chestnut Poundcake\nIngredients: ["70 grams Butter", "60 grams Sugar", "2 tbsp Syrup from candied chestnuts", "2 Eggs", "100 grams Flour", "2 grams Baking powder", "10 Candied chestnuts", "1 for glazing Syrup from candied chestnuts"]\nRecipe Instructions:\n1. "To prep the ingredients, bring the butter and eggs to room temperature, sift together the flour and baking powder, and chop the chestnuts into small pieces.\n2. Whip butter to cream-like consistency.\n3. Add sugar and mix until it\'s well blended.\n4. Add syrup from the candied chestnuts and mix.\n5. Beat an egg in a separate bowl, then mix into the batter, a little at a time.\n6. Add dry ingredients and fold in using a rubber spatula.\n7. Add the chestnuts, briskly stir, then pour into a poundcake mold.\n8. Bake for 30 to 40 minutes in a preheated oven set to 340F/170C.\n9. It\'s ready when a toothpick inserted into the middle comes out clean.\n10. Brush on syrup for glazing while it\'s still hot."\n']
# Recipe Title: Chicken Pineapple Stir-Fry
# Ingredients: ["1 can (20 ounces) unsweetened pineapple tidbits", "2 tablespoons cornstarch", "1/4 cup cider vinegar", "1/4 cup ketchup", "2 tablespoons brown sugar", "2 tablespoons reduced-sodium soy sauce", "1/4 teaspoon ground ginger", "1-1/2 pounds boneless skinless chicken breasts, cubed", "3 tablespoons canola oil, divided", "1/2 teaspoon garlic salt", "2 medium carrots, sliced", "1 medium green pepper, julienned", "1 medium tomato, cut into wedges", "Hot cooked rice"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
# ['Recipe Title: Sesame Baked Chicken Recipe\nIngredients: ["1 Tbsp. lemon juice", "1 Tbsp. Gravy Master", "2 Tbsp. vegetable oil", "1/3 tsp. poultry seasoning", "Salt and pepper to taste", "1/3 c. sesame seeds", "1 (2 1/2 to 3 lb.) frying chicken, cut up"]\nRecipe Instructions:\n1. "Arrange chicken pcs in baking pan in single layer.\n2. Combine lemon juice, Gravy Master, oil and poultry seasoning.\n3. Brush over chicken pcs.\n4. Sprinkle with salt and pepper and sesame seeds.\n5. Cover and bake at 400 degree symbol F. for one hour.\n6. Uncover and bake 15 to 20 min longer.\n7. Makes 4 servings."\n']
# Recipe Title: Cilantro Sauce
# Ingredients: ["2 bunches fresh cilantro chopped", "10 cloves garlic rough chopped", "4 jalapenos rough chopped", "1 sweet onion large, rough chopped", "1 teaspoon coarse salt", "1 teaspoon fresh ground black pepper", "1 teaspoon liquid smoke", "1 cup olive oil", "1/2 cup balsamic vinegar", "1/2 cup water"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
# ['Recipe Title: Roasted Butternut Squash Soup\nIngredients: ["1 butternut squash", "2 carrots", "1/4 medium onion", "1 apple", "1 teaspoon olive oil", "1/8 teaspoon curry powder...may need additional for taste", "1/8 teaspoon fresh grated ginger", "salt and pepper to taste", "3 cups chicken broth", "1 sprig dried sage"]\nRecipe Instructions:\n1. "Split the squash in half lengthwise with a sharp knife\n2. Cut carrots in half lengthwise\n3. Peel and core apple and slice\n4. slice onion\n5. smear cut side of squash and carrots with the olive oil then dust with curry powder\n6. place squash and carrots in 375 degree oven on baking sheet for 30 minutes then add apple slices and onion for another 15 minutes\n7. Place all roasted ingredients into a food processor and process on high for about 30 seconds or until all is smooth.\n8. Add the cooled chicken broth a cup at a time until smooth.\n9. Add the grated ginger at the end and season additionally to taste with additional Curry powder, salt and pepper\n10. For company may drizzle with a little cream or olive oil when serving"\n']
# Recipe Title: Butterscotch Spice Cake
# Ingredients: ["1 (18.25 ounce) package spice cake mix", "1 (3.4 ounce) package instant butterscotch pudding mix", "4 eggs", "1 cup water", "1/2 cup vegetable oil"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
# ['Recipe Title: Roasted Carrots With Cumin Seeds \nIngredients: ["4 tablespoons olive oil", "24 small fresh carrots with tops", "1 tablespoon cumin seeds", "1 tablespoon orange zest", "4 tablespoons fresh orange juice", "1/2 teaspoon sea salt", "1/4 teaspoon black pepper", "12 Medjool dates split and pitted", "1/4 cup whole milk Greek yogurt", "1/2 cup toasted sliced almonds", "1/4 cup loosely packed cilantro leaves"]\nRecipe Instructions:\n1. "Preheat oven to 325F\n2. Heat 2 tablespoons of the oil on medium heat in a large oven-proof skillet\n3. Add the carrots and cook until lightly browned on each side, about 6-8 minutes\n4. Add in cumin seeds and stir\n5. Put the skillet in the oven and roast for 8-10 minutes until tender.\n6. In a large bowl, whisk together the orange juice, orange zest, salt, peppper and remaining 2 tablespoons of oil\n7. Add the carrots to the bowl and mix to coat carrots\n8. Place skillet over medium heat\n9. Add dates to skillet, split side down and cook for ~4 minutes until golden brown\n10. Pile carrots on a serving dish and dollop with yogurt. Top with dates.\n11. Sprinkle with almonds and cilantro\n12. Drizzle with olive oil"\n']
# Recipe Title: Sauteed Calamari Salad
# Ingredients: ["1/2 cup fresh lime juice", "1/3 cup fish sauce", "1 tablespoon sugar", "1/2 tablespoon minced garlic", "1/2 tablespoon minced ginger", "3 each Thai bird chiles, minced", "1/4 cup minced cilantro", "1/4 cup thinly sliced mint", "1/4 cup thinly sliced Thai basil", "2 pounds fresh calamari, cleaned and cut into 1/2 inch rings, slice head in half lengthwise", "2 large, ripe tomatoes, medium dice", "2 pounds washed arugula in a large salad bowl", "Baguette croutons for garnish"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
# ['Recipe Title: Roast Duck with Orange Sauce\nIngredients: ["1 medium-sized whole duck", "1 diced apple", "1 diced orange", "1 diced onion", "1 tbsp (15 ml) rosemary", "1 tsp (5 ml) olive oil", "3 tbsp (45 ml) Grand Marnier", "salt and pepper to taste"]\nRecipe Instructions:\n1. "Season duck inside and out with salt, pepper, and rosemary.\n2. Glaze duck with olive oil.\n3. Stuff duck with all the apple, orange, and onion.\n4. Bake approximately 3 1/2 hours at 275 degrees (125 C.).\n5. Turn duck every 30 minutes and glaze with juices dropped into pan.\n6. Cool duck, remove stuffing, and debone gently.\n7. Place bones and stuffing in a medium pot with 2 cups (475 ml) of water.\n8. Boil for 45 minutes.\n9. Strain, and adjust seasoning, and add Grand Marnier.\n10. Serve duck with sauce, wild rice, and vegetables."\n']
# Recipe Title: Popcorn Christmas Wreath Cake Recipe
# Ingredients: ["5 to 6 quarts. popped popcorn", "1/2 pound butter", "1/2 c. oil", "1 pound miniature marshmallows", "1 pound gum drops", "1/2 pound unsalted roasted peanuts"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
# ['Recipe Title: Chicken Tetrazzini\nIngredients: ["8 ounces dried pasta (thin spaghetti or angel hair recommended)", "2 tablespoons vegetable oil", "1 medium onion, sliced into slivers", "1 teaspoon garlic powder", "1/2 teaspoon white pepper", "2 tablespoons all-purpose flour", "5 oyster mushrooms, slivered", "2 cups roasted chicken (page 16) shredded by hand or using two forks", "2 cups chicken stock", "1/2 cup heavy cream", "1 teaspoon salt", "1 teaspoon black pepper"]\nRecipe Instructions:\n1. "Bring 3 quarts of water to a rolling boil in a large pot.\n2. Add the pasta and let boil until cooked to desired tenderness.\n3. Drain and set aside.\n4. In a large skillet, heat the oil over medium-low heat.\n5. Add the onion and saute until translucent.\n6. Add the garlic powder, white pepper, and flour to the skillet and cook for 2 minutes, stirring frequently.\n7. Be careful not to let the mixture brown.\n8. Add the mushrooms, chicken, stock, cream, and salt and black pepper.\n9. Stir well to completely cover the chicken.\n10. Cover and let cook for 15 to 20 minutes over low heat.\n11. Serve over the cooked pasta."\n']
# Recipe Title: Slow Cooker Pork Chop And Potatoes in Mustard Sauce
# Ingredients: ["6 each pork loin chops up to 8 chops", "2 tablespoons vegetable oil", "1 each soup, cream of mushroom 10 oz can", "1/4 cup chicken broth", "1/4 cup dijon mustard country-style", "1/2 teaspoon thyme dried, crushed", "1 each garlic clove, minced OR 1/4 ts garlic powder", "1/4 teaspoon black pepper", "6 each potatoes cut in thin slices"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
# ['Recipe Title: Almond Joy Fudge Recipe\nIngredients: ["2 pkt semisweet chocolate chips", "2 can sweetened condensed lowfat milk", "2 tsp vanilla extract", "2 c. mini Almond Joy candy bars, cut into 1/4 inch pcs from 1 (1 lb.) package", "1 x tube green decorating icing, optional", "1 x tube red decorating icing, optional"]\nRecipe Instructions:\n1. "Butter square baking pan.\n2. Line with sufficient wax paper to overhang 2 sides by 2 inches.\n3. In pot combine chips and lowfat milk, over medium heat, cook, stirring constantly till mix is melted and smooth.\n4. Remove from heat, stir in vanilla.\n5. Cold 1 minute.\n6. Stir in candy bars.\n7. Spread mix proportionately in pan.\n8. Chill till hard, at least 2 hrs.\n9. Use wax paper to help remove from pan.\n10. Peel off paper, cut into squares.\n11. If you like, pipe holly leaf and berries on top of each piece with icings.\n12. Makes 36pieces."\n']
# Recipe Title: Pepperoni Bread Recipe
# Ingredients: ["1 frzn bread dough rolled out", "1 stick of pepperoni, sliced", "1 onion, minced", "1 egg", "1/2 c. Parmesan cheese", "1/2 c. Mozzarella cheese"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
# ['Recipe Title: Sweet Baked Carrots\nIngredients: ["1 (16 ounce) package frozen whole baby carrots", "1/2 cup white sugar", "1/3 cup butter", "1/3 cup boiling water", "1 teaspoon salt", "1/2 teaspoon ground cinnamon"]\nRecipe Instructions:\n1. "Preheat oven to 350 degrees F (175 degrees C).\n2. Arrange carrots in an 8-inch square pan. Combine sugar, butter, boiling water, salt, and cinnamon in a bowl; pour over carrots. Cover pan with aluminum foil.\n3. Bake in preheated oven until carrots are tender, about 1 1/2 hours."\n']
# Recipe Title: Roasted Pork Tenderloin
# Ingredients: ["1 package Pork Tenderloins (2 Loins Per Package)", "4 cloves Garlic", "2 sprigs Rosemary", "Salt And Pepper, to taste", "1/4 cups Olive Oil, Or As Needed To Drizzle On The Loins"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
# ['Recipe Title: Bombay Chicken Salad Recipe\nIngredients: ["1/2 c. light lowfat sour cream", "1/2 c. reduced-fat mayonnaise", "3 Tbsp. Major Grey\'s Chutney Juice of 1 lemon", "3 c. cooked pasta, such as orecchiette, corkscrew or possibly penne", "3 c. cooked cubed chicken", "1/2 c. minced green onions", "1/2 c. sliced celery", "1 c. pitted and sliced dates", "2 c. fresh or possibly canned pineapple chunks, liquid removed", "1/2 c. toasted almonds, minced (see note)", "1 x (11-oz) can mandarin oranges, liquid removed", "1/2 c. golden brown raisins"]\nRecipe Instructions:\n1. "Mix lowfat sour cream, mayonnaise, chutney and lemon juice in a large bowl.\n2. Add in pasta, chicken, green onions, celery, dates, pineapple, almonds, oranges and raisins, and toss gently.\n3. If you wish, refrigerateup to an hour before serving.\n4. Note: To toast nuts, heat in a dry skillet over medium heat till they start to brown.\n5. Stir occasionally.\n6. Be careful not to scorch them.\n7. -\n8. Trader Joe\'s"\n']
# Recipe Title: Three Cheese Tart
# Ingredients: ["1 sheet frozen puff pastry, thawed", "1 1/2 cups ricotta cheese", "1 cup crumbled feta cheese", "1/4 cup grated Parmesan cheese", "3 None eggs", "1/4 cup heavy cream", "1 None lemon, grated peel only", "2 tbsp pine nuts", "None None Salad, to serve"]
# Recipe Instructions:
# Saving the dataset (0/1 shards):   0%|          | 0/3671 [00:00<?, ? examples/s]

# %%
generated_dataset_three_shot_instructions = three_shot.map(
    generate_instruction_batch,
    batched=True,
    batch_size=BATCH_SIZE,
    fn_kwargs={"cot": False, "model": model, "tokenizer": tokenizer, "examples": 3}
)
generated_dataset_three_shot_instructions.save_to_disk(f'{recipe_nlg_data_path}/Generated_Data/oob_three_shot_generated')
# Out:
# Map:   0%|          | 0/3671 [00:00<?, ? examples/s]
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
# ['Recipe Title: Vanilla Tapioca Pudding\nIngredients: ["2-3/4 cups Milk", "1 Egg, Beaten", "1/3 cups Honey", "2 Tablespoons Instant Tapioca Mix (like Kraft)", "1 teaspoon Vanilla Extract", "1 teaspoon Grated Lemon Zest, Optional"]\nRecipe Instructions:\n1. "1. In a medium saucepan (off the heat), whisk milk, egg, honey, and tapioca until combined. Allow to sit 5 minutes.\n2. 2. Then bring milk mixture to a boil over medium heat, stirring constantly. Remove from heat and stir in vanilla and lemon zest if desired. Let the mixture sit 20 minutes. It will thicken into a custard-y pudding during this time. Refrigerate 1 hour if you like your pudding cold. Or serve warm.\n3. Yield: 6 servings\n4. Store in the refrigerator for up to 3-4 days."\n\nRecipe Title: Manhattan Sunrise\nIngredients: ["1/2 cup bourbon, Makers Mark preferred", "2 tablespoons sweet vermouth", "2 dashes bitters", "Splash of orange juice", "2 tablespoons Chambord", "4 maraschino cherries"]\nRecipe Instructions:\n1. "Combine the bourbon, vermouth, bitters, and OJ in a shaker.\n2. Shake it up and pour into 2 highball glasses filled with ice.\n3. Add the Chambord by tilting the glass and slowly pouring it down the side of the glass (as you would a beer).\n4. The Chambord should go straight to the bottom and then rise up slowly through the drink.\n5. Garnish each drink with a couple of cherries."\n\nRecipe Title: Baked Red Snapper in a Mediterranean Tomato Sauce\nIngredients: ["1/2 tablespoon olive oil, extra virgin if available", "4 pounds tomatoes, peeled, seeded, and diced or 6 pounds canned tomatoes, drained and diced", "3 shallots, finely chopped", "2 garlic cloves, finely chopped", "1 small bulb fennel, finely diced*", "1 pinch saffron", "1/2 teaspoon salt", "1/4 teaspoon freshly ground pepper", "10 sprigs parsley, chopped, plus 8 whole sprigs, for garnish", "1 whole red snapper (4 to 5 pounds)"]\nRecipe Instructions:\n1. "Preheat the oven to 350.\n2. In a large skillet, heat the oil over high heat.\n3. Add the tomatoes, shallots, garlic, and fennel and cook, stirring occasionally, until the tomatoes soften but still have some shape, about 5 minutes.\n4. The tomatoes excess moisture should have evaporated, but if not, strain and reserve the tomatoes and return the excess liquid to the pan.\n5. Cook the liquid over high heat until it is reduced to a syrup.\n6. Return the tomatoes to the pan, and season with the saffron, salt, and pepper.\n7. Stir in the chopped parsley.\n8. (The sauce can be made ahead of time.\n9. Let cool to room temperature, cover, and refrigerate.)\n10. Place a layer of the sauce on a large, deep ovenproof serving platter.\n11. Place the fish on the platter and cover all but the head and tail with the remaining sauce.\n12. Bake 50 to 60 minutes, until a knife penetrates easily to the bone.\n13. Decorate the platter with parsley sprigs and serve."\n']
# Recipe Title: Dinah'S Stuffed Mushrooms
# Ingredients: ["20 fresh mushrooms, stems removed", "2 (6.5 ounce) cans minced clams, drained", "2 cloves garlic, peeled and minced", "1/2 cup grated Parmesan cheese", "1 small onion, finely chopped", "3/4 cup dry bread crumbs", "1/2 cup chopped green bell pepper", "2 tablespoons dried parsley", "2 tablespoons Italian-style seasoning", "ground black pepper to taste", "1 1/2 cups butter, melted", "1/2 cup shredded mozzarella cheese"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
# ['Recipe Title: Turkey Loaf with Spinach\nIngredients: ["1 pound turkey breast cut into 1 inch cubes and frozen for 45 minutes", "1 cup onions peeled and diced", "1 large carrots peeled and sliced", "1/4 cup bread crumbs plain", "4 each egg whites", "1/4 teaspoon salt", "1/4 teaspoon cayenne pepper", "1 teaspoon paprika", "1/2 teaspoon thyme", "10 1/2 ounces spinach frozen, chopped, cooked and drained", "2 each egg whites", "2 tablespoons parmesan, parmigiano-reggiano cheese, grated grated", "1/4 teaspoon salt", "1/4 teaspoon black pepper", "1 x vegetable oil spray"]\nRecipe Instructions:\n1. "Place the turkey, onions and carrot in the bowl of a food processor fitted with the steel blade and puree.\n2. Combine with the remaining meat ingredients in a bowl.\n3. Mix well.\n4. Combine the filling ingredients (but not the vegetable spray) and mix well.\n5. Spray a baking sheet with vegetable oil spray.\n6. Place half the meat on the sheet and form a rectangle 8 x 4 inch.\n7. Make a long mound in the center with the spinach and then cover with the remaining meat, smooth the edges.\n8. Bake for 1 hour in a preheated 375 degree F oven and then serve hot, warm or chilled."\n\nRecipe Title: Pineapple BBQ Shrimp\nIngredients: ["2 tablespoons Land O Lakes Butter", "1 pound large (21 to 30 count) fresh peeled deveined shrimp, tails removed", "1 teaspoon finely chopped fresh garlic", "1 large (1 cup) green or red bell pepper, cut into 3/4-inch pieces", "1 large (1 cup) onion, cut into 3/4-inch pieces", "1 (8-ounce) can pineapple tidbits, drained", "1/2 cup prepared barbecue sauce", "Hot cooked rice", "Chopped fresh parsley, if desired"]\nRecipe Instructions:\n1. "Melt 1 tablespoon butter in 12-inch skillet or wok over medium-high heat until sizzling; add shrimp and garlic.\n2. Cook, stirring occasionally, 2-3 minutes or until shrimp turn pink.\n3. Remove shrimp from pan; set aside.\n4. Melt remaining 1 tablespoon butter in same pan over medium-high heat; add green pepper and onion.\n5. Cook, stirring occasionally, 3-4 minutes or until vegetables are crisply tender.\n6. Stir in cooked shrimp, pineapple tidbits and barbecue sauce.\n7. Cook over medium heat, stirring occasionally, 1-2 minutes or until heated through.\n8. Serve immediately over hot cooked rice; sprinkle with chopped fresh parsley, if desired."\n\nRecipe Title: Linguine In Tomato And Speck Sauce\nIngredients: ["1/2 onions peeled and diced", "1 3/4 ounces speck or smoked ham, chopped", "28 ounces diced tomatoes canned, with basil", "extra-virgin olive oil", "3/4 pound linguine", "Parmesan cheese grated", "fresh basil minced"]\nRecipe Instructions:\n1. "In a frying pan, heat 4 tablespoons of oil and add the onion and speck. Saute for a few minutes.\n2. Add the tomato and cook for another 10 minutes.\n3. Cook the pasta in boiling salted water for 9 minutes.\n4. Drain the and add to the tomato mixture.\n5. Serve sprinkled with parmesan and basil."\n']
# Recipe Title: Roasted Cauliflower
# Ingredients: ["2 teaspoons olive oil", "2 medium onions, quartered", "5 garlic cloves, halved", "4 cups cauliflower florets (about 1 1/2 pounds)", "Cooking spray", "1 tablespoon water", "1 tablespoon Dijon mustard", "1/2 teaspoon salt", "1/4 teaspoon freshly ground black pepper", "1 tablespoon chopped fresh flat-leaf parsley"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
# ['Recipe Title: Simple Salsa Guacamole\nIngredients: ["2 Avocados", "3 Tablespoons Salsa", "2 Tablespoons Taco Seasoning", "2 teaspoons Lime Juice", "Tortilla Chips Or Cucumber Slices, To Serve"]\nRecipe Instructions:\n1. "Cut avocados in half, remove the pits and score the flesh.\n2. Scoop out flesh and put it into a bowl.\n3. Stir in salsa, taco seasoning and lime juice.\n4. Refrigerate until serving.\n5. Keep avocado pits in the guacamole until serving to prevent browning.\n6. Serve with tortilla chips or cucumber slices."\n\nRecipe Title: Tuscan Grill Panini\nIngredients: ["1/2 cup KRAFT Tuscan House Italian Dressing and Marinade, divided", "2 (4 ounce) boneless skinless chicken breast halves", "1 red pepper, cut into strips", "1 small zucchini, cut lengthwise in half, then sliced crosswise", "4 slices Italian bread", "1/2 cup KRAFT Shredded Low-Moisture Part-Skim Mozzarella Cheese", "2 tablespoons chopped fresh basil"]\nRecipe Instructions:\n1. "Reserve 1 tablespoon dressing; pour remaining over chicken and vegetables in shallow dish. Stir vegetables and turn chicken to evenly coat both sides of each piece. Refrigerate 30 min. to marinate.\n2. Heat panini grill. Meanwhile, drain chicken and vegetables; discard marinade. Cook chicken and vegetables in skillet on medium heat 10 min. or until chicken is done (165 degrees F) and vegetables are crisp-tender, turning chicken after 5 min. and stirring vegetables occasionally.\n3. Fill bread slices with chicken, vegetables, cheese and basil to make 2 sandwiches; brush outsides with reserved dressing. Grill 5 min. or until golden brown."\n\nRecipe Title: Pamper\'D Pumpkin Pie \nIngredients: ["1 Pamper\'d Pumpkin Pie", "1/2 cup pumpkin", "1/2 cup granulated sugar", "1/2 cup brown sugar", "1 pinch of salt", "1/2 tsp. cinnamon", "1/4 tsp. allspice", "3 eggs", "1/2 cup evaporated milk", "1/2 cup water"]\nRecipe Instructions:\n1. "Clean your Pamper\'d Pie Pumpkin (remove the stem and seeds).\n2. Cut pumpkin in to squares.\n3. Put into a large baking dishand cover with foil.\n4. Bake at 400\\u00b0 for 30 minuted or until tender.\n5. Scoop out flesh from skin and puree until smooth.\n6. If there is excess liquid, let stand for 30 min and drain with a cheese cloth.\n7. Blend sugars, pumpkin and spices until smooth.\n8. Add three eggs, 1/2 cup evaporated milk and 1/2 cup water.\n9. Blend just until mixed.\n10. (Note: Eggs and milk must go in after the pumpkin. Don\'t over mix the eggs and milk)\n11. Pour filling into pie crust 2/3 full.\n12. Transfer to oven and bake at 375\\u00b0 for one hour (or until set and crust is cooked)"\n']
# Recipe Title: Grilled Salmon Steaks with Lime Butter
# Ingredients: ["1/2 cup (1 stick) butter, melted", "1/4 cup lime juice", "1 tablespoon pepper", "4 9-ounce salmon steaks", "Lime wedges"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
# ['Recipe Title: 20 Minute Vegetable Beef & Rice Skillet Dinner\nIngredients: ["1 lb. ground beef", "1 small onion, chopped", "1 can (14-1/2 oz.) diced tomatoes, undrained", "1 can (10-1/2 oz.) condensed beef broth", "1 cup frozen mixed vegetables, thawed", "2 cups instant white rice, uncooked", "1/4 cup KRAFT Grated Parmesan Cheese"]\nRecipe Instructions:\n1. "Brown meat with onion in large skillet on medium-high heat; drain.\n2. Add tomatoes with liquid, broth and vegetables; stir.\n3. Bring to boil.\n4. Stir in rice and cheese; cover.\n5. Remove from heat.\n6. Let stand 5 minutes."\n\nRecipe Title: Dressed Oyster Po\'Boys\nIngredients: ["1 1/4 cups self-rising cornmeal", "2 tablespoons Creole seasoning", "2 (12-ounce) containers fresh select oysters, drained", "Peanut or vegetable oil", "1 cup mayonnaise, divided", "2 tablespoons white vinegar", "2 tablespoons Dijon mustard", "1 (10-ounce) package finely shredded cabbage", "2 tablespoons ketchup", "1 tablespoon prepared horseradish", "1 teaspoon Creole seasoning", "3/4 teaspoon paprika", "4 French bread rolls, split and toasted"]\nRecipe Instructions:\n1. "Combine cornmeal and Creole seasoning; dredge oysters in mixture.\n2. Pour oil to a depth of 2 inches into a Dutch oven; heat to 375\\u00b0. Fry oysters, in 3 batches, 2 to 3 minutes or until golden. Drain on wire racks.\n3. Stir together 1/2 cup mayonnaise, vinegar, and mustard. Stir in cabbage; set slaw aside.\n4. Stir together remaining 1/2 cup mayonnaise, ketchup, and next 3 ingredients.\n5. Spread cut sides of rolls with mayonnaise mixture. Place oysters and slaw evenly on bottom halves of rolls; cover with roll tops."\n\nRecipe Title: Herb-Crusted Chicken with VELVEETA Shells & Cheese Dinner\nIngredients: ["1-1/2 tsp. Italian seasoning", "1/2 tsp. garlic powder", "4 small boneless skinless chicken breasts (1 lb.)", "1 Tbsp. oil", "1 pkg. (12 oz.) VELVEETA Shells & Cheese Dinner"]\nRecipe Instructions:\n1. "Combine Italian seasoning and garlic powder; sprinkle evenly over both sides of chicken breasts.\n2. Heat oil in large skillet.\n3. Add chicken; cook 10 to 12 minutes or until cooked through and evenly browned on both sides, turning occasionally.\n4. Meanwhile, prepare the VELVEETA Shells & Cheese Dinner.\n5. Serve with chicken."\n']
# Recipe Title: Broccoli Casserole
# Ingredients: ["2 pounds broccoli florets fresh, cut into florets", "1 each soup, cream of mushroom 10-3/4 oz can, condensed, undiluted", "1/2 cup mayonnaise", "2 cups cheddar cheese", "1 tablespoon lemon juice", "1 x seasoned dry bread crumbs"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
# ['Recipe Title: Cinnamon Date Cake Mix Cookies\nIngredients: ["cooking spray", "1 (21.5 ounce) package cinnamon swirl cake mix (with cinnamon flavoring packet)", "1 cup chopped dried dates", "1 cup chopped walnuts (optional)", "1/2 cup egg white substitute", "1/2 cup olive oil"]\nRecipe Instructions:\n1. "Preheat oven to 350 degrees F (175 degrees C). Grease a baking sheet with cooking spray.\n2. Mix cinnamon cake mix, flavoring packet, dates, walnuts, egg white substitute, and olive oil together in a large bowl.\n3. Drop heaping tablespoonfuls of cake mixture onto the prepared baking sheet.\n4. Bake in the preheated oven until bottoms start to brown, 12 to 15 minutes. Let cool on the baking sheet, about 10 minutes."\n\nRecipe Title: Pasta Italiano\nIngredients: ["1 (15-ounce) container ricotta cheese", "1 large egg, lightly beaten", "2 teaspoons garlic powder", "14 jumbo pasta shells, cooked", "1 pound lean ground beef", "1 medium onion, chopped", "2 garlic cloves, pressed", "1 (28-ounce) can whole tomatoes", "1 (8-ounce) package sliced fresh mushrooms", "1 tablespoon chopped Italian parsley", "1 teaspoon salt", "1 teaspoon Italian seasoning", "1 (15-ounce) can tomato sauce", "Grated Parmesan cheese (optional)"]\nRecipe Instructions:\n1. "Stir together first 3 ingredients. Spoon 2 tablespoonfuls of mixture into each shell. Arrange shells, stuffed side up, into a lightly greased 11- x 7-inch baking dish. Set aside.\n2. Cook beef, onion, and garlic in a large skillet over medium heat 15 minutes, stirring until beef crumbles and is no longer pink; drain.\n3. Stir in tomatoes and next 4 ingredients; bring to a boil. Cover, reduce heat, and simmer, stirring occasionally, 10 minutes. Stir in tomato sauce; cook 2 minutes. Pour beef mixture over shells.\n4. Bake at 350\\u00b0 for 15 minutes. Sprinkle with Parmesan cheese, if desired."\n\nRecipe Title: Breaded chicken cutlets\nIngredients: ["1/2 cup flour", "1/3 cup panko bread crumbs", "1 pinch kosher salt", "2 pinch fresh ground black pepper", "1 tsp onion powder", "1 tsp garlic powder", "2 tbsp dried marjoram", "4 medium chicken breasts", "1 tsp old bay seasoning"]\nRecipe Instructions:\n1. "wash and pat dry chicken breasts.\n2. trim off excess fat and butterfly breasts.\n3. combine all dry ingredients thoroughly.\n4. bread chicken breasts using up nearly all of the dry mixture.\n5. cook in 1/2 cup light olive oil over med-high heat for 2-3min per side or until breading is golden brown."\n']
# Recipe Title: Linguine with Winter Pesto
# Ingredients: ["2 1/2 cups lightly packed Italian parsley leaves", "3/4 cup olive oil", "1/2 cup toasted pine nuts", "2 teaspoons fresh thyme leaves or 3/4 teaspoons dried, crumbled", "1 teaspoon minced fresh rosemary or 1/2 teaspoon dried, crumbled", "1 medium garlic clove", "1/3 cup freshly grated Parmesan cheese", "12 ounces linguine pasta", "1/3 cup chopped toasted pine nuts"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
# ['Recipe Title: Frozen Cranberry, Cherry and Orange Cocktail\nIngredients: ["1 cup cracked ice", "1 pony (1 ounce) cranberry liqueur", "1 pony (1 ounce) Cherry Heering", "1 pony (1 ounce) Grand Marnier", "1 tablespoon superfine granulated sugar, or to taste", "Garnish: twist of orange"]\nRecipe Instructions:\n1. "In a blender, blend cracked ice, cranberry liqueur, Cherry Heering, Grand Marnier and, if desired, sugar for 30 seconds.\n2. Pour into a chilled 12-ounce glass.\n3. Garnish with the twist of orange."\n\nRecipe Title: Bacon Avocado Potato Salad Recipe\nIngredients: ["6 med Boiling potatoes", "2 x Avocados -- cubed", "8 slc Bacon", "1/2 c. Minced onions -- minced", "1 Tbsp. Fresh lime juice", "1/2 c. White wine", "1/4 c. Cider vinegar Salt Black pepper Paprika", "1/4 tsp Mustard pwdr", "2 Tbsp. Fresh parsley -- minced", "1 Tbsp. Fresh cilantro -- minced"]\nRecipe Instructions:\n1. "Boil potatoes in their skins.\n2. While potatoes boil, cube avocados and toss with lime juice.\n3. Chop bacon into one inch pcs and fry till crisp in a large skillet.\n4. Remove bacon to paper towels to drain.\n5. In bacon fat, saute/fry onions till golden brown.\n6. Remove pan from heat and stir in wine, vinegar, mustard, and salt, pepper, and paprika to taste.\n7. When potatoes are tender, drain, peel, and dice.\n8. While still hot, pour dressing over potatoes and toss.\n9. Allow to cold to room temperature.\n10. Mix in avocado, bacon, parsley, and cilantro.\n11. Serve at room temperature or possibly refrigerateone hour or possibly longer."\n\nRecipe Title: Cranberry-Pear Pie\nIngredients: ["2 1/2 cups peeled, quartered, cored pears, sliced crosswise", "2 cups fresh or thawed frozen cranberries", "1 tablespoon lemon juice", "1 1/2 tablespoons cornstarch", "1 tablespoon milk", "2/3 cup plus 1 teaspoon sugar", "Refrigerated or frozen prepared piecrust"]\nRecipe Instructions:\n1. "Preheat the oven to 400\\u00b0 F.\n2. Mix the pears, cranberries, and lemon juice in a large bowl. Add 2/3 cup sugar and cornstarch and stir them into the fruit. Pour the filling into the pie shell.\n3. Invert the top pastry over the filling and press the edges together. Trim the pastry flush with the edge of the pan and crimp with a fork. Poke several steam vents in the top. Lightly brush on the milk and sprinkle 1 teaspoon sugar.\n4. Bake for 30 minutes. Reduce the oven temperature to 375\\u00b0 F. Bake until the juices bubble thickly, 25 to 30 minutes more. Cool 2 hours."\n']
# Recipe Title: Dulce De Leche Ice Cream
# Ingredients: ["2 cups whole milk", "1 cup heavy cream", "1 pound", "(about 1 2/3 cups; preferably La Salamandra brand)", "1/8 teaspoon pure vanilla extract", "3/4 cup chopped pecans (2 1/2 to 3 oz),", "an ice cream maker"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
# ['Recipe Title: Chickpea Sundal \nIngredients: ["1 tablespoon virgin coconut oil or vegetable oil", "2 teaspoons black or brown mustard seeds", "6 fresh curry leaves", "3 dried Kashmiri or guajillo chiles, broken into pieces, seeds removed", "1/4 teaspoon asafetida (optional)", "2 (15-ounce) cans chickpeas, rinsed", "Kosher salt", "1/4 cup freshly grated coconut or unsweetened shredded coconut", "Lime wedges (for serving)"]\nRecipe Instructions:\n1. "Heat oil in a large skillet over medium-high. Cook mustard seeds, swirling pan occasionally, until oil begins to sputter. Add curry leaves, chiles, and asafetida (if using) and cook, stirring occasionally, until curry leaves are slightly darkened, about 45 seconds. Add chickpeas; cook, tossing often, just until warmed through, about 3 minutes. Let cool; season with salt.\n2. Scoop sundal into a bowl; top with coconut. Serve with lime wedges.\n3. Asafetida is a combination of dried gum resins from plant roots; available at Indian markets."\n\nRecipe Title: Chicken Paella\nIngredients: ["1 pound italian sausage", "1 each chicken, whole", "1 medium onions chopped", "1 small green bell peppers cut into chunks", "1 clove garlic minced", "3/4 cup long grain rice", "1 1/2 teaspoons chicken broth", "1/4 teaspoon turmeric ground", "3 cups water hot", "4 each carrots cut into 3 inch chunks"]\nRecipe Instructions:\n1. "Brown sliced sausage in 4 quart Dutch oven over medium heat.\n2. Cut chicken into serving pieces.\n3. Brown in sausage drippings; season with salt and pepper.\n4. Remove chicken.\n5. Add onion, green pepper and garlic; cook until onion is tender.\n6. Stir in uncooked rice, bouillon, turmeric and water; bring to boiling.\n7. Add sausage and carrots.\n8. Arrange chicken on top.\n9. Cover and bake at 375F (190C).\n10. for 40 minutes or until chicken and rice are tender.\n11. To serve, toss mixture gently together."\n\nRecipe Title: Buttermilk Biscuits\nIngredients: ["1 1/2 cup Rice flour", "1 1/2 cup Coconut flour", "1/2 tsp xanthum gum", "1 tbsp baking powder", "1 tbsp sugar substitute, such as splenda", "1 tsp baking soda", "1/2 tsp salt", "2/3 cup shortening", "1 1/2 cup buttermilk (or up to 2 cups)"]\nRecipe Instructions:\n1. "Combine flours, xanthum gum, sugar, baking powder, baking soda, & salt.\n2. Mix well.\n3. Add shortening.\n4. Mix together with fork or pastry blender until mixture looks like fine crumbs.\n5. Make a well in the middle & add 1 cup of buttermilk.\n6. Mix together until soft dough forms & leaves side of bowl, adding more buttermilk as needed to reach this consistency.\n7. (If don\'t have buttermilk, can substitute with putting 2 tbsp of vinegar in measuring glass then add enough milk of your choice & stir.\n8. Let set 5 minutes.\n9. Stir again & add to recipe.)\n10. Preheat oven to 450F.\n11. Form into 2\\" balls then flatten some.\n12. Place on ungreased cookie sheet.\n13. Bake for 15-20 minutes or until golden brown."\n']
# Recipe Title: Asparagus With Garlic And Balsamic Reduction
# Ingredients: ["1 pound asparagus spears, trimmed", "Cooking spray", "2 tablespoons sliced garlic", "1 teaspoon olive oil", "1/2 cup balsamic vinegar", "1/2 teaspoon kosher salt", "1/2 teaspoon black pepper"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
# ['Recipe Title: Easy Potato Soup\nIngredients: ["5 each bacon", "1 teaspoon margarine", "1/4 cup onions minced", "1 cup soup, cream of potato", "5 ounces water", "5 ounces milk", "1 x cayenne pepper", "1 x salt", "1 x paprika"]\nRecipe Instructions:\n1. "Cook bacon until crisp.\n2. Drain on paper towel.\n3. Pour off half the bacon drippings and add butter.\n4. Saute onion until tender and lightly browned.\n5. Combine soup, milk and water in saucepan.\n6. Add dash of cayenne pepper and salt.\n7. Heat, stirring.\n8. crumble bacon and add to soup along with the onion."\n\nRecipe Title: Cabbage Tabbouleh \nIngredients: ["1/4 cup bulgur (not quick-cooking)", "1/4 medium head of green cabbage, cored, very thinly sliced (about 4 cups)", "1/2 medium white onion, very thinly sliced", "2 cups very finely chopped parsley", "1 cup mint leaves, torn if large", "1 tsp. ground allspice", "1/3 cup extra-virgin olive oil", "1/3 cup fresh lemon juice", "Kosher salt", "Fresh green chiles (optional)"]\nRecipe Instructions:\n1. "Place bulgur in a small bowl; pour in boiling water to cover by 2\\". Let soak until tender, about 50 minutes; drain.\n2. Toss cabbage, onion, parsley, mint, allspice, and half of the bulgur in a large bowl. Drizzle olive oil and lemon juice over tabbouleh and season with salt; toss again to combine.\n3. Transfer tabbouleh to a platter and sprinkle with remaining bulgur. Serve with chiles alongside if desired (they\'re meant to add some heat in between bites of the cooling tabbouleh)."\n\nRecipe Title: Marinated Crab Salad\nIngredients: ["1 cup olive oil", "1 cup red wine vinegar", "2 large garlic cloves, minced", "1 1/2 teaspoons salt", "1/2 teaspoon freshly ground black pepper", "1/2 cup chopped parsley, leaves", "1/4 cup chopped fresh tarragon", "1/2 pound cooked lump or back fin crabmeat", "1/2 pound cooked special crabmeat", "6 cups mixed greens", "4 to 6 lemon wedges"]\nRecipe Instructions:\n1. "In a non-reactive bowl combine the oil, vinegar, garlic, salt, pepper, parsley, and tarragon.\n2. Add the crab and place in the refrigerator.\n3. Toss every hour for 4 hours.\n4. Serve on a bed of mixed greens and squeeze a lemon wedge over right before eating."\n']
# Recipe Title: Canned  Rueben
# Ingredients: ["12 ounces elbow macaroni", "1 (10.75 ounce) can condensed cream of mushroom soup", "6 ounces shredded mozzarella cheese", "12 ounces sauerkraut", "1 (12 ounce) can corned beef"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
# ['Recipe Title: Basic Roll Dough Recipe\nIngredients: ["1 pkt Active dry yeast", "1/4 c. Water, hot", "1 c. Lowfat milk, scalded", "1/2 c. Sugar", "1/4 c. Shortening", "1 tsp Salt", "3 1/2 c. Flour, self-rising", "1 x Egg"]\nRecipe Instructions:\n1. "Soften yeast in water.\n2. Combine lowfat milk, sugar, shortening and salt.\n3. Add in 1-1/2 c. flour and beat well.\n4. Beat in egg and then yeast.\n5. Gradually add in remaining flour to create soft dough, beating well.\n6. Place in greased bowl, cover and let rise till double (about 1-1/2 - 2 hrs or possibly you can put it in the refrigerator, see recipe below).\n7. Turn out on lightly floured surface and shape as desired.\n8. Cover and let rise until double (30-45 min).\n9. Bake on greased baking sheet 10-13 min at 400 .\n10. Yield: 2 dozen rolls.\n11. Refrigerator rolls: Prepare Basic roll dough as seen above.\n12. Don\'t LET RISE.\n13. Place dough in greased bowl, cover and chill at least 2 hrs or possibly up to 4 or possibly 5 days.\n14. About 2 hrs before serving, shape the dough on floured surface.\n15. Cover and let rise till double (1-1/4 hrs).\n16. Bake as above."\n\nRecipe Title: Tomato Soup With Herb Dumplings\nIngredients: ["2 cans (14-1/2 ounces each) diced tomatoes, undrained", "4 cups tomato juice", "1/4 cup butter", "1 teaspoon beef bouillon granules", "1/4 teaspoon garlic powder", "1/4 teaspoon salt", "1/4 teaspoon pepper", "1/4 teaspoon dried oregano", "1-1/2 cups all-purpose flour", "2 teaspoons baking powder", "1/4 teaspoon salt", "1/4 teaspoon poultry seasoning", "1/4 teaspoon dried parsley flakes", "1 egg", "2/3 cup milk"]\nRecipe Instructions:\n1. "In a Dutch oven, combine the first eight ingredients; bring to a boil. Reduce heat to simmer.\n2. Meanwhile, for dumplings, combine the dry ingredients in a bowl. Beat egg and milk; stir into dry ingredients until a stiff dough forms. Drop by tablespoonfuls onto simmering soup.\n3. Cover and simmer for 20 minutes or until toothpick inserted into a dumpling comes out clean (do not lift the cover while simmering). Serve immediately."\n\nRecipe Title: Broccoli Romanesco With Green Herb Sauce\nIngredients: ["6 to 8 baby heads broccoli romanesco*; or 1 full-size head or 1 head cauliflower, broken into florets", "1/2 cup coarsely chopped flat-leaf parsley leaves", "1 teaspoon chopped fresh oregano", "1 teaspoon chopped fresh thyme leaves", "Zest of 1 large lemon", "2 tablespoons lemon juice", "2 tablespoons brined capers, rinsed and chopped", "2 tablespoons finely diced shallot (about 1 medium)", "1 small garlic clove, minced", "1/2 cup extra-virgin olive oil", "Sea salt and pepper"]\nRecipe Instructions:\n1. "Peel only toughest outer leaves from broccoli romanesco, leaving tender inner ones attached. Steam broccoli in a steamer basket over simmering water, covered, until tender to the core when pierced with a knife, 15 to 20 minutes. Put in a serving dish.\n2. Meanwhile, mix remaining ingredients, seasoning with salt and pepper to taste.\n3. Spoon about half the green herb sauce over broccoli and turn gently to coat. Serve warm or at room temperature, with extra sauce on the side.\n4. *Find at farmers\' markets in fall and winter, and increasingly at well-stocked grocery stores.\n5. Make ahead: Sauce, up to 1 day, chilled (add lemon juice at the last minute, or it will dull the sauce\'s color). Broccoli romanesco may be steamed a few hours ahead; let sit, loosely covered, at room temp (if chilled overnight in a container, it gets sulfurous).\n6. Note: Nutritional analysis is per serving with 1 Tbsp. extra sauce."\n']
# Recipe Title: Carrot "Pasta" With Hot Peppered Raisins
# Ingredients: ["1 box plain or falvored quick cooking couscous", "2 tablespoons light vegetable oil", "2 tablespoons unsalted butter", "2 large shallots, minced", "A 1-inch piece fresh ginger, peeled and finely chopped", "8 ounces golden raisins", "1/4 teaspoon hot red pepper flakes, or more to taste", "10 large carrots, preferably California grown core; discard cores", "2 cups heavy cream", "1-1/2 cups light vegetable broth", "1 cup thawed petite peas", "kosher salt and freshly ground black pepper, to taste"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
# ['Recipe Title: Chive Linguine With Or Without Fresh Clams\nIngredients: ["For the pasta", "2 large egg yolks", "1/2 cup heavy cream", "2 tablespoons vermouth or dry white wine", "1/2 teaspoon freshly ground black pepper", "Kosher salt", "1 pound linguine, fresh or dried", "3/4 cup finely chopped fresh chives and chive blossoms", "For the clams (optional)", "2 tablespoons unsalted butter", "1 garlic clove", "2-3 pounds little neck clams, scrubbed"]\nRecipe Instructions:\n1. "Whisk the yolks, cream, vermouth and pepper in a mixing bowl and set aside.\n2. Bring a large pot of well-salted water to a boil. Add the linguine and cook until al dente. Reserve 1/2 cup pasta water if not using clams.\n3. If using clams, melt the butter in a large saute pan. Add the garlic clove and cook until fragrant, about 30 seconds. Add the clams, cover the pot and steam until they all open, about 8 minutes.\n4. When the linguine is al dente, drain it well and return it to the pot over low heat.Add the reserved egg mixture and stir until the sauce coats the pasta. Add the chives and stir to blend. (If you are not adding clams, add some of the reserved pasta water to keep the sauce creamy.)\n5. If using clams, strain them from their liquid, add them to the pasta and stir to coat them in the sauce with enough of the cooking liquid to keep the sauce creamy."\n\nRecipe Title: Pork And Apple Supper\nIngredients: ["1-1/2 pounds boneless pork, cubed", "1 tablespoon canola oil", "4 cups water", "1 tablespoon chicken bouillon granules", "1 teaspoon dried thyme", "1/4 teaspoon pepper", "1 bay leaf", "10 to 12 small red potatoes (about 2 pounds), quartered", "4 medium tart apples, peeled and cut into wedges", "2 tablespoons cornstarch", "2 tablespoons cold water"]\nRecipe Instructions:\n1. "In a Dutch oven, brown pork in oil. Add water, bouillon, thyme, pepper and bay leaf; bring to a boil. Reduce heat; cover and simmer for 1-1/2 to 2 hours or until pork is tender.\n2. Add potatoes; cover and cook for 15 minutes. Add apples; cover and cook for 10-12 minutes or until crisp-tender. Discard bay leaf.\n3. Combine cornstarch and cold water until smooth; stir into pork mixture. Bring to a boil; cook and stir for 2 minutes or until thickened."\n\nRecipe Title: Rhubarb Berry Cheesecake Pie\nIngredients: ["1 package (8 ounces) cream cheese, softened", "1 can (14 ounces) sweetened condensed milk", "6 tablespoons lemon juice", "1 teaspoon grated lemon zest", "1 teaspoon vanilla extract", "Dash salt", "1 graham cracker crust (9 inches)", "2 cups sliced fresh or frozen rhubarb", "1/2 cup sugar", "1/4 cup water", "1 pint fresh strawberries, hulled and halved lengthwise", "2 teaspoons lemon juice"]\nRecipe Instructions:\n1. "In a large bowl, beat cream cheese and milk until smooth. Beat in lemon juice, lemon zest, vanilla and salt; pour into crust. Refrigerate, covered, 2 hours.\n2. Meanwhile, in a large saucepan, bring rhubarb, sugar and water to a boil. Reduce heat; simmer, uncovered, 6-8 minutes or until rhubarb is tender. Drain.\n3. Stir in strawberries and lemon juice. Refrigerate until cold. Serve pie with topping."\n']
# Recipe Title: Avocado Hummus
# Ingredients: ["16 ounces chickpeas", "2 avocados cored and peeled", "1/4 cup olive oil", "1/4 cup lime juice", "1/2 teaspoon minced garlic", "3 tablespoons tahini", "salt to taste", "pepper to taste", "tomato chopped, for garnish", "onion chopped, for garnish", "cilantro for garnish"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
# ['Recipe Title: Easy Baked Fish & Chips\nIngredients: ["1 large baking potato (380 g), cut into 8 wedges", "2 Tbsp. Kraft Calorie-Wise Zesty Italian Dressing", "1 pouch (71 g) Shake\'N Bake Original Coating Mix, divided", "2 cod fillets (1/2 lb./225 g)", "2 Tbsp. Miracle Whip Calorie-Wise Spread Family Dollar $3.50 thru 02/07"]\nRecipe Instructions:\n1. "Heat oven to 400F.\n2. Toss potatoes with Italian dressing; spread onto bottom of 17x11-1/2x3/4-inch pan sprayed with cooking spray.\n3. Bake 15 min.\n4. Meanwhile, place 3 Tbsp.\n5. coating mix on plate.\n6. Spread fish with half the Miracle Whip; press, Miracle Whip-sides down, into coating mix.\n7. Repeat to coat other sides of fillets.\n8. Turn potatoes.\n9. Place around edges of pan; sprinkle with remaining coating mix.\n10. Place fish in centre of pan.\n11. Bake 15 min.\n12. or until fish flakes easily with fork and potatoes are tender."\n\nRecipe Title: Turkey Roasted Nyt \nIngredients: ["1 teaspoon cinamon", "1 tablespoon toasted coriander", "2 tablespoon ground cumin", "1 tablespoon ground black pepper", "2 tablespoons Lowrys seasoned salt", "8 pounds Butterball Turkey Breast with breast bone"]\nRecipe Instructions:\n1. "oven 250\n2. mix rub material in a bowl and rub thoroughly into the turkey\n3. set turkey on a rack in a roasting pan on a pce of foil for 2 hours\n4. remove from oven, wrap thoroughly and tightly in foil and replace in oven for at least 3 more hours\n5. at this point, keep it wrapped until you are ready to carve it up, or let it return to room temp and then refrigerate until you are ready to carve"\n\nRecipe Title: Bloody Good Steak\nIngredients: ["1 slab of flank steak", "2 tablespoons black peppercorns", "Extra-virgin olive oil", "Kosher salt", "Real Balsamic vinegar"]\nRecipe Instructions:\n1. "Place peppercorns in plastic bag (ziploc-type) and smash with a hammer until they are coarsely crushed.\n2. Drizzle meat on both sides with olive oil and salt. Rub peppercorns onto both sides, coating like steak au poivre.\n3. Heat cast-iron skillet until very hot. Cook meat on both sides (3 to 4 minutes or so, depending on size of slab). Meat should be well-browned but still rare. Should be soft to the touch when pressed\n4. Remove steak and drizzle liberally on both sides with vinegar. Let rest for 15 minutes. Slice and serve, spooning bloody juicy vinegar sauce onto meat."\n']
# Recipe Title: Shrimp Cakes
# Ingredients: ["1/2 cup mayonnaise", "1 tablespoon hot sauce", "1 pound shelled and deveined shrimp, chopped", "3/4 cup panko", "2 large eggs", "3 tablespoons finely chopped scallions", "1 teaspoon finely grated lemon zest", "3/4 teaspoon smoked paprika", "1 teaspoon salt", "1/2 teaspoon pepper", "1/4 cup extra-virgin olive oil", "Lemon wedges, for serving"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
# ['Recipe Title: Hawaiian Baked Beans Recipe\nIngredients: ["1 lg. can of pork and beans", "2 tbsp. Worcestershire sauce", "1/2 c. brown sugar", "7 ounce. catsup (almost a c.)", "1 sm. onion", "1 med. can of pineapple chunks"]\nRecipe Instructions:\n1. "Mix all together and simmer or possibly bake at 325 degrees for 1 1/2 hrs.\n2. If you wanted a casserole.\n3. You could add in celery and 1 lb.\n4. of hamburger meat browned."\n\nRecipe Title: Cream Cheese Pumpkin Roll\nIngredients: ["3 eggs", "1 cup white sugar", "2/3 cup pumpkin puree", "3/4 cup all-purpose flour", "2 teaspoons ground cinnamon", "1 teaspoon baking powder", "1 teaspoon ground ginger", "1/2 teaspoon ground nutmeg", "1/2 teaspoon salt", "Filling:", "1 (8 ounce) package cream cheese, softened", "1 cup confectioners\' sugar", "1/4 cup butter, softened", "1 tablespoon pumpkin puree", "1 teaspoon vanilla extract"]\nRecipe Instructions:\n1. "Preheat oven to 375 degrees F (190 degrees C). Grease a 10x15-inch jelly roll pan and line with wax paper.\n2. Beat eggs and white sugar in a large bowl until well blended; stir in 2/3 cup pumpkin puree.\n3. Combine flour, cinnamon, baking powder, ginger, nutmeg, and salt in another bowl; stir into egg mixture until just blended. Pour mixture into prepared jelly roll pan.\n4. Bake in preheated oven until a toothpick inserted into the center comes out clean, about 15 minutes. Cool in the pans for 10 minutes, then turn cake out onto a clean towel. Remove and discard wax paper. Roll cake up into the towel, starting with the short end. Cool.\n5. Beat cream cheese, confectioners\' sugar, butter, 1 tablespoon pumpkin puree, and vanilla extract in another bowl until smooth.\n6. Spread a large sheet of plastic wrap on a work surface. Place and unroll cake over plastic and spread with prepared filling. Re-roll cake and wrap with plastic. Refrigerate, seam-side down, until chilled, about 2 hours."\n\nRecipe Title: Sauteed Hotdogs and Carrots in Sauerkraut\nIngredients: ["2 lb beef hotdogs use your favorite", "14 oz Baverian style sauerkraut the one with caraway seeds in it", "27 oz sauerkraut", "1/2 cup sliced carrots", "2 tbsp olive oil, extra virgin"]\nRecipe Instructions:\n1. "Heat oil add the carrots saute for 4 minutes stirring occasionally.\n2. Add both sauerkrauts to carrots in pan.\n3. Add hotdogs saute covered for 7-8 minutes.\n4. Remove from heat.\n5. Let sit 5 minutes.\n6. Serve hope you enjoy!"\n']
# Recipe Title: Dry-Aged Strip Steaks Without Drying Or Aging
# Ingredients: ["1 1/2 ounces dried porcini mushrooms", "1/2 teaspoon granulated white sugar", "1/2 teaspoon ground white pepper", "2 10-ounce boneless New York strip steaks, about 1 inch thick", "2 tablespoons soy sauce (gluten-free if that is a concern)", "3 tablespoons unsalted butter", "2 tablespoons balsamic vinegar"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
# ['Recipe Title: Tailgate Ham & Cheese Sandwiches\nIngredients: ["1 1/2 stick melted butter", "3 1/2 tbsp horseradish sandwich spread", "4 tsp poppy seeds", "1/4 cup finely chopped onion", "2 lb thin sliced ham", "24 slice American cheese", "24 hamburger buns", "1 foil wrap"]\nRecipe Instructions:\n1. "Preheat oven to 350\n2. Mix together first 4 ingredients and brush on each side of 24 hamburger buns.\n3. Put ham on each side of bun with cheese in between the meat.\n4. Wrap sandwiches in foil and bake for 15 to 20 minutes.\n5. After cooking, put wrapped sandwiches directly into a cooler and transport to the big game, picnic or favorite event.\n6. They stay hot and melty in the cooler until you\'re ready for them."\n\nRecipe Title: Grain Free Low Carb Cheesy Bread Sticks\nIngredients: ["1 head Cauliflower, Washed, Dried Or 4 Cups Chopped", "1 cup Grated Parmesan Cheese", "1/4 cups Egg Whites Or 2 Egg Whites", "1 teaspoon Dried Italian Seasonings", "1 teaspoon Garlic Powder", "1/2 teaspoons Salt", "1 cup Mozzarella Cheese, Shredded", "Marinara Sauce, For Dipping"]\nRecipe Instructions:\n1. "Preheat oven to 450 degrees F. Line 2 baking sheets with parchment paper.\n2. Cut cauliflower into bite size pieces and steam for 20 minutes until just tender.\n3. (You can also microwave the cauliflower for 7-8 minutes instead).\n4. Place cauliflower in a food processor and pulse until the size of rice.\n5. Pour riced cauliflower into a large bowl and add Parmesan cheese, egg whites, and seasonings.\n6. Mix well then spread mixture onto baking sheet in a rectangular 8x12 shape.\n7. Bake for 30 minutes until browned on top.\n8. Invert over onto the other baking sheet with parchment paper.\n9. Bake another 10 minutes until browned.\n10. Sprinkle mozzarella over the top and broil for 1 minute until melted.\n11. Let rest 10 minutes.\n12. Slice into 24 pieces.\n13. Serve with marinara sauce for dipping."\n\nRecipe Title: Baked Chicken with Provolone & Ziti\nIngredients: ["2 each chicken breasts boneless and skinless", "1/2 teaspoon basil", "1/2 teaspoon dill weed", "1/2 teaspoon garlic powder", "1/4 teaspoon parsley leaves", "1 x parmesan, parmigiano-reggiano cheese, grated", "3 cups pasta sauce or your own", "2 slices provolone cheese large slices", "1 x pasta, ziti make the amount you think you will eat"]\nRecipe Instructions:\n1. "Put the chicken breasts in a baking pan, sprayed with a non-stick spray.\n2. Sprinkle herbs on top of chicken breasts.\n3. Bake uncovered at 350F (180C) for 1 hour.\n4. Meanwhile, heat the sauce and cook the ziti separately (cook ziti according to directions on the box).\n5. Once the ziti is cooked and drained, return to the saucepan and put a pat of margarine or butter in it.\n6. Mix well, and pour into another 1 1/2 quart sprayed baking dish.\n7. When the chicken is finished baking, put it on top of the ziti, and sprinkle with parmesan cheese.\n8. Pour the sauce on top of all and place the cheese on top of the chicken.\n9. Put under the broiler until the cheese is melted and bubbly."\n']
# Recipe Title: Pureed Artichoke Crostini with Lime Salt
# Ingredients: ["1 tablespoon olive oil", "12 ounces frozen artichoke hearts, thawed and patted dry", "2 cups baby spinach", "3 cloves garlic, 2 chopped, 1 left whole", "2 tablespoons plus 1 teaspoon freshly squeezed lemon juice", "1/4 cup grated Parmigiano-Reggiano", "3 tablespoons crumbled feta cheese", "2 tablespoons fresh flat-leaf parsley leaves", "1/4 teaspoon kosher salt", "Freshly ground black pepper", "2 tablespoons sea salt flakes", "1 lime, zested", "1 baguette, sliced into 16 rounds and toasted", "4 radishes, very thinly sliced, for garnish"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
# ['Recipe Title: Turkey Oola\nIngredients: ["4 flour tortillas (medium to large)", "3 tablespoons butter", "3-4 cups chicken broth", "2 cups diced turkey", "2 cups shredded cheese (cheddar, jack, pepper jack)", "1/4 cup diced green pepper", "10 ounces can of Rotel (2 small cans)", "1/2 cup diced green onions", "1/4 cup diced red onions", "salt and pepper as you go--to taste", "toppings of avocado, crispy bacon, lime wedges, shredded cabbages, and diced cilantro"]\nRecipe Instructions:\n1. "Spread butter on bottom of crock pot.\n2. The rest of this recipe is a layering job. Layer torn tortillas in one layer, another layer of turkey and veggies and cheese, then repeat. Add S&P to taste as you like.\n3. Your goal is 3-4 layers, ending with tortillas and topping with the cheese.\n4. Pour chicken broth over the entire dish until just at the top, but not covering.\n5. Cover and turn slow cooker to high for 3 hours or medium for 5.\n6. It is done when bubbly and the tortillas have turned to dumplings.\n7. Serve with toppings available for folks to add."\n\nRecipe Title: Cranberry-Lemon Pudding\nIngredients: ["White Chocolate Pudding", "8 oz. cranberries", "1/2 c. sugar", "1/2 c. water", "1/2 tsp. lemon zest", "1 tsp. lemon juice"]\nRecipe Instructions:\n1. "Make White Chocolate Pudding.\n2. While pudding chills, bring cranberries, sugar, and water to a boil in a saucepan (reserve 12 cranberries for garnish).\n3. Boil until cranberries burst and liquid reduces, 5 minutes.\n4. Toss reserved cranberries in sugar to coat.\n5. Remove sauce from heat and stir in lemon zest and lemon juice; cool until thickened.\n6. Layer pudding and cranberry sauce in each of 4 glasses.\n7. Garnish with sugared cranberries and lemon peel."\n\nRecipe Title: Italian sausage with pepper/onions\nIngredients: ["packages Sweet Italian sausge (5)", "medium onion", "medium pepper (green or red)", "2 tbsp butter", "1 tbsp worcestershire sauce"]\nRecipe Instructions:\n1. "Cut sausage into approximately 1 inch pieces.\n2. Caution..when doing this, be gentle and use a very sharp knife so you don\'t break the sausage casing.\n3. Cut onion in half and then slice into thin strips.\n4. Cut pepper into strips.\n5. Melt 2 tablespoons of butter in a frying pan.\n6. Add all the ingredients and mix together.\n7. Again be gentle with the sausage.\n8. Cook until sausage is browned adding the Worcestershire sauce just before its done."\n']
# Recipe Title: Strawberry Donut Holes
# Ingredients: ["5 cups Vegetable Oil", "2 cups Flour", "4 Tablespoons Sugar", "1-1/2 Tablespoon Baking Powder", "1/2 teaspoons Salt", "1/4 teaspoons Nutmeg", "1/4 teaspoons Cinnamon", "1 cup Milk", "1 Egg", "1 teaspoon Vanilla", "1/4 cups Melted Butter", "1 cup Diced Strawberries", "1 cup Powdered Sugar"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
# ...
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
# ['Recipe Title: Beef Curry With Apple Recipe\nIngredients: ["2 lbs. boneless beef, cut into 1 inch cubes", "3 tbsp. flour", "2 teaspoon salt", "1/2 teaspoon pepper", "3 tbsp. drippings (or possibly oil)", "1 bay leaf", "1 teaspoon curry pwdr", "3 whole cloves", "2 teaspoon sugar", "1 lg. onion, thinly sliced", "1 clove garlic", "1 c. water", "3 lg. tart apples, cut into eighths", "1 c. raisins (opt.)", "Cooked rice"]\nRecipe Instructions:\n1. "Combine flour, salt, pepper and dredge meat.\n2. Brown meat in drippings.\n3. Pour off excess.\n4. Add in bay leaf, curry, cloves, sugar, onion, garlic and water.\n5. Cover tightly and cook slowly for 2 hrs.\n6. Add in apple and raisins and cook 45 min.\n7. Throw away bay leaf and garlic and serve over rice.\n8. Serves 6."\n\nRecipe Title: Tuna Chow Mein Recipe\nIngredients: ["2 c. celery, diced", "1/2 c. onion, minced", "1/4 c. green pepper, minced", "1/8 c. butter", "2 (6 1/2 ounce.) cans white water pack tuna, undrained", "1/2 lg. pkg. chow mein noodles", "3 cans cream of mushroom soup", "1/2 c. water", "1/2 c. lowfat milk", "1/2 teaspoon salt", "1/4 pound cashew nuts"]\nRecipe Instructions:\n1. "Save 1 c. of chow mein noodles for topping.\n2. Dilute cream of mushroom soup with water and lowfat milk.\n3. Saute/fry celery, onion and green pepper in butter till slightly glazed.\n4. Don\'t over cook.\n5. Add in tuna, noodles, soup, salt and nuts.\n6. Pour into greased casserole and sprinkle with remaining noodles.\n7. Bake at 350 degrees about an hour.\n8. Makes 12 generous servings."\n\nRecipe Title: Macronatha\nIngredients: ["1 (2 to 3 pound) whole chicken, cut into pieces", "1 onion", "30 whole cloves", "1 cinnamon stick", "1 (6 ounce) can tomato paste", "1 pound penne pasta", "1 pound grated Parmesan cheese"]\nRecipe Instructions:\n1. "Place chicken in large pot or Dutch oven and cover with water. Stud whole peeled onion with cloves and pierce with cinnamon stick. Place in pot with chicken. Stir in tomato paste. Bring to a boil, reduce heat, cover, and stew 60 to 90 minutes, until chicken is tender.\n2. Bring a large pot of lightly salted water to a boil. Add pasta and cook for 8 to 10 minutes or until al dente; drain.\n3. Layer pasta with Parmesan in a large serving bowl. Remove onion and pour chicken stock over pasta. Serve chicken pieces on the side."\n']
# Recipe Title: Popcorn Christmas Wreath Cake Recipe
# Ingredients: ["5 to 6 quarts. popped popcorn", "1/2 pound butter", "1/2 c. oil", "1 pound miniature marshmallows", "1 pound gum drops", "1/2 pound unsalted roasted peanuts"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
# ['Recipe Title: Our Family\'s Popular Cheese Hot Pot\nIngredients: ["200 grams Chicken thigh (cut into bite-sized pieces)", "2 slice Bacon (width of 1 cm)", "150 grams Tofu (easy to eat pieces)", "2 medium Potatoes (bite-sized pieces)", "1/3 Carrot (round slices about 3 mm...or cut in half)", "1 if cabbage, about 200 grams if onion, 1 medium Cabbage (3 cm cubes) or Onion (1 cm wedges)", "1/2 head Broccoli or Cauliflower (bite-sized pieces)", "1 pack Shimeji mushrooms (broken into easy to eat pieces)", "800 ml Water", "1 tsp Consomme soup stock granules", "2 tbsp White wine or sake (salt-additive free if possible)", "50 grams White miso", "50 grams Cream cheese", "1 tbsp Sake"]\nRecipe Instructions:\n1. "Cut the ingredients as stated in the ingredients list.\n2. Sprinkle 2 teaspoons of sake (not listed) on the chicken and rub in.\n3. In a pot, add the ingredients and bring to a boil.\n4. Once it\'s boiled, add the ingredients in order from the top (starting from the ingredients needing the longest to cook).\n5. While skimming the scum, simmer until an appropriate tenderness.\n6. While the pot is simmering, mix together the ingredients and 1 tablespoon of soup from Step 2 and set aside.\n7. Once the ingredients have cooked through, dissolve the mixture into the pot.\n8. Please refer to Helpful Hints."\n\nRecipe Title: Quick & Easy Mini Pizza Buns!\nIngredients: ["genoa salami", "gouda", "bun", "4 hamburger buns top/bottom", "1/2 cup tomato sauce good quality", "8 slices genoa salami diced", "1/2 cup smoked gouda cheese shredded", "parsley for garnish", "4 hamburger buns top/bottom", "1/2 cup tomato sauce good quality", "1/2 cup feta cheese crumbled", "2 tomatoes sliced", "mint for garnish"]\nRecipe Instructions:\n1. "Preheat oven at 425 degrees.\n2. Lay the buns (top and bottom) flat on their backs on a baking sheet.\n3. Genoa Salami & Gouda Mini Pizza Bun\n4. For each bun, add 1 tbsp of tomato sauce, 1 tbsp of Gouda cheese, 1 slice of salami.\n5. Feta & Tomato Mini Pizza Bun\n6. For each bun, add 1 tbsp of tomato sauce, 1 tbsp of feta cheese, 1 slice of tomato.\n7. Bake the mini pizza buns in the ovens for around 12 minutes, or until the buns look toasted and cheese has melted.\n8. Garnish with herbs and serve!"\n\nRecipe Title: Salsa Baked Chicken\nIngredients: ["2 chicken breasts; boneless, skinless", "1 1/2 cup salsa", "2 tsp ground toasted cumin", "2 tsp onion powder", "2 tsp paprika", "2 tsp dried Mexican oregano", "1 tsp garlic powder", "1 tsp white pepper", "1 vegetable oil; as needed", "1 salt"]\nRecipe Instructions:\n1. "Toss chicken in enough oil to cover.\n2. Season.\n3. Spray an oven safe saute pan or small dish with non-stick cooking spray.\n4. Add enough salsa to cover the bottom.\n5. Place chicken in saute pan.\n6. Pour salsa on top.\n7. Cover.\n8. Bake at 350 for approximately 45 minutes or until thermometer reaches 165 and juices run clear.\n9. Variations; Cilantro, lime, tequila, chicken stock, tomatillos, corn, caramelized onions or shallots, roasted bell peppers, roasted tomato salsa, cayenne, adobo, mole, tortillas, sour cream, nopalitos, pork"\n']
# Recipe Title: Slow Cooker Pork Chop And Potatoes in Mustard Sauce
# Ingredients: ["6 each pork loin chops up to 8 chops", "2 tablespoons vegetable oil", "1 each soup, cream of mushroom 10 oz can", "1/4 cup chicken broth", "1/4 cup dijon mustard country-style", "1/2 teaspoon thyme dried, crushed", "1 each garlic clove, minced OR 1/4 ts garlic powder", "1/4 teaspoon black pepper", "6 each potatoes cut in thin slices"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
# ['Recipe Title: Mixed Salad Greens & Cherries\nIngredients: ["2 gal. mixed baby salad greens, loosely packed", "2 qt. fresh dark sweet cherries, pitted, halved", "2 qt. celery, thinly sliced diagonally", "2 cups scallions, sliced", "2 cups whole natural almonds, toasted, coarsely chopped", "1-1/2 cups PURE Kraft Refrigerated Sweet Balsamic Vinaigrette"]\nRecipe Instructions:\n1. "For each serving: Combine 1-1/3 cups (325 mL) greens, 1/3 cup (75 mL) cherries, 1/3 cup (75 mL) celery and 4 tsp.\n2. (20 mL) each scallions and nuts in bowl.\n3. Add 1 Tbsp.\n4. (15 mL) dressing; toss lightly."\n\nRecipe Title: Detox Broccoli Bean Salad\nIngredients: ["5-6 cups broccoli florets", "15 ounces can butter beans, drained and rinsed", "5 green onions, sliced", "1/2 cup chopped fresh parsley", "1 clove garlic, minced", "2 teaspoons dijon mustard", "1 teaspoon honey", "1 tablespoon lemon zest", "1/4 cup lemon juice, from approximately 2 lemons", "1 tablespoon good-quality olive oil", "salt and pepper"]\nRecipe Instructions:\n1. "Boil or steam broccoli florets for about 5-7 minutes, or until tender. Meanwhile, prep your beans, green onions and parsley.\n2. Once the broccoli is done, remove from heat to cool. Make the dressing by combining the garlic, mustard, honey, zest and lemon juice in a bowl. Whisk in the olive oil and a dash of salt and pepper.\n3. Add the beans, green onions and parsley to the broccoli and toss with dressing. Season with additional salt and pepper, if desired."\n\nRecipe Title: Ham Reuben\nIngredients: ["2 slices rye bread", "1 Tbsp. KRAFT Fat Free Thousand Island Dressing", "1 KRAFT Big Slice Swiss Cheese Slice", "5 slices OSCAR MAYER Deli Fresh Smoked Ham", "2 Tbsp. CLAUSSEN Sauerkraut, drained"]\nRecipe Instructions:\n1. "Spread 1 bread slice with dressing.\n2. Fill bread slices with remaining ingredients.\n3. Cook in skillet sprayed with cooking spray on medium heat 3 min.\n4. on each side or until golden brown on both sides."\n']
# Recipe Title: Pepperoni Bread Recipe
# Ingredients: ["1 frzn bread dough rolled out", "1 stick of pepperoni, sliced", "1 onion, minced", "1 egg", "1/2 c. Parmesan cheese", "1/2 c. Mozzarella cheese"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
# ['Recipe Title: Just Delicious Beef Stew\nIngredients: ["2-3 pounds beef chuck", "salt and pepper", "1 medium onion, chopped", "5 fresh shitake mushrooms", "3 garlic cloves", "4 tablespoons sweet rice wine (or sherry)", "1 14 oz can chopped tomato or 2-3 fresh tomatoes", "1 tablespoon brown sugar", "5 carrots cut into 1 in pieces", "3 cups chicken stock (homemade if possible, beef stock is okay too)", "1 cabbage, coarsely cut", "1/2 pound potatoes (waxy, like a yukon gold or red, peeled and cut into 1 inch pieces)"]\nRecipe Instructions:\n1. "Salt and pepper the beef.\n2. Brown both sides of beef. Pour off excess oil. Take the meat out of the pan.\n3. Saute the onions and mushrooms with some salt. When the onion is soft, add the garlic (don\'t burn it).\n4. Return the beef. Add wine, carrots, and stock and check seasoning. Add salt and pepper if needed\n5. Add tomatoes. Check for seasoning again. If it tastes a little sour, add the brown sugar. Bring to a boil.\n6. Put into a slow cooker on low for 6 hours.\n7. Add potatoes and cabbage. Leave for another hour.\n8. Check seasoning. When ready to serve, the meat should be soft enough to pull apart into chunks.\n9. Serve with hot white rice. You can also leave out the potatoes and serve with buttery mashed potatoes."\n\nRecipe Title: Blackberry-Lime Gin Fizz\nIngredients: ["FOR THE SIMPLE SYRUP:", "1 cup Fresh Blackberries", "1/2 cups Granulated Sugar", "1/2 cups Water", "FOR THE COCKTAIL:", "1 ounce, fluid Blackberry Simple Syrup", "1 ounce, fluid Gin", "1 whole Splash Of Lime Juice", "6 ounces, fluid Club Soda", "Ice, To Fill Your Glass", "Optional For Garnish: Lime Wedges"]\nRecipe Instructions:\n1. "For the simple syrup:\n2. In a small pot, add blackberries, sugar, and water. Bring the mixture to a gentle boil. Mash the berries with a potato masher or a fork. Allow the mixture to boil for 5 minutes. Remove from the heat and cool to room temperature. Strain the mixture into a bowl through a fine mesh sieve. Transfer the syrup to an airtight container and store in the refrigerator until ready to use.\n3. For the cocktail:\n4. Add simple syrup, gin and lime juice into a glass. Add ice and top with club soda. Give the mixture a stir and garnish with a wedge of lime."\n\nRecipe Title: Potato jalapeno balls\nIngredients: ["1 tsp bicarbonate soda", "1 cup ap flour", "2 tsp cornstarch", "15 oz cubed potatoes", "1/4 cup pickled jalapeno cubed finely", "1/4 cup green onion slicef", "1 tsp granulated garlic powder", "1/4 tsp salt", "2 tsp ground cumin", "2 cup corn meal finely ground", "1 water as needed"]\nRecipe Instructions:\n1. "Mix all the ingredients together in a bowl making a thick batter\n2. Form into balls size varying the bigger the balls the longer it cooks\n3. Cook till done serve with sour cream"\n']
# Recipe Title: Roasted Pork Tenderloin
# Ingredients: ["1 package Pork Tenderloins (2 Loins Per Package)", "4 cloves Garlic", "2 sprigs Rosemary", "Salt And Pepper, to taste", "1/4 cups Olive Oil, Or As Needed To Drizzle On The Loins"]
# Recipe Instructions:
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
# ['Recipe Title: Paleo Coffee Frappuccino \nIngredients: ["3/4 organic brewed coffee", "1 teaspon organic coffee instant powder", "3 tablespoons Agave Maple Syrup or 1 1/2 tablespoons Organic Raw Honey", "1 cup Ice Cold", "1/2 Unsweetened Silk Coconut Milk", "1/2 cup Coconut Whipped Cream or Any dairy free whipped cream", "Sprinkles of Cacao Nibs"]\nRecipe Instructions:\n1. "Make your favorite brewed coffee and chill or fridge at least 8 minutes\n2. Combine all Ingredients in a blender\\n( cold coffee,coffee instant powder, agave, ice cold, coconut milk)\n3. Blend until ice is pureed\n4. Whipped Cream and Cacao Nibs\n5. Serve in a tall glass & straw. Enjoy!"\n\nRecipe Title: Lapsang Souchong Tea Steamed Clams\nIngredients: ["1 gallon water", "1 tablespoon sea or kosher salt", "3 bay leaves", "2 carrots, peeled and cut into 1/2-inch semi-circles", "2 celery ribs, cut into 1/2-inch lengths", "4 stalks lemongrass, bottom white part only, roughly chopped", "1 large onion, quartered and halved", "1 (2-inch) piece ginger, grated", "1 lemon, quartered", "1 lime, quartered", "1 orange, quartered", "6 individual bags Lapsang Souchong tea or 2 ounces whole leaves", "4 pounds fresh clams in bags, (recommended: littleneck or cherrystone)"]\nRecipe Instructions:\n1. "In a 2 to 3 gallon stock pot, over medium-high heat, add the water, salt, bay leaves, carrots, celery, lemongrass and onion.\n2. Bring to a boil, then reduce the heat and simmer for 20 to 30 minutes.\n3. Once the vegetables have softened slightly, add the ginger, fruits, and tea.\n4. Allow the flavors to blend for 10 minutes, then add the bagged clams.\n5. Cook until the clams have opened about 10 to 14 minutes.\n6. Remove the clam bags from the water, and put them into a colander.\n7. Open the bags, drain and serve."\n\nRecipe Title: Vegetable Pancakes\nIngredients: ["1/2 cup all-purpose flour", "1/2 teaspoon baking powder", "1/2 teaspoon salt", "1/4 teaspoon pepper", "1 egg", "1/4 cup milk", "1 cup grated carrots (about 2 carrots)", "1 cup grated zucchini (1 medium zucchini)", "2 green onions, sliced", "2 tablespoons vegetable oil"]\nRecipe Instructions:\n1. "In a mixing bowl, stir together the flour, baking powder, salt, and pepper.\n2. In another bowl, beat together the egg, milk, carrots, zucchini, and onions.\n3. Add this to the dry ingredients and stir until just combined.\n4. Heat 1 tablespoon of the oil in a large skillet over medium heat.\n5. Pour the batter by tablespoonfuls into the pan, making a few pancakes at a time.\n6. Cook until golden, about 2 minutes on each side.\n7. Add the remaining oil to the pan as needed.\n8. Serve at once."\n']
# Recipe Title: Three Cheese Tart
# Ingredients: ["1 sheet frozen puff pastry, thawed", "1 1/2 cups ricotta cheese", "1 cup crumbled feta cheese", "1/4 cup grated Parmesan cheese", "3 None eggs", "1/4 cup heavy cream", "1 None lemon, grated peel only", "2 tbsp pine nuts", "None None Salad, to serve"]
# Recipe Instructions:
# Saving the dataset (0/1 shards):   0%|          | 0/3671 [00:00<?, ? examples/s]

# %%
pprint(generated_dataset_one_shot_instructions['generated'][1])
# Out:
# ('You are an expert in generating recipe instructions from the recipe title '
#  'and ingredient list.\n'
#  'Fill in the missing Recipe Instructions. Be sure to number each step. After '
#  'the following examples, provide your response.\n'
#  '[\'Recipe Title: Fudge\\nIngredients: ["23 cup evaporated milk", "1 23 cups '
#  'sugar", "1/2 teaspoon salt", "1 1/2 cups semi-sweet chocolate chips", "1 1/2 '
#  'cups miniature marshmallows", "1 teaspoon vanilla"]\\nRecipe '
#  'Instructions:\\n1. "Combine evaporated milk, sugar and salt.\\n2. Boil for '
#  'five minutes stirring constantly.\\n3. Remove from heat.\\n4. Add chocolate '
#  'chips and marshmallows, and stir until melted.\\n5. Then stir in the '
#  'vanilla.\\n6. Spoon fudge into a greased eight-by-eight-by-two-inch pan, and '
#  'smooth out with a spatula.\\n7. Cut into squares when cool."\\n\']\n'
#  'Recipe Title: Diabetic French Fudge\n'
#  'Ingredients: ["1 can (13 oz.) skim evaporated milk", "2 tbsp. cornstarch", '
#  '"1 tbsp. liquid sugar replacement", "1/2 cup chocolate chips", "3 oz. cream '
#  'cheese, softened", "1-1/2 tsp. vanilla extract"]\n'
#  'Recipe Instructions:\n'
#  '1. In a saucepan, combine the evaporated milk and cornstarch.\n'
#  '2. Cook over medium heat, stirring constantly, until thickened. \n'
#  '3. Stir in sugar replacement until dissolved.\n'
#  '4. Remove from heat and stir in chocolate chips until melted.\n'
#  '5. In a separate bowl, beat cream cheese and vanilla until smooth.\n'
#  '6. Stir cream cheese mixture into chocolate mixture.\n'
#  '7. Pour into a greased 8x8 inch baking dish.\n'
#  '8. Refrigerate until set.\n'
#  '9. Cut into squares and serve.')

# %% [markdown]
# ### Fine-Tuned Evaluation

# %%
small_test = small_test.map(lambda x: {"examples": ""})

# %%
generated_dataset_ft = small_test.map(
    generate_instruction_batch,
    batched=True,
    batch_size=BATCH_SIZE,
    fn_kwargs={"cot": False, 'model':model_ft, 'tokenizer':tokenizer}
)
generated_dataset_ft.save_to_disk(f'{recipe_nlg_data_path}/ft_generated_1k_5e_3')
# Out:
# Parameter 'fn_kwargs'={'cot': False, 'model': PeftModelForCausalLM(
#   (base_model): LoraModel(
#     (model): MistralForCausalLM(
#       (model): MistralModel(
#         (embed_tokens): Embedding(32002, 4096)
#         (layers): ModuleList(
#           (0-27): 28 x MistralDecoderLayer(
#             (self_attn): MistralAttention(
#               (q_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#               (k_proj): Linear4bit(in_features=4096, out_features=1024, bias=False)
#               (v_proj): Linear4bit(in_features=4096, out_features=1024, bias=False)
#               (o_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#             )
#             (mlp): MistralMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (act_fn): SiLU()
#             )
#             (input_layernorm): MistralRMSNorm((4096,), eps=1e-05)
#             (post_attention_layernorm): MistralRMSNorm((4096,), eps=1e-05)
#           )
#           (28-31): 4 x MistralDecoderLayer(
#             (self_attn): MistralAttention(
#               (q_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=4096, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (k_proj): Linear4bit(in_features=4096, out_features=1024, bias=False)
#               (v_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=1024, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (o_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#             )
#             (mlp): MistralMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (act_fn): SiLU()
#             )
#             (input_layernorm): MistralRMSNorm((4096,), eps=1e-05)
#             (post_attention_layernorm): MistralRMSNorm((4096,), eps=1e-05)
#           )
#         )
#         (norm): MistralRMSNorm((4096,), eps=1e-05)
#         (rotary_emb): MistralRotaryEmbedding()
#       )
#       (lm_head): Linear(in_features=4096, out_features=32002, bias=False)
#     )
#   )
# ), 'tokenizer': LlamaTokenizerFast(name_or_path='teknium/OpenHermes-2.5-Mistral-7B', vocab_size=32000, model_max_length=1000000000000000019884624838656, is_fast=True, padding_side='left', truncation_side='right', special_tokens={'bos_token': '<s>', 'eos_token': '<|im_end|>', 'unk_token': '<unk>', 'pad_token': '<|im_end|>'}, clean_up_tokenization_spaces=False, added_tokens_decoder={
# 	0: AddedToken("<unk>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	1: AddedToken("<s>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	2: AddedToken("</s>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32000: AddedToken("<|im_end|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32001: AddedToken("<|im_start|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# }
# )} of the transform datasets.arrow_dataset.Dataset._map_single couldn't be hashed properly, a random hash was used instead. Make sure your transforms and parameters are serializable with pickle or dill for the dataset fingerprinting and caching to work. If you reuse this transform, the caching mechanism will consider it to be different from the previous calls and recompute everything. This warning is only showed once. Subsequent hashing failures won't be showed.
# WARNING:datasets.fingerprint:Parameter 'fn_kwargs'={'cot': False, 'model': PeftModelForCausalLM(
#   (base_model): LoraModel(
#     (model): MistralForCausalLM(
#       (model): MistralModel(
#         (embed_tokens): Embedding(32002, 4096)
#         (layers): ModuleList(
#           (0-27): 28 x MistralDecoderLayer(
#             (self_attn): MistralAttention(
#               (q_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#               (k_proj): Linear4bit(in_features=4096, out_features=1024, bias=False)
#               (v_proj): Linear4bit(in_features=4096, out_features=1024, bias=False)
#               (o_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#             )
#             (mlp): MistralMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (act_fn): SiLU()
#             )
#             (input_layernorm): MistralRMSNorm((4096,), eps=1e-05)
#             (post_attention_layernorm): MistralRMSNorm((4096,), eps=1e-05)
#           )
#           (28-31): 4 x MistralDecoderLayer(
#             (self_attn): MistralAttention(
#               (q_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=4096, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (k_proj): Linear4bit(in_features=4096, out_features=1024, bias=False)
#               (v_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=1024, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (o_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#             )
#             (mlp): MistralMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (act_fn): SiLU()
#             )
#             (input_layernorm): MistralRMSNorm((4096,), eps=1e-05)
#             (post_attention_layernorm): MistralRMSNorm((4096,), eps=1e-05)
#           )
#         )
#         (norm): MistralRMSNorm((4096,), eps=1e-05)
#         (rotary_emb): MistralRotaryEmbedding()
#       )
#       (lm_head): Linear(in_features=4096, out_features=32002, bias=False)
#     )
#   )
# ), 'tokenizer': LlamaTokenizerFast(name_or_path='teknium/OpenHermes-2.5-Mistral-7B', vocab_size=32000, model_max_length=1000000000000000019884624838656, is_fast=True, padding_side='left', truncation_side='right', special_tokens={'bos_token': '<s>', 'eos_token': '<|im_end|>', 'unk_token': '<unk>', 'pad_token': '<|im_end|>'}, clean_up_tokenization_spaces=False, added_tokens_decoder={
# 	0: AddedToken("<unk>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	1: AddedToken("<s>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	2: AddedToken("</s>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32000: AddedToken("<|im_end|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32001: AddedToken("<|im_start|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# }
# )} of the transform datasets.arrow_dataset.Dataset._map_single couldn't be hashed properly, a random hash was used instead. Make sure your transforms and parameters are serializable with pickle or dill for the dataset fingerprinting and caching to work. If you reuse this transform, the caching mechanism will consider it to be different from the previous calls and recompute everything. This warning is only showed once. Subsequent hashing failures won't be showed.
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Fill in the missing Recipe Instructions. Be sure to number each step. After the following examples, provide your response.
#
# Recipe Title: Orange Cookies Iii
# Ingredients: ["1 cup shortening", "2 cups white sugar", "2 eggs", "1 cup buttermilk", "1/2 cup orange juice", "2 tablespoons orange zest", "4 1/2 cups all-purpose flour", "2 teaspoons baking powder", "1 teaspoon salt", "1/2 teaspoon baking soda", "1/4 cup butter", "4 cups confectioners' sugar", "3 tablespoons thawed orange juice concentrate"]
# Recipe Instructions:

# %%
generated_dataset_ft = one_shot.map(
    generate_instruction_batch,
    batched=True,
    batch_size=BATCH_SIZE,
    fn_kwargs={"cot": False, 'model':model_ft, 'tokenizer':tokenizer}
)
generated_dataset_ft.save_to_disk(f'{recipe_nlg_data_path}/ft_generated_1k_5e_one_shot')

# %%
generated_dataset_ft = two_shot.map(
    generate_instruction_batch,
    batched=True,
    batch_size=BATCH_SIZE,
    fn_kwargs={"cot": False, 'model':model_ft, 'tokenizer':tokenizer}
)
generated_dataset_ft.save_to_disk(f'{recipe_nlg_data_path}/ft_generated_1k_5e_two_shot')

# %%
generated_dataset_ft = three_shot.map(
    generate_instruction_batch,
    batched=True,
    batch_size=BATCH_SIZE,
    fn_kwargs={"cot": False, 'model':model_ft, 'tokenizer':tokenizer}
)
generated_dataset_ft.save_to_disk(f'{recipe_nlg_data_path}/ft_generated_1k_5e_three_shot')

# %%
generated_dataset_ft = one_shot_ret.map(
    generate_instruction_batch,
    batched=True,
    batch_size=BATCH_SIZE,
    fn_kwargs={"cot": False, 'model':model_ft, 'tokenizer':tokenizer}
)
generated_dataset_ft.save_to_disk(f'{recipe_nlg_data_path}/ft_generated_1k_5e_one_shot_retrieval')

# %%
generated_dataset_ft = two_shot_ret.map(
    generate_instruction_batch,
    batched=True,
    batch_size=BATCH_SIZE,
    fn_kwargs={"cot": False, 'model':model_ft, 'tokenizer':tokenizer}
)
generated_dataset_ft.save_to_disk(f'{recipe_nlg_data_path}/ft_generated_1k_5e_two_shot_retrieval')

# %%
generated_dataset_ft = three_shot_ret.map(
    generate_instruction_batch,
    batched=True,
    batch_size=BATCH_SIZE,
    fn_kwargs={"cot": False, 'model':model_ft, 'tokenizer':tokenizer}
)
generated_dataset_ft.save_to_disk(f'{recipe_nlg_data_path}/ft_generated_1k_5e_three_shot_retrieval')

# %%
generated_dataset_base_test = small_test.select([1,2]).map(
    generate_instruction_batch,
    batched=True,
    batch_size=2,
    fn_kwargs={"cot": False, "model": model, "tokenizer": tokenizer}
)
# Out:
# Map:   0%|          | 0/2 [00:00<?, ? examples/s]
# You are an expert in generating recipe instructions from the recipe title and ingredient list.
# Enclose your recipe instructions in <instructions> tags and number each step.
# Examples: None
# Title: Tarragon Chicken Salad
# Ingredients: ["1/4 cup MIRACLE WHIP FREE Dressing", "1/4 tsp. dried tarragon leaves", "3 oz. , cubed", "1 cup red or green grapes, seedless Target 1 lb For $2.99 thru 02/06", "1/2 whole wheat pita bread round", "2 SNACKWELL'S Sugar Free Shortbread Cookies", "4 fl oz (1/2 cup) orange juice"]
# Your response:

# %% [markdown]
# ### ROUGE Evaluation

# %%
rouge = evaluate.load("rouge")

oob_scores = rouge.compute(
    predictions=generated_dataset_oob['generated'],
    references=small_test['directions']
)

cot_scores = rouge.compute(
    predictions=generated_dataset_cot_instructions['generated'],
    references=small_test['directions']
)

scores = {
    'OOB': oob_scores,
    'COT': cot_scores
}

eval_results = pd.DataFrame.from_dict(scores).T
eval_results
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-1-3359839084.py in <cell line: 0>()
# ----> 1 import evaluate
#       2
#       3 rouge = evaluate.load("rouge")
#       4
#       5 oob_scores = rouge.compute(
#
# ModuleNotFoundError: No module named 'evaluate'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
cot_ds = load_from_disk(f'file://{recipe_nlg_data_path}/oob_cot_generated')
ds = load_from_disk(f'file://{recipe_nlg_data_path}/oob_generated')

# %% [markdown]
# ### Fine-Tune Generation
